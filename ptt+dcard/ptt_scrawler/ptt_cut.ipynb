# %%
import pandas as pd
import os
import jieba
source_file_path = r'./res_creditcard'
file_list = os.listdir(source_file_path)
file_list
# Out:
# ['  [問題] 關於學歷問題.txt',
#  ' [心得] Ubear 網路消費回饋分享.txt',
#  ' [心得] 台新Flygo、玉山pi 核卡.txt',
#  ' [心得] 台新黑狗悠遊卡脫白任務再度失敗.txt',
#  ' [心得] 國泰長榮聯名卡調額失敗.txt',
#  ' [心得] 學生 台新gogo核卡.txt',
#  ' [心得] 新申辦上海2D小小兵分期卡無照會核卡.txt',
#  ' [心得] 花旗饗樂、台新@gogo、渣打現金回饋 核卡.txt',
#  '108年信用卡代繳綜合所得稅優惠資訊.txt',
#  '2018信用卡配置使用請教.txt',
#  '@gogo分期回饋問題.txt',
#  'ANA 今年續繳年費贈里程活動.txt',
#  'ANA哩程點數過期.txt',
#  'article3.txt',
#  'article5.txt',
#  'Citi.com是花旗信用卡的嗎？.txt',
#  'Costco無限卡已經完全廢掉了.txt',
#  'DCC申訴半成功經驗分享.txt',
#  'Flygo終於飛到（1-2核卡）.txt',
#  'Fw',
#  'HSBC的帳單好難懂@@.txt',
#  'iCASH繳勞保費，自動加值次數？.txt',
#  'Koko combo icash 在日本POS機完全不能刷.txt',
#  'KOKO combo卡回饋認定.txt',
#  'KOKO不能選visa或master了嗎？.txt',
#  'koko卡指定通路問題.txt',
#  'Line pay 信用卡 全國加油站回饋.txt',
#  'line pay 超商消費問題.txt',
#  'Line Pay&華南op&樂天 核卡.txt',
#  'Pi信用卡買車.txt',
#  'PI錢包APP綁UBEAR卡.txt',
#  'R',
#  'Re',
#  'Richart gogo現金回饋疑問.txt',
#  'Richart帳戶刷卡入帳大delay.txt',
#  'Ubear卡Ubereats請款名稱.txt',
#  'Uber信用卡資料刪除問題.txt',
#  '[ 分享] 台新國泰卡夏季加碼活動.txt',
#  '[ 問題] 國泰KOKO app問題.txt',
#  '[creditcard] 看板 選情報導.txt',
#  '[公告] === 卡板板規 V8.0 === (2018-05-25修訂).txt',
#  '[公告] JohnyDamon 警告一次.txt',
#  '[公告] 信用卡板 第一屆優選心得徵文活動.txt',
#  '[公告] 即日起禁止詢問業務專員哪裡有...文章.txt',
#  '[公告] 取消MJdavid板友警告、道歉、及代重發.txt',
#  '[公告] 水桶+退文名單 evian520.txt',
#  '[公告] 水桶+退文名單 z5419.txt',
#  '[公告] 水桶名單 2人 補桶1人.txt',
#  '[公告] 水桶名單 33人.txt',
#  '[公告] 水桶名單 3人.txt',
#  '[公告] 水桶名單 4人.txt',
#  '[公告] 水桶名單 7人.txt',
#  '[公告] 水桶名單 a9995559、gary24、style05.txt',
#  '[公告] 水桶名單 adaniel.txt',
#  '[公告] 水桶名單 aiyowaya.txt',
#  '[公告] 水桶名單 Alerande77.txt',
#  '[公告] 水桶名單 alice0918.txt',
#  '[公告] 水桶名單 andykhu01.txt',
#  '[公告] 水桶名單 anif.txt',
#  '[公告] 水桶名單 Anyotw、POPOYOYO.txt',
#  '[公告] 水桶名單 ayu906132.txt',
#  '[問題]  美國運通信用白金卡 住宿優惠.txt',
#  '[問題]  股市的融資會出現在聯徵嗎.txt',
#  '[問題]  花旗寰旅轉卡疑問.txt',
#  '[問題]  請問渣打現金回饋御璽卡溢繳認定.txt',
#  '[問題] 10-30前刷666回饋66.txt',
#  '[問題] 100萬的 躉繳保費 首選？.txt',
#  '[問題] 101無限卡vs101御璽卡.txt',
#  '[問題] 101的apple樂天算不算國內通路.txt',
#  '[問題] 101鼎極卡升等邀請.txt',
#  '[問題] 1111買淘寶交易日期是1110.txt',
#  '[問題] 11月份帳單無週六全家活動回饋.txt',
#  '[問題] 12月中旅日海外刷卡選擇請益.txt',
#  '[問題] 18年 升等-里程-貴賓是-頂級卡片推薦哪張.txt',
#  '[問題] 2016年停用的卡被盜刷(境外.txt',
#  '[問題] 2018 Q3 大額保費信用卡選擇.txt',
#  '[問題] 2018 Q3的保費信用卡選擇.txt',
#  '[問題] 2018 年費頂級卡推薦？.txt',
#  '[問題] 2018信用卡綁定及配置請益.txt',
#  '[問題] 2018凱基 威秀ishow卡.txt',
#  '[問題] 2018年KOKO消費與2019年gogo超商.txt',
#  '[問題] 2018年繳學費神卡.txt',
#  '[問題] 2018搭計程車的優惠.txt',
#  '[問題] 2018申請的合庫卡娜赫拉icash鑽現卡.txt',
#  '[問題] 2018該辦GOGO黑狗or國泰KOKO？.txt',
#  '[問題] 2019 koko問題請教.txt',
#  '[問題] 2019年有推薦的JCB卡嗎？.txt',
#  '[問題] 2019美食信用卡.txt',
#  '[問題] 2019辦卡請益.txt',
#  '[問題] 20歲有薪轉有工作想辦卡.txt',
#  '[問題] 24K 小白 核卡.txt',
#  '[問題] 25元以下的現金回饋卡.txt',
#  '[問題] 30歲無業 無辦過卡(已解決).txt',
#  '[問題] 3D驗證刷卡.txt',
#  '[問題] 7-11刷元大icash買咖啡.txt',
#  '[問題] 7-11悠遊聯名卡的加值問題.txt',
#  '[問題] 7-11買遊戲點數刷koko優惠詢問.txt',
#  '[問題] 9-15 Iphone8官網刷卡，樂天JCB能用嗎.txt',
#  '[問題] 9-23linepay消費完全沒記錄.txt',
#  '[問題] 9-9蝦皮台新滿25000折2688消費日認定.txt',
#  '[問題] @gogo vs 元大鑽金JCB.txt',
#  '[問題] @GOGO 指定數位通路.txt',
#  '[問題] @GOGO 高鐵刷卡失敗.txt',
#  '[問題] @gogo 黑狗卡 & 虛擬卡 相關問題.txt',
#  '[問題] @gogo+richart letspay.txt',
#  '[問題] @gogo也排除超商了嗎？.txt',
#  '[問題] @gogo免年費的3選2.txt',
#  '[問題] @gogo刷ubereats 3%手續費？.txt',
#  '[問題] @gogo刷卡問題.txt',
#  '[問題] @gogo刷高鐵APP3.5%回饋.txt',
#  '[問題] @GoGo卡 自助加油.txt',
#  '[問題] @gogo卡自動繳款請益.txt',
#  '[問題] @gogo海外消費回饋4.5%.txt',
#  '[問題] @gogo消費金額在richart app顯示都是0.txt',
#  '[問題] @GoGo被秒拒絕.txt',
#  '[問題] ACCOR 雅高訂房，刷卡幣別.txt',
#  '[問題] AE 大白.txt',
#  '[問題] AE 美國運通可收單刷卡機種類.txt',
#  '[問題] AE信用白金想剪或降簽帳金.txt',
#  '[問題] AE台灣卡的促銷活動是否美卡也適用？.txt',
#  '[問題] AE大白0800客服竟然只服務到晚上10點？.txt',
#  '[問題] AE小白 剪卡重辦.txt',
#  '[問題] AE小白一晚訂兩間不同飯店.txt',
#  '[問題] AE小白申辦處有差異嗎？.txt',
#  '[問題] AE用Richart繳費.txt',
#  '[問題] AE白金秘書.txt',
#  '[問題] AE美卡實體店面刷apple pay有人成功過？.txt',
#  '[問題] AE轉卡(國際轉卡轉美卡) - 帳戶與地址.txt',
#  '[問題] AE轉卡.txt',
#  '[問題] AE轉卡詢問 - 美國.txt',
#  '[問題] AE長榮簽帳白金  國泰長榮極致無限.txt',
#  '[問題] agoda DCC 問題(2-18更新).txt',
#  '[問題] Agoda 付款幣別釐清 （DCC或匯率）.txt',
#  '[問題] AGODA刷大戶卡指定5%回饋與否.txt',
#  '[問題] agoda即時付款和延遲付款問題.txt',
#  '[問題] AGODA外幣結帳問題.txt',
#  '[問題] agoda消費滿額可機場周圍免費停車.txt',
#  '[問題] agoda等訂房網站,使用星展還是合庫.txt',
#  '[問題] AGODA訂大陸飯店中了DCC.txt',
#  '[問題] agoda訂房問題.txt',
#  '[問題] agoda訂房網付款問題.txt',
#  '[問題] Airbnb 刷國內房源.txt',
#  '[問題] airbnb 華南i網購認列.txt',
#  '[問題] amazon 購買gift card.txt',
#  '[問題] AMEX美國轉卡問題.txt',
#  '[問題] ANA晶緻卡剪卡問題.txt',
#  '[問題] ANA極緻卡刷ANA機票的問題.txt',
#  '[問題] ANA聯名卡第二年年費列帳時間.txt',
#  '[問題] android pay刷線上高鐵票回饋算法.txt',
#  '[問題] ANZ澳盛 帳單無日期、金額錯誤.txt',
#  '[問題] ANZ澳盛飛行點數該轉移嗎？.txt',
#  '[問題] ANZ現金回饋卡一年疑問.txt',
#  '[問題] Apple pay 綁定 Line pay卡 回饋趴數.txt',
#  '[問題] ApplePay GoGo悠遊御璽卡 卡面還是紫狗的.txt',
#  '[問題] applepay的回饋.txt',
#  '[問題] applepay綁定linepay卡繳稅.txt',
#  '[問題] Apple官網刷@gogo分期.txt',
#  '[問題] apple詐騙網站.txt',
#  '[問題] ATM繳款錢不見了.txt',
#  '[問題] booking.com訂房的信用卡回饋金.txt',
#  '[問題] booking訂房 國內外回饋的定義？.txt',
#  '[問題] booking訂房，被預收款.txt',
#  '[問題] Chase Freedom 申請疑問.txt',
#  '[問題] Chase sapphire 台灣刷卡問題.txt',
#  '[問題] Chase Visa 信用卡刷台幣異常匯率.txt',
#  '[問題] Chase信用卡與app問題.txt',
#  '[問題] chase海外退刷問題.txt',
#  '[問題] costco 似乎可接受美國花旗發的聯名卡.txt',
#  '[問題] Dawho Debit 現金回饋 vs Sports.txt',
#  '[問題] debit card 被盜刷流程問題.txt',
#  '[問題] Discover it 卡 google play無法使用.txt',
#  '[問題] etag-ETC 信用卡推薦.txt',
#  '[問題] ETC自動儲值是否會有現金紅利？.txt',
#  '[問題] expedia亞萬哩程累積與信用卡優惠選擇.txt',
#  '[問題] expedia重複扣款.txt',
#  '[問題] e秒刷 agoda 回饋.txt',
#  '[問題] e秒刷 監理所線上繳罰單回饋？.txt',
#  '[問題] e秒刷 線上申辦 身份驗證.txt',
#  '[問題] e秒刷-KOKO罰單能回饋嗎？.txt',
#  '[問題] e秒刷「國外」網購認定？.txt',
#  '[問題] e秒刷刷高鐵.txt',
#  '[問題] E秒刷自動分期 這是明年續辦的意思？ .txt',
#  '[問題] e秒刷自動分期問題.txt',
#  '[問題] fly go 刷機票 2.2%回饋 有人收到了嗎？.txt',
#  '[問題] Fly go機票5%條件限制.txt',
#  '[問題] FLY GO的機票5%回饋條件與期限.txt',
#  '[問題] flygo 刷訂票app.txt',
#  '[問題] flygo 首刷禮 旅行收納折疊包 名額？.txt',
#  '[問題] Flygo 龍騰貴賓室釋疑.txt',
#  '[問題] flygo.txt',
#  '[問題] Flygo刷哩程票稅金也有5%嗎.txt',
#  '[問題] flygo刷新航的機票.txt',
#  '[問題] flygo卡今天沒核卡 是不是就沒首刷禮了.txt',
#  '[問題] flygo卡面的圖案.txt',
#  '[問題] flygo回饋問題.txt',
#  '[問題] Flygo外幣換算匯率對不到master公告匯率.txt',
#  '[問題] Flygo機票加碼認定問題.txt',
#  '[問題] FlyGo海外消費回饋認定.txt',
#  '[問題] flygo申請問題.txt',
#  '[問題] flygo的現金回饋跟你們的消費對的上嗎？.txt',
#  '[問題] Flygo等級.txt',
#  '[問題] Flygo綁Famipay支付算一般消費嗎？.txt',
#  '[問題] flygo飛狗卡刷機票回饋算法.txt',
#  '[問題] Flygo飛狗卡國外擋刷.txt',
#  '[問題] FlyGo龍騰卡申請.txt',
#  '[問題] foodpanda.txt',
#  '[問題] friday etag pi信用卡 2.5%.txt',
#  '[問題] Friday聯名卡綁定line mobile疑問.txt',
#  '[問題] friDay錢包無法付款.txt',
#  '[問題] friday錢包綁中信linepay.txt',
#  '[問題] friday錢包綁兆豐e秒刷到底算不算網購通.txt',
#  '[問題] gogo 加辦虛擬卡需要財力-薪轉證明嗎.txt',
#  '[問題] gogo-flygo海外消費 richart提領.txt',
#  '[問題] gogoro卡買gogoro的回饋計算.txt',
#  '[問題] GOGORO電費回饋推薦.txt',
#  '[問題] gogo分期回饋問題.txt',
#  '[問題] gogo刷pchome商店街.txt',
#  '[問題] gogo卡 之 icash與悠遊卡選擇.txt',
#  '[問題] gogo卡 搭台鐵 常常讀卡失敗.txt',
#  '[問題] gogo卡 數位通路認定 淘寶-天貓.txt',
#  '[問題] gogo卡 是否成功.txt',
#  '[問題] GOGO卡, 機票回饋.txt',
#  '[問題] GoGo卡三種回饋不同步.txt',
#  '[問題] GOGO卡刷蝦皮認愛貝不認Aipei.txt',
#  '[問題] Gogo卡回饋似乎有問題 .txt',
#  '[問題] gogo卡每筆消費回饋查詢.txt',
#  '[問題] GOGO卡的一些疑問.txt',
#  '[問題] Gogo卡綁定AP回饋.txt',
#  '[問題] GOGO卡繳公共事業跟水電費的疑問.txt',
#  '[問題] gogo卡自動扣款問題.txt',
#  '[問題] gogo卡訂機票.txt',
#  '[問題] gogo卡跟玉山pi信用卡的相關問題.txt',
#  '[問題] gogo回饋刷退.txt',
#  '[問題] GOGO指定網購以外的網購好用的卡？.txt',
#  '[問題] gogo溢繳的問題.txt',
#  '[問題] GoGo結帳日問題.txt',
#  '[問題] gogo虛擬卡搭街口刷全聯？.txt',
#  '[問題] GOMAJI請款時間.txt',
#  '[問題] google app綁信用卡，收到刷卡簡訊.txt',
#  '[問題] google store.txt',
#  '[問題] Google商店.txt',
#  '[問題] grab綁兆豐e秒刷有認列嗎.txt',
#  '[問題] HAMI PAY 綁中信VISA 回饋問題.txt',
#  '[問題] happcash靠卡問題（OK商店）.txt',
#  '[問題] happy cash聯名卡退卡.txt',
#  '[問題] Happygo pay怎麼配點數才多？.txt',
#  '[問題] HAPPYGO聯名卡挑選請教.txt',
#  '[問題] hinet小額付款是什麼？.txt',
#  '[問題] hotel.com訂房信用卡的問題.txt',
#  '[問題] hotels.com幣別問題.txt',
#  '[問題] Hotels.com海外訂房手續費.txt',
#  '[問題] HSBC是否只有台灣改字體.txt',
#  '[問題] icash信用卡遺失.txt',
#  '[問題] icash搭捷運的問題.txt',
#  '[問題] icash聯名卡無法感應有救嗎？.txt',
#  '[問題] icash聯名卡請益.txt',
#  '[問題] icash記名.txt',
#  '[問題] iOS 日本手遊課金.txt',
#  '[問題] ios日本手遊課金.txt',
#  '[問題] IOS的Apple pay刷的卡是我沒綁定的卡.txt',
#  '[問題] iPhone XS 官網分期利率國泰卡.txt',
#  '[問題] ishow和凱基moneyback 儲值問題.txt',
#  '[問題] J-Speedy 使用Visa wave 感應交易.txt',
#  '[問題] JCB五星活動漢來餐廳詢問.txt',
#  '[問題] JCB五星饗宴真的有人搶到嗎？.txt',
#  '[問題] JCB信用卡哪張比較好？(已解決，感恩）.txt',
#  '[問題] JCB免費機場接送被放鴿子.txt',
#  '[問題] JCB卡買LINE代幣是用美金計價.txt',
#  '[問題] jcb在澳洲的適用性？.txt',
#  '[問題] JCB悠遊10% 聯邦回饋時間.txt',
#  '[問題] jcb悠遊10%.txt',
#  '[問題] JCB悠遊卡推薦.txt',
#  '[問題] JCB悠遊卡自動加值回饋疑問.txt',
#  '[問題] JCB悠遊卡選擇.txt',
#  '[問題] JCB悠遊聯名卡自動加值10%....txt',
#  '[問題] JCB悠遊請款日會幾天.txt',
#  '[問題] JCB日韓遊新春加碼活動--聯邦微風JCB卡.txt',
#  '[問題] JCB晶緻卡買一送一.txt',
#  '[問題] jcb樟宜機場貴賓室使用疑問.txt',
#  '[問題] kkbox被盜刷？.txt',
#  '[問題] KKDAY使用永豐大戶卡.txt',
#  '[問題] KKDAY和KLOOK刷卡問題.txt',
#  '[問題] KLOOK刷富邦J卡優惠.txt',
#  '[問題] KOKO 5% 的計算週期.txt',
#  '[問題] koko @gogo 2卡怎麼綁.txt',
#  '[問題] KOKO app信用卡帳務怪怪的.txt',
#  '[問題] koko app更新後出現問題。.txt',
#  '[問題] koko app消費金額.txt',
#  '[問題] koko combo  icash. 聯名卡新戶首刷禮.txt',
#  '[問題] KOKO combo 7月開始的活動？.txt',
#  '[問題] KOKO Combo icash app伸辦閃退.txt',
#  '[問題] KOKO Combo icash 刷卡禮？.txt',
#  '[問題] KOKO combo icash.txt',
#  '[問題] koko combo icash他行自動扣款.txt',
#  '[問題] koko combo icash卡對信用累積.txt',
#  '[問題] KOKO COMBO icash卡帳戶問題.txt',
#  '[問題] KOKO Combo iCash登錄問題.txt',
#  '[問題] KOKO COMBO icash聯名卡-全家超商問題.txt',
#  '[問題] koko combo icash聯名卡刷台鐵？.txt',
#  '[問題] KOKO COMBO icash聯名卡還能辦嗎？.txt',
#  '[問題] Koko combo icash要回寄書面嗎？.txt',
#  '[問題] koko combo 卡透過 icash去速邁樂加油.txt',
#  '[問題] koko combo 尚未拿到卡可以刷嗎？.txt',
#  '[問題] koko combo 持簽單刷國賓影城.txt',
#  '[問題] koko combo 自動儲值問題.txt',
#  '[問題] koko combo卡.txt',
#  '[問題] KOKO combo卡申請問題.txt',
#  '[問題] KOKO COMBO回饋週期.txt',
#  '[問題] koko combo結帳日提前？？.txt',
#  '[問題] KOKO icach無法繳瓦斯及電費.txt',
#  '[問題] KOKO iCash Combo卡號.txt',
#  '[問題] koko icash combo的便利店5% 繳費.txt',
#  '[問題] koko icash 先辦 combo 後辦.txt',
#  '[問題] koko icash 聯名卡.txt',
#  '[問題] Koko icash信用卡 7-11 + google pay？.txt',
#  '[問題] koko icash卡跟koko combo icah卡.txt',
#  '[問題] KOKO 九月回饋.txt',
#  '[問題] koko 推薦人欄位.txt',
#  '[問題] koko 新戶問題.txt',
#  '[問題] koko 綁定街口.txt',
#  '[問題] koko 語音開卡有成功嗎？.txt',
#  '[問題] KOKO 超商取票 (火車 or 客運).txt',
#  '[問題] koko 超商繳費失敗.txt',
#  '[問題] KOKO5%回饋這樣顯示是正常的嗎？.txt',
#  '[問題] koko一卡通金融卡.txt',
#  '[問題] KOKO信用卡年度回饋調整？.txt',
#  '[問題] koko信用卡查結帳日.txt',
#  '[問題] koko分期5%問題.txt',
#  '[問題] KOKO卡 5%回饋如何查詢？.txt',
#  '[問題] koko卡 自動加值10000服務.txt',
#  '[問題] koko卡回饋疑問.txt',
#  '[問題] KOKO卡多問跟LINE PAY保費不小心分期.txt',
#  '[問題] koko卡申請 無法上傳證件.txt',
#  '[問題] KOKO卡申請中  系統姓名錯誤.txt',
#  '[問題] KOKO卡的電銷保單有算在5000門檻？.txt',
#  '[問題] koko卡與國泰登錄蝦皮優惠問題.txt',
#  '[問題] KOKO卡被盜刷.txt',
#  '[問題] KOKO卡超商分期回饋.txt',
#  '[問題] KOKO卡首刷禮疑問.txt',
#  '[問題] KOKO回饋時間與帳單週期.txt',
#  '[問題] KOKO回饋金問題.txt',
#  '[問題] KoKo國泰問題.txt',
#  '[問題] Koko學生卡補件請益.txt',
#  '[問題] KOKO專版在哪.txt',
#  '[問題] KOKO已電話開卡但app顯示未開卡.txt',
#  '[問題] KOKO帳戶 自動扣繳 .txt',
#  '[問題] KOKO帳戶設定信用卡自動扣繳.txt',
#  '[問題] koko搭20次回饋15000OP有人收到三月份的嗎？.txt',
#  '[問題] KOKO新戶.txt',
#  '[問題] KOKO正常化後~富邦數位和一銀星璨的選擇.txt',
#  '[問題] KOKO活動3.5% & 日本消費划算卡.txt',
#  '[問題] KOKO用line pay刷kkday回饋.txt',
#  '[問題] koko的一般消費和5%回饋.txt',
#  '[問題] KOKO的現金回饋要怎麼查詢.txt',
#  '[問題] KOKO綁line pay 遠百消費分期.txt',
#  '[問題] KOKO網拍 超取付款還回饋嗎.txt',
#  '[問題] koko繳水電.txt',
#  '[問題] koko繳罰單.txt',
#  '[問題] KOKO辦卡這樣是？.txt',
#  '[問題] koko這是核卡失敗了嗎？.txt',
#  '[問題] koko首刷500回饋速度？.txt',
#  '[問題] line pay 2大超商6%回饋.txt',
#  '[問題] Line Pay Q3加碼送LP100點活動.txt',
#  '[問題] line pay 卡刷公立醫院醫療費回饋問題.txt',
#  '[問題] Line pay 無限卡該換極緻卡嗎？.txt',
#  '[問題] line pay 盜刷再＋1.txt',
#  '[問題] line pay 鼎極卡門檻問題請教.txt',
#  '[問題] LINE PAY+數位生活卡.txt',
#  '[問題] Line pay一筆未知刷卡，刷卡請款日問題.txt',
#  '[問題] Line pay卡在愛買消費無通知.txt',
#  '[問題] line pay卡相關問題.txt',
#  '[問題] line pay卡繳中華電信問題.txt',
#  '[問題] Line Pay卡臨時額度的部分~是否有回饋.txt',
#  '[問題] Line Pay歐洲刷卡.txt',
#  '[問題] line pay沒有刷卡通知.txt',
#  '[問題] line pay海外回饋.txt',
#  '[問題] LINE Pay溢繳36萬申請鼎極卡.txt',
#  '[問題] line pay綁@gogo卡可能無指定加碼回饋.txt',
#  '[問題] Line pay繳地價稅(非納稅義務人).txt',
#  '[問題] line pay首刷禮.txt',
#  '[問題] line pay首刷禮被收回.txt',
#  '[問題] line pay首購多久拿到.txt',
#  '[問題] Line pay鼎極 專屬活動？.txt',
#  '[問題] line pay鼎極卡 主動送件問題.txt',
#  '[問題] Line pay鼎極卡邀請問題.txt',
#  '[問題] Line Pay鼎極卡面被換了.txt',
#  '[問題] Line Pay鼎極無限卡 人工核卡.txt',
#  '[問題] line play 學費？.txt',
#  '[問題] Line point換HappyGo.txt',
#  '[問題] LINE 購物導購至樂天網站.txt',
#  '[問題] linepay & pi信用卡.txt',
#  '[問題] LinePay 匯豐7-11消費.txt',
#  '[問題] linepay 鼎極卡 降標準？.txt',
#  '[問題] Linepay10%搭配兆豐e秒刷分期問題.txt',
#  '[問題] LinePay信用卡尚未綁定Line的回饋.txt',
#  '[問題] linepay加凱基mb買電影票問題.txt',
#  '[問題] linepay卡被解除綁定，虧了2000多元.txt',
#  '[問題] LinePay卡退貨後LinePoints扣回問題.txt',
#  '[問題] Linepay卡額度無法提升.txt',
#  '[問題] linepay卡首刷888達成條件.txt',
#  '[問題] linepay回饋問題.txt',
#  '[問題] linepay消費沒提醒.txt',
#  '[問題] Linepay綁台新卡支付 這樣算是刷台新卡嗎.txt',
#  '[問題] Linepay綁定別人名字的信用卡？.txt',
#  '[問題] Linepay繳電信費回饋疑問.txt',
#  '[問題] linepay點數若折抵後退貨.txt',
#  '[問題] Linepay鼎極卡邀約.txt',
#  '[問題] Linepay鼎級卡 一直未受邀約.txt',
#  '[問題] line旅遊轉kkday刷卡回饋與手續費.txt',
#  '[問題] LP-Flygo綁 Apple pay 海外消費回饋.txt',
#  '[問題] LP卡或現金回饋卡的抉擇.txt',
#  '[問題] LP和KOKO如何搭配.txt',
#  '[問題] LP鼎極卡申請時機.txt',
#  '[問題] Master Travel好用嗎.txt',
#  '[問題] MasterCard Apple Pay in 全家.txt',
#  '[問題] mastercard海外消費選擇.txt',
#  '[問題] Mastercard港幣匯率.txt',
#  '[問題] mastercard的Lounge Key服務.txt',
#  '[問題] Mastercard訂房刷退選擇.txt',
#  '[問題] Mastercard飯店預訂計畫(類似Amex FHR).txt',
#  '[問題] momo 35000贈3500.txt',
#  '[問題] momo jcb每週一登記送紅利金.txt',
#  '[問題] MOMO刷國泰12000送7-11禮卷.txt',
#  '[問題] MOMO刷花旗送的紅利金何時入帳？.txt',
#  '[問題] MOMO取消訂單後退刷.txt',
#  '[問題] MOMO台新滿1288送100.txt',
#  '[問題] MOMO購物-玉山信用卡登錄.txt',
#  '[問題] MOMO購物一般宅配+快速到貨(國泰優惠).txt',
#  '[問題] momo購物刷玉山單筆分期滿萬送千.txt',
#  '[問題] momo購物網刷台新的回饋 106年11月.txt',
#  '[問題] myfone ,購物還有算gogo卡加碼嗎？.txt',
#  '[問題] myfone 網路購物.txt',
#  '[問題] myfone購物是否算gogo數位通路.txt',
#  '[問題] M卡搭uber.txt',
#  '[問題] NCCC & debit卡.txt',
#  '[問題] only卡儲蓄險有紅利倍增嗎？.txt',
#  '[問題] open錢包 支付問題.txt',
#  '[問題] open錢包 綁koko 有5%回饋嗎 .txt',
#  '[問題] OP天天10倍卡只剩合庫了嗎？.txt',
#  '[問題] PayPal 以訪客身分付款失敗.txt',
#  '[問題] PayPal 取消信用卡認證.txt',
#  '[問題] paypal 綁定信用卡問題.txt',
#  '[問題] Paypal 郵局visa卡.txt',
#  '[問題] paypal 郵局visa卡問題.txt',
#  '[問題] PayPal付款發生錯誤.txt',
#  '[問題] paypal刷卡匯率詢問.txt',
#  '[問題] Paypal匯入帳號的問題.txt',
#  '[問題] paypal在gogo卡的回饋？.txt',
#  '[問題] Paypal新手問題請教.txt',
#  '[問題] paypal無法綁定新信用卡.txt',
#  '[問題] pc home商店街個人賣場消費.txt',
#  '[問題] PChome 個人賣場 撥款日 與 請款日 差別.txt',
#  '[問題] pchome 花旗聯名卡綁line pay .txt',
#  '[問題] PChome中信滿額回饋1111P幣的登錄頁面消.txt',
#  '[問題] pchome刷卡金疑問.txt',
#  '[問題] pchome刷卡，自動分期有回饋金嗎.txt',
#  '[問題] PChome刷國泰一直出現授權失敗.txt',
#  '[問題] pchome刷花旗卡回饋4000的登錄.txt',
#  '[問題] PCHOME單筆刷卡問題.txt',
#  '[問題] PChome玉山信用卡回饋使用pi錢包.txt',
#  '[問題] pchome玉山第二波登陸 倒數!!.txt',
#  '[問題] pchome用line導購算是app消費嗎？.txt',
#  '[問題] PCHOME登錄戶認定問題.txt',
#  '[問題] pchome的信用卡刷卡金活動.txt',
#  '[問題] PCHOME的銀行優惠活動-第一銀行.txt',
#  '[問題] PCHOME突然打來說要核對信用卡資訊.txt',
#  '[問題] pchome購物.txt',
#  '[問題] pc網購中信卡 分期？.txt',
#  '[問題] PI 錢包 P幣折抵.txt',
#  '[問題] pi卡刷醫院回饋.txt',
#  '[問題] pi卡回饋.txt',
#  '[問題] pi卡外幣保單回饋問題.txt',
#  '[問題] Pi客服是不是全世界最難打進的客服電話.txt',
#  '[問題] PI幣折抵失敗.txt',
#  '[問題] pi幣折抵後是否可以再分期.txt',
#  '[問題] Pi幣折抵支付，沒發票？.txt',
#  '[問題] Pi錢包 綁定華南i網購.txt',
#  '[問題] pi錢包全家4.5%是刷卡還是刷手機條碼.txt',
#  '[問題] pi錢包卡-@gogo卡選用問題~.txt',
#  '[問題] pi錢包卡取代兩張卡.txt',
#  '[問題] pi錢包的「pi幣獲得紀錄」沒有更新-已ok.txt',
#  '[問題] pi錢包的拍享券刷u bear回饋.txt',
#  '[問題] pi錢包繳納台北市自來水費上限.txt',
#  '[問題] pp卡取得最低門檻的信用卡？.txt',
#  '[問題] refund 失敗（transaction declined).txt',
#  '[問題] RFID防盜保護套問題.txt',
#  '[問題] richart app進不去.txt',
#  '[問題] Richart gogo自動扣款問題.txt',
#  '[問題] Richart 信用卡繳稅.txt',
#  '[問題] richart 台新消費.txt',
#  '[問題] richart 掛掉？.txt',
#  '[問題] Richart 溢繳.txt',
#  '[問題] Richart 無即時消費..更新停止.txt',
#  '[問題] Richart 申請卡住.txt',
#  '[問題] richart-hotels.com海外消費？.txt',
#  '[問題] richart入帳.txt',
#  '[問題] richart卡費.txt',
#  '[問題] Richart台新app最近是否常爆掉.txt',
#  '[問題] Richart如何當財力證明.txt',
#  '[問題] Richart家族搭配請益.txt',
#  '[問題] Richart帳戶自動扣繳他行信用卡 .txt',
#  '[問題] richart消費通知金額比實際高(apple).txt',
#  '[問題] RICHART繳交電信費用之回饋.txt',
#  '[問題] richart繳信用卡費.txt',
#  '[問題] Richart繳電信帳單.txt',
#  '[問題] richart繳電信費功能壞了嗎？.txt',
#  '[問題] richart自動扣繳卡費.txt',
#  '[問題] richart顯示已核卡時不能加辦新卡嗎.txt',
#  '[問題] Samsung Pay綁卡支付超商及北捷.txt',
#  '[問題] Sisley hair rituel (中信JCB極致卡).txt',
#  '[問題] soho族申辦中信秀泰聯名卡.txt',
#  '[問題] Spotify無法刷卡.txt',
#  '[問題] STEAM 搭配的信用卡.txt',
#  '[問題] Steam買遊戲推薦的信用卡或省錢買法.txt',
#  '[問題] Switch eshop 購買遊戲.txt',
#  '[問題] taiwan pay vs paytax.txt',
#  '[問題] target 刷哪家的卡刷得過？.txt',
#  '[問題] U bear 證期會 研訓院.txt',
#  '[問題] U bear 辦卡線上補件.txt',
#  '[問題] U Bear新戶首刷禮回饋時間.txt',
#  '[問題] Ubear NETFLIX 無網購回饋.txt',
#  '[問題] UBEAR 刷 apple store算不算網路通路.txt',
#  '[問題] ubear 綁google pay認列.txt',
#  '[問題] ubear 線上用apple pay回饋.txt',
#  '[問題] ubear、pi跟only以外的玉山卡.txt',
#  '[問題] ubear威秀臨櫃儲值問(已解決.txt',
#  '[問題] Ubear是不是缺卡了.txt',
#  '[問題] Ubear綁微風支付.txt',
#  '[問題] Ubear網購分期疑問.txt',
#  '[問題] ubear線上刷卡.txt',
#  '[問題] Ubear電影現場刷卡問題.txt',
#  '[問題] uber uber eat 刷卡後顯示的名稱.txt',
#  '[問題] ubereats使用ubear卡未獲點數回饋.txt',
#  '[問題] UBER刷卡不能過.txt',
#  '[問題] ubike的信用卡優惠？.txt',
#  '[問題] Virtual Visa Prepaid card 使用方式.txt',
#  '[問題] VISA Debit卡問題.txt',
#  '[問題] VISA 線上驗證.txt',
#  '[問題] VISA信用卡秘書.txt',
#  '[問題] VISA卡的退款問題.txt',
#  '[問題] visa商務御璽卡行李限制疑問.txt',
#  '[問題] visa圈存的金額.txt',
#  '[問題] Visa御璽卡機場接送.txt',
#  '[問題] VISA無限卡秘書多久回覆.txt',
#  '[問題] VISA的480元接機大家有搶過嗎.txt',
#  '[問題] visa買亞馬遜用美金計價是扣台幣帳還是...txt',
#  '[問題] visa金融卡如何不被盜刷？.txt',
#  '[問題] VISA順風車機場接送.txt',
#  '[問題] webatm 繳花旗卡費問題.txt',
#  '[問題] webATM 選繳費來繳信用卡費，手續費問題.txt',
#  '[問題] Yahoo!購物中心 滿額刷卡金活動登錄.txt',
#  '[問題] yahoo刷玉山卡 注意事項.txt',
#  '[問題] yahoo愛8節登錄.txt',
#  '[問題] YAHOO聯名卡無法參加中信刷卡金活動？.txt',
#  '[問題] [問題] Re',
#  '[問題] 一卡通(電子票證&電子支付).txt',
#  '[問題] 一卡通推薦哪張？(已爬文.txt',
#  '[問題] 一張卡低額度會影響其他新辦卡片的額度嗎.txt',
#  '[問題] 一筆錢之還款及其他用途請教.txt',
#  '[問題] 一般消費認定.txt',
#  '[問題] 一銀-兆豐 電影EzDing活動消費日期認定.txt',
#  '[問題] 一銀icash聯名卡還有消費送openpoint嗎？.txt',
#  '[問題] 一銀信用卡APP是否能設定消費即時通知？.txt',
#  '[問題] 一銀星璨卡疑問.txt',
#  '[問題] 一銀綠活卡=分期卡？.txt',
#  '[問題] 一銀綠活卡可以同時申請2張嗎？.txt',
#  '[問題] 丈母娘想辦卡 .txt',
#  '[問題] 三個月內辦太多張卡會有問題嗎？.txt',
#  '[問題] 三大航空聯名卡.txt',
#  '[問題] 三天內同銀行聯徵兩次？.txt',
#  '[問題] 三張卡比較(line pay , pi , 元大鑽金).txt',
#  '[問題] 三月底到四月的玉山pi卡分眾回饋.txt',
#  '[問題] 上半年度華南銀行的淘寶網活動.txt',
#  '[問題] 上月刷卡 繳清再刷同額.txt',
#  '[問題] 上海 日上免稅.txt',
#  '[問題] 上海debit卡被盜刷.txt',
#  '[問題] 上海商銀單筆分期.txt',
#  '[問題] 上海簡單-元大鑽金 韓國消費優先選擇？.txt',
#  '[問題] 上海簡單卡未核.txt',
#  '[問題] 上海銀行刷卡通知.txt',
#  '[問題] 不同台新卡線上儲值星巴克會回饋那堤？.txt',
#  '[問題] 不同銀行的虛擬龍騰卡綁定.txt',
#  '[問題] 不收海外手續費的Expedia，算海外消費嗎.txt',
#  '[問題] 不是學生的學生卡.txt',
#  '[問題] 不補件會影響信用紀錄？.txt',
#  '[問題] 不超過22倍是額度還是預借金？.txt',
#  '[問題] 世華亞萬-花旗寰旅-玉山商務辦卡通路.txt',
#  '[問題] 中信 Line Pay 卡首刷禮.txt',
#  '[問題] 中信 line pay 鼎極卡.txt',
#  '[問題] 中信 line pay卡消費名稱？.txt',
#  '[問題] 中信 line 錢包漏訊息.txt',
#  '[問題] 中信 visa 卡開通一卡通.txt',
#  '[問題] 中信 X 安納塔拉度假會優惠券.txt',
#  '[問題] 中信 中華電信聯名卡.txt',
#  '[問題] 中信 大中華攜手飛 生日加碼活動.txt',
#  '[問題] 中信 無印良品卡生日點數要刷3000才有.txt',
#  '[問題] 中信-玉山分期信用卡推薦.txt',
#  '[問題] 中信ae卡有送生日禮嗎.txt',
#  '[問題] 中信ANA商務御璽卡的旅平險.txt',
#  '[問題] 中信Ana晶緻卡JCB感應失敗.txt',
#  '[問題] 中信ANA晶緻卡後申辦極緻卡點數計算.txt',
#  '[問題] 中信ana極緻卡剪卡問題.txt',
#  '[問題] 中信ANA極緻卡與商務御璽卡之比較.txt',
#  '[問題] 中信ANA極致卡貴賓室資格求解.txt',
#  '[問題] 中信ANA無限卡有消息嗎.txt',
#  '[問題] 中信ANA無限卡請益.txt',
#  '[問題] 中信ANA聯名卡里程累積問題.txt',
#  '[問題] 中信ApplePay的咖啡怎麼領？.txt',
#  '[問題] 中信app加辦.txt',
#  '[問題] 中信line pay 一卡通自動儲值.txt',
#  '[問題] 中信line pay 信用卡+一卡通.txt',
#  '[問題] 中信line pay 卡片換發 發卡組織.txt',
#  '[問題] 中信line pay 卡繳保費問題.txt',
#  '[問題] 中信LINE PAY 卡繳罰單.txt',
#  '[問題] 中信LINE Pay 金融卡自助加油失敗被請款.txt',
#  '[問題] 中信line pay信用卡首刷禮？.txt',
#  '[問題] 中信line pay卡 發卡快遞費150.txt',
#  '[問題] 中信Line Pay卡一般消費項目請教.txt',
#  '[問題] 中信line pay卡信用卡簽帳消費.txt',
#  '[問題] 中信LINE PAY卡加碼禮.txt',
#  '[問題] 中信Line Pay卡回饋計算.txt',
#  '[問題] 中信line pay卡張數問題.txt',
#  '[問題] 中信LINE PAY卡感應.txt',
#  '[問題] 中信line pay卡申請 發現問題.txt',
#  '[問題] 中信line pay卡的晶片容易挑機？.txt',
#  '[問題] 中信Line Pay卡被盜刷 客服打不通.txt',
#  '[問題] 中信Line Pay卡被盜刷.txt',
#  '[問題] 中信Line pay卡點數計算方式.txt',
#  '[問題] 中信line pay有辦法儲etag嗎？.txt',
#  '[問題] 中信line pay申請問題.txt',
#  '[問題] 中信LINE Pay聯名卡一卡通感應異常？(已解決).txt',
#  '[問題] 中信line pay首刷疑問.txt',
#  '[問題] 中信line pay鼎極之貴賓室疑問.txt',
#  '[問題] 中信Line Pay鼎極卡邀約額度計算.txt',
#  '[問題] 中信linepay 刷保費分期回饋.txt',
#  '[問題] 中信linepay 附卡回饋-手機支付問題.txt',
#  '[問題] 中信LinePay一卡通卡號.txt',
#  '[問題] 中信Linepay信用卡設為Apple Pay.txt',
#  '[問題] 中信linepay分期刷退linepoint重複扣問題.txt',
#  '[問題] 中信linepay刷卡問題.txt',
#  '[問題] 中信linepay卡 hotels.com 15%.txt',
#  '[問題] 中信LinePay卡 LinePoint點數問題.txt',
#  '[問題] 中信linepay卡刷伯朗咖啡沒跳出line訊息.txt',
#  '[問題] 中信Linepay卡訂房回饋.txt',
#  '[問題] 中信linepay國外網站刷退會退手續費嗎？.txt',
#  '[問題] 中信Linepay消費蝦皮Linepoint被取消.txt',
#  '[問題] 中信linepay跟台新gogo卡超商支付問題.txt',
#  '[問題] 中信LinePay較快核卡的方式？.txt',
#  '[問題] 中信LP x 一卡通 4月回饋 未入帳.txt',
#  '[問題] 中信LP+台新flygo&gogo+玉山Pi.txt',
#  '[問題] 中信LP卡溢繳.txt',
#  '[問題] 中信LP卡綁LP消費通知 .txt',
#  '[問題] 中信LP鼎極卡疑問.txt',
#  '[問題] 中信LP鼎極龍騰套餐使用問題.txt',
#  '[問題] 中信muji御璽卡 muji點數.txt',
#  '[問題] 中信muji紅利.txt',
#  '[問題] 中信YAHOO聯名卡超贈點問題.txt',
#  '[問題] 中信YAHOO購物中心週年慶登錄.txt',
#  '[問題] 中信中油卡點數兌換問題.txt',
#  '[問題] 中信享想卡 問題.txt',
#  '[問題] 中信享想卡明年住宿訂房.txt',
#  '[問題] 中信享想卡的簽名欄.txt',
#  '[問題] 中信享想卡續卡禮.txt',
#  '[問題] 中信信用卡帳單寄送.txt',
#  '[問題] 中信信用卡網站刷卡今天沒有3D驗證？.txt',
#  '[問題] 中信刷保費的問題.txt',
#  '[問題] 中信刷卡手機推播通知president.txt',
#  '[問題] 中信加油卡.txt',
#  '[問題] 中信加辦 聯徵問題.txt',
#  '[問題] 中信卡使用龍騰卡APP問題.txt',
#  '[問題] 中信卡優惠的電影牆.txt',
#  '[問題] 中信卡刷威秀電影票沒折扣了嗎.txt',
#  '[問題] 中信卡在 7-11 拆單繳問題.txt',
#  '[問題] 中信卡掛失或停卡可以免費的方式.txt',
#  '[問題] 中信卡盜刷，金額是10倍額度.txt',
#  '[問題] 中信卡線上購買高鐵票失敗.txt',
#  '[問題] 中信卡繳保費.txt',
#  '[問題] 中信卡與Amazon不能刷卡.txt',
#  '[問題] 中信卡莫名被刷國外交易.txt',
#  '[問題] 中信卡被暫時管制.txt',
#  '[問題] 中信卡設定電子帳單免年費活動.txt',
#  '[問題] 中信卡進貴賓室問題.txt',
#  '[問題] 中信卡附卡使用貴賓室.txt',
#  '[問題] 中信可eTag自動儲值了 但不能指定卡片.txt',
#  '[問題] 中信商務卡刷學費.txt',
#  '[問題] 中信大中華卡刷華航機票請益.txt',
#  '[問題] 中信大中華攜手飛  購買華航機票的問題.txt',
#  '[問題] 中信大中華攜手飛 哩程問題.txt',
#  '[問題] 中信大中華攜手飛聯名卡.txt',
#  '[問題] 中信大中華攜手飛龍騰卡詢問.txt',
#  '[問題] 中信學生卡財力證明文件.txt',
#  '[問題] 中信客服永久調額相關經驗.txt',
#  '[問題] 中信審核的問題.txt',
#  '[問題] 中信寰遊美國運通卡繳保費.txt',
#  '[問題] 中信帳單多了一筆逾期違約金.txt',
#  '[問題] 中信御璽卡機場貴賓室（正附卡）.txt',
#  '[問題] 中信新戶選哪張好(首刷禮現金為主.txt',
#  '[問題] 中信新辦卡核卡速度？.txt',
#  '[問題] 中信是不是超厲害的？.txt',
#  '[問題] 中信機場接送 會看機票嗎？.txt',
#  '[問題] 中信機場貴賓室.txt',
#  '[問題] 中信機場貴賓室有使用次數限制？.txt',
#  '[問題] 中信溢繳 額度.txt',
#  '[問題] 中信溢繳不能退嗎？.txt',
#  '[問題] 中信溢繳後卻仍顯示未繳費.txt',
#  '[問題] 中信無印卡刷KKTIX刷不過.txt',
#  '[問題] 中信無印卡與改制的muji passport生日券.txt',
#  '[問題] 中信無印良品聯名卡繳電信費拿首刷禮？.txt',
#  '[問題] 中信環亞貴賓室與龍騰餐可以同天使用嗎.txt',
#  '[問題] 中信申請自動扣款失敗(從台新Richart扣.txt',
#  '[問題] 中信發核卡簡訊後又發一封未核卡？.txt',
#  '[問題] 中信的中華聯名卡.txt',
#  '[問題] 中信的聯徵.txt',
#  '[問題] 中信秀泰晶緻卡JCB疑問.txt',
#  '[問題] 中信秀泰聯名卡買票優惠.txt',
#  '[問題] 中信突然給一筆88元回饋刷卡金.txt',
#  '[問題] 中信系統入帳作業調整 額度無法立即恢復.txt',
#  '[問題] 中信紅利點數是帳單結帳日入帳嗎？.txt',
#  '[問題] 中信紅利點數過期.txt',
#  '[問題] 中信網路刷卡 沒收到OTP.txt',
#  '[問題] 中信網銀同時兩張申請  一張消失~.txt',
#  '[問題] 中信線上補件.txt',
#  '[問題] 中信自動扣繳.txt',
#  '[問題] 中信自動扣繳失敗.txt',
#  '[問題] 中信調額 一個禮拜沒下文？.txt',
#  '[問題] 中信超商atm信用卡繳款多久才入帳.txt',
#  '[問題] 中信辦卡 業務說不要說自己是學生.txt',
#  '[問題] 中信金融卡Line pay.txt',
#  '[問題] 中信開戶辦卡問題後續請益.txt',
#  '[問題] 中信雙幣卡.txt',
#  '[問題] 中信首刷禮大概多久會寄出呀.txt',
#  '[問題] 中信鼎極卡 機場接送認定.txt',
#  '[問題] 中信鼎極卡停車優惠問題.txt',
#  '[問題] 中信龍騰貴賓室.txt',
#  '[問題] 中國信託 信用卡 語音剪卡 年費？.txt',
#  '[問題] 中國信託 商務雙幣卡.txt',
#  '[問題] 中國信託 辦卡未核發.txt',
#  '[問題] 中國信託ANA無限卡 附卡 請教.txt',
#  '[問題] 中國信託ATM信用卡繳費.txt',
#  '[問題] 中國信託ebay刷卡沒有3D簡訊驗證.txt',
#  '[問題] 中國信託line pay被打槍.txt',
#  '[問題] 中國信託Line即時通沒收到出帳通知.txt',
#  '[問題] 中國信託LINE御璽卡.txt',
#  '[問題] 中國信託享想卡 剪卡.txt',
#  '[問題] 中國信託使用國內貴賓室和餐飲服務問題.txt',
#  '[問題] 中國信託信用卡pchome刷卡回饋金.txt',
#  '[問題] 中國信託信用卡使用ATM.txt',
#  '[問題] 中國信託信用卡有推薦的嗎？.txt',
#  '[問題] 中國信託信用卡每況愈下.txt',
#  '[問題] 中國信託卡費應繳總金額帳單與線上不同.txt',
#  '[問題] 中國信託大中華鼎極 - ana極緻卡.txt',
#  '[問題] 中國信託御璽卡 貴賓室使用.txt',
#  '[問題] 中國信託新戶信用卡建議請教.txt',
#  '[問題] 中國信託核卡額度詢問.txt',
#  '[問題] 中國信託漢神聯名卡停卡….txt',
#  '[問題] 中國信託鼎極或商務卡貴賓室可以攜伴嗎？.txt',
#  '[問題] 中國刷卡DCC疑問.txt',
#  '[問題] 中國卡還是台灣卡？.txt',
#  '[問題] 中國地區代儲刷卡問題.txt',
#  '[問題] 中國大陸旅遊刷卡問題.txt',
#  '[問題] 中國醫刷卡回饋 問題.txt',
#  '[問題] 中國醫可以刷美卡或是國外卡嗎？.txt',
#  '[問題] 中壢壢新醫院 line pay 回饋.txt',
#  '[問題] 中山醫院可否刷amex.txt',
#  '[問題] 中山附醫刷卡有回饋嗎？.txt',
#  '[問題] 中年保全小白月光族辦卡.txt',
#  '[問題] 中油 加油回饋 or 現金回饋.txt',
#  '[問題] 中油加油刷卡要簽名？.txt',
#  '[問題] 中油直營自助加油要選哪張卡？.txt',
#  '[問題] 中油自助加油 哪張卡最划算.txt',
#  '[問題] 中華電信繳費回饋.txt',
#  '[問題] 中華電信費,線上刷卡(+$10)有回饋的卡？.txt',
#  '[問題] 中華電信電子帳單用信用卡自動代繳.txt',
#  '[問題] 主力卡調整及卡片建議.txt',
#  '[問題] 主動調降額度 會影響信用評分嗎.txt',
#  '[問題] 五月底日本刷卡選擇.txt',
#  '[問題] 亞洲萬里通問題.txt',
#  '[問題] 人在國外讀書，台銀visa無法提款.txt',
#  '[問題] 人在國外需要有mail 通知刷卡記錄的銀行.txt',
#  '[問題] 人在海外信用卡卻不能用.txt',
#  '[問題] 人在海外被盜刷.txt',
#  '[問題] 什麼樣的情況會可刷卡但用現金？.txt',
#  '[問題] 今天的澳盛一直被拒絕交易.txt',
#  '[問題] 今年兩人看電影，一人兆豐請的活動.txt',
#  '[問題] 今年度玉山家樂福icash送咖啡活動.txt',
#  '[問題] 付費APP使用Visa金融卡扣款失敗.txt',
#  '[問題] 代收款項刷卡 有算入年刷卡金額嗎.txt',
#  '[問題] 以刷信用卡做押金被扣手續費.txt',
#  '[問題] 住完旅館信用卡擔保被亂扣款怎麼辦.txt',
#  '[問題] 使用pi錢包的p幣購物，還有發票？.txt',
#  '[問題] 使用信用卡在大陸消費.txt',
#  '[問題] 使用聯合信用卡中心的機器的商店.txt',
#  '[問題] 使用ＫＧＩ卡訂威秀電影票接到詐騙電話.txt',
#  '[問題] 來自信用卡的收入.txt',
#  '[問題] 便利商店可否刷國外卡.txt',
#  '[問題] 保健食品網購的6位數認證碼.txt',
#  '[問題] 保單當財力辦卡疑問.txt',
#  '[問題] 保費分期該如何是好.txt',
#  '[問題] 保費無設定自動扣繳.txt',
#  '[問題] 保險刷gogog卡分期回饋方案.txt',
#  '[問題] 保險用lp或pi卡.txt',
#  '[問題] 信用不良(已清償)重新申請信用卡問題.txt',
#  '[問題] 信用到底怎麼養.txt',
#  '[問題] 信用卡 儲值功能通知.txt',
#  '[問題] 信用卡(美國)繳交所得稅.txt',
#  '[問題] 信用卡代繳保費額度.txt',
#  '[問題] 信用卡代繳費用，到期要重辦嗎？.txt',
#  '[問題] 信用卡使用配置請教.txt',
#  '[問題] 信用卡停用，但遺失了.txt',
#  '[問題] 信用卡停車優惠--星展.txt',
#  '[問題] 信用卡優惠配合停車過卡=刷卡？！.txt',
#  '[問題] 信用卡兌換酬賓券.txt',
#  '[問題] 信用卡公司會主動來電詢問消費紀錄嗎.txt',
#  '[問題] 信用卡分期問題.txt',
#  '[問題] 信用卡分期回饋的問題.txt',
#  '[問題] 信用卡分期會影響信用分數？.txt',
#  '[問題] 信用卡分期溢繳.txt',
#  '[問題] 信用卡利息累積金額是啥？.txt',
#  '[問題] 信用卡到期停用與信用.txt',
#  '[問題] 信用卡刷退需要信用卡影本嗎？.txt',
#  '[問題] 信用卡剪卡後龍騰會員會一起消失嗎？.txt',
#  '[問題] 信用卡卡號若被人知道會不會有影響？.txt',
#  '[問題] 信用卡及信貸關係.txt',
#  '[問題] 信用卡可以繳車貸分期嗎.txt',
#  '[問題] 信用卡各別協商銀行態度很硬.txt',
#  '[問題] 信用卡嘟嘟房停車優惠.txt',
#  '[問題] 信用卡大戰-海外消費策略請益.txt',
#  '[問題] 信用卡少了名字是否有使用問題？.txt',
#  '[問題] 信用卡已停用，但之前消費要退費.txt',
#  '[問題] 信用卡帳單結算日的小問題.txt',
#  '[問題] 信用卡帳戶自動扣款.txt',
#  '[問題] 信用卡得到航空會員可申請香港E通關嗎.txt',
#  '[問題] 信用卡新手 icash用途.txt',
#  '[問題] 信用卡最低繳款.txt',
#  '[問題] 信用卡核卡金額標準.txt',
#  '[問題] 信用卡機場接送.txt',
#  '[問題] 信用卡權益 團費的定義.txt',
#  '[問題] 信用卡消費的簡訊認證.txt',
#  '[問題] 信用卡消費選擇請益.txt',
#  '[問題] 信用卡照會問題.txt',
#  '[問題] 信用卡特約停車的app推薦.txt',
#  '[問題] 信用卡理財？.txt',
#  '[問題] 信用卡申請中途取消會有影響嗎.txt',
#  '[問題] 信用卡申請問題.txt',
#  '[問題] 信用卡申請撤件是否會影響信用評分？.txt',
#  '[問題] 信用卡申請文件 行員親自拿文件後說沒收.txt',
#  '[問題] 信用卡申請表單還沒送出就聯徵？.txt',
#  '[問題] 信用卡申請資料員工編號可修改嗎？.txt',
#  '[問題] 信用卡申辦推薦.txt',
#  '[問題] 信用卡申辦身份及額度問題.txt',
#  '[問題] 信用卡發票.txt',
#  '[問題] 信用卡的電子發票？.txt',
#  '[問題] 信用卡紅利換亞萬還是ANA里程好？.txt',
#  '[問題] 信用卡給的龍騰有沒有時間間隔限制.txt',
#  '[問題] 信用卡繳保費累積里程.txt',
#  '[問題] 信用卡繳勞健保.txt',
#  '[問題] 信用卡繳最低會怎樣嗎.txt',
#  '[問題] 信用卡繳款問題.txt',
#  '[問題] 信用卡繳稅.txt',
#  '[問題] 信用卡繳費問題.txt',
#  '[問題] 信用卡繳費期限問題.txt',
#  '[問題] 信用卡繳電信費.txt',
#  '[問題] 信用卡能辦暫停嗎.txt',
#  '[問題] 信用卡自動扣繳取消.txt',
#  '[問題] 信用卡至少保持4個月？.txt',
#  '[問題] 信用卡被盜刷 退了兩筆的問題.txt',
#  '[問題] 信用卡被盜刷需要報警嘛.txt',
#  '[問題] 信用卡要補件，不想辦有差嗎？.txt',
#  '[問題] 信用卡該更新了.txt',
#  '[問題] 信用卡調額問題請教.txt',
#  '[問題] 信用卡買機票.txt',
#  '[問題] 信用卡買車票 遇意外都有理賠.txt',
#  '[問題] 信用卡退款問題...不知道適不適合在這邊.txt',
#  '[問題] 信用卡退款問題.txt',
#  '[問題] 信用卡送不便險 認定.txt',
#  '[問題] 信用卡過期，人在國外.txt',
#  '[問題] 信用卡選擇建議？可以衝里程嗎？.txt',
#  '[問題] 信用卡選擇有問題.txt',
#  '[問題] 信用卡選擇請益.txt',
#  '[問題] 信用卡選擇（有選手.txt',
#  '[問題] 信用卡醫療分期.txt',
#  '[問題] 信用卡電影優惠可用行動支付嗎？.txt',
#  ...]

# %%
df = pd.DataFrame(columns = ['編號','標題','時間','網址','內文'])
df
# Out:
# Empty DataFrame
# Columns: [編號, 標題, 時間, 網址, 內文]
# Index: []

# %%
for n, each_article in enumerate(file_list):
    article_path = source_file_path + '/' + each_article
    with open(article_path, 'r', encoding = 'utf-8') as f:
        tmp_article_string = f.read()
    try:
        tmp_row_data = tmp_article_string.split('看板creditcard標題')[1].split('---split---')
        cont=tmp_row_data[0]
        info_1=tmp_row_data[1]
        k=info_1.split('\n')
        title=k[5].split(':')[1]
        time=k[6].split(':')[1]
        link=k[7].split('網址:')[1]
        serial=n+1
#         print(title)
#         print(time)
#         print(link)
    except:
        print(n)
    df.loc[n]= serial,title,time,link,cont
#     print(n)
# Out:
# 13
# 19
# 20
# 31
# 32
# 39
# 143
# 189
# 233
# 372
# 483
# 527
# 672
# 936
# 1072
# 1128
# 1481
# 1508
# 1649
# 1789
# 1813
# 2513
# 3085
# 3411
# 3528
# 3533
# 3775
# 3777
# 3991
# 4112
# 4116
# 4123
# 4332
# 4337
# 4466
# 4601
# 4624
# 4667
# 4818
# 4881
# 4974
# 5109
# 5289
# 5361
# 5362
# 5428
# 5635
# 5660
# 5719
# 5910
# 6294
# 6322
# 6455
# 6492
# 6558
# 6559
# 6590
# 6670
# 6735
# 6813
# 7010
# 7346
# 7406
# 7659
# 7710
# 7725
# 7763
# 7793
# 7871
# 7883
# 7989
# 8155
# 8230
# 8242
# 8245
# 8304
# 8322
# 8323
# 8361
# 8362
# 8461
# 8497
# 8501
# 8779
# 8781
# 8782
# 8846
# 9061
# 9105
# 9109
# 9484
# 9538
# 9562
# 9572
# 9598
# 9611
# 9617
# 9641
# 9753
# 10096
# 10154
# 10336
# 10533
# 10640
# 10700
# 11232

# %%
df
# Out:
#           編號                            標題              時間  \
# 0          1                   [問題] 關於學歷問題   Thu Sep 21 01
# 1          2           [心得] Ubear 網路消費回饋分享   Sun Sep 22 13
# 2          3          [心得] 台新Flygo、玉山pi 核卡   Sat Feb  2 23
# 3          4          [心得] 台新黑狗悠遊卡脫白任務再度失敗   Tue Sep  4 15
# 4          5              [心得] 國泰長榮聯名卡調額失敗   Fri Apr 26 00
# ...      ...                           ...             ...
# 11414  11415           [情報] 確定大戶卡刷淘寶只有2%回饋   Fri Nov  1 21
# 11415  11416                  大眾（元大）客服無人接聽   Tue Jan 23 11
# 11416  11417         ［心得］玉山 PI UBEAR 無照會核卡   Thu Aug  1 22
# 11417  11418   富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14   Thu Sep  5 11
# 11418  11419                     贈送 寰宇商務通關   Mon Oct  7 10
#
#                                                       網址  \
# 0       https://www.ptt.cc/bbs/creditcard/M.150592954...
# 1       https://www.ptt.cc/bbs/creditcard/M.156913024...
# 2       https://www.ptt.cc/bbs/creditcard/M.154912240...
# 3       https://www.ptt.cc/bbs/creditcard/M.153604658...
# 4       https://www.ptt.cc/bbs/creditcard/M.155620843...
# ...                                                  ...
# 11414   https://www.ptt.cc/bbs/creditcard/M.157261425...
# 11415   https://www.ptt.cc/bbs/creditcard/M.151667690...
# 11416   https://www.ptt.cc/bbs/creditcard/M.156467139...
# 11417   https://www.ptt.cc/bbs/creditcard/M.156765417...
# 11418   https://www.ptt.cc/bbs/creditcard/M.157041459...
#
#                                                       內文
# 0      [問題] 關於學歷問題時間Thu Sep 21 01:45:44 2017\n手機排版，請見...
# 1       [心得] Ubear 網路消費回饋分享時間Sun Sep 22 13:30:40 2019...
# 2       [心得] 台新Flygo、玉山pi 核卡時間Sat Feb  2 23:46:42 201...
# 3       [心得] 台新黑狗悠遊卡脫白任務再度失敗時間Tue Sep  4 15:36:24 201...
# 4       [心得] 國泰長榮聯名卡調額失敗時間Fri Apr 26 00:07:15 2019\n\...
# ...                                                  ...
# 11414  [情報] 確定大戶卡刷淘寶只有2%回饋時間Fri Nov  1 21:17:28 2019\...
# 11415  大眾（元大）客服無人接聽時間Tue Jan 23 11:08:22 2018\n最近因爲大眾...
# 11416  ［心得］玉山 PI UBEAR 無照會核卡時間Thu Aug  1 22:56:37 201...
# 11417  富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14時間Thu Sep  5 11:29:...
# 11418  贈送 寰宇商務通關時間Mon Oct  7 10:16:29 2019\n手機發文找不到 贈...
#
# [11419 rows x 5 columns]

# %%
df.to_json(r'./ptt_creditcard.json', orient='index', force_ascii=False)

# %%
# 以'核卡'和'心得'作為關鍵字，找出符合核卡心得的文章編號
import jieba
import pandas as pd
import re
df=pd.read_json (r'./ptt_creditcard.json')
jieba.load_userdict('./userdict.txt')
# print(df)
title=df.loc['標題']
# print(title)
ti_ind=[]
for idx,i in enumerate(title):
    a=re.findall(r'.*核卡.*',i)
    if a!=[]:
        ti_ind.append(idx)
    a=re.findall(r'.*心得.*',i)
    if a!=[]:
        if idx not in ti_ind:
            ti_ind.append(idx)
print(ti_ind)
for z in ti_ind:
    print(df.loc['標題'][z])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 18, 19, 20, 28, 42, 208, 310, 477, 504, 625, 765, 815, 828, 871, 952, 1005, 1274, 1311, 1317, 1348, 1350, 1364, 1371, 1456, 1598, 1715, 1793, 1827, 1849, 1871, 1883, 1962, 1983, 2002, 2033, 2100, 2129, 2192, 2193, 2194, 2281, 2296, 2365, 2413, 2416, 2507, 2530, 2562, 2585, 2586, 2604, 2852, 2901, 3086, 3235, 3237, 3282, 3345, 3351, 3463, 3617, 3647, 3720, 3722, 3723, 3724, 3725, 3726, 3727, 3728, 3729, 3730, 3731, 3732, 3733, 3734, 3735, 3736, 3737, 3738, 3739, 3740, 3741, 3742, 3743, 3744, 3745, 3746, 3747, 3748, 3749, 3750, 3751, 3752, 3753, 3754, 3755, 3756, 3757, 3758, 3759, 3760, 3761, 3762, 3763, 3764, 3765, 3766, 3767, 3768, 3769, 3770, 3771, 3772, 3773, 3774, 3775, 3776, 3777, 3778, 3779, 3780, 3781, 3782, 3783, 3784, 3785, 3786, 3787, 3788, 3789, 3790, 3791, 3792, 3793, 3794, 3795, 3796, 3797, 3798, 3799, 3800, 3801, 3802, 3803, 3804, 3805, 3806, 3807, 3808, 3809, 3810, 3812, 3813, 3814, 3815, 3816, 3817, 3818, 3819, 3820, 3821, 3822, 3823, 3824, 3825, 3826, 3827, 3828, 3829, 3830, 3831, 3832, 3833, 3834, 3835, 3836, 3837, 3838, 3839, 3840, 3841, 3842, 3843, 3844, 3845, 3846, 3847, 3848, 3849, 3850, 3851, 3852, 3853, 3854, 3855, 3856, 3857, 3858, 3859, 3860, 3861, 3862, 3863, 3864, 3865, 3866, 3867, 3868, 3869, 3870, 3871, 3872, 3873, 3874, 3875, 3876, 3877, 3878, 3879, 3880, 3881, 3882, 3883, 3884, 3885, 3886, 3887, 3888, 3889, 3890, 3891, 3892, 3893, 3894, 3895, 3896, 3897, 3898, 3899, 3900, 3901, 3902, 3903, 3904, 3905, 3906, 3907, 3908, 3909, 3910, 3911, 3912, 3913, 3914, 3915, 3916, 3917, 3918, 3919, 3920, 3921, 3922, 3923, 3924, 3925, 3926, 3927, 3928, 3929, 3930, 3931, 3932, 3933, 3934, 3935, 3936, 3937, 3938, 3939, 3940, 3941, 3942, 3943, 3944, 3945, 3946, 3947, 3948, 3949, 3950, 3951, 3952, 3953, 3954, 3955, 3956, 3957, 3958, 3959, 3960, 3961, 3962, 3963, 3964, 3965, 3966, 3967, 3968, 3969, 3970, 
#  小白 星展炫晶御璽卡 核卡
#  應屆畢業 中信Line Pay / 玉山Pi拍錢包 核卡
#  我們長輩被盜刷...心得分享！
#  新光核卡 永豐調額成功
#  星展炫晶核卡/中信花旗調額
#  星展飛行世界卡核卡
#  永豐大戶卡無照會核卡
#  渣打 現金回饋御璽卡  核卡
#  渣打現金回饋御璽卡 核卡
#  無照會核卡 國泰世華 KOKO combo icash卡
#  玉山 Pi 拍錢包信用卡 核卡
#  玉山 UBear核卡&主動調額
#  玉山UBEAR 玉山Pi無照會核卡
#  自由業小白 玉山光速打槍/富邦無照會核卡
#  花旗寰旅世界卡-核卡
#  花旗饗樂卡 學生 快速核卡
#  花旗饗樂卡核卡
#  花旗饗樂白金悠遊卡  小白核卡
#  華南卡納赫拉禮物款 核卡
#  長榮無限卡 核卡
#  高負債比  兆豐e秒刷、國泰koko combo核卡
#  ?心得?玉山 PI UBEAR 無照會核卡

# %%
import jieba
jieba.load_userdict('./userdict.txt')
gg_list=[]
word_clist=[]
content=df.loc['內文']
# print(content)
for j in range(len(content)):
    gg=jieba.lcut(content[j])
#     print(gg)
    gg_list.append(gg)
    
    word_c={}
    for i in gg:
        if i in word_c:
            word_c[i] +=1
        else:
            word_c[i] =1
    word_clist.append(word_c)
# print('gg_list')
print(len(gg_list))
print(len(word_clist))
print(len(content))
df.loc['斷詞']=gg_list
df.loc['詞頻']=word_clist
# Out:
# 11419
# 11419
# 11419

# %%
len(word_clist)

# %%
len(gg_list)

# %%
len(df)

# %%
df
# Out:
#                                                 0      \
# 編號                                                  1
# 標題                                        [問題] 關於學歷問題
# 時間                                      Thu Sep 21 01
# 網址   https://www.ptt.cc/bbs/creditcard/M.150592954...
# 內文  [問題] 關於學歷問題時間Thu Sep 21 01:45:44 2017\n手機排版，請見...
# 斷詞  [[, 問題, ],  , 關於, 學歷, 問題, 時間, Thu,  , Sep,  , ...
# 詞頻  {'[': 1, '問題': 2, ']': 1, ' ': 5, '關於': 1, '學歷...
#
#                                                 1      \
# 編號                                                  2
# 標題                                [心得] Ubear 網路消費回饋分享
# 時間                                      Sun Sep 22 13
# 網址   https://www.ptt.cc/bbs/creditcard/M.156913024...
# 內文   [心得] Ubear 網路消費回饋分享時間Sun Sep 22 13:30:40 2019...
# 斷詞  [ , [, 心得, ],  , Ubear,  , 網路, 消費, 回饋, 分享, 時間,...
# 詞頻  {' ': 9, '[': 1, '心得': 2, ']': 1, 'Ubear': 1, ...
#
#                                                 2      \
# 編號                                                  3
# 標題                               [心得] 台新Flygo、玉山pi 核卡
# 時間                                      Sat Feb  2 23
# 網址   https://www.ptt.cc/bbs/creditcard/M.154912240...
# 內文   [心得] 台新Flygo、玉山pi 核卡時間Sat Feb  2 23:46:42 201...
# 斷詞  [ , [, 心得, ],  , 台新, Flygo, 、, 玉山, pi,  , 核卡, ...
# 詞頻  {' ': 39, '[': 11, '心得': 2, ']': 11, '台新': 1, ...
#
#                                                 3      \
# 編號                                                  4
# 標題                               [心得] 台新黑狗悠遊卡脫白任務再度失敗
# 時間                                      Tue Sep  4 15
# 網址   https://www.ptt.cc/bbs/creditcard/M.153604658...
# 內文   [心得] 台新黑狗悠遊卡脫白任務再度失敗時間Tue Sep  4 15:36:24 201...
# 斷詞  [ , [, 心得, ],  , 台新, 黑狗, 悠遊卡, 脫白, 任務, 再度, 失敗, ...
# 詞頻  {' ': 30, '[': 13, '心得': 1, ']': 13, '台新': 7, ...
#
#                                                 4      \
# 編號                                                  5
# 標題                                   [心得] 國泰長榮聯名卡調額失敗
# 時間                                      Fri Apr 26 00
# 網址   https://www.ptt.cc/bbs/creditcard/M.155620843...
# 內文   [心得] 國泰長榮聯名卡調額失敗時間Fri Apr 26 00:07:15 2019\n\...
# 斷詞  [ , [, 心得, ],  , 國泰, 長榮, 聯名卡, 調額, 失敗, 時間, Fri,...
# 詞頻  {' ': 6, '[': 5, '心得': 1, ']': 5, '國泰': 2, '長榮...
#
#                                                 5      \
# 編號                                                  6
# 標題                                   [心得] 學生 台新gogo核卡
# 時間                                      Wed Dec 26 16
# 網址   https://www.ptt.cc/bbs/creditcard/M.154581182...
# 內文   [心得] 學生 台新gogo核卡時間Wed Dec 26 16:10:20 2018\n\...
# 斷詞  [ , [, 心得, ],  , 學生,  , 台新, gogo, 核卡, 時間, Wed,...
# 詞頻  {' ': 17, '[': 12, '心得': 2, ']': 12, '學生': 3, ...
#
#                                                 6      \
# 編號                                                  7
# 標題                            [心得] 新申辦上海2D小小兵分期卡無照會核卡
# 時間                                      Thu Aug  1 14
# 網址   https://www.ptt.cc/bbs/creditcard/M.156463930...
# 內文   [心得] 新申辦上海2D小小兵分期卡無照會核卡時間Thu Aug  1 14:01:39 ...
# 斷詞  [ , [, 心得, ],  , 新, 申辦, 上海, 2D, 小小兵, 分期, 卡, 無照...
# 詞頻  {' ': 9, '[': 8, '心得': 2, ']': 8, '新': 1, '申辦'...
#
#                                                 7      \
# 編號                                                  8
# 標題                        [心得] 花旗饗樂、台新@gogo、渣打現金回饋 核卡
# 時間                                      Mon Feb 26 14
# 網址   https://www.ptt.cc/bbs/creditcard/M.151962656...
# 內文   [心得] 花旗饗樂、台新@gogo、渣打現金回饋 核卡時間Mon Feb 26 14:29...
# 斷詞  [ , [, 心得, ],  , 花旗, 饗樂, 、, 台新, @, gogo, 、, 渣打...
# 詞頻  {' ': 7, '[': 1, '心得': 2, ']': 1, '花旗': 7, '饗樂...
#
#                                                 8      \
# 編號                                                  9
# 標題                                 108年信用卡代繳綜合所得稅優惠資訊
# 時間                                      Wed May  1 10
# 網址   https://www.ptt.cc/bbs/creditcard/M.155667661...
# 內文  108年信用卡代繳綜合所得稅優惠資訊時間Wed May  1 10:10:08 2019\n...
# 斷詞  [108, 年, 信用卡, 代繳, 綜合所得稅, 優惠, 資訊, 時間, Wed,  , M...
# 詞頻  {'108': 47, '年': 42, '信用卡': 35, '代繳': 5, '綜合所得...
#
#                                                 9      ...  \
# 編號                                                 10  ...
# 標題                                      2018信用卡配置使用請教  ...
# 時間                                      Wed Jan 17 04  ...
# 網址   https://www.ptt.cc/bbs/creditcard/M.151613418...  ...
# 內文  2018信用卡配置使用請教時間Wed Jan 17 04:23:06 2018\n小弟我目前...  ...
# 斷詞  [2018, 信用卡, 配置, 使用, 請教, 時間, Wed,  , Jan,  , 17...  ...
# 詞頻  {'2018': 2, '信用卡': 1, '配置': 1, '使用': 2, '請教': ...  ...
#
#                                                 11409  \
# 編號                                              11410
# 標題                                     關於一卡通 回饋5% 的部分
# 時間                                      Sun Sep 10 15
# 網址   https://www.ptt.cc/bbs/creditcard/M.150503017...
# 內文  關於一卡通 回饋5% 的部分時間Sun Sep 10 15:56:14 2017\n想請問 ...
# 斷詞  [關於, 一卡通,  , 回饋, 5%,  , 的部分, 時間, Sun,  , Sep, ...
# 詞頻  {'關於': 1, '一卡通': 3, ' ': 14, '回饋': 4, '5%': 3,...
#
#                                                 11410  \
# 編號                                              11411
# 標題                                    關於台新用台灣大車隊app叫車
# 時間                                      Tue Dec 12 08
# 網址   https://www.ptt.cc/bbs/creditcard/M.151303992...
# 內文  關於台新用台灣大車隊app叫車時間Tue Dec 12 08:51:59 2017\n\n網...
# 斷詞  [關於, 台新, 用, 台灣, 大, 車隊, app, 叫車, 時間, Tue,  , De...
# 詞頻  {'關於': 1, '台新': 1, '用': 1, '台灣': 1, '大': 1, '車...
#
#                                                 11411  \
# 編號                                              11412
# 標題                                           韓國遊玩刷卡請益
# 時間                                      Thu Sep 19 22
# 網址   https://www.ptt.cc/bbs/creditcard/M.156890333...
# 內文  韓國遊玩刷卡請益時間Thu Sep 19 22:28:50 2019\n知道永豐大戶海外回饋...
# 斷詞  [韓國, 遊玩, 刷卡, 請益, 時間, Thu,  , Sep,  , 19,  , 22...
# 詞頻  {'韓國': 1, '遊玩': 1, '刷卡': 2, '請益': 1, '時間': 1, ...
#
#                                                 11412  \
# 編號                                              11413
# 標題                                           香港刷元大JCB
# 時間                                      Wed Jul 18 20
# 網址   https://www.ptt.cc/bbs/creditcard/M.153191663...
# 內文  香港刷元大JCB時間Wed Jul 18 20:23:52 2018\n之前為了去日本玩，辦...
# 斷詞  [香港, 刷, 元大, JCB, 時間, Wed,  , Jul,  , 18,  , 20...
# 詞頻  {'香港': 2, '刷': 2, '元大': 2, 'JCB': 3, '時間': 1, ...
#
#                                                 11413  \
# 編號                                              11414
# 標題                         高負債比  兆豐e秒刷、國泰koko combo核卡
# 時間                                      Wed Jul 17 01
# 網址   https://www.ptt.cc/bbs/creditcard/M.156329809...
# 內文  高負債比  兆豐e秒刷、國泰koko combo核卡時間Wed Jul 17 01:28:1...
# 斷詞  [高, 負債, 比,  ,  , 兆豐, e秒刷, 、, 國泰, koko,  , comb...
# 詞頻  {'高': 1, '負債': 1, '比': 1, ' ': 81, '兆豐': 3, 'e...
#
#                                                 11414  \
# 編號                                              11415
# 標題                                [情報] 確定大戶卡刷淘寶只有2%回饋
# 時間                                      Fri Nov  1 21
# 網址   https://www.ptt.cc/bbs/creditcard/M.157261425...
# 內文  [情報] 確定大戶卡刷淘寶只有2%回饋時間Fri Nov  1 21:17:28 2019\...
# 斷詞  [[, 情報, ],  , 確定, 大戶, 卡刷, 淘, 寶, 只有, 2%, 回饋, 時間...
# 詞頻  {'[': 1, '情報': 1, ']': 1, ' ': 10, '確定': 1, '大...
#
#                                                 11415  \
# 編號                                              11416
# 標題                                       大眾（元大）客服無人接聽
# 時間                                      Tue Jan 23 11
# 網址   https://www.ptt.cc/bbs/creditcard/M.151667690...
# 內文  大眾（元大）客服無人接聽時間Tue Jan 23 11:08:22 2018\n最近因?大眾...
# 斷詞  [大眾, （, 元大, ）, 客服, 無人, 接聽, 時間, Tue,  , Jan,  ,...
# 詞頻  {'大眾': 4, '（': 2, '元大': 1, '）': 2, '客服': 3, '無...
#
#                                                 11416  \
# 編號                                              11417
# 標題                              ?心得?玉山 PI UBEAR 無照會核卡
# 時間                                      Thu Aug  1 22
# 網址   https://www.ptt.cc/bbs/creditcard/M.156467139...
# 內文  ?心得?玉山 PI UBEAR 無照會核卡時間Thu Aug  1 22:56:37 201...
# 斷詞  [?, 心得, ?, 玉山,  , PI,  , UBEAR,  , 無照, 會, 核卡, ...
# 詞頻  {'?': 2, '心得': 2, '玉山': 6, ' ': 30, 'PI': 4, '...
#
#                                                 11417  \
# 編號                                              11418
# 標題                        富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14
# 時間                                      Thu Sep  5 11
# 網址   https://www.ptt.cc/bbs/creditcard/M.156765417...
# 內文  富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14時間Thu Sep  5 11:29:...
# 斷詞  [富邦, J, 卡,  , 中秋, 快, 閃, 愛買, /, 家樂福, 10%, 回饋, 9...
# 詞頻  {'富邦': 8, 'J': 8, '卡': 8, ' ': 10, '中秋': 2, '快...
#
#                                                 11418
# 編號                                              11419
# 標題                                          贈送 寰宇商務通關
# 時間                                      Mon Oct  7 10
# 網址   https://www.ptt.cc/bbs/creditcard/M.157041459...
# 內文  贈送 寰宇商務通關時間Mon Oct  7 10:16:29 2019\n手機發文找不到 贈...
# 斷詞  [贈送,  , 寰宇, 商務, 通關, 時間, Mon,  , Oct,  ,  , 7, ...
# 詞頻  {'贈送': 2, ' ': 11, '寰宇': 1, '商務': 3, '通關': 3, ...
#
# [7 rows x 11419 columns]

# %%
df.to_json(r'./ptt_creditcard_cut.json', orient='index', force_ascii=False)

# %%
df.to_csv(r'./ptt_creditcard_cut.csv', index=0, encoding='utf-16')

# %%
import xlsxwriter
writer = pd.ExcelWriter('ptt_cut.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
writer.save()

# %%
import jieba
import re
import pandas as pd
df=pd.read_json (r'./ptt_creditcard_cut.json')

# %%
bank={'中信':'中信','中國信託':'中信' ,'中信金':'中信' ,'中信金控':'中信','中信銀':'中信',
'玉山':'玉山','玉山金':'玉山','玉山金控':'玉山','玉山銀':'玉山',
'Richart':'Richart', 'richart':'Richart',
'KOKO':'KOKO','koko':'KOKO',
'國泰':'國泰','國泰世華':'國泰','國泰金':'國泰','國泰金控':'國泰',
'台新':'台新','台新金':'台新','台新金控':'台新','台新銀':'台新','台新銀行':'台新',
'永豐':'永豐','永豐銀':'永豐','永豐金':'永豐','永豐金控':'永豐','永豐銀行':'永豐',
'兆豐':'兆豐','兆豐銀':'兆豐','兆豐金':'兆豐','兆豐金控':'兆豐','兆豐銀行':'兆豐',
'花旗':'花旗','花旗銀':'花旗','花旗銀行':'花旗',
'一銀':'一銀','第一銀':'一銀','第一金':'一銀','第一金控':'一銀','第一銀行':'一銀',
'富邦':'富邦','富邦金':'富邦','富邦金控':'富邦','富邦銀':'富邦','富邦銀行':'富邦',
'彰化':'彰化','彰化銀':'彰化','彰化金控':'彰化','彰化金':'彰化','彰化銀行':'彰化',
'新光':'新光','新光銀':'新光','新光金':'新光','新光金控':'新光','新光銀行':'新光',
'匯豐':'匯豐','匯豐銀行':'匯豐','匯豐銀':'匯豐',
'陽信銀行':'陽信','陽信':'陽信','陽信銀':'陽信',
'元大':'元大','元大銀行':'元大','元大金控':'元大','元大銀':'元大',
'星展':'星展','星展銀行':'星展','星展銀':'星展','DBS':'星展','dbs':'星展',
'渣打':'渣打','渣打銀行':'渣打','渣打銀':'渣打',
'上海商銀':'上海商銀','上海銀行':'上海商銀','上海商業':'上海商銀',
'華南':'華南','華南銀行':'華南','華南金控':'華南','華南銀':'華南',
'凱基':'凱基','凱基銀行':'凱基','凱基金控':'凱基',
'合作金庫':'合作金庫','合庫':'合作金庫',
'王道':'王道','王道銀行':'王道',
'澳盛':'澳盛','澳盛銀行':'澳盛','ANZ':'澳盛','anz':'澳盛',
'遠東商銀':'遠東商銀','遠銀':'遠東商銀','遠東銀':'遠東商銀',
'土地銀行':'土地','土銀':'土地',
'聯邦銀行':'聯邦','聯邦':'聯邦',
'台灣銀行':'臺灣銀行','臺灣銀行':'臺灣銀行',
'京城':'京城','京城銀行':'京城',
'日盛':'日盛','日盛銀行':'日盛',
'華泰':'華泰','華泰銀行':'華泰',
'台中銀行':'台中銀行','台中銀':'台中銀行',
'高雄銀行':'高雄銀行','高雄銀':'高雄銀行',
'台灣企銀':'臺灣企銀','臺灣企銀':'臺灣企銀','臺企銀':'臺灣企銀',
'瑞興銀行':'瑞興銀行','瑞興':'瑞興銀行',}

behavior={'跑步':'運動','健身房':'運動','運動':'運動',
'旅遊':'旅遊','旅行':'旅遊','機票':'旅遊','飯店':'旅遊','機場':'旅遊','出國':'旅遊',
'保險':'保險','保費':'保險',
'加油':'加油','中油':'加油',
'國外':'國外','海外':'國外',
'電影':'電影','國賓':'電影','威秀':'電影',
'網購':'網購' ,'網拍':'網購', '蝦皮':'網購', '電商':'網購','pchome':'網購','PChome':'網購','Yahoo':'網購','momo':'網購','MOMO':'網購',
'行動支付':'行動支付','PI錢包':'行動支付','pi錢包':'行動支付','街口':'行動支付','Pi錢包':'行動支付','拍錢包':'行動支付',
'新光三越':'百貨','SOGO':'百貨','sogo':'百貨','遠百':'百貨','遠東百貨':'百貨',
'紅利點數':'紅利','紅利兌換':'紅利',
'超商':'超商','7-11':'超商','全家':'超商','全家便利':'超商','萊爾富':'超商','OK便利':'超商',
'屈臣氏':'藥妝','康是美':'藥妝',
'大潤發':'量販店','家樂福':'量販店','愛買':'量販店',
'全聯':'超市','頂好':'超市',
'哩程':'航空哩程','航空哩程':'航空哩程'}

card={'linepay':'LINEPay','Linepay':'LINEPay','LinePay':'LINEPay','LINEPAY':'LINEPay','LINE PAY':'LINEPay','Line pay':'LINEPay',
'line pay':'LINEPay','Line':'LINEPay','LINE':'LINEPay','line':'LINEPay',
'GOGO':'GoGo','gogo':'GoGo','黑狗':'GoGo','黑狗卡':'GoGo','gogo卡':'GoGo','GOGO卡':'GoGo','Gogo卡':'GoGo','Gogo':'GoGo','GoGo':'GoGo',
'flygo':'Flygo','Flygo':'Flygo','FLYGO':'Flygo','飛狗':'Flygo','飛狗卡':'Flygo','FlyGo':'Flygo','fly':'Flygo',
'大戶':'dawho','dawho':'dawho','Dawho':'dawho','DAWHO':'dawho',
'PI':'Pi','Pi':'Pi','pi卡':'Pi','PI卡':'Pi',
'ubear':'Ubear','UBEAR':'Ubear','Ubear':'Ubear','ubear':'Ubear','bear':'Ubear','BEAR':'Ubear',
'u bear':'Ubear','U bear':'Ubear','u bear':'Ubear', 'Ubear卡':'Ubear','U Bear':'Ubear',
'only':'Only','ONLY':'Only','Only':'Only',
'賴點':'賴點卡','賴點卡':'賴點卡', 
'酷玩卡':'酷玩卡','酷玩卡':'酷玩卡',
'饗樂':'饗樂卡','饗樂卡':'饗樂卡',
'koko':'KOKO','KOKO':'KOKO','KoKo':'KOKO','Koko':'KOKO',
'星燦':'星燦卡','星燦卡':'星燦卡','星璨':'星燦卡',
'統一獅':'統一獅聯名卡',
'中信兄弟':'中信兄弟聯名卡',
'富邦悍將':'富邦悍將聯名卡',
'My樂現金回饋卡':'My樂現金回饋卡','My樂現金回饋':'My樂現金回饋卡',
'哆啦A夢JCB聯名卡':'哆啦A夢JCB聯名卡','哆啦A夢':'哆啦A夢JCB聯名卡',
'Omiyage':'Omiyage','omiyage':'Omiyage',
'尊御世界卡':'尊御世界卡',
'鑽金一卡通聯名卡':'鑽金','鑽金':'鑽金',
'炫晶御璽卡':'炫晶御璽卡','炫晶卡':'炫晶御璽卡','炫晶':'炫晶御璽卡',
'現金回饋御璽卡':'現金回饋御璽卡',
'PChome Prime聯名卡':'PChome Prime聯名卡','Prime聯名卡':'PChome Prime聯名卡','Prime':'PChome Prime聯名卡','rime':'PChome Prime聯名卡',
'購物聯名卡':'蝦皮購物聯名卡','蝦皮聯名':'蝦皮購物聯名卡','蝦皮卡':'蝦皮購物聯名卡','國泰世華蝦皮卡':'蝦皮購物聯名卡',
'Lamigo聯名卡':'Lamigo聯名卡','Lamigo':'Lamigo聯名卡','lamigo':'Lamigo聯名卡',
'SPORT卡':'SPORT卡','SPORT':'SPORT卡',
'e秒刷鈦金卡':'e秒刷鈦金卡','e秒刷':'e秒刷鈦金卡',
'小小兵信用卡':'小小兵信用卡','小小兵':'小小兵信用卡',
'everyday鈦金卡':'everyday鈦金卡','everyday':'everyday鈦金卡',
'街口聯名卡':'街口聯名卡','街口聯名':'街口聯名卡',
'Gogoro聯名卡':'Gogoro聯名卡','Gogoro':'Gogoro聯名卡','gogoro':'Gogoro聯名卡',
'現金回饋御璽卡':'現金回饋御璽卡',
'簡單卡':'簡單卡',
'數位生活':'數位生活卡',
'美國運通':'美國運通','法拉利':'法拉利無限卡',
'omiyage':'Omiyage','OMIYAGE':'Omiyage','omiyage':'Omiyage',
'e秒刷鈦金卡':'e秒刷鈦金卡','e秒刷':'e秒刷鈦金卡',
'南開科技大學認同卡':'南開科技大學認同卡',
'聯邦OTA手機信用卡':'聯邦OTA手機信用卡',
'魔法少女iPASS一卡通聯名卡':'魔法少女iPASS一卡通聯名卡',
'富邦鑽保卡':'富邦鑽保卡',
'行遍天下聯名卡':'行遍天下聯名卡',
'幸運鈦金卡':'幸運鈦金卡',
'昇恒昌聯名卡':'昇恒昌聯名卡',
'新光三越一卡通聯名卡':'新光三越一卡通聯名卡',
'悠遊晶緻卡':'悠遊晶緻卡',
'鈦金商務卡':'鈦金商務卡',
'永豐Me Card':'永豐Me Card',
'永豐鈦豐卡':'永豐鈦豐卡',
'利倍卡':'利倍卡',
'富邦財神卡':'富邦財神卡',
'八福公益卡':'八福公益卡',
'台灣銀行':'台灣銀行',
'F1加油卡':'F1加油卡',
'全家Fish悠遊聯名卡':'全家Fish悠遊聯名卡',
'新光銀行寰宇卡':'新光銀行寰宇卡',
'建築師無限卡':'建築師無限卡',
'icash聯名卡':'icash聯名卡',
'世界卡(icash)':'世界卡(icash)',
'玉山教師卡':'玉山教師卡',
'安泰銀行信用卡':'安泰銀行信用卡',
'寰宇現金回饋卡':'寰宇現金回饋卡',
'合作金庫無限卡':'合作金庫無限卡',
'合庫雙幣信用卡(日圓)':'合庫雙幣信用卡(日圓)',
'一卡通聯名卡':'一卡通聯名卡',
'TAIPEI 101 聯名卡':'TAIPEI 101 聯名卡',
'公務人員國民旅遊卡':'公務人員國民旅遊卡',
'C’est Moi我的卡':'C’est Moi我的卡',
'Super Life 卡':'Super Life 卡',
'聯邦銀行無限卡':'聯邦銀行無限卡',
'匯豐銀行白金卡':'匯豐銀行白金卡',
'樂活Visapaywave感應式白金卡':'樂活Visapaywave感應式白金卡',
'臺北科大愛校認同卡':'臺北科大愛校認同卡',
'新光三越icash聯名卡':'新光三越icash聯名卡',
'鈦金悠遊聯名卡':'鈦金悠遊聯名卡',
'公司戶商務卡':'公司戶商務卡',
'樂享晶緻卡(原大眾)':'樂享晶緻卡(原大眾)',
'華歌爾聯名卡':'華歌爾聯名卡',
'高雄going鈦金卡':'高雄going鈦金卡',
'長庚紀念醫院悠遊認同卡':'長庚紀念醫院悠遊認同卡',
'樂購卡':'樂購卡',
'雙幣信用卡':'雙幣信用卡',
'鈦金商旅卡':'鈦金商旅卡',
'大台北商銀聯名卡':'大台北商銀聯名卡',
'KOKOicash聯名卡':'KOKOicash聯名卡',
'商務卡':'商務卡',
'商旅鈦金卡商務':'商旅鈦金卡商務',
'花蓮一信聯名卡':'花蓮一信聯名卡',
'元大白金卡':'元大白金卡',
'燦坤生活一卡通聯名卡':'燦坤生活一卡通聯名卡',
'富多卡':'富多卡',
'ｉ網購生活卡':'ｉ網購生活卡',
'台塑(一卡通)聯名卡商務':'台塑(一卡通)聯名卡商務',
'哆啦A夢悠遊晶緻卡':'哆啦A夢悠遊晶緻卡',
'大甲媽祖悠遊認同卡':'大甲媽祖悠遊認同卡',
'玉山雙幣信用卡':'玉山雙幣信用卡',
'獅子之友認同卡':'獅子之友認同卡',
'太陽卡':'太陽卡',
'農金悠遊聯名卡':'農金悠遊聯名卡',
'理財型白金卡':'理財型白金卡',
'東海大學悠遊認同卡':'東海大學悠遊認同卡',
'導盲犬認同卡':'導盲犬認同卡',
'桃園市市民卡聯名信用卡':'桃園市市民卡聯名信用卡',
'比漾聯名卡':'比漾聯名卡',
'Global Mall聯名卡':'Global Mall聯名卡',
'KOKO COMBO icash':'KOKO COMBO icash',
'夢時代icash 聯名卡':'夢時代icash 聯名卡',
'陽信鈦金卡':'陽信鈦金卡',
'VOGUE聯名卡':'VOGUE聯名卡',
'NFC手機信用卡':'NFC手機信用卡',
'現金回饋悠遊鈦金卡':'現金回饋悠遊鈦金卡',
'Display金融信用卡':'Display金融信用卡',
'信義房屋聯名卡':'信義房屋聯名卡',
'現金回饋悠遊鈦金Combo卡':'現金回饋悠遊鈦金Combo卡',
'微風廣場Visa Pay Wave感應式聯名卡':'微風廣場Visa Pay Wave感應式聯名卡',
'陽信櫻花白金卡':'陽信櫻花白金卡',
'微風聯名卡':'微風聯名卡',
'行動鈦金卡':'行動鈦金卡',
'玉山統一時代icash聯名卡':'玉山統一時代icash聯名卡',
'NFC寰宇鈦商手機信用卡':'NFC寰宇鈦商手機信用卡',
'家扶公益認同卡':'家扶公益認同卡',
'花旗HAPPY GO聯名卡':'花旗HAPPY GO聯名卡',
'美樂家生活卡':'美樂家生活卡',
'兆豐無限卡':'兆豐無限卡',
'手機信用卡':'手機信用卡',
'ESPRIT聯名卡':'ESPRIT聯名卡',
'樂天信用卡':'樂天信用卡',
'晶片Combo card':'晶片Combo card',
'一卡通聯名鈦金卡':'一卡通聯名鈦金卡',
'棉花田悠遊聯名卡':'棉花田悠遊聯名卡',
'新世代信用卡':'新世代信用卡',
'中國醫藥大學暨附設醫院晶緻認同卡':'中國醫藥大學暨附設醫院晶緻認同卡',
'Combo Life卡':'Combo Life卡',
'遠東HAPPY GO頂級信用卡':'遠東HAPPY GO頂級信用卡',
'南紡夢時代聯名卡':'南紡夢時代聯名卡',
'永豐Me Display Card':'永豐Me Display Card',
'分享卡':'分享卡',
'中華電信感恩卡':'中華電信感恩卡',
'微風悠遊聯名卡':'微風悠遊聯名卡',
'經典鈦金卡':'經典鈦金卡',
'I-FIRST生活卡':'I-FIRST生活卡',
'雙幣鈦金商旅卡':'雙幣鈦金商旅卡',
'C’est Moi旅遊悠遊卡':'C’est Moi旅遊悠遊卡',
'中興大學認同卡':'中興大學認同卡',
'大葉高島屋聯名卡':'大葉高島屋聯名卡',
'TheShoppingCard分期卡':'TheShoppingCard分期卡',
'NewCentury世界卡':'NewCentury世界卡',
'新光銀行世界卡':'新光銀行世界卡',
'中華電信商務鈦金感恩卡':'中華電信商務鈦金感恩卡',
'澎湖iPASS卡':'澎湖iPASS卡',
'LOVE晶緻悠遊聯名卡－酷愛黑卡':'LOVE晶緻悠遊聯名卡－酷愛黑卡',
'合庫雙幣信用卡':'合庫雙幣信用卡',
'台塑(悠遊)聯名卡商務':'台塑(悠遊)聯名卡商務',
'富貴無限卡':'富貴無限卡',
'美安悠遊聯名卡':'美安悠遊聯名卡',
'山隆優油卡':'山隆優油卡',
'金采鈦商卡':'金采鈦商卡',
'順發多謝聯名卡':'順發多謝聯名卡',
'MAZDA天空卡':'MAZDA天空卡',
'i-Fun愛玩樂卡':'i-Fun愛玩樂卡',
'凱基無限卡':'凱基無限卡',
'板信銀行聯名卡':'板信銀行聯名卡',
'葡眾聯名卡':'葡眾聯名卡',
'幸運PLUS鈦金卡':'幸運PLUS鈦金卡',
'大紀元認同卡':'大紀元認同卡',
'富邦財神手機卡':'富邦財神手機卡',
'得利COMBO晶片卡':'得利COMBO晶片卡',
'白沙屯拱天宮媽祖認同卡':'白沙屯拱天宮媽祖認同卡',
'HappyCash & HAPPY GO聯名卡':'HappyCash & HAPPY GO聯名卡',
'民間版國民旅遊卡':'民間版國民旅遊卡',
'鈦豐卡':'鈦豐卡',
'玩全南投認同卡':'玩全南投認同卡',
'宜蘭大學悠遊認同卡':'宜蘭大學悠遊認同卡',
'聯邦國民旅遊卡':'聯邦國民旅遊卡',
'Sweet Home白金卡':'Sweet Home白金卡',
'ｉ網購生活卡':'ｉ網購生活卡',}

# %%
df
df['銀行']=None
df['卡片']=None
df['行為']=None

# %%
for article in range(len(df)):
    article_bank={}
    for word in df['斷詞'][article]:
        if word in bank:
            if bank[word] not in article_bank:
                article_bank[bank[word]] = 1
            else:
                article_bank[bank[word]] += 1
    print(article_bank)
    df['銀行'][article]=article_bank
# Out:
# {'兆豐': 1}
# {'玉山': 1}
# {'台新': 2, '玉山': 8, 'Richart': 2, '中信': 1}
# {'台新': 7, '中信': 1, 'Richart': 2, '華南': 1, '花旗': 2, '聯邦': 3, '國泰': 1}
# {'國泰': 2}
# {'台新': 4, 'Richart': 1}
# {'中信': 1, '國泰': 1, '台新': 1, '玉山': 1, '富邦': 1, '聯邦': 1, '花旗': 1, '永豐': 1, '華南': 1, '彰化': 1}
# {'花旗': 7, '台新': 5, '渣打': 8, '合作金庫': 1}
# {'玉山': 6, '中信': 2, '永豐': 3, '花旗': 4, '台新': 3, 'Richart': 1, '聯邦': 4, '星展': 2, '上海商銀': 1, '彰化': 1, '一銀': 1, '華南': 3, '國泰': 2, '合作金庫': 1, '新光': 2, '陽信': 1, '凱基': 2, '日盛': 3}
# {'花旗': 2, '玉山': 1, '中信': 2}
# {'台新': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'富邦': 1}
# {'花旗': 3}
# {}
# {'王道': 1, '中信': 3}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 2, '國泰': 1}
# {}
# {'中信': 1}
# {'華南': 4, '中信': 3}
# {}
# {}
# {}
# {}
# {'Richart': 2}
# {'Richart': 2}
# {}
# {}
# {'台新': 2, '國泰': 3}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'澳盛': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'聯邦': 2}
# {'上海商銀': 4}
# {'上海商銀': 4}
# {'星展': 2, '澳盛': 2}
# {'中信': 5}
# {'花旗': 1, '玉山': 6, '聯邦': 1, '中信': 2, '土地': 2}
# {}
# {}
# {}
# {}
# {}
# {'台新': 1, 'Richart': 3}
# {}
# {}
# {'台新': 1, '華南': 1, '富邦': 1, '國泰': 1, '元大': 1, '玉山': 1}
# {}
# {'兆豐': 1}
# {'中信': 2}
# {'一銀': 1}
# {'中信': 1}
# {'中信': 2}
# {'國泰': 1}
# {'台新': 3}
# {'台新': 2}
# {'臺灣銀行': 1}
# {'國泰': 1}
# {'國泰': 2}
# {'台新': 2, '中信': 1, '新光': 1}
# {'匯豐': 2, '中信': 2}
# {'花旗': 4}
# {'KOKO': 7, '國泰': 2}
# {'台新': 1, '兆豐': 2, '渣打': 2, '星展': 1}
# {'國泰': 2, 'KOKO': 2}
# {'聯邦': 2, '元大': 1}
# {'永豐': 3}
# {}
# {}
# {'玉山': 2, '中信': 2, '富邦': 1, '華南': 2, '兆豐': 1, '花旗': 1}
# {}
# {}
# {'花旗': 1}
# {'渣打': 3}
# {}
# {'玉山': 1, '聯邦': 1, '中信': 2}
# {'新光': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 5, '富邦': 2, '國泰': 1}
# {'富邦': 3, '國泰': 2, '花旗': 1}
# {}
# {'新光': 1, '聯邦': 6, '玉山': 1, '中信': 1, '永豐': 1, 'Richart': 1, '日盛': 2, '星展': 1}
# {'台新': 2, '聯邦': 1, '永豐': 1, '國泰': 4, '華南': 1, '花旗': 1, '星展': 1, 'KOKO': 1}
# {'國泰': 1, '花旗': 1}
# {'KOKO': 2, '澳盛': 7, '星展': 1, '台新': 6, '王道': 3, '花旗': 6, 'Richart': 1, '中信': 1}
# {'凱基': 2}
# {'KOKO': 3, '台新': 1}
# {'永豐': 1, '台新': 1, '中信': 2}
# {'玉山': 2, '兆豐': 2, '凱基': 2}
# {'合作金庫': 2}
# {'國泰': 5, 'KOKO': 3, '富邦': 1, '台新': 7}
# {'KOKO': 2}
# {'合作金庫': 1}
# {'玉山': 1, '匯豐': 1}
# {'國泰': 2, 'KOKO': 2, '台新': 1, 'Richart': 1, '中信': 1, '兆豐': 1, '玉山': 2, '華南': 1}
# {'玉山': 1}
# {'中信': 1, '國泰': 1}
# {'渣打': 1}
# {'聯邦': 1}
# {}
# {'元大': 2}
# {}
# {'KOKO': 2}
# {'聯邦': 1}
# {}
# {'台新': 2}
# {'元大': 3, '台新': 3}
# {'台新': 1}
# {'台新': 1}
# {}
# {'Richart': 2}
# {}
# {'台新': 1, 'Richart': 1}
# {'Richart': 1, '台新': 2}
# {'台新': 1}
# {'Richart': 1}
# {}
# {'Richart': 1}
# {}
# {'Richart': 1, '台新': 1}
# {'玉山': 2, '台新': 3, 'Richart': 1, '國泰': 1, '兆豐': 2}
# {'玉山': 2, '台新': 3, 'Richart': 1, '國泰': 1, '兆豐': 2}
# {}
# {'國泰': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Richart': 2}
# {}
# {}
# {}
# {'國泰': 2}
# {}
# {'國泰': 15, '玉山': 1}
# {}
# {}
# {}
# {}
# {'星展': 1}
# {'台新': 2}
# {'星展': 2, '合作金庫': 3}
# {'玉山': 2}
# {'國泰': 1}
# {'元大': 1, '台新': 1, '渣打': 1, '中信': 1}
# {'元大': 1, '富邦': 1}
# {'華南': 2}
# {}
# {'花旗': 1}
# {'中信': 1}
# {'中信': 1}
# {}
# {'台新': 1}
# {'澳盛': 5}
# {'澳盛': 8, '星展': 2}
# {'澳盛': 2}
# {}
# {}
# {'國泰': 1, '台新': 1}
# {}
# {'台新': 4, 'Richart': 1}
# {}
# {'中信': 1}
# {'花旗': 8}
# {'星展': 1, '花旗': 1}
# {'中信': 2, '元大': 1, '花旗': 1}
# {}
# {}
# {}
# {}
# {}
# {'花旗': 2}
# {}
# {}
# {}
# {'玉山': 2, '台新': 1, '國泰': 1, '聯邦': 1}
# {'國泰': 2, '台新': 2, '玉山': 2}
# {'國泰': 2}
# {}
# {'華南': 1}
# {}
# {'Richart': 1}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {'Richart': 1}
# {'兆豐': 1}
# {}
# {'台新': 1}
# {'台新': 1, '玉山': 1}
# {}
# {'台新': 1}
# {}
# {}
# {}
# {'Richart': 4}
# {'台新': 4}
# {}
# {}
# {}
# {}
# {}
# {'台新': 1}
# {}
# {'元大': 2}
# {}
# {}
# {}
# {}
# {}
# {'中信': 2, '遠東商銀': 1}
# {'兆豐': 2, '富邦': 1, '渣打': 1}
# {}
# {'台新': 1}
# {'中信': 1}
# {'KOKO': 1, '華南': 1, '富邦': 1}
# {'台新': 2}
# {'Richart': 1}
# {'Richart': 1}
# {}
# {'Richart': 1, '台新': 2}
# {'Richart': 1, '台新': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 1}
# {}
# {}
# {'Richart': 1, '台新': 1}
# {'Richart': 1}
# {}
# {'Richart': 4}
# {'台新': 1, '玉山': 1}
# {'玉山': 2, '台新': 1, 'Richart': 1}
# {}
# {'Richart': 1, '國泰': 2, 'KOKO': 6, '華南': 4, '台新': 1}
# {'台新': 1, 'Richart': 3}
# {'Richart': 1}
# {'台新': 1}
# {'國泰': 2, 'KOKO': 1}
# {}
# {'匯豐': 2, '玉山': 1}
# {}
# {'兆豐': 1}
# {'中信': 1}
# {}
# {'中信': 1}
# {'玉山': 1}
# {'華南': 2}
# {'玉山': 3}
# {'匯豐': 1}
# {'兆豐': 1}
# {}
# {}
# {'玉山': 6}
# {'玉山': 1, 'KOKO': 1, '花旗': 1}
# {'玉山': 1, 'KOKO': 1, '花旗': 1}
# {'合作金庫': 1}
# {}
# {'華南': 1, '元大': 1}
# {'玉山': 1, '華南': 1}
# {'台新': 2, '玉山': 2, '國泰': 1}
# {'國泰': 2}
# {'凱基': 1}
# {}
# {}
# {}
# {'元大': 1, '中信': 3}
# {}
# {}
# {'兆豐': 1}
# {'聯邦': 7}
# {'台新': 1}
# {'玉山': 1}
# {}
# {'玉山': 1}
# {}
# {}
# {}
# {}
# {}
# {'國泰': 1}
# {'永豐': 1}
# {'台新': 1, '國泰': 1, 'KOKO': 1, '中信': 1, '渣打': 1}
# {'富邦': 2}
# {'KOKO': 3}
# {'KOKO': 4, '富邦': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 3, '國泰': 1}
# {'KOKO': 3, '國泰': 2}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 3, '國泰': 1}
# {'KOKO': 5}
# {'KOKO': 1, '國泰': 1}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 1}
# {'國泰': 1}
# {'KOKO': 1}
# {'KOKO': 2, '永豐': 1, '國泰': 2}
# {'KOKO': 2}
# {'KOKO': 1, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 5, '國泰': 1}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2, '國泰': 2}
# {'KOKO': 3}
# {'KOKO': 3}
# {'KOKO': 2}
# {'渣打': 2, '國泰': 3, 'KOKO': 4}
# {'KOKO': 8, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 6}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 1, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 3, '國泰': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 3, 'Richart': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 1, '國泰': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 4}
# {'KOKO': 2}
# {'國泰': 2, 'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 4}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2, '富邦': 2, '一銀': 3}
# {'KOKO': 4, '富邦': 1}
# {'KOKO': 2}
# {'KOKO': 3, '富邦': 1}
# {'KOKO': 2}
# {'KOKO': 5, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 3, '國泰': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {}
# {'中信': 1}
# {}
# {'玉山': 1}
# {'玉山': 1}
# {}
# {'花旗': 1}
# {}
# {'中信': 1}
# {'中信': 2}
# {'聯邦': 1}
# {'中信': 1}
# {}
# {}
# {}
# {'中信': 1}
# {}
# {'中信': 1}
# {}
# {}
# {}
# {'中信': 1}
# {}
# {'中信': 1}
# {}
# {}
# {'台新': 1, '中信': 1}
# {}
# {'兆豐': 1, '玉山': 1}
# {}
# {'匯豐': 3}
# {}
# {'兆豐': 6}
# {}
# {'凱基': 4}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'渣打': 1}
# {}
# {'台新': 2}
# {'中信': 1}
# {}
# {}
# {'中信': 1}
# {}
# {'星展': 1, '元大': 1}
# {'星展': 1, '元大': 1}
# {'匯豐': 1, '花旗': 1}
# {'KOKO': 3, '中信': 1}
# {}
# {'花旗': 1}
# {'中信': 1}
# {'元大': 3, '聯邦': 2, '中信': 1, '華南': 1}
# {'元大': 2}
# {}
# {'元大': 1, '玉山': 1}
# {}
# {}
# {}
# {'國泰': 3}
# {'花旗': 1}
# {'玉山': 2}
# {'台新': 1}
# {'玉山': 2}
# {'國泰': 1, 'KOKO': 1}
# {'玉山': 5}
# {'台新': 6}
# {}
# {'KOKO': 1}
# {'台新': 1, '富邦': 1}
# {}
# {}
# {}
# {'國泰': 1}
# {'KOKO': 3}
# {'合作金庫': 4, '華南': 1}
# {'中信': 2}
# {}
# {'花旗': 1}
# {}
# {}
# {'Richart': 1, '王道': 1}
# {'台新': 1}
# {'玉山': 1}
# {'台新': 2}
# {}
# {}
# {'台新': 1}
# {}
# {'花旗': 4}
# {'中信': 1, '台新': 1}
# {'中信': 1}
# {'兆豐': 2, 'KOKO': 1}
# {'國泰': 1}
# {'花旗': 2}
# {'玉山': 1}
# {'玉山': 4}
# {'玉山': 1}
# {'國泰': 1}
# {'中信': 2, '玉山': 1}
# {}
# {'一銀': 4}
# {'中信': 4}
# {'玉山': 1}
# {'中信': 1}
# {}
# {}
# {}
# {'新光': 1, '玉山': 1}
# {'玉山': 1}
# {}
# {'玉山': 1}
# {}
# {'華南': 2, '玉山': 1}
# {'玉山': 2}
# {}
# {'元大': 2, '富邦': 2}
# {'玉山': 2}
# {}
# {'玉山': 1}
# {'遠東商銀': 1}
# {}
# {}
# {'Richart': 1}
# {'Richart': 1}
# {'Richart': 2, '台新': 1}
# {'Richart': 2, '台新': 1}
# {'Richart': 1}
# {'Richart': 1}
# {'Richart': 4}
# {'Richart': 2}
# {'Richart': 2}
# {'Richart': 2}
# {'Richart': 2}
# {'Richart': 1, '台新': 1}
# {'Richart': 5, '玉山': 1, 'KOKO': 1}
# {'Richart': 2, 'KOKO': 2, '國泰': 1, '渣打': 2}
# {'Richart': 3}
# {'Richart': 4}
# {'台新': 2}
# {'Richart': 2, '中信': 1}
# {'Richart': 2}
# {'Richart': 1}
# {'Richart': 3}
# {'Richart': 2, '台新': 1}
# {'國泰': 1}
# {'中信': 3, '玉山': 1}
# {'中信': 3, '花旗': 2, '玉山': 1, '元大': 1}
# {'國泰': 1, 'KOKO': 1}
# {'永豐': 2, '渣打': 2, '台新': 2, '華南': 3}
# {'兆豐': 1}
# {'台新': 1, '凱基': 1, '渣打': 1}
# {}
# {}
# {'兆豐': 1}
# {}
# {}
# {}
# {'玉山': 1}
# {}
# {}
# {'玉山': 4, '國泰': 2}
# {'玉山': 1}
# {}
# {}
# {'玉山': 1}
# {}
# {}
# {}
# {}
# {'中信': 7, '上海商銀': 1}
# {'玉山': 1}
# {}
# {}
# {}
# {'臺灣企銀': 1, '中信': 2}
# {'中信': 1}
# {}
# {}
# {}
# {}
# c:\users\big data\pycharmprojects\py\venv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# {}
# {}
# {'國泰': 2, '合作金庫': 1, '台新': 1}
# {'元大': 1}
# {'花旗': 3}
# {}
# {}
# {'玉山': 2}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {}
# {'兆豐': 1, '中信': 1}
# {'永豐': 1, '台中銀行': 1, '富邦': 2}
# {}
# {'土地': 1}
# {'一銀': 3, '兆豐': 3}
# {'一銀': 2}
# {'一銀': 7}
# {'一銀': 2}
# {'一銀': 2}
# {'一銀': 1}
# {}
# {'玉山': 1, '國泰': 1, '華南': 1, '台新': 1}
# {'國泰': 2, '台新': 1}
# {'華南': 2}
# {'元大': 1, '玉山': 1}
# {'玉山': 2}
# {'華南': 3}
# {}
# {'元大': 1}
# {}
# {'上海商銀': 1}
# {'元大': 3, '上海商銀': 1}
# {'台新': 1, '玉山': 1, '中信': 1, '花旗': 1, '國泰': 1, '上海商銀': 1}
# {'上海商銀': 2}
# {'台新': 1}
# {'玉山': 1, '中信': 2}
# {}
# {'台新': 2, '玉山': 1}
# {'國泰': 2}
# {}
# {'花旗': 2, '玉山': 2, '國泰': 1}
# {'中信': 1}
# {'中信': 3}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1, '台新': 2}
# {'中信': 1, 'KOKO': 1, '富邦': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1, '玉山': 1}
# {'中信': 2}
# {'中信': 3, '花旗': 1, '國泰': 1, '富邦': 1}
# {'中信': 2}
# {'中信': 4}
# {'中信': 3}
# {'中信': 3}
# {'中信': 2}
# {'中信': 4}
# {'中信': 1}
# {'中信': 3}
# {'中信': 1}
# {'中信': 4}
# {'中信': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 7}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 3}
# {'中信': 2}
# {'中信': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 1, '國泰': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 9}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 3, '元大': 1}
# {'中信': 4}
# {'中信': 4, '台新': 2, '合作金庫': 2, 'Richart': 2}
# {'中信': 3}
# {'中信': 1}
# {'中信': 3, '台新': 3, '玉山': 3, 'Richart': 3}
# {'中信': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 5, '玉山': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 3}
# {'中信': 2}
# {'中信': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 4}
# {'中信': 1}
# {'中信': 3}
# {'中信': 3}
# {'中信': 3}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1, '花旗': 1}
# {'中信': 3}
# {'中信': 6}
# {'中信': 1, '星展': 1}
# {'中信': 4}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 4}
# {'中信': 2}
# {'中信': 2}
# {'中信': 4, '兆豐': 8, '國泰': 2}
# {'中信': 2, '永豐': 1, '台新': 1}
# {'中信': 3}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2}
# {'中信': 9, '台新': 3, 'Richart': 3, '渣打': 2, '國泰': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 3, '匯豐': 1}
# {'中信': 3, '聯邦': 1}
# {'中信': 1}
# {'中信': 3}
# {'中信': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2, '玉山': 1}
# {'中信': 3, '兆豐': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 4}
# {'中信': 2}
# {'中信': 4, '玉山': 2}
# {'中信': 3}
# {'中信': 2}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 5, '國泰': 5}
# {'中信': 2}
# {'中信': 4}
# {'中信': 2}
# {'中信': 2, '台新': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 4}
# {'中信': 4}
# {'中信': 2}
# {'中信': 7, '華南': 1}
# {'中信': 3, '花旗': 1, '玉山': 1}
# {'中信': 3, '渣打': 1, '花旗': 1}
# {'中信': 1}
# {'中信': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 3, '富邦': 1}
# {'中信': 3}
# {'中信': 1}
# {}
# {'匯豐': 1, '花旗': 3}
# {}
# {'中信': 1, '玉山': 1, '國泰': 1, '花旗': 1, '台新': 1}
# {}
# {}
# {'中信': 3}
# {}
# {'花旗': 1, '台新': 1, '聯邦': 1}
# {'一銀': 3}
# {'玉山': 3, '星展': 1, '渣打': 1, '富邦': 2}
# {'渣打': 1}
# {'花旗': 1, '元大': 1, '中信': 1}
# {}
# {}
# {'華南': 1, '玉山': 3, '兆豐': 2, '合作金庫': 1, '花旗': 2, '富邦': 1, '一銀': 1}
# {'KOKO': 1}
# {'花旗': 2, '國泰': 2, '台新': 1, '元大': 1}
# {'花旗': 1}
# {'玉山': 1, '中信': 1, '國泰': 1, 'KOKO': 1, '富邦': 1}
# {}
# {}
# {}
# {'玉山': 3}
# {'國泰': 1}
# {}
# {'澳盛': 2, '星展': 1}
# {'兆豐': 1}
# {'玉山': 2}
# {}
# {'新光': 1, '中信': 2, '玉山': 1}
# {'匯豐': 3, '台新': 2}
# {}
# {'玉山': 1}
# {}
# {'中信': 1}
# {}
# {'花旗': 2}
# {}
# {}
# {'國泰': 1, '富邦': 1}
# {}
# {}
# {'Richart': 1, '台新': 1}
# {'玉山': 4, '中信': 1}
# {'台新': 1}
# {}
# {'台新': 1}
# {}
# {'台新': 1}
# {'富邦': 2}
# {'元大': 1, '台新': 1, '富邦': 1, '中信': 3, '國泰': 1, 'KOKO': 4}
# {}
# {}
# {'元大': 3}
# {'澳盛': 2}
# {}
# {'匯豐': 3}
# {'中信': 2, '玉山': 1}
# {}
# {'富邦': 1}
# {}
# {}
# {}
# {'中信': 1}
# {'合作金庫': 2}
# {'花旗': 4}
# {'星展': 1, 'KOKO': 1}
# {'花旗': 4, '富邦': 2, '元大': 3}
# {'玉山': 2}
# {'國泰': 2, '玉山': 1}
# {'兆豐': 2}
# {}
# {'國泰': 1}
# {}
# {'國泰': 1, '台新': 1, '匯豐': 1}
# {'台新': 3}
# {}
# {'兆豐': 2}
# {}
# {}
# {'富邦': 1}
# {'元大': 4, '花旗': 2, '富邦': 1, '中信': 1, 'Richart': 1, '台新': 2}
# {'中信': 1, '玉山': 1, '台新': 1}
# {'中信': 3, '玉山': 1}
# {}
# {}
# {'台新': 2}
# {}
# {'富邦': 1}
# {'花旗': 3}
# {}
# {'中信': 2, '華南': 2, '玉山': 2, '台新': 1, '國泰': 1, '花旗': 1, '元大': 1}
# {'台新': 2}
# {'凱基': 2}
# {}
# {}
# {}
# {'國泰': 1}
# {'KOKO': 2, '台新': 1}
# {'玉山': 1}
# {'元大': 1}
# {'中信': 1}
# {'元大': 3}
# {'台新': 1}
# {}
# {'台新': 1}
# {}
# {'花旗': 1, '渣打': 1, '匯豐': 1, 'KOKO': 1}
# {}
# {'花旗': 1}
# {'中信': 1}
# {'花旗': 2, '富邦': 1, '凱基': 2, '台新': 4, '渣打': 1, 'KOKO': 1}
# {}
# {'華南': 2, '玉山': 1}
# {}
# {}
# {}
# {}
# {}
# {'玉山': 1, '華南': 1, '永豐': 2, '元大': 1, '台新': 1, '富邦': 1}
# {'華南': 1}
# {'國泰': 1, '玉山': 1, 'KOKO': 2, '元大': 1}
# {'兆豐': 1}
# {}
# {'玉山': 3}
# {}
# {}
# {'國泰': 1, 'KOKO': 1, '渣打': 2}
# {'Richart': 1}
# {'元大': 1}
# {'台新': 2, '花旗': 1}
# {}
# {'國泰': 1}
# {'花旗': 3, '澳盛': 2, '匯豐': 1, '星展': 1, '華南': 1}
# {}
# {'玉山': 3, '聯邦': 2}
# {}
# {}
# {}
# {'中信': 4, '玉山': 3}
# {'玉山': 1, '國泰': 1}
# {}
# {}
# {'富邦': 1, '中信': 1}
# {'花旗': 1, '中信': 1, '永豐': 1, '國泰': 1}
# {'華南': 6, '中信': 3, '玉山': 2, '台新': 2, '富邦': 2, '兆豐': 3}
# {'元大': 2}
# {'元大': 6, '富邦': 1}
# {'元大': 2}
# {'元大': 2}
# {'元大': 4}
# {'元大': 3}
# {'元大': 2}
# {'元大': 2}
# {'元大': 2}
# {'元大': 1}
# {'元大': 1}
# {'元大': 3, '中信': 1}
# {'元大': 3}
# {'元大': 2, 'Richart': 3}
# {'元大': 3}
# {'元大': 2}
# {'元大': 1}
# {'元大': 4}
# {'元大': 5}
# {'元大': 1}
# {'元大': 2}
# {'元大': 3}
# {'元大': 1, '中信': 1, '國泰': 1, '花旗': 1}
# {'元大': 3}
# {'元大': 7}
# {'元大': 4, '華南': 2}
# {'元大': 3}
# {'元大': 2, '花旗': 1}
# {'元大': 2}
# {'元大': 2}
# {'元大': 2}
# {'元大': 3}
# {'元大': 2}
# {'匯豐': 3, '中信': 1, '花旗': 1}
# {'中信': 1, '台新': 2}
# {'元大': 1, 'Richart': 1}
# {}
# {}
# {}
# {'元大': 2}
# {'元大': 2}
# {'元大': 6}
# {'元大': 1}
# {'元大': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 2}
# {'兆豐': 3, 'KOKO': 3, '元大': 1, '國泰': 1}
# {'兆豐': 1}
# {'兆豐': 2}
# {'兆豐': 2}
# {'兆豐': 2, '花旗': 1}
# {'兆豐': 1}
# {'兆豐': 2}
# {'兆豐': 4, 'KOKO': 3, '華南': 1}
# {'兆豐': 2, '台新': 1}
# {'兆豐': 1}
# {'兆豐': 3}
# {'兆豐': 2}
# {'兆豐': 2, 'KOKO': 4}
# {'兆豐': 2}
# {'兆豐': 3}
# {'兆豐': 3, '國泰': 1, 'KOKO': 1}
# {'兆豐': 1}
# {'兆豐': 2}
# {'兆豐': 3, '台新': 1, '遠東商銀': 1}
# {'兆豐': 2}
# {'兆豐': 3}
# {'兆豐': 4, '玉山': 1, '花旗': 1, '凱基': 1}
# {'兆豐': 1}
# {'兆豐': 4}
# {'兆豐': 3}
# {'兆豐': 6}
# {'兆豐': 2}
# {'兆豐': 3}
# {'兆豐': 2}
# {'台新': 1}
# {}
# {'聯邦': 2, '新光': 1}
# {'中信': 4}
# {'國泰': 1, 'KOKO': 2, '台新': 3, '兆豐': 2, '中信': 3, '玉山': 3, '台中銀行': 1, '永豐': 1}
# {'台新': 2}
# {'花旗': 1, '台新': 1}
# {'國泰': 2, 'KOKO': 3}
# {}
# {'國泰': 1, 'KOKO': 2}
# {'Richart': 2, '台新': 1, '中信': 1}
# {}
# {'KOKO': 1}
# {}
# {'台新': 1}
# {}
# {'國泰': 1, 'KOKO': 2}
# {}
# {'元大': 1}
# {}
# {'台新': 2}
# {'KOKO': 3, '國泰': 2}
# {'華南': 4}
# {}
# {'花旗': 1}
# {'中信': 3}
# {'花旗': 2}
# {'永豐': 1, '玉山': 1, '國泰': 1, '華南': 1}
# {}
# {'花旗': 2, '渣打': 2, '國泰': 2, 'KOKO': 2, '中信': 11}
# {'花旗': 2, '渣打': 2, '國泰': 2, 'KOKO': 2, '中信': 11}
# {'凱基': 1}
# {'凱基': 2}
# {'凱基': 2}
# {'凱基': 2}
# {'凱基': 1}
# {'凱基': 2}
# {'凱基': 2, '聯邦': 1}
# {'凱基': 2, '花旗': 1}
# {'凱基': 2}
# {'凱基': 3}
# {'Richart': 1}
# {'國泰': 2}
# {'花旗': 1, '華南': 1, '國泰': 1, 'KOKO': 1, '台新': 2, '渣打': 3}
# {'花旗': 1, '元大': 1}
# {'中信': 1}
# {'中信': 1, '台新': 1}
# {'華南': 2}
# {'元大': 1}
# {'花旗': 1}
# {'華南': 1}
# {}
# {'中信': 1}
# {'一銀': 1}
# {'台新': 2, '新光': 2, '玉山': 1, '花旗': 1}
# {'國泰': 1, 'KOKO': 1}
# {'一銀': 3}
# {}
# {'渣打': 1, '台新': 1}
# {}
# {'兆豐': 1, '玉山': 1}
# {}
# {}
# {}
# {'中信': 2}
# {'中信': 2}
# {'富邦': 1, '台新': 3, '匯豐': 1}
# {'聯邦': 2, '玉山': 1, '渣打': 1, '永豐': 1}
# {}
# {'遠東商銀': 3, '元大': 4}
# {}
# {}
# {}
# {'花旗': 1}
# {}
# {'國泰': 2, 'KOKO': 2}
# {'花旗': 1}
# {'國泰': 5, '台新': 2}
# {'聯邦': 2, '上海商銀': 1}
# {'台新': 1, '渣打': 2, '玉山': 1}
# {'台新': 2, '中信': 1, '國泰': 1}
# {'玉山': 1}
# {'花旗': 1, '中信': 1, '星展': 1}
# {'中信': 1, '玉山': 1}
# {'花旗': 1, '玉山': 1, '中信': 1}
# {'台新': 2, '國泰': 3, '花旗': 1, '中信': 1}
# {'玉山': 2, '一銀': 2}
# {'玉山': 5, '中信': 2, '永豐': 1}
# {'玉山': 1, '元大': 1, '中信': 2, '王道': 1}
# {'花旗': 2}
# {'星展': 1, '王道': 1}
# {'花旗': 1}
# {}
# {'玉山': 2, '花旗': 2}
# {}
# {}
# {}
# {'永豐': 1}
# {}
# {'中信': 1, '澳盛': 1}
# {'台新': 1, '中信': 3}
# {'台新': 2, '澳盛': 1}
# {}
# {'台新': 1}
# {'中信': 3, '國泰': 3, 'KOKO': 1, '台新': 2, 'Richart': 1, '華南': 1, '渣打': 1}
# {'國泰': 1}
# {'一銀': 1}
# {'玉山': 1}
# {'玉山': 3}
# {}
# {'聯邦': 1, '渣打': 1}
# {'玉山': 1, '台新': 1, '國泰': 1}
# {'玉山': 4, '台新': 5}
# {'中信': 3}
# {'KOKO': 2, '玉山': 8, '台新': 3, '聯邦': 1, '國泰': 1, '中信': 3, '元大': 1, '合作金庫': 1}
# {'國泰': 5, 'KOKO': 1, '玉山': 1, '花旗': 1}
# {'中信': 1, '玉山': 2}
# {}
# {'中信': 2}
# {'玉山': 4, '台新': 2}
# {}
# {}
# {'土地': 1}
# {}
# {'花旗': 2}
# {'匯豐': 1}
# {'匯豐': 1}
# {'匯豐': 6, '元大': 5}
# {'匯豐': 3}
# {'匯豐': 2}
# {'匯豐': 2}
# {'匯豐': 4}
# {'匯豐': 2}
# {'匯豐': 1}
# {'匯豐': 2}
# {'匯豐': 1}
# {'匯豐': 1}
# {'匯豐': 5, '中信': 5}
# {'匯豐': 2}
# {'匯豐': 1}
# {'匯豐': 4, '台新': 2, '玉山': 1, 'Richart': 1}
# {}
# {'花旗': 2, '國泰': 2, '台新': 2, '玉山': 2, '中信': 1}
# {'國泰': 1, '渣打': 1}
# {'國泰': 1}
# {'中信': 2}
# {}
# {'玉山': 4, '聯邦': 1, '中信': 3, '渣打': 2, '國泰': 1, 'KOKO': 2, '星展': 1, '花旗': 1}
# {'台新': 9, '花旗': 1, '元大': 5, '玉山': 2, '中信': 1}
# {'花旗': 1, '國泰': 1, 'KOKO': 1, '富邦': 1, '華南': 1, '兆豐': 1, '台新': 2}
# {'富邦': 2, '華南': 6, '永豐': 1, '花旗': 1, '國泰': 1, '渣打': 2, '匯豐': 1, '新光': 2}
# {'花旗': 3, '台新': 1, '中信': 4, '玉山': 4, '國泰': 2, 'KOKO': 1, '匯豐': 1, '渣打': 1}
# {}
# {'元大': 1}
# {'台新': 1, 'Richart': 1}
# {}
# {'花旗': 2}
# {'富邦': 1, '台新': 1, '玉山': 1, '花旗': 1, '元大': 1, '中信': 1, 'KOKO': 1}
# {}
# {'中信': 1, 'Richart': 1}
# {'聯邦': 1, '合作金庫': 1}
# {'台新': 1, '國泰': 1}
# {}
# {'KOKO': 3}
# {'永豐': 2}
# {'澳盛': 5, '星展': 7}
# {'國泰': 4}
# {'永豐': 1, '國泰': 1, 'KOKO': 1}
# {'國泰': 1, '花旗': 1, '中信': 1, '元大': 1}
# {'KOKO': 4, '華南': 1}
# {'台新': 5}
# {'國泰': 1, 'KOKO': 2}
# {}
# {'華南': 1}
# {'星展': 1, '中信': 2}
# {}
# {'富邦': 2}
# {}
# {}
# {'花旗': 1, '星展': 1, '國泰': 2, '台新': 1}
# {'花旗': 1, '土地': 1}
# {}
# {}
# {'渣打': 2}
# {'花旗': 1}
# {}
# {'華南': 1}
# {'台新': 1, '玉山': 1}
# {'新光': 1, 'Richart': 1}
# {'台中銀行': 2}
# {'台中銀行': 3, '元大': 1}
# {'台中銀行': 2}
# {'永豐': 2, '國泰': 1}
# {'玉山': 1, '中信': 1}
# {}
# {'玉山': 1}
# {'國泰': 2, '台新': 1}
# {'富邦': 1}
# {'花旗': 2}
# {}
# {'聯邦': 1, '台新': 1, '渣打': 1}
# {}
# {}
# {'富邦': 2, '台新': 1, '華南': 1, '玉山': 1}
# {'玉山': 2}
# {}
# {}
# {}
# {}
# {'聯邦': 2, '台新': 2, '富邦': 1}
# {'台新': 1, 'Richart': 1}
# {'台新': 2}
# {'台新': 2}
# {'台新': 2, 'Richart': 1, '國泰': 1}
# {'台新': 1}
# {'台新': 1, 'Richart': 2}
# {'台新': 2, '國泰': 2, '花旗': 1}
# {'台新': 2, '新光': 1}
# {'台新': 2}
# {'台新': 4, '華南': 4, '玉山': 1, '星展': 1, '中信': 1}
# {'台新': 7, 'Richart': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 1, '中信': 2}
# {'台新': 1, 'Richart': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1, 'Richart': 1}
# {'台新': 4, '中信': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 2}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2}
# {'台新': 2, 'Richart': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 2, 'Richart': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 3, '中信': 1}
# {'台新': 3, '富邦': 2, '中信': 1, '華南': 1, '國泰': 1}
# {'台新': 5, '華南': 1}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2}
# {'台新': 2, '富邦': 1, '土地': 1}
# {'台新': 3, '中信': 3, 'Richart': 1}
# {'台新': 3}
# {'台新': 1, 'Richart': 1}
# {'台新': 2}
# {'台新': 1}
# {'台新': 1, '兆豐': 1}
# {'台新': 3, '新光': 2}
# {'台新': 3, '花旗': 1}
# {'台新': 2}
# {'台新': 3}
# {'台新': 1, 'Richart': 1}
# {'台新': 3}
# {'台新': 4}
# {'台新': 2, 'Richart': 1, '花旗': 1, '富邦': 1}
# {'台新': 2}
# {'台新': 1, 'Richart': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1}
# {'台新': 4}
# {'台新': 2}
# {'台新': 1, '土地': 2, '渣打': 4, 'Richart': 3}
# {'台新': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 2, 'Richart': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1, 'Richart': 3}
# {'台新': 5}
# {'台新': 1}
# {'台新': 2}
# {'台新': 4, 'Richart': 6}
# {'台新': 3, 'Richart': 2, '中信': 2}
# {'台新': 1, 'Richart': 1}
# {'台新': 6, 'Richart': 1, '富邦': 2}
# {'台新': 1, 'Richart': 1}
# {'台新': 2, 'Richart': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 3}
# {'台新': 3}
# {'台新': 2, '新光': 1}
# {'台新': 4}
# {'台新': 2}
# {'台新': 1}
# {'台新': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 10}
# {'台新': 2}
# {'台新': 2}
# {'台新': 3, 'Richart': 1}
# {}
# {'台新': 2}
# {'台新': 2}
# {}
# {'台新': 4}
# {'台新': 2, '國泰': 1}
# {'台新': 3, '國泰': 6}
# {'台新': 1}
# {'台新': 1, '國泰': 1}
# {'台新': 2, '國泰': 2}
# {'台新': 1, '國泰': 1}
# {'台新': 3, '國泰': 5}
# {'台新': 1, '國泰': 1}
# {'台新': 2, '國泰': 2}
# {'台新': 3, '國泰': 6}
# {'台新': 1, '國泰': 2}
# {'台新': 1, '國泰': 1, 'Richart': 1}
# {'台新': 1, '國泰': 2}
# {'台新': 3, '國泰': 3}
# {'台新': 1, 'Richart': 2}
# {'台新': 4, '國泰': 1, 'KOKO': 2, '渣打': 1}
# {'台新': 2}
# {'台新': 3, '花旗': 1}
# {'台新': 3, 'Richart': 1}
# {'台新': 2}
# {'台新': 4}
# {'台新': 2}
# {'台新': 4}
# {'台新': 2}
# {'台新': 3}
# {'台新': 1}
# {'台新': 2}
# {'台新': 3}
# {'台新': 1, 'Richart': 1}
# {'台新': 5, 'Richart': 1}
# {'台新': 2}
# {'台新': 2}
# {'台新': 5, '國泰': 1}
# {'台新': 2}
# {'台新': 13, '土地': 1, '國泰': 4, '富邦': 2, '中信': 4, '花旗': 1}
# {'台新': 2}
# {'台新': 2}
# {'台新': 1}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2}
# {'台新': 2}
# {'台新': 2}
# {'台新': 1}
# {'台新': 5}
# {'台新': 3, '國泰': 1}
# {'台新': 4, '聯邦': 1}
# {'台新': 3}
# {'台新': 1, '國泰': 1}
# {'台新': 2}
# {}
# {'台新': 3, 'Richart': 1, '王道': 1}
# {}
# {'台新': 3}
# {'台新': 2, '國泰': 1}
# {'台新': 3, '中信': 1}
# {'台新': 2}
# {'台新': 4}
# {'台新': 8, '中信': 4, '玉山': 1, '聯邦': 1, '國泰': 1, '花旗': 3, '富邦': 1, '永豐': 1, '華南': 1}
# {'台新': 1, 'Richart': 1}
# {'台新': 5, '澳盛': 1, 'Richart': 1, '中信': 1, 'KOKO': 3}
# {'台新': 1}
# {'台新': 3, '土地': 2}
# {'台新': 2}
# {'台新': 6, '元大': 4, '中信': 1, '國泰': 1, 'KOKO': 1, '玉山': 1, '渣打': 2, '花旗': 3, '兆豐': 2}
# {'台新': 4}
# {'台新': 2}
# {'台新': 1}
# {'花旗': 1}
# {'華南': 2}
# {'華南': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'玉山': 1, '國泰': 2, 'KOKO': 1}
# {'台新': 1, '元大': 1, '匯豐': 1, '玉山': 1}
# {}
# {}
# {'兆豐': 1, '台新': 1}
# {}
# {'富邦': 1}
# {'台新': 2}
# {'合作金庫': 3}
# {}
# {'合作金庫': 4}
# {'合作金庫': 2}
# {'合作金庫': 1}
# {'合作金庫': 4}
# {'玉山': 2}
# {'合作金庫': 2}
# {'凱基': 1, '元大': 1}
# {'花旗': 1, '玉山': 1}
# {}
# {'台新': 3, 'Richart': 1}
# {'台新': 3, 'Richart': 1}
# {'渣打': 1}
# {'花旗': 2, '國泰': 1}
# {'花旗': 2, '中信': 1, '渣打': 1, '玉山': 1, '聯邦': 1, '國泰': 3, '台新': 1, '星展': 1}
# {'星展': 4}
# {'匯豐': 1, '國泰': 1, '星展': 1, '花旗': 2, 'KOKO': 1, '渣打': 2}
# {'國泰': 3, '花旗': 1}
# {'花旗': 1, '星展': 1, '國泰': 1}
# {'星展': 3, '中信': 1, '花旗': 2}
# {'兆豐': 1}
# {'台新': 2, '富邦': 2, '華南': 1}
# {}
# {'花旗': 1}
# {'遠東商銀': 2}
# {}
# {'臺灣銀行': 1, '永豐': 1}
# {'國泰': 1}
# {}
# {}
# {'台新': 2}
# {'台新': 1, '匯豐': 1, '中信': 1, '國泰': 1, '聯邦': 1}
# {'台新': 1, '富邦': 1}
# {'中信': 3, '台新': 1, '匯豐': 1, '元大': 1, '渣打': 2}
# {'玉山': 1, '中信': 1}
# {}
# {}
# {'永豐': 2}
# {'玉山': 4}
# {'國泰': 2}
# {'富邦': 1}
# {}
# {}
# {}
# {'一銀': 4}
# {'渣打': 2}
# {'台新': 1}
# {}
# {}
# {}
# {'玉山': 1}
# {'匯豐': 1}
# {'玉山': 3, '永豐': 3, '富邦': 1, '聯邦': 1, '渣打': 1}
# {}
# {'玉山': 1}
# {}
# {'玉山': 1, '台新': 1}
# {}
# {'花旗': 1, '匯豐': 1}
# {'花旗': 2, '台新': 1}
# {}
# {'玉山': 2, '永豐': 1, '台新': 1}
# {'中信': 2, '國泰': 1, 'KOKO': 1, '華南': 1}
# {}
# {'元大': 3, '匯豐': 2, '華南': 2, '星展': 3, '澳盛': 1, '一銀': 1, '玉山': 3}
# {'匯豐': 2, '花旗': 2, '國泰': 1, 'KOKO': 1}
# {}
# {}
# {'中信': 3, '花旗': 1}
# {}
# {'國泰': 1, '永豐': 1, '王道': 1}
# {}
# {}
# {'國泰': 1, 'KOKO': 8, '新光': 2}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 5}
# {'國泰': 1}
# {'國泰': 3, 'KOKO': 4}
# {'KOKO': 2, '國泰': 2}
# {'國泰': 5}
# {'國泰': 2, '中信': 3, '台新': 1}
# {'國泰': 2}
# {'國泰': 2}
# {'國泰': 2}
# {'華南': 1, '國泰': 1}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 2}
# {'國泰': 2}
# {'國泰': 4}
# {'國泰': 1}
# {'國泰': 3}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 2, '台新': 1, '富邦': 1}
# {'國泰': 2, 'KOKO': 5}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 5}
# {'國泰': 2, 'KOKO': 5}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 6}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 2, '台新': 1, '永豐': 1}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 2, 'KOKO': 1, '台新': 1, 'Richart': 2}
# {'國泰': 2, 'KOKO': 3}
# {'國泰': 3, 'KOKO': 3}
# {'國泰': 1, 'KOKO': 6, '中信': 1}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 4}
# {'國泰': 2}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 3, 'KOKO': 4}
# {'國泰': 2, 'KOKO': 3}
# {'國泰': 3}
# {'國泰': 3, '遠東商銀': 1}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 1}
# {'國泰': 7, '聯邦': 1}
# {'國泰': 1}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 3}
# {'國泰': 3}
# {'國泰': 2}
# {'國泰': 2, '花旗': 2}
# {'國泰': 1}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 3}
# {'國泰': 2}
# {}
# {'國泰': 2}
# {'國泰': 2, '花旗': 1}
# {'國泰': 3}
# {'國泰': 1}
# {'國泰': 4}
# {'國泰': 2}
# {'國泰': 1, '元大': 1}
# {'國泰': 1, '永豐': 2}
# {'國泰': 3}
# {'國泰': 2, '台新': 1}
# {'國泰': 2, '台新': 1}
# {'國泰': 3}
# {'國泰': 4, 'KOKO': 4}
# {'國泰': 1}
# {'國泰': 1}
# {'國泰': 3}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 2}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 1}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 2, 'KOKO': 3}
# {'國泰': 2, 'KOKO': 4}
# {'國泰': 2}
# {'國泰': 2, 'KOKO': 1, '台新': 1}
# {'國泰': 4}
# {'國泰': 3, 'KOKO': 9}
# {'國泰': 3, 'KOKO': 3, '永豐': 1, '台新': 1, 'Richart': 1}
# {'國泰': 3, 'KOKO': 5}
# {'國泰': 3}
# {'國泰': 2}
# {'國泰': 4, '花旗': 1}
# {'國泰': 4, '台新': 3}
# {'國泰': 2, '花旗': 2}
# {'國泰': 2}
# {'國泰': 3}
# {'國泰': 7, '花旗': 6}
# {'國泰': 2}
# {'國泰': 3}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 1}
# {'國泰': 1}
# {'國泰': 2}
# {'國泰': 1}
# {'國泰': 2, '中信': 1}
# {'國泰': 2, '匯豐': 1}
# {'國泰': 2, '星展': 2, '台新': 1}
# {'國泰': 2}
# {'國泰': 2}
# {'國泰': 2}
# {'國泰': 3}
# {'國泰': 1, '中信': 1}
# {'凱基': 1}
# {'凱基': 1, '兆豐': 1, '台新': 1, '玉山': 1}
# {}
# {'凱基': 2}
# {'花旗': 1, '渣打': 1, '匯豐': 1}
# {'中信': 1, '玉山': 1, '一銀': 1, '台新': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'元大': 1}
# {'遠東商銀': 3}
# {'玉山': 3}
# {'花旗': 7, '中信': 1}
# {'花旗': 4, '元大': 2}
# {}
# {'台新': 2}
# {'國泰': 1, '中信': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'元大': 3, '中信': 3}
# {'中信': 1}
# {}
# {'中信': 1}
# {'國泰': 1}
# {'中信': 3}
# {'花旗': 1}
# {}
# {'聯邦': 1}
# {'玉山': 2, '中信': 1, '台新': 2}
# {}
# {'中信': 2}
# {}
# {}
# {}
# {}
# {'永豐': 8, '中信': 1, '兆豐': 1}
# {'玉山': 2, '台新': 1}
# {'花旗': 2, '台新': 1}
# {'永豐': 1}
# {}
# {}
# {}
# {'臺灣銀行': 2}
# {'永豐': 1}
# {'永豐': 1}
# {}
# {}
# {}
# {'元大': 4}
# {'元大': 2}
# {}
# {'花旗': 1, '台新': 1}
# {'台新': 2}
# {}
# {}
# {}
# {'國泰': 1, '玉山': 1}
# {'Richart': 1, '華南': 1, '合作金庫': 1, '凱基': 1, '中信': 1}
# {'澳盛': 1}
# {'國泰': 2}
# {'花旗': 2}
# {'國泰': 1}
# {'國泰': 1}
# {}
# {'華南': 2}
# {}
# {'玉山': 1}
# {'中信': 2}
# {}
# {'國泰': 2, '玉山': 2, '中信': 2, '花旗': 1}
# {'KOKO': 1}
# {}
# {'凱基': 1}
# {'元大': 3}
# {'中信': 2}
# {}
# {'富邦': 1, 'Richart': 1, '中信': 1, '玉山': 3, '花旗': 1}
# {'土地': 1, '上海商銀': 2, '中信': 1, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 1, '台新': 1}
# {'玉山': 1, '中信': 2}
# {'台新': 1, '中信': 1, '華南': 1, '兆豐': 1}
# {'國泰': 1, 'KOKO': 1}
# {'華南': 4, '中信': 2}
# {'台新': 7, 'Richart': 1}
# {'台新': 7, 'Richart': 1}
# {'中信': 2, '花旗': 1}
# {'花旗': 2, '國泰': 3, 'KOKO': 2, '台新': 1, '玉山': 1, '兆豐': 1}
# {'玉山': 1}
# {}
# {'台新': 1}
# {'玉山': 3, '富邦': 1, '花旗': 1}
# {}
# {'玉山': 3, '中信': 1}
# {'中信': 3}
# {'中信': 1}
# {'中信': 1, '台新': 1, '一銀': 1, '國泰': 1, 'KOKO': 1}
# {'台新': 2}
# {'台新': 1, '國泰': 1, 'KOKO': 2, '華南': 1}
# {'富邦': 4}
# {'華南': 2}
# {}
# {'花旗': 1}
# {'KOKO': 3, '台新': 1, '國泰': 1, '華南': 1, '玉山': 1}
# {}
# {}
# {'兆豐': 1, '華南': 1, '中信': 1, '台新': 1}
# {}
# {'元大': 1, '渣打': 1, '匯豐': 1}
# {'元大': 1, '渣打': 1, '匯豐': 1}
# {'花旗': 1}
# {'台新': 1, '玉山': 4}
# {}
# {'玉山': 2, '國泰': 3, '中信': 1, 'KOKO': 1}
# {'富邦': 1}
# {'富邦': 2}
# {'富邦': 2}
# {'富邦': 2}
# {'富邦': 1}
# {'富邦': 3}
# {'富邦': 1}
# {'富邦': 1}
# {'富邦': 2}
# {'富邦': 4}
# {'富邦': 6}
# {'富邦': 3}
# {'富邦': 4, '陽信': 3, '永豐': 1, '台新': 1, '玉山': 2}
# {'富邦': 2}
# {'富邦': 2, '渣打': 1, '聯邦': 1, '中信': 1}
# {'富邦': 2}
# {'富邦': 3}
# {'富邦': 1}
# {'富邦': 3}
# {'富邦': 5, '國泰': 7, '元大': 2, '台新': 1, 'KOKO': 1}
# {'台新': 8, '富邦': 10}
# {'中信': 2, '富邦': 2}
# {}
# {'富邦': 2}
# {'富邦': 2}
# {}
# {}
# {'富邦': 1}
# {'富邦': 1}
# {'台新': 2}
# {'富邦': 2}
# {'富邦': 2}
# {'富邦': 1}
# {'富邦': 1}
# {'富邦': 1}
# {'富邦': 1}
# {'富邦': 2, '台新': 1}
# {'富邦': 1}
# {'富邦': 2, '玉山': 3}
# {'富邦': 2}
# {'富邦': 1}
# {'花旗': 1, '元大': 1, '國泰': 1}
# {'台新': 1}
# {'玉山': 4, 'KOKO': 2, '花旗': 2, '永豐': 1, '中信': 2, '富邦': 1, '一銀': 1, '華南': 2}
# {}
# {'花旗': 6, '星展': 6, '台新': 1, '國泰': 1}
# {}
# {'台新': 1, 'Richart': 1, '中信': 2, '玉山': 1, '元大': 1, '國泰': 1, 'KOKO': 1, '花旗': 1}
# {'聯邦': 1, '玉山': 1}
# {}
# {'中信': 5, '花旗': 4, '玉山': 4}
# {}
# {'玉山': 2, '一銀': 3, '花旗': 2, '國泰': 1, 'KOKO': 1, '台新': 1}
# {'台新': 1, 'Richart': 1}
# {'中信': 1, '華南': 1, '星展': 1, '花旗': 2}
# {'花旗': 1}
# {'玉山': 3}
# {'玉山': 2, '國泰': 1, '王道': 2}
# {'玉山': 4, '台新': 1, 'Richart': 2}
# {'玉山': 1, '台新': 1}
# {'KOKO': 4, '國泰': 2, '玉山': 2, 'Richart': 1, '王道': 1, '中信': 1}
# {'國泰': 2, 'KOKO': 1, '中信': 2, '渣打': 1}
# {'台新': 1}
# {'元大': 2}
# {'台新': 3, '玉山': 1, 'Richart': 1}
# {'台新': 1}
# {'花旗': 1}
# {'國泰': 2, '花旗': 1, '中信': 1}
# {}
# {}
# {}
# {'一銀': 1, '花旗': 1}
# {}
# {'華南': 1}
# {'玉山': 6, '台新': 5, 'Richart': 1, '兆豐': 1}
# {'中信': 1, '華南': 2}
# {}
# {'花旗': 1, '國泰': 1, 'Richart': 1, 'KOKO': 1, '中信': 2}
# {}
# {}
# {'台新': 1}
# {'花旗': 1, '中信': 1, '台新': 1, '渣打': 1}
# {'國泰': 1, '華南': 1, '兆豐': 1}
# {'一銀': 3, '永豐': 3, '國泰': 5, '遠東商銀': 1, '渣打': 1, 'KOKO': 1, '花旗': 2}
# {}
# {'玉山': 3, '合作金庫': 1, '華南': 3, 'KOKO': 1, '中信': 1, '元大': 1, '渣打': 1}
# {'玉山': 1}
# {'兆豐': 1, '永豐': 2, '星展': 1, '陽信': 1, '華南': 1, '元大': 1}
# {'玉山': 1}
# {'中信': 1}
# {'玉山': 2, '中信': 2}
# {}
# {'KOKO': 1}
# {'玉山': 3}
# {}
# {}
# {'王道': 1}
# {}
# {}
# {'渣打': 1, '台新': 1, '華南': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'富邦': 3}
# {'國泰': 1, '花旗': 2}
# {}
# {'台新': 1}
# {'聯邦': 2, 'KOKO': 1, '國泰': 2}
# {'玉山': 1}
# {}
# {}
# {}
# {'國泰': 1, '台新': 1}
# {}
# {'花旗': 2}
# {}
# {}
# {}
# {'台新': 1, '華南': 1}
# {'永豐': 1}
# {}
# {'花旗': 2, '中信': 1}
# {'中信': 1}
# {'花旗': 1, '元大': 1, '台新': 1, '玉山': 5, '永豐': 2, 'Richart': 1, '台中銀行': 2, '一銀': 2}
# {}
# {'凱基': 2, '台新': 1}
# {'玉山': 1}
# {}
# {'元大': 4}
# {'國泰': 1, '中信': 3, 'KOKO': 2}
# {}
# {'中信': 1, '聯邦': 2, '兆豐': 1}
# {'中信': 3}
# {'中信': 1}
# {'花旗': 1, '台新': 1, '元大': 1, '匯豐': 1}
# {'玉山': 1, '台新': 1, '國泰': 1, 'KOKO': 1, '華南': 1, '元大': 1, '匯豐': 1, '中信': 2}
# {'花旗': 2, '中信': 1}
# {}
# {'中信': 3}
# {'中信': 1}
# {'國泰': 1, 'KOKO': 7, '玉山': 2, '中信': 3}
# {'元大': 1, '玉山': 2}
# {'花旗': 2}
# {}
# {}
# {}
# {}
# {}
# {'永豐': 3, '花旗': 1}
# {'玉山': 3}
# {}
# {}
# {}
# {'中信': 1, '國泰': 1, 'KOKO': 1}
# {'元大': 2}
# {'台新': 1, 'Richart': 4, '華南': 2, '國泰': 4}
# {}
# {'日盛': 7}
# {'Richart': 1}
# {}
# {}
# {'渣打': 2}
# {'合作金庫': 1, '元大': 2}
# {}
# {}
# {'玉山': 2}
# {'KOKO': 1}
# {'台新': 1}
# {}
# {}
# {'國泰': 2}
# {}
# {'玉山': 1}
# {'中信': 2, 'KOKO': 1}
# {}
# {}
# {'聯邦': 1}
# {'花旗': 2}
# {'玉山': 3}
# {}
# {'中信': 3}
# {'Richart': 1, '台新': 1}
# {'花旗': 2}
# {'星展': 1, '匯豐': 1, '渣打': 1, '中信': 1, '台新': 1, '國泰': 1, 'KOKO': 1, '新光': 1, '玉山': 1}
# {}
# {}
# {'花旗': 2, '渣打': 1}
# {'花旗': 1, '玉山': 1, '富邦': 1, '兆豐': 1}
# {'玉山': 1}
# {'國泰': 2}
# {}
# {'中信': 1}
# {'國泰': 1}
# {'花旗': 1}
# {'中信': 2}
# {'元大': 1}
# {'玉山': 6}
# {'中信': 4}
# {'中信': 2}
# {'台新': 1}
# {}
# {}
# {}
# {'新光': 2}
# {'新光': 1}
# {'新光': 2}
# {'新光': 3, '花旗': 2}
# {'新光': 1}
# {'元大': 1}
# {'元大': 1, '國泰': 1, '渣打': 1, '花旗': 1, '星展': 1}
# {'台新': 1, '星展': 1}
# {'兆豐': 1}
# {}
# {'中信': 2, '富邦': 2, '元大': 1, '匯豐': 4, '永豐': 2, '台新': 4, '國泰': 2, '花旗': 2, 'KOKO': 1}
# {'玉山': 3}
# {'一銀': 1}
# {'KOKO': 1}
# {}
# {'一銀': 1}
# {'玉山': 1}
# {'國泰': 1, '匯豐': 1, '元大': 2, '台新': 1}
# {}
# {}
# {'台新': 1, 'Richart': 12}
# {'國泰': 2, 'KOKO': 3, '兆豐': 3, '台新': 1, 'Richart': 1, '渣打': 1}
# {'玉山': 1, '元大': 1, '星展': 1}
# {}
# {}
# {'KOKO': 5, '國泰': 2, '渣打': 3, '王道': 3}
# {'中信': 2}
# {'玉山': 1, '中信': 2, '元大': 1}
# {'Richart': 1, '玉山': 1, '台新': 1, '國泰': 1, 'KOKO': 1}
# {'台新': 1, '永豐': 2}
# {}
# {'玉山': 1}
# {'花旗': 1, '元大': 1}
# {'一銀': 3}
# {}
# {}
# {}
# {}
# {'中信': 1}
# {'匯豐': 3, '元大': 2}
# {'華南': 1}
# {'中信': 2, '元大': 1}
# {'華南': 5, '玉山': 2}
# {'台新': 3, '聯邦': 2, '華南': 2}
# {'元大': 7}
# {'元大': 1}
# {'花旗': 1, '元大': 1}
# {}
# {'華南': 6, '花旗': 2, '永豐': 1}
# {'元大': 2}
# {'中信': 4, '元大': 1}
# {}
# {'元大': 1, '中信': 1}
# {}
# {'永豐': 4, '富邦': 1, '玉山': 2}
# {'日盛': 3}
# {}
# {'台新': 3, '玉山': 1}
# {}
# {}
# {}
# {}
# {'華南': 2}
# {'國泰': 1, '台新': 2}
# {}
# {}
# {'聯邦': 1}
# {'台新': 1}
# {}
# {'星展': 5, '玉山': 1, '一銀': 1}
# {'星展': 2}
# {'星展': 5, '花旗': 2}
# {'星展': 2}
# {'星展': 2}
# {'星展': 2, '元大': 2, '澳盛': 1, '台新': 1}
# {'星展': 2, '富邦': 1, '匯豐': 1, '渣打': 1, '中信': 1}
# {'星展': 2}
# {'星展': 1}
# {'星展': 2}
# {'星展': 2}
# {'星展': 2}
# {'星展': 9, '玉山': 5, '聯邦': 1, '花旗': 2, '國泰': 1}
# {'星展': 1}
# {'星展': 3}
# {'星展': 3, '澳盛': 2}
# {'星展': 3, '中信': 2}
# {'星展': 3, '花旗': 2}
# {'星展': 2}
# {'星展': 2}
# {'聯邦': 3, '台新': 1}
# {}
# {}
# {}
# {'富邦': 1, '花旗': 1, '台新': 1, '中信': 2}
# {'玉山': 1, '國泰': 1, '中信': 1}
# {'台新': 1}
# {}
# {}
# {'永豐': 1, '玉山': 1}
# {'KOKO': 2, '星展': 5, '富邦': 4, '渣打': 3, '元大': 1, '台新': 1, '聯邦': 1}
# {'玉山': 2, 'KOKO': 1}
# {'渣打': 4}
# {}
# {'富邦': 1, '台新': 1, '玉山': 1, '國泰': 1, 'KOKO': 1, '中信': 1}
# {'聯邦': 2}
# {'台新': 5, '華南': 1, '聯邦': 1}
# {'澳盛': 1, '星展': 1}
# {'KOKO': 3, '台新': 1}
# {'台新': 2}
# {}
# {'台新': 2}
# {}
# {'台新': 2}
# {'一銀': 2}
# {}
# {'渣打': 12, 'Richart': 2, '台新': 8}
# {'玉山': 3}
# {}
# {}
# {'台新': 1, '花旗': 1, '富邦': 1}
# {'中信': 2, '國泰': 1}
# {'中信': 1}
# {'花旗': 1}
# {'中信': 1}
# {'台新': 1}
# {}
# {'華南': 1}
# {'彰化': 4, '中信': 1, '國泰': 1, '花旗': 1}
# {'中信': 1, '華南': 1}
# {'富邦': 2}
# {'永豐': 3}
# {'澳盛': 2}
# {}
# {}
# {'玉山': 1, '國泰': 2, 'KOKO': 2, '富邦': 1, '台新': 1}
# {'玉山': 2, '中信': 2}
# {'澳盛': 2}
# {'國泰': 3, '台新': 1}
# {'KOKO': 1}
# {'KOKO': 3, '國泰': 1}
# {'花旗': 1}
# {'中信': 3}
# {}
# {}
# {}
# {'元大': 1}
# {'渣打': 3, '玉山': 2, '兆豐': 3}
# {}
# {}
# {}
# {'玉山': 3, '新光': 2, '台新': 1}
# {'花旗': 4, '台新': 1, '國泰': 2, '玉山': 2, 'KOKO': 1}
# {'花旗': 5}
# {}
# {'凱基': 1}
# {'花旗': 2}
# {}
# {}
# {'陽信': 4, '華南': 1}
# {'KOKO': 3}
# {'中信': 5, '元大': 5}
# {'花旗': 1}
# {'台新': 1, '兆豐': 1, '玉山': 1}
# {}
# {'KOKO': 2}
# {}
# {'中信': 1}
# {'玉山': 1}
# {'聯邦': 1, '台新': 1, '凱基': 1, '花旗': 1}
# {'花旗': 1, '元大': 1, '國泰': 1}
# {'台新': 2, '國泰': 1, 'KOKO': 1, '兆豐': 1}
# {}
# {'台新': 1, 'KOKO': 1, '國泰': 1, '玉山': 1, '永豐': 1, '華南': 1, '兆豐': 1, '富邦': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'玉山': 1, '中信': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Richart': 1}
# {}
# {}
# {}
# {'華南': 2}
# {}
# {}
# {}
# {'國泰': 1, 'KOKO': 1}
# {}
# {}
# {}
# {'花旗': 1, '中信': 1, '國泰': 1, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {'元大': 1, '富邦': 1}
# {}
# {}
# {'台新': 1}
# {'渣打': 2}
# {}
# {'凱基': 1, '中信': 1}
# {'匯豐': 1}
# {'中信': 1}
# {'永豐': 1}
# {}
# {}
# {}
# {'中信': 2, '玉山': 1}
# {'星展': 1}
# {'中信': 1}
# {'匯豐': 3}
# {'玉山': 1, '兆豐': 1}
# {'中信': 1, '玉山': 1}
# {}
# {'台新': 1, '花旗': 1, '兆豐': 1}
# {'中信': 1, '台新': 1, '花旗': 1, '華南': 2}
# {'星展': 2, '中信': 4, '聯邦': 1, '元大': 3}
# {'王道': 4, '匯豐': 2}
# {'花旗': 1, '華南': 1, '元大': 1}
# {'凱基': 1, '元大': 7}
# {}
# {}
# {'花旗': 1, '土地': 1}
# {'花旗': 1}
# {'永豐': 2, '上海商銀': 1}
# {'永豐': 2}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 2}
# {'永豐': 2}
# {'永豐': 2}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 3}
# {'永豐': 3}
# {'永豐': 2}
# {'永豐': 3}
# {'永豐': 1}
# {'永豐': 2}
# {'永豐': 3}
# {'永豐': 2}
# {'永豐': 2}
# {'永豐': 2, '富邦': 1, '元大': 1, '國泰': 1, 'KOKO': 1, '台新': 1}
# {'永豐': 1}
# {'永豐': 3}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 4, '玉山': 3}
# {'永豐': 2}
# {'永豐': 1}
# {'永豐': 2}
# {'永豐': 2}
# {'永豐': 2, '玉山': 2, '台新': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 3}
# {'永豐': 2}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1, '富邦': 1}
# {'永豐': 2}
# {'永豐': 3}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 2}
# {'永豐': 4}
# {'永豐': 2, '富邦': 1}
# {'永豐': 1}
# {'永豐': 1}
# {'永豐': 4}
# {'永豐': 4}
# {'永豐': 3}
# {'台新': 7, '遠東商銀': 2, '中信': 1, '元大': 2}
# {}
# {'國泰': 1}
# {'華南': 1, '富邦': 1, '元大': 1, '花旗': 1, '國泰': 1, 'KOKO': 1, '台新': 1}
# {'玉山': 2}
# {}
# {}
# {'花旗': 7}
# {'台新': 2}
# {}
# {'花旗': 2}
# {'中信': 1, '王道': 1}
# {'元大': 2}
# {'國泰': 4, 'KOKO': 1, '台新': 1}
# {}
# {}
# {}
# {'KOKO': 1, '元大': 2, '上海商銀': 1, '一銀': 1}
# {}
# {'台新': 1, '富邦': 1, '中信': 1}
# {'國泰': 2, '台新': 2, 'Richart': 1, '中信': 1}
# {'花旗': 1, '星展': 4, '匯豐': 2}
# {}
# {'元大': 3, '華南': 3, '陽信': 2, '凱基': 3}
# {}
# {}
# {'富邦': 1}
# {'中信': 3}
# {'上海商銀': 1, '台新': 1, 'Richart': 1}
# {'元大': 1}
# {'花旗': 1, '永豐': 1, '台新': 2}
# {'元大': 2}
# {'永豐': 4, '台新': 1, '國泰': 1, '星展': 1, '匯豐': 1}
# {'凱基': 2}
# {'中信': 1}
# {'華南': 1, '元大': 1}
# {}
# {'台新': 3, '中信': 1, '玉山': 1, 'Richart': 1, '元大': 2}
# {}
# {}
# {'日盛': 1, '中信': 2, '富邦': 3, '國泰': 1, 'KOKO': 1, '玉山': 3, '台新': 3}
# {'KOKO': 1}
# {'玉山': 2}
# {'國泰': 1, 'KOKO': 2, '玉山': 1}
# {'中信': 1, '國泰': 1, '玉山': 1, '花旗': 1, '華南': 2}
# {'渣打': 2}
# {'國泰': 1, 'KOKO': 1}
# {}
# {}
# {'臺灣銀行': 1, '華南': 1}
# {'渣打': 3}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 3}
# {'渣打': 3}
# {'渣打': 7, '台新': 2, '匯豐': 1}
# {'渣打': 3}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 2, '土地': 1}
# {'渣打': 2}
# {'渣打': 1}
# {'渣打': 2}
# {'渣打': 3}
# {'渣打': 3}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 1}
# {'渣打': 1}
# {'渣打': 1}
# {'渣打': 2}
# {'渣打': 3}
# {'渣打': 2, '兆豐': 1}
# {'渣打': 1}
# {'渣打': 3, 'KOKO': 2}
# {'渣打': 1}
# {'渣打': 1}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 4}
# {'渣打': 2}
# {'渣打': 4}
# {'渣打': 3, '花旗': 1}
# {'渣打': 1}
# {'渣打': 1}
# {'渣打': 4, 'KOKO': 1, 'Richart': 1}
# {'渣打': 2, '中信': 1, '富邦': 1}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 3}
# {'渣打': 1}
# {'渣打': 2}
# {'渣打': 4}
# {'渣打': 3}
# {'渣打': 2}
# {'渣打': 2}
# {}
# {}
# {}
# {}
# {'花旗': 1}
# {}
# {'玉山': 1}
# {}
# {'澳盛': 3, '星展': 4}
# {'澳盛': 1, '台新': 3}
# {'澳盛': 2, '星展': 1}
# {'澳盛': 1}
# {'澳盛': 2}
# {}
# {'澳盛': 2, '星展': 1}
# {'澳盛': 5, '星展': 4}
# {'澳盛': 2, '星展': 2}
# {'澳盛': 2, '星展': 4}
# {'澳盛': 2, '星展': 1, '國泰': 1}
# {'澳盛': 3}
# {'台新': 2, '國泰': 3}
# {}
# {}
# {}
# {'台新': 1, '國泰': 1, '匯豐': 1}
# {'台新': 2, 'Richart': 1, '花旗': 1, '富邦': 1, '元大': 1, '兆豐': 2, '渣打': 1}
# {'Richart': 2, '元大': 1, '台新': 1}
# {'台新': 6}
# {}
# {'華南': 4}
# {}
# {'台新': 2, '華南': 3, '一銀': 1, '元大': 1, '富邦': 1, '兆豐': 1}
# {}
# {'中信': 1, '星展': 3, '澳盛': 1, '花旗': 3, '聯邦': 2, '國泰': 1, '富邦': 1}
# {'台新': 3, '花旗': 1, '國泰': 1}
# {'國泰': 1, '玉山': 3, '華南': 2}
# {'台新': 1, '國泰': 1, 'KOKO': 1, '中信': 1}
# {'中信': 1, '兆豐': 2, '永豐': 1}
# {'中信': 4}
# {'玉山': 2}
# {'花旗': 2, '華南': 1, '元大': 3, '中信': 1, '台新': 4, 'KOKO': 3, '國泰': 1, 'Richart': 1, '富邦': 1}
# {'玉山': 1, '台新': 1}
# {}
# {}
# {}
# {}
# {'花旗': 3}
# {'玉山': 1}
# {'台新': 6, '中信': 3}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 5}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 2, '新光': 4}
# {'玉山': 2}
# {'玉山': 8}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 4}
# {'玉山': 4}
# {'玉山': 1}
# {'玉山': 2, '國泰': 1, 'KOKO': 1, '永豐': 1}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 7}
# {'玉山': 2}
# {'玉山': 2, 'KOKO': 2}
# {'玉山': 2}
# {'玉山': 1, '富邦': 2}
# {'玉山': 6, '中信': 2}
# {'玉山': 1}
# {'玉山': 1, '星展': 2}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 2, '中信': 2, '渣打': 2, 'KOKO': 1}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 5}
# {'玉山': 1, '富邦': 3}
# {'玉山': 2}
# {'玉山': 3, '台新': 1, '華南': 3, '富邦': 2, '元大': 2}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 4}
# {'玉山': 1, '富邦': 2}
# {'玉山': 4, '富邦': 2}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1, 'Richart': 1}
# {'玉山': 4, '台新': 4, '華南': 1, '國泰': 1, 'KOKO': 1, '兆豐': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 4}
# {'玉山': 2, '台新': 1}
# {'玉山': 3}
# {'玉山': 3}
# {'玉山': 2, '台新': 2, 'Richart': 1}
# {'玉山': 4}
# {'玉山': 1}
# {'玉山': 1, 'KOKO': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 2, '花旗': 1}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 3}
# {'玉山': 6}
# {}
# {}
# {'玉山': 1}
# {}
# {'玉山': 3}
# {'玉山': 2, '台新': 2, '中信': 2}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 6}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 6}
# {'玉山': 2}
# {'玉山': 1, '臺灣銀行': 1, '中信': 2}
# {'玉山': 3}
# {'玉山': 2, '國泰': 1, 'KOKO': 1, '富邦': 1, '渣打': 1, '星展': 1, '台新': 1}
# {'玉山': 1}
# {'玉山': 3}
# {'玉山': 1, 'KOKO': 1}
# {'玉山': 2}
# {'玉山': 4}
# {'玉山': 2}
# {'玉山': 6}
# {'玉山': 4}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 3, '台新': 1}
# {'玉山': 3, '中信': 1}
# {'玉山': 2}
# {'玉山': 6}
# {'玉山': 1}
# {'玉山': 5}
# {'玉山': 2, '聯邦': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 4}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 8, '國泰': 1, '兆豐': 1, '中信': 1}
# {'玉山': 4, '王道': 1}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 4}
# {'玉山': 6}
# {'玉山': 4}
# {'玉山': 4}
# {'玉山': 6}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 5}
# {'玉山': 2, '富邦': 1}
# {'玉山': 1}
# {'玉山': 3}
# {'玉山': 3}
# {'玉山': 4, '國泰': 1}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 3}
# {'玉山': 2}
# {}
# {'王道': 1}
# {'王道': 3, '元大': 1}
# {}
# {'華南': 1, '合作金庫': 1}
# {}
# {}
# {'KOKO': 2}
# {'渣打': 1}
# {'花旗': 2, '國泰': 1, '元大': 1, '台新': 3, '中信': 2, '匯豐': 1, 'Richart': 1}
# {'兆豐': 2, '玉山': 1, '台新': 1}
# {'國泰': 1, 'KOKO': 1, '台新': 1, 'Richart': 1, '富邦': 1, '元大': 2, '華南': 1, '匯豐': 3, '渣打': 3, '中信': 1, '新光': 1}
# {'匯豐': 2, '渣打': 2}
# {}
# {'富邦': 1}
# {'台新': 1, 'Richart': 1}
# {'玉山': 1}
# {'中信': 1, '玉山': 1}
# {}
# {'Richart': 2, '星展': 3, '國泰': 1}
# {'Richart': 5, '國泰': 2, '中信': 1}
# {}
# {}
# {'台新': 2, '國泰': 3}
# {}
# {'中信': 3}
# {'中信': 4, '台新': 3, '花旗': 4, '元大': 1, '富邦': 1, '國泰': 1, '澳盛': 2}
# {'匯豐': 1}
# {'國泰': 2}
# {'澳盛': 1}
# {'新光': 3, '中信': 1, '玉山': 1}
# {'渣打': 2}
# {'花旗': 2}
# {'華南': 3}
# {}
# {}
# {'永豐': 1}
# {'星展': 3, '澳盛': 1, '匯豐': 2, '王道': 1}
# {'玉山': 2}
# {'花旗': 1}
# {'花旗': 5}
# {}
# {'花旗': 2, '國泰': 1}
# {'渣打': 2}
# {'花旗': 2, '台新': 2}
# {'中信': 1}
# {'台新': 2}
# {}
# {}
# {}
# {'中信': 1}
# {'新光': 1, '花旗': 2, '富邦': 2, '星展': 4, '台新': 3, '玉山': 3}
# {'台新': 1}
# {'匯豐': 1, '澳盛': 1, '玉山': 1, '聯邦': 1, '中信': 3, '華南': 1}
# {'新光': 1, '台新': 1, '國泰': 1, '聯邦': 1}
# {'國泰': 1}
# {}
# {}
# {'中信': 1}
# {'KOKO': 1}
# {'台新': 2, 'Richart': 2}
# {'台新': 1, '國泰': 1}
# {'凱基': 3, '華南': 3}
# {'中信': 7}
# {'花旗': 2}
# {}
# {'元大': 1}
# {}
# {}
# {'KOKO': 1}
# {'國泰': 2, '一銀': 2, '玉山': 1}
# {'國泰': 2}
# {'花旗': 2, '玉山': 2, '中信': 1, '星展': 1}
# {'一銀': 3}
# {'一銀': 2}
# {'一銀': 1}
# {'一銀': 4, '中信': 1}
# {}
# {'台新': 1, '玉山': 2, '永豐': 1}
# {}
# {'元大': 1, '永豐': 1, '華南': 1, '台新': 1, '國泰': 1, 'KOKO': 2, '兆豐': 1}
# {'華南': 1, '花旗': 1}
# {}
# {}
# {}
# {'國泰': 2, '中信': 2, '台新': 2}
# {}
# {}
# {'花旗': 1}
# {}
# {'中信': 1}
# {'花旗': 1}
# {'國泰': 5, '台新': 1}
# {}
# {'玉山': 2, '國泰': 1, '中信': 2}
# {'玉山': 1, '中信': 1, '土地': 1, '富邦': 1}
# {'玉山': 1}
# {'台新': 1, '華南': 1, '玉山': 1}
# {'花旗': 1, '國泰': 1, '玉山': 2}
# {'台新': 1, 'Richart': 1, '一銀': 1, '凱基': 1}
# {'國泰': 1, 'KOKO': 1, '台新': 1}
# {'富邦': 2}
# {}
# {'合作金庫': 13, '華南': 12, '兆豐': 13, '富邦': 1}
# {}
# {}
# {'永豐': 1}
# {}
# {}
# {}
# {}
# {'兆豐': 2}
# {'匯豐': 4, '台新': 4, '富邦': 3, '玉山': 2, '華南': 1, '元大': 1}
# {'玉山': 3}
# {}
# {}
# {'國泰': 2}
# {}
# {'兆豐': 1}
# {'兆豐': 2, '華南': 1}
# {'台新': 1, 'Richart': 1}
# {'花旗': 1}
# {'KOKO': 1}
# {'兆豐': 1, '匯豐': 1, '永豐': 1}
# {'華南': 1}
# {}
# {}
# {'花旗': 2, '元大': 1}
# {'台新': 1, 'Richart': 2}
# {'玉山': 1}
# {}
# {}
# {}
# {}
# {}
# {'元大': 4}
# {'玉山': 1, '元大': 1, '台新': 1, '中信': 1, '花旗': 1, '渣打': 1}
# {}
# {}
# {'Richart': 1}
# {'元大': 2, 'KOKO': 1, '兆豐': 1, '中信': 1}
# {'國泰': 1, '中信': 2}
# {'中信': 1}
# {}
# {}
# {}
# {}
# {'中信': 2, '國泰': 2}
# {}
# {}
# {}
# {}
# {}
# {'華泰': 1}
# {'中信': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'玉山': 1}
# {}
# {'花旗': 5}
# {}
# {'中信': 1, '聯邦': 1, '彰化': 1, '兆豐': 1, '王道': 1, '匯豐': 2, '華南': 2, '永豐': 1}
# {}
# {}
# {}
# {'玉山': 1}
# {'元大': 4, '匯豐': 5, '中信': 2}
# {'合作金庫': 2, '花旗': 1}
# {}
# {}
# {'國泰': 1}
# {'花旗': 1, '聯邦': 1, '元大': 1, '合作金庫': 1, '中信': 1, '國泰': 1, '玉山': 1, '兆豐': 1}
# {'中信': 4, '國泰': 1, 'KOKO': 8}
# {'星展': 1, '兆豐': 1}
# {}
# {}
# {}
# {'永豐': 4, '中信': 1}
# {'聯邦': 4}
# {'聯邦': 1}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 1}
# {'聯邦': 3, '中信': 1}
# {'聯邦': 4}
# {'聯邦': 2}
# {'聯邦': 3}
# {'聯邦': 3}
# {'聯邦': 3, 'KOKO': 2, '富邦': 1}
# {'聯邦': 1}
# {'聯邦': 2}
# {'聯邦': 2, '中信': 1}
# {'聯邦': 2, '元大': 1, '華南': 1}
# {'聯邦': 1}
# {'聯邦': 3}
# {'聯邦': 2}
# {'聯邦': 1}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 3}
# {'聯邦': 3, '中信': 1}
# {'聯邦': 4, '花旗': 1, '元大': 1}
# {'聯邦': 3}
# {'聯邦': 3}
# {'聯邦': 2}
# {'聯邦': 1}
# {'聯邦': 3}
# {'聯邦': 4, '元大': 1}
# {'聯邦': 4}
# {'聯邦': 4}
# {}
# {'台新': 4, '華南': 2, '永豐': 1, '王道': 4, '元大': 1, '匯豐': 1}
# {}
# {'中信': 1}
# {'富邦': 1}
# {'台新': 1}
# {}
# {'元大': 1}
# {'元大': 1}
# {}
# {'台新': 2, '聯邦': 1, '玉山': 1}
# {'聯邦': 1, '花旗': 1, '台新': 1}
# {'花旗': 1}
# {'台新': 3, '上海商銀': 1, '玉山': 1, '中信': 1}
# {'富邦': 2, '聯邦': 1}
# {'國泰': 2, '花旗': 1}
# {}
# {}
# {'臺灣銀行': 1, '富邦': 1}
# {}
# {'華南': 9, '玉山': 7, '富邦': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 4, '中信': 3}
# {'花旗': 1}
# {'花旗': 4, '永豐': 1, '華南': 1}
# {'花旗': 1}
# {'花旗': 5}
# {'花旗': 4}
# {'花旗': 3, '中信': 1}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 4}
# {'花旗': 4}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 3, '國泰': 2}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 3, '王道': 1}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 1}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 6}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 4}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 5, '玉山': 1, '台新': 1, '渣打': 1}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 4}
# {'花旗': 2, '台新': 2, '中信': 1, '國泰': 1}
# {'花旗': 4}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 5, '台新': 1}
# {'花旗': 4}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 2, '星展': 3}
# {'花旗': 1}
# {'花旗': 1}
# {'花旗': 5}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 4}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 4}
# {'花旗': 3}
# {'花旗': 6}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 1, '一銀': 1, '富邦': 1}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 5, '中信': 1}
# {'花旗': 2}
# {'花旗': 6}
# {'聯邦': 1}
# {'花旗': 2}
# {'花旗': 2, '元大': 1, '富邦': 1}
# {'花旗': 5, '國泰': 1}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 2, '玉山': 1}
# {'花旗': 2}
# {'花旗': 5}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 7}
# {'花旗': 2}
# {'花旗': 4}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 5, '兆豐': 1}
# {'花旗': 2}
# {'花旗': 2, '玉山': 1, '中信': 1}
# {'花旗': 4, '台新': 1}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 3, '中信': 1, '台新': 1, '國泰': 5, '元大': 1}
# {'花旗': 1}
# {'花旗': 7}
# {'花旗': 2}
# {'花旗': 3, '國泰': 2, '台新': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 4}
# {'花旗': 2}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 1}
# {'花旗': 1}
# {'兆豐': 2}
# {'國泰': 2}
# {}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 4}
# {'華南': 4, '臺灣銀行': 1}
# {'華南': 2}
# {'華南': 3}
# {'華南': 3}
# {'華南': 3, '富邦': 1}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 1}
# {'華南': 3, '兆豐': 1}
# {'華南': 2}
# {'華南': 2, '台新': 1, '元大': 2}
# {'華南': 5}
# {'華南': 2}
# {'華南': 1, '合作金庫': 1}
# {'華南': 1}
# {'華南': 2}
# {'華南': 3}
# {'華南': 1}
# {'華南': 1}
# {'華南': 5, '聯邦': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 2}
# {'華南': 1}
# {'華南': 3}
# {'華南': 2}
# {'華南': 3}
# {'華南': 3, '國泰': 1}
# {'華南': 4}
# {'玉山': 1}
# {'國泰': 1}
# {'中信': 2}
# {'兆豐': 3}
# {'玉山': 2, 'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {'中信': 1, '玉山': 1}
# {}
# {'台新': 1, '玉山': 1, '花旗': 1}
# {'永豐': 1}
# {'台新': 2}
# {}
# {}
# {'KOKO': 2}
# {}
# {'聯邦': 3}
# {}
# {'華南': 2, '渣打': 1}
# {'Richart': 1}
# {'中信': 4}
# {'華南': 3}
# {'玉山': 3}
# {'台新': 2, '王道': 1, '玉山': 1, '兆豐': 1, '中信': 2}
# {'KOKO': 1, '元大': 2}
# {'台新': 2}
# {}
# {'澳盛': 1, '星展': 2}
# {'台新': 1}
# {'新光': 1}
# {}
# {}
# {'中信': 2}
# {}
# {}
# {}
# {}
# {'玉山': 1}
# {'中信': 1, '玉山': 1}
# {'中信': 3}
# {'花旗': 1}
# {'中信': 1}
# {}
# {}
# {}
# {'聯邦': 1, '渣打': 2, '中信': 1}
# {'KOKO': 1, '富邦': 1, '台新': 2, 'Richart': 1, '中信': 1, '元大': 1, '花旗': 1, '匯豐': 1, '國泰': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'華南': 1}
# {'KOKO': 1}
# {'KOKO': 3, 'Richart': 1}
# {'KOKO': 2}
# {'KOKO': 1}
# {}
# {'華南': 1}
# {'中信': 2}
# {'凱基': 2}
# {'KOKO': 4}
# {}
# {'Richart': 2, '台新': 3}
# {'Richart': 3, '台新': 4}
# {}
# {}
# {'玉山': 3, '台新': 1, '新光': 1, '中信': 1}
# {'台新': 1, '富邦': 2}
# {'富邦': 2}
# {'中信': 3}
# {'中信': 3}
# {'中信': 3, '台新': 3, '華南': 3}
# {'中信': 2}
# {'台新': 1}
# {'富邦': 3, 'Richart': 1, '台新': 2, '中信': 1, '玉山': 1}
# {}
# {'華南': 1}
# {'玉山': 3}
# {}
# {'國泰': 3}
# {}
# {'國泰': 1}
# {'國泰': 1, '台新': 1}
# {'玉山': 4}
# {}
# {'元大': 4, '富邦': 1}
# {}
# {'元大': 3}
# {}
# {'兆豐': 3}
# {'兆豐': 2}
# {}
# {'玉山': 1}
# {'華南': 1, '國泰': 2, '玉山': 2, 'KOKO': 1, '中信': 1}
# {'玉山': 1, '合作金庫': 1, '花旗': 1}
# {'玉山': 1}
# {'中信': 2, '花旗': 2, '玉山': 3}
# {'國泰': 1, 'KOKO': 2}
# {}
# {'台新': 1}
# {'台新': 1, '國泰': 1}
# {'台新': 1}
# {}
# {'合作金庫': 3}
# {}
# {}
# {'王道': 1, '華南': 1}
# {'中信': 1}
# {'國泰': 3}
# {'國泰': 5}
# {'國泰': 1, 'KOKO': 1, '花旗': 1, '台新': 1}
# {'國泰': 2, 'KOKO': 2, '新光': 2}
# {}
# {'渣打': 1}
# {'聯邦': 2}
# {'中信': 2}
# {'玉山': 3, '中信': 2, '兆豐': 1, '花旗': 1}
# {'玉山': 1}
# {}
# {'玉山': 1, '華南': 1, '中信': 1, '渣打': 1, '台新': 1, '國泰': 2, 'KOKO': 1}
# {'中信': 1, '國泰': 1}
# {'富邦': 2}
# {'富邦': 3, '國泰': 1}
# {}
# {}
# {}
# {'永豐': 1}
# {'玉山': 3}
# {'星展': 7}
# {'星展': 2, '澳盛': 1}
# {'玉山': 1}
# {'台新': 3, '聯邦': 1, '國泰': 2, '花旗': 1, '中信': 1}
# {}
# {}
# {'富邦': 1}
# {'匯豐': 3}
# {'KOKO': 2}
# {'聯邦': 3}
# {}
# {}
# {}
# {'玉山': 2}
# {'中信': 1, '永豐': 1, '玉山': 1, '花旗': 1, '一銀': 1}
# {'花旗': 1}
# {'永豐': 2}
# {}
# {'渣打': 4}
# {'澳盛': 2, '星展': 3}
# {}
# {'台新': 2, '富邦': 2}
# {}
# {}
# {'玉山': 1}
# {'玉山': 4}
# {'玉山': 2}
# {'玉山': 3}
# {'玉山': 5}
# {'玉山': 4}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 3}
# {}
# {'兆豐': 2, 'KOKO': 1}
# {'玉山': 1, '華南': 2, '匯豐': 1, '渣打': 1, '國泰': 1, '新光': 1}
# {}
# {'台新': 1, '聯邦': 1}
# {'聯邦': 1}
# {'玉山': 1, '富邦': 1, '國泰': 1, '中信': 1, '花旗': 1}
# {'匯豐': 1, '中信': 1}
# {}
# {'兆豐': 1}
# {'台新': 1}
# {}
# {'台新': 1, '中信': 1}
# {'花旗': 4, '國泰': 1}
# {}
# {'玉山': 2}
# {'聯邦': 2}
# {'聯邦': 2, '中信': 1}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 2}
# {'華南': 2, '新光': 2}
# {'中信': 1, '台新': 1}
# {}
# {'花旗': 2}
# {'KOKO': 3, '國泰': 4}
# {'中信': 1, '玉山': 1, '澳盛': 1}
# {}
# {'台新': 2}
# {'中信': 1}
# {'台新': 1, 'Richart': 1}
# {'中信': 1, '玉山': 1}
# {'匯豐': 2}
# {'KOKO': 4, '中信': 1, '國泰': 1}
# {'玉山': 1}
# {}
# {}
# {'花旗': 3}
# {'台新': 1}
# {'國泰': 1}
# {}
# {}
# {'中信': 6, '新光': 3}
# {'華南': 1}
# {'花旗': 3}
# {}
# {}
# {'凱基': 3, '國泰': 4, '渣打': 1, '中信': 1}
# {}
# {}
# {}
# {'玉山': 2}
# {'花旗': 1}
# {'新光': 1, '台新': 5, '中信': 2, '富邦': 6, '玉山': 2, '渣打': 1, '國泰': 1, 'KOKO': 1, '聯邦': 1, '遠東商銀': 1, '華南': 1, '花旗': 1, '凱基': 1, '華泰': 1}
# {'中信': 3, '花旗': 1, '國泰': 1}
# {'國泰': 2}
# {'中信': 1, '國泰': 1}
# {}
# {'花旗': 2, '中信': 2, '國泰': 1, 'KOKO': 1, '台新': 2, '聯邦': 1}
# {'中信': 1}
# {}
# {}
# {}
# {'玉山': 4}
# {}
# {'合作金庫': 5, '台新': 1, 'Richart': 1, '花旗': 3, '玉山': 2}
# {'玉山': 1}
# {'中信': 1, '聯邦': 1, '玉山': 3, '國泰': 2}
# {'中信': 2}
# {'花旗': 4, '玉山': 2, '中信': 4}
# {'玉山': 1}
# {}
# {'花旗': 1, '匯豐': 1}
# {'花旗': 1, '土地': 1, '台新': 1, '中信': 1}
# {'中信': 4, '國泰': 2, '花旗': 7, '玉山': 10, '遠東商銀': 1, '台新': 8, '新光': 2, '彰化': 1, '兆豐': 3, '富邦': 1, '一銀': 1, 'Richart': 3, 'KOKO': 1}
# {'玉山': 1, '花旗': 1}
# {}
# {'台新': 1}
# {'國泰': 3}
# {}
# {'Richart': 2, '台新': 1, '中信': 1}
# {}
# {'台新': 1}
# {}
# {'台新': 1, '中信': 1}
# {'兆豐': 1}
# {}
# {}
# {}
# {'玉山': 4, '國泰': 2, '台新': 1}
# {}
# {}
# {'玉山': 1}
# {}
# {'永豐': 1, '台新': 1}
# {'國泰': 1, 'KOKO': 1}
# {'永豐': 1, '國泰': 1}
# {'KOKO': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'國泰': 1, 'KOKO': 2, '兆豐': 1}
# {}
# {'國泰': 1, 'KOKO': 1}
# {'花旗': 1}
# {'渣打': 1, '元大': 2, 'KOKO': 1, '華南': 1}
# {}
# {}
# {'兆豐': 3, '華南': 3, 'KOKO': 2, '台新': 1, '富邦': 4, '中信': 1, '渣打': 1, '星展': 1}
# {'花旗': 1}
# {'中信': 4, '台新': 2, '國泰': 1, '合作金庫': 1}
# {'KOKO': 2, '中信': 1}
# {}
# {'中信': 1, '華南': 1}
# {}
# {'玉山': 1}
# {'聯邦': 2, '一銀': 1, '華南': 1, '玉山': 2}
# {'台新': 1, '中信': 1}
# {'國泰': 1, 'KOKO': 1}
# {'中信': 1}
# {'中信': 1, '富邦': 1}
# {'玉山': 1}
# {'台新': 2, 'Richart': 1}
# {}
# {}
# {}
# {'Richart': 1, 'KOKO': 1}
# {'台新': 1}
# {}
# {'台新': 1, '中信': 2, 'Richart': 1}
# {}
# {'玉山': 2}
# {'花旗': 1}
# {}
# {'一銀': 1, '玉山': 1}
# {}
# {'中信': 1, '上海商銀': 2}
# {}
# {'玉山': 1, 'KOKO': 1, '星展': 1}
# {'遠東商銀': 1, '富邦': 1}
# {'渣打': 2, '花旗': 3, '國泰': 2}
# {'KOKO': 1, '中信': 1}
# {'花旗': 3}
# {}
# {'台新': 2}
# {'凱基': 1}
# {'花旗': 5, '國泰': 4, '玉山': 4}
# {}
# {'新光': 3}
# {}
# {}
# {'凱基': 2}
# {'台新': 3}
# {'中信': 1}
# {}
# {'中信': 4, '玉山': 6}
# {'元大': 1, '玉山': 1, '中信': 3}
# {'元大': 1}
# {'匯豐': 1, '土地': 1, '富邦': 1}
# {'國泰': 1}
# {'台新': 1}
# {}
# {}
# {'遠東商銀': 1}
# {}
# {'遠東商銀': 1}
# {'聯邦': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'合作金庫': 1, '國泰': 1, '台新': 1, '玉山': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國泰': 2}
# {'玉山': 1, '聯邦': 1, '兆豐': 1, '陽信': 1, '上海商銀': 1}
# {'KOKO': 1, '玉山': 1, '元大': 1}
# {}
# {'中信': 1}
# {'星展': 1, '富邦': 2}
# {'中信': 1}
# {'玉山': 2, '星展': 1}
# {'玉山': 1, '元大': 1, '匯豐': 1, '花旗': 1, '國泰': 1}
# {'花旗': 1, '星展': 1}
# {'國泰': 2, '台新': 1}
# {'國泰': 1}
# {}
# {'兆豐': 2}
# {'渣打': 4, '富邦': 1, '元大': 1}
# {}
# {}
# {'國泰': 1}
# {}
# {'富邦': 4, '中信': 3, '澳盛': 2, '台新': 2}
# {'元大': 4}
# {'永豐': 1}
# {}
# {'國泰': 1}
# {'渣打': 2}
# {'華南': 1, '元大': 1, '玉山': 1}
# {'元大': 4, '花旗': 2, '星展': 1}
# {'元大': 4, '花旗': 2, '星展': 1}
# {'國泰': 5}
# {}
# {'台新': 1}
# {'KOKO': 1}
# {}
# {'遠東商銀': 2, '玉山': 2}
# {'中信': 1, '渣打': 1, '澳盛': 1, '王道': 1, '國泰': 1, 'KOKO': 1}
# {'Richart': 1}
# {'華南': 4, '合作金庫': 2}
# {}
# {'KOKO': 1}
# {}
# {}
# {'Richart': 4, '台新': 2}
# {}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {'中信': 1}
# {}
# {}
# {}
# {'元大': 2, '台新': 1, '玉山': 1, '華南': 1, '兆豐': 1}
# {'玉山': 1, '台新': 1, '花旗': 1}
# {'玉山': 2}
# {}
# {}
# {}
# {'元大': 3}
# {'元大': 1}
# {'元大': 2, '永豐': 3}
# {}
# {'元大': 1, 'KOKO': 1, '台中銀行': 2}
# {}
# {}
# {'KOKO': 4, '花旗': 2, '中信': 1}
# {}
# {'玉山': 3}
# {'中信': 2, '兆豐': 1, '華南': 1, '國泰': 1, '玉山': 1}
# {}
# {'台新': 2, '玉山': 1}
# {'台新': 2}
# {'台新': 3}
# {'國泰': 1, 'KOKO': 2}
# {}
# {}
# {}
# {'富邦': 1}
# {}
# {'中信': 2, '彰化': 1}
# {'永豐': 1}
# {'新光': 2}
# {}
# {'中信': 1}
# {'永豐': 1}
# {'渣打': 3}
# {'渣打': 3}
# {'澳盛': 4, '星展': 4}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 1}
# {'台新': 1}
# {}
# {}
# {'國泰': 1}
# {'花旗': 1}
# {}
# {}
# {'聯邦': 3}
# {'聯邦': 2}
# {'花旗': 4}
# {'花旗': 3}
# {'花旗': 2}
# {'華南': 2}
# {'華南': 4, '元大': 1}
# {'華南': 1}
# {'富邦': 1}
# {'台新': 1, '國泰': 1, '玉山': 3}
# {'台新': 3, '中信': 1}
# {}
# {'花旗': 4, '澳盛': 2, '國泰': 3, '台新': 2, 'KOKO': 1}
# {'台新': 1, '國泰': 2, 'KOKO': 1, '玉山': 1}
# {'玉山': 2}
# {}
# {}
# {'Richart': 1}
# {}
# {'台新': 1}
# {'中信': 4, '台新': 1}
# {'玉山': 1}
# {'中信': 2, '富邦': 2}
# {}
# {}
# {'台新': 1, '國泰': 2, '花旗': 1}
# {'花旗': 2}
# {'玉山': 4, '永豐': 4, '一銀': 2}
# {'台新': 1}
# {}
# {'兆豐': 3, '凱基': 1}
# {'凱基': 5, '渣打': 1}
# {'KOKO': 1}
# {}
# {}
# {'台新': 1}
# {'玉山': 2, '富邦': 1, '台新': 1}
# {}
# {'玉山': 1}
# {'中信': 1}
# {'台新': 1}
# {}
# {'中信': 2}
# {'台新': 2}
# {}
# {'花旗': 1}
# {'花旗': 1}
# {}
# {'國泰': 1}
# {}
# {}
# {}
# {}
# {}
# {'國泰': 1, 'KOKO': 1}
# {'台新': 1}
# {}
# {'國泰': 2, '中信': 1, '台新': 1, '星展': 1}
# {'渣打': 2, '國泰': 1, '星展': 1}
# {}
# {}
# {'中信': 1, '華南': 1}
# ...
# {'花旗': 3, '一銀': 1, '玉山': 1, '華南': 3, '國泰': 1, '台新': 1, 'KOKO': 1}
# {}
# {}
# {'台新': 2, '中信': 1, '花旗': 1}
# {'國泰': 1, '花旗': 2, 'KOKO': 1}
# {'台新': 1}
# {'中信': 1}
# {'國泰': 3, 'KOKO': 1, '中信': 1, '元大': 1}
# {'玉山': 6, '中信': 4, '渣打': 4, '國泰': 4, 'KOKO': 4, '兆豐': 4, '台新': 4, '凱基': 1, '新光': 2, '一銀': 3, '華南': 5, '富邦': 2, '星展': 2, '澳盛': 1, '永豐': 2, '合作金庫': 2, '聯邦': 2, '花旗': 2, '元大': 2, '台中銀行': 1, '匯豐': 1, '陽信': 1}
# {'玉山': 1, '花旗': 12, '台新': 1}
# {'台新': 2, '花旗': 13, '玉山': 1}
# {'匯豐': 3, '星展': 3, '中信': 3, '新光': 2, '華南': 1, '日盛': 1, '國泰': 1, '元大': 2, '花旗': 1, '一銀': 1}
# {'中信': 1, '玉山': 1, '日盛': 1, '富邦': 1}
# {}
# {'元大': 1, '渣打': 1}
# {'渣打': 6}
# {'台新': 2}
# {}
# {'國泰': 2}
# {'花旗': 1}
# {}
# {'匯豐': 1}
# {}
# {'國泰': 6}
# {}
# {}
# {'中信': 1}
# {}
# {'澳盛': 2, '星展': 1}
# {'花旗': 3}
# {}
# {'花旗': 1}
# {}
# {'永豐': 3, '玉山': 1}
# {'星展': 5, '澳盛': 7}
# {}
# {'華南': 1, '兆豐': 1}
# {'渣打': 1, '兆豐': 1}
# {}
# {'Richart': 1}
# {'Richart': 2}
# {'KOKO': 2, '台新': 1, '國泰': 2}
# {'Richart': 1, '台新': 1}
# {}
# {}
# {'國泰': 5, '台新': 6, '聯邦': 5, '中信': 6}
# {}
# {}
# {'玉山': 2, '王道': 1}
# {'聯邦': 4, '中信': 2}
# {'華南': 2, '合作金庫': 2, '國泰': 2, 'KOKO': 2}
# {}
# {'新光': 1, '富邦': 1}
# {}
# {'土地': 2, '新光': 2}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 4}
# {'KOKO': 3}
# {'KOKO': 1}
# {'KOKO': 3, '國泰': 4, '中信': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 5}
# {'KOKO': 2}
# {'KOKO': 4}
# {'KOKO': 1, '國泰': 1}
# {'KOKO': 2}
# {'KOKO': 4, '玉山': 1, '台新': 1, '國泰': 1}
# {'KOKO': 7, '玉山': 4, '國泰': 5}
# {'KOKO': 1}
# {'KOKO': 1, '國泰': 1, '玉山': 1, '台新': 1}
# {'KOKO': 2, '國泰': 1}
# {'KOKO': 2}
# {'KOKO': 3, '國泰': 1}
# {}
# {'玉山': 2}
# {'KOKO': 2}
# {'中信': 2}
# {}
# {}
# {'中信': 1}
# {'玉山': 1, '花旗': 1}
# {}
# {}
# {'匯豐': 3, '元大': 1}
# {'玉山': 1}
# {'國泰': 3}
# {'國泰': 2}
# {}
# {'玉山': 1}
# {}
# {'富邦': 1}
# {'國泰': 2}
# {'國泰': 2}
# {'Richart': 2, '台新': 1}
# {}
# {'KOKO': 2}
# {'富邦': 1}
# {}
# {'玉山': 1}
# {'玉山': 6}
# {}
# {'富邦': 10, '永豐': 1, '玉山': 2}
# {'玉山': 2}
# {'凱基': 1}
# {'富邦': 1}
# {'玉山': 2}
# {'玉山': 12}
# {'玉山': 1}
# {'中信': 1, '玉山': 3, '花旗': 3, '國泰': 1, 'KOKO': 1, '台新': 2, '富邦': 1}
# {'KOKO': 2}
# {}
# {}
# {'永豐': 3}
# {'匯豐': 1}
# {'中信': 2}
# {}
# {}
# {'一銀': 3}
# {'一銀': 2}
# {'一銀': 2}
# {'一銀': 3}
# {'一銀': 3}
# {'華南': 5}
# {'上海商銀': 2}
# {}
# {'台新': 10}
# {'玉山': 2}
# {}
# {'中信': 2}
# {'中信': 1}
# {'中信': 3, '王道': 2}
# {'中信': 3}
# {'元大': 1, '玉山': 1, '花旗': 1, '國泰': 1, '富邦': 1}
# {'中信': 2}
# {'中信': 4, '台新': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 2, '永豐': 2}
# {'中信': 4}
# {'中信': 2}
# {'中信': 2}
# {'中信': 2, '國泰': 1}
# {'中信': 1}
# {'中信': 5}
# {'中信': 2, '一銀': 1}
# {'中信': 3}
# {'中信': 3}
# {'中信': 1}
# {'中信': 1}
# {'中信': 4}
# {'中信': 3, '玉山': 1}
# {'中信': 10}
# {'中信': 4, '玉山': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 5}
# {'中信': 3}
# {'中信': 3}
# {'中信': 4}
# {'中信': 1}
# {'中信': 3, '聯邦': 1}
# {'中信': 3, '國泰': 1, '台新': 1, '花旗': 1}
# {'中信': 5}
# {'中信': 1}
# {'中信': 2}
# {'中信': 3}
# {'中信': 3}
# {'中信': 2, '彰化': 1}
# {'中信': 2}
# {'中信': 1}
# {'中信': 1}
# {}
# {'聯邦': 3}
# {'台新': 3, '國泰': 4}
# {'元大': 3}
# {'台新': 3}
# {'玉山': 3}
# {'花旗': 4}
# {'KOKO': 3, '國泰': 5, '花旗': 1, '中信': 1}
# {'中信': 2, '國泰': 1, 'KOKO': 1, '渣打': 1, '兆豐': 1}
# {'合作金庫': 4, '陽信': 2}
# {}
# {'玉山': 2, '中信': 2, '國泰': 1, 'KOKO': 1, '華南': 1}
# {'星展': 1, '澳盛': 1}
# {}
# {'花旗': 1, '國泰': 1, 'Richart': 1}
# {'華南': 3}
# {'中信': 3}
# {}
# {}
# {'富邦': 1, '元大': 1}
# {}
# {}
# {}
# {'中信': 1}
# {'玉山': 3, '台新': 4, '華南': 3, '國泰': 3, 'KOKO': 1, 'Richart': 2}
# {'花旗': 1}
# {}
# {'凱基': 1}
# {'凱基': 1}
# {}
# {'一銀': 1}
# {'台新': 3, '星展': 5, '華南': 1, '中信': 1}
# {'元大': 2, 'Richart': 1}
# {'元大': 2}
# {'元大': 5}
# {'元大': 3}
# {'元大': 2}
# {'元大': 1}
# {'花旗': 1, '聯邦': 1}
# {'元大': 2}
# {'元大': 1}
# {'元大': 2}
# {'元大': 2}
# {'元大': 3}
# {'元大': 5}
# {'元大': 1}
# {'元大': 1}
# {'元大': 1}
# {}
# {}
# {'元大': 1}
# {'華南': 1, '台新': 1, '富邦': 1, '國泰': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 3, '國泰': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 1}
# {'兆豐': 2}
# {'兆豐': 2}
# {'兆豐': 4}
# {}
# {}
# {}
# {'凱基': 2}
# {'台新': 1}
# {'國泰': 5, '台新': 2}
# {'台新': 2, '中信': 1, '國泰': 1, '一銀': 1, '聯邦': 1}
# {'聯邦': 3}
# {'中信': 3, '富邦': 1}
# {'王道': 4, '中信': 2, '聯邦': 1, '臺灣銀行': 1, '玉山': 1}
# {'聯邦': 1}
# {'遠東商銀': 3}
# {'凱基': 3}
# {'凱基': 3}
# {'凱基': 3}
# {'凱基': 1}
# {'凱基': 1}
# {'凱基': 4}
# {'凱基': 1}
# {'凱基': 3}
# {'凱基': 6, '台新': 1}
# {'凱基': 2}
# {'凱基': 1}
# {'凱基': 1}
# {'凱基': 4}
# {}
# {}
# {'兆豐': 1}
# {'元大': 1}
# {}
# {}
# {}
# {}
# {'玉山': 2, '國泰': 2, '台新': 1}
# {'花旗': 2}
# {'合作金庫': 1}
# {'凱基': 3}
# {'玉山': 1, '富邦': 1, '星展': 2, '澳盛': 2}
# {'花旗': 1}
# {'台新': 5, '兆豐': 1}
# {'合作金庫': 2}
# {'渣打': 4}
# {'匯豐': 2}
# {'匯豐': 6, '星展': 7, '台新': 5, 'Richart': 2, '華南': 1, '國泰': 2, '中信': 1, '玉山': 2, 'KOKO': 1, '花旗': 1, '富邦': 1, '凱基': 1}
# {'匯豐': 14, '富邦': 1}
# {'匯豐': 3}
# {'中信': 1}
# {'中信': 4, '台新': 7, '國泰': 4, '富邦': 1, '新光': 1, '花旗': 1, '兆豐': 4, 'KOKO': 2, '合作金庫': 2, '華南': 4, '玉山': 1, '元大': 1, '聯邦': 1}
# {'兆豐': 1, '台新': 2, '中信': 2}
# {'國泰': 4}
# {'富邦': 1}
# {'台新': 17, '花旗': 1, '國泰': 1, '中信': 3, '玉山': 1, 'Richart': 2, '聯邦': 1, '元大': 1}
# {'台新': 4, '渣打': 5, '匯豐': 4, '元大': 6, '華南': 6, '中信': 5}
# {'台新': 7, '國泰': 1}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1}
# {'台新': 1}
# {'台新': 3, 'KOKO': 2}
# {'台新': 1}
# {'台新': 1, 'Richart': 1}
# {'台新': 1}
# {'台新': 1, 'Richart': 1}
# {'台新': 1}
# {'台新': 1, '中信': 6}
# {'台新': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 2, '玉山': 1}
# {'台新': 3, 'Richart': 2}
# {'台新': 2}
# {'台新': 2}
# {'台新': 1}
# {'台新': 2, 'Richart': 21, '玉山': 3, '中信': 1}
# {'台新': 15, '富邦': 3, '玉山': 5, '王道': 1, '中信': 2, '花旗': 2}
# {'富邦': 2, '台新': 2}
# {'台新': 4}
# {'台新': 2, '國泰': 4}
# {'台新': 4, '國泰': 4}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2}
# {'台新': 3}
# {'台新': 12}
# {'台新': 1}
# {'台新': 3}
# {'台新': 11, '中信': 4, '合作金庫': 2, '玉山': 1}
# {'台新': 2}
# {'台新': 3}
# {'台新': 2}
# {'台新': 2, 'Richart': 1}
# {'台新': 5}
# {'玉山': 3, '台新': 5}
# {'台新': 2}
# {'台新': 2}
# {'台新': 1}
# {'台新': 2}
# {'台新': 1}
# {'臺灣企銀': 2, '玉山': 1, '合作金庫': 1}
# {'匯豐': 1, '臺灣銀行': 1}
# {'花旗': 1}
# {'中信': 2, '台新': 3, '國泰': 4, '玉山': 1}
# {'中信': 2}
# {}
# {'台新': 3}
# {'玉山': 3}
# {'花旗': 2}
# {'玉山': 3, '國泰': 3, '中信': 3, '台新': 3, '花旗': 3, 'Richart': 1}
# {'台新': 1, '國泰': 3}
# {'中信': 4, '玉山': 4, '國泰': 3, '台新': 2, '星展': 2}
# {'華南': 1, '富邦': 1, '台新': 1}
# {'聯邦': 1, '台新': 1, '花旗': 1, '中信': 1, '國泰': 1, '玉山': 1}
# {'合作金庫': 2}
# {'合作金庫': 6, '台新': 1, '中信': 1, '國泰': 1}
# {'合作金庫': 2}
# {'合作金庫': 3}
# {'合作金庫': 2}
# {'合作金庫': 4, '華南': 1}
# {'合作金庫': 6, '國泰': 5, '華南': 1, '台新': 3, 'KOKO': 1, '中信': 3}
# {'合作金庫': 3}
# {'合作金庫': 7, '玉山': 1, '渣打': 1, '台新': 3, '中信': 1}
# {'玉山': 1, '國泰': 1, '中信': 1}
# {'台新': 2, '中信': 3, '國泰': 4, '華南': 2, '玉山': 2, '花旗': 2}
# {'國泰': 3, 'KOKO': 1}
# {'玉山': 7}
# {'元大': 1}
# {'中信': 2, '台新': 1, '兆豐': 2, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 6}
# {'國泰': 1, '聯邦': 2}
# {'國泰': 2}
# {'國泰': 2, 'KOKO': 2, '台新': 2, '中信': 1, '玉山': 1, '永豐': 1, '華南': 2, '王道': 1}
# {'國泰': 2, 'KOKO': 3, '花旗': 2, '一銀': 1}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 1, 'KOKO': 2}
# {'國泰': 4, 'KOKO': 3}
# {'國泰': 1, 'KOKO': 1}
# {'國泰': 2}
# {}
# {'國泰': 3, '遠東商銀': 2}
# {'國泰': 3, '中信': 1}
# {'國泰': 2}
# {'國泰': 2, 'KOKO': 2}
# {'國泰': 3}
# {'國泰': 2}
# {'國泰': 6}
# {'國泰': 6, 'KOKO': 1}
# {'國泰': 3}
# {'國泰': 2, '新光': 3, '彰化': 2}
# {'國泰': 3}
# {'國泰': 2}
# {'國泰': 4, '玉山': 1, '富邦': 1}
# {'國泰': 2}
# {'國泰': 3, 'KOKO': 2}
# {'國泰': 2, '中信': 1}
# {'國泰': 2}
# {'國泰': 3}
# {'國泰': 1}
# {'國泰': 2, 'KOKO': 1}
# {'國泰': 1}
# {'國泰': 1}
# {'玉山': 1}
# {}
# {'渣打': 2, '台新': 1}
# {'中信': 2, '台新': 2, '玉山': 1, '聯邦': 1, '國泰': 1, 'KOKO': 1}
# {'玉山': 1, '國泰': 2, '中信': 1, '匯豐': 2}
# {}
# {}
# {'中信': 13, '花旗': 2}
# {'台新': 2, '國泰': 1}
# {'元大': 3}
# {'元大': 4, '台新': 1}
# {'元大': 4}
# {'元大': 1}
# {'元大': 2}
# {'元大': 2}
# {'元大': 2}
# {'花旗': 3}
# {'台新': 2, 'Richart': 1}
# {'王道': 1}
# {'中信': 2}
# {}
# {'一銀': 1}
# {}
# {'台中銀行': 1}
# {}
# {'富邦': 2, '玉山': 1, '台新': 1}
# {'富邦': 2}
# {'富邦': 1}
# {'富邦': 4}
# {'富邦': 1}
# {'富邦': 1}
# {'富邦': 4}
# {'富邦': 2}
# {}
# {'富邦': 5}
# {}
# {'富邦': 5, '台新': 1}
# {'富邦': 3}
# {'富邦': 3}
# {'富邦': 2, '花旗': 1, '國泰': 1}
# {}
# {'花旗': 3}
# {}
# {'花旗': 1, '玉山': 2}
# {}
# {}
# {'彰化': 2}
# {'花旗': 1, '渣打': 1, '台新': 1}
# {}
# {'星展': 7, '國泰': 1, 'KOKO': 2, '玉山': 2, 'Richart': 1, '王道': 1, '中信': 1, '聯邦': 1, '合作金庫': 2, '一銀': 3}
# {'中信': 1}
# {'聯邦': 1, '凱基': 2, '匯豐': 2, '一銀': 1, '兆豐': 1, '土地': 2}
# {'凱基': 2, '臺灣銀行': 1}
# {'富邦': 1, '玉山': 1}
# {}
# {'玉山': 5, '中信': 2, '渣打': 3, '新光': 1}
# {'澳盛': 1, '星展': 1, '玉山': 4, '國泰': 3, '台新': 1, '上海商銀': 1, '中信': 1}
# {'台新': 3, '國泰': 3}
# {}
# {'花旗': 1, '一銀': 1, '華南': 3, '匯豐': 3, '渣打': 3, '元大': 2, '澳盛': 2, '星展': 3, '富邦': 1, '台新': 1, 'Richart': 1, '國泰': 2, 'KOKO': 1, '中信': 2}
# {'一銀': 2}
# {}
# {'中信': 1}
# {'永豐': 3}
# {'國泰': 3, '台新': 1, '中信': 1, '玉山': 2}
# {'中信': 3}
# {}
# {'國泰': 2}
# {'台新': 3}
# {}
# {}
# {}
# {'KOKO': 1}
# {'中信': 2}
# {'中信': 2}
# {'中信': 3}
# {'中信': 1}
# {'元大': 2}
# {'台新': 3}
# {'玉山': 1, '中信': 1}
# {'台新': 1}
# {'新光': 1}
# {'台新': 1}
# {'新光': 1}
# {'新光': 4, '華南': 2, '中信': 1}
# {'新光': 1}
# {'國泰': 3, 'KOKO': 3}
# {}
# {}
# {'日盛': 3}
# {'日盛': 2}
# {}
# {'台新': 2}
# {'渣打': 1, '華南': 3, '國泰': 1, 'KOKO': 1, '澳盛': 1}
# {}
# {'星展': 1}
# {'星展': 6}
# {'星展': 2}
# {'星展': 6, '玉山': 2}
# {'星展': 2, '澳盛': 1}
# {'星展': 3, '玉山': 1, '中信': 1, '花旗': 1, '元大': 2}
# {'星展': 2}
# {'星展': 1}
# {'星展': 2}
# {'星展': 2}
# {'星展': 1}
# {'星展': 2}
# {'國泰': 4, '中信': 2}
# {'富邦': 6, '永豐': 1, '花旗': 2}
# {'KOKO': 3}
# {}
# {'玉山': 1, '聯邦': 1}
# {}
# {}
# {'富邦': 1, '中信': 1, '台新': 1, '兆豐': 1, '華南': 1, '國泰': 1, '合作金庫': 1}
# {}
# {'台新': 1, '凱基': 1}
# {'國泰': 3}
# {'中信': 1, '花旗': 2, '聯邦': 1}
# {'中信': 4, '台新': 6, '玉山': 2}
# {}
# {'永豐': 1, '聯邦': 1}
# {'玉山': 2}
# {'玉山': 4}
# {'凱基': 1, '花旗': 1}
# {'中信': 1, '國泰': 2, '富邦': 2, '玉山': 1, '台新': 1}
# {}
# {}
# {'玉山': 2}
# {}
# {}
# {}
# {}
# {}
# {'國泰': 1, 'KOKO': 1, '華南': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'玉山': 1, '匯豐': 1}
# {}
# {'元大': 1, '中信': 3}
# {'中信': 2}
# {'台新': 1, '玉山': 1, '永豐': 1, '兆豐': 1}
# {'玉山': 2}
# {'KOKO': 1, '富邦': 2, '玉山': 1, '元大': 1, '國泰': 1}
# {'兆豐': 2}
# {}
# {'永豐': 5, '中信': 1}
# {'永豐': 2, 'Richart': 1}
# {'永豐': 3, '富邦': 1}
# {'永豐': 5}
# {'永豐': 2}
# {'永豐': 1}
# {'永豐': 5, '富邦': 1}
# {'永豐': 3}
# {'永豐': 4}
# {'永豐': 4, '中信': 1, '玉山': 1, '花旗': 1}
# {'永豐': 3}
# {'花旗': 6}
# {'玉山': 3}
# {}
# {}
# {'中信': 2, '永豐': 5, '國泰': 2, 'KOKO': 1, '台新': 2, '玉山': 1, '富邦': 2, '花旗': 1, '聯邦': 1, '華南': 1}
# {}
# {'玉山': 5}
# {'渣打': 2}
# {'渣打': 2}
# {'渣打': 1}
# {'渣打': 1}
# {'渣打': 5, '華南': 1}
# {'渣打': 6}
# {'渣打': 3}
# {'渣打': 2}
# {'渣打': 1}
# {'渣打': 1, '玉山': 1}
# {'渣打': 1}
# {'渣打': 2}
# {'渣打': 5, '匯豐': 1}
# {'渣打': 1}
# {'渣打': 3}
# {'渣打': 3, '花旗': 1, '中信': 1, '台新': 1, '新光': 2, '玉山': 1}
# {'澳盛': 2, '星展': 1}
# {'澳盛': 4, '星展': 3}
# {}
# {}
# {}
# {}
# {'國泰': 1}
# {}
# {'聯邦': 1}
# {}
# {'富邦': 7, '中信': 3, '台新': 6, '聯邦': 1}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 3, '新光': 1}
# {'玉山': 6}
# {'玉山': 1}
# {'玉山': 10}
# {'玉山': 3, 'KOKO': 1, '兆豐': 1}
# {'玉山': 3, '國泰': 1, '花旗': 1, '星展': 1}
# {'玉山': 1}
# {'玉山': 4}
# {'玉山': 1, '國泰': 1, 'KOKO': 3}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 2, '台新': 2, '中信': 1}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 7, '富邦': 1}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 3}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 4}
# {'玉山': 3}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 1}
# {'玉山': 7, '台新': 1, '新光': 1, '聯邦': 9}
# {'玉山': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 4}
# {}
# {}
# {}
# {'KOKO': 3, '永豐': 1}
# {'花旗': 3, '台新': 4, '澳盛': 4, '匯豐': 4, '元大': 6, 'Richart': 3}
# {}
# {'KOKO': 4}
# {'中信': 2}
# {}
# {'中信': 1, '台新': 1, '玉山': 1}
# {'玉山': 2}
# {'中信': 3}
# {'華南': 1, '玉山': 1, '中信': 1, '元大': 1, '一銀': 1}
# {'台新': 1}
# {'台新': 3}
# {'國泰': 2}
# {}
# {}
# {'星展': 2, '玉山': 2}
# {'花旗': 3, '聯邦': 1, '元大': 5, '國泰': 2, 'KOKO': 1, '台新': 4}
# {'中信': 1}
# {'中信': 1, '匯豐': 1}
# {'元大': 7, '聯邦': 1, '台新': 1}
# {'元大': 2, '國泰': 1, 'KOKO': 2}
# {'星展': 2, '花旗': 1}
# {'中信': 1}
# {'台新': 1}
# {}
# {}
# {}
# {'國泰': 1}
# {}
# {}
# {}
# {}
# {}
# {'國泰': 4, '中信': 2, '花旗': 2}
# {'國泰': 3, '花旗': 1}
# {}
# {'花旗': 3}
# {'渣打': 2, '中信': 3, '聯邦': 1}
# {'聯邦': 6}
# {'聯邦': 2}
# {'聯邦': 2}
# {'聯邦': 1}
# {'聯邦': 2, '台新': 2, '花旗': 1, '合作金庫': 1, '凱基': 1}
# {'聯邦': 3}
# {'聯邦': 1}
# {'聯邦': 5, '玉山': 1}
# {'聯邦': 3}
# {'聯邦': 4}
# {'聯邦': 1}
# {'聯邦': 2, '國泰': 1, '台新': 1, '中信': 1}
# {'聯邦': 4, '富邦': 3}
# {'聯邦': 2}
# {'聯邦': 6}
# {'聯邦': 1}
# {'聯邦': 5}
# {'聯邦': 2}
# {'聯邦': 1}
# {'中信': 1, '玉山': 1, '國泰': 1, '華南': 1}
# {}
# {'日盛': 2, '合作金庫': 2, '花旗': 2, '一銀': 1, '永豐': 1}
# {'花旗': 2, '新光': 2, '永豐': 1}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 5, 'Richart': 2}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 5}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 2, '星展': 1}
# {'花旗': 6, '玉山': 2}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 6}
# {'花旗': 1}
# {'花旗': 9}
# {'花旗': 2, '中信': 1}
# {'花旗': 1}
# {'花旗': 5}
# {'花旗': 1}
# {'花旗': 1}
# {'花旗': 1}
# {'花旗': 6, '台新': 1}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 2}
# {'花旗': 1}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 5}
# {'花旗': 3}
# {'花旗': 4}
# {'花旗': 9}
# {'花旗': 7}
# {'花旗': 2}
# {'花旗': 2}
# {'花旗': 4}
# {'花旗': 3}
# {}
# {'華南': 3}
# {'華南': 1}
# {'華南': 2, 'KOKO': 1}
# {'華南': 2}
# {'華南': 2}
# {'華南': 1}
# {'華南': 1}
# {'華南': 1}
# {'華南': 8, '台新': 1}
# {'華南': 4}
# {'華南': 2, '兆豐': 1}
# {'華南': 2, '新光': 1}
# {'華南': 2}
# {'華南': 1}
# {'華南': 3}
# {'華南': 4}
# {'華南': 1, '台新': 1}
# {'華泰': 5, '高雄銀行': 2}
# {'中信': 6}
# {}
# {'國泰': 1, 'KOKO': 1, '玉山': 1}
# {'元大': 7, '聯邦': 4}
# {'中信': 5}
# {'華南': 3}
# {'台新': 1}
# {}
# {'永豐': 3}
# {'星展': 5, '澳盛': 4, '華南': 1}
# {}
# {'台新': 1}
# {}
# {'中信': 1, '台新': 1, '玉山': 1, '國泰': 1, '花旗': 1, '兆豐': 1, '永豐': 1, '華南': 1}
# {}
# {'華南': 1}
# {'國泰': 3}
# {}
# {'匯豐': 2}
# {'KOKO': 1}
# {}
# {'元大': 1, '玉山': 2, '富邦': 1}
# {'星展': 2, '花旗': 2, '澳盛': 1}
# {'華南': 6, '永豐': 1, '匯豐': 1, '元大': 1, '中信': 3, '花旗': 2, '國泰': 1, 'KOKO': 1}
# {'華南': 1, '富邦': 2, '台新': 2}
# {'渣打': 2}
# {}
# {'花旗': 2}
# {'國泰': 5}
# {}
# {}
# {}
# {'台新': 1, '新光': 1}
# {'遠東商銀': 6}
# {'中信': 3, '國泰': 1, '台新': 2}
# {}
# {'永豐': 1, '星展': 2, '渣打': 1, '華泰': 1, '澳盛': 2}
# {'國泰': 1, '華南': 1, '元大': 1}
# {'國泰': 1, '華南': 1, '元大': 1}
# {}
# {}
# {'元大': 4}
# {'永豐': 2}
# {}
# {'玉山': 2}
# {}
# {'渣打': 1}
# {'陽信': 2, '中信': 1, '國泰': 1}
# {'台新': 1}
# {'國泰': 1, '華南': 1, '花旗': 1, '中信': 2}
# {'玉山': 1}
# {'中信': 2, '花旗': 3}
# {'台新': 2, '永豐': 1}
# {}
# {}
# {}
# {'永豐': 2, '花旗': 2, '中信': 1}
# {}
# {'富邦': 2}
# {'兆豐': 1}
# {}
# {'台新': 1}
# {}
# {'中信': 5}
# {'中信': 1}
# {'凱基': 4}
# {'華南': 2, '中信': 1}
# {}
# {'KOKO': 1}
# {'國泰': 25, '中信': 23, '元大': 11, '澳盛': 5, '星展': 9}
# {}
# {'華南': 1, '中信': 1}
# {}
# {'玉山': 4}
# {'國泰': 1, 'KOKO': 1}
# {}
# {}
# {'玉山': 2}
# {'台新': 1}
# {'中信': 2}
# {'元大': 13, '中信': 1}
# {'玉山': 3, '花旗': 1, '中信': 1, '富邦': 1}
# {'一銀': 2, '華南': 2}
# {'中信': 5, '台新': 7, '永豐': 2, '凱基': 2}
# {'中信': 2}
# {'中信': 2, '台新': 1, '新光': 1}
# {'中信': 2}
# {'中信': 5, '玉山': 3}
# {'中信': 2}
# {'中信': 9, '玉山': 7}
# {'中信': 1}
# {'中信': 3, '台新': 1, '國泰': 1, 'KOKO': 1, '富邦': 1, '兆豐': 1, '元大': 1, '永豐': 1}
# {'中信': 3}
# {'中信': 3, '花旗': 2}
# {'中信': 3}
# {'匯豐': 2, '國泰': 1, 'KOKO': 1, '富邦': 1, '花旗': 1}
# {'玉山': 1, '華南': 1}
# {}
# {'元大': 2}
# {'元大': 2}
# {'元大': 3, '匯豐': 4, '台新': 1}
# {'兆豐': 2}
# {'兆豐': 3, '永豐': 1}
# {'兆豐': 2}
# {'花旗': 2, '台新': 1, '國泰': 1, '富邦': 3}
# {'中信': 1, '匯豐': 1, '花旗': 1}
# {}
# {'中信': 1, '台新': 2}
# {'匯豐': 4, '花旗': 2, '渣打': 2}
# {'匯豐': 3, '台新': 1, '玉山': 1, '花旗': 3, '元大': 1}
# {'匯豐': 4, '永豐': 2, '聯邦': 2, '中信': 1, '國泰': 1, 'KOKO': 1, '玉山': 1, '台新': 1, '兆豐': 1}
# {'澳盛': 1, '星展': 1}
# {'玉山': 2}
# {'台新': 4, '國泰': 1, 'KOKO': 1, '中信': 2, '花旗': 2, 'Richart': 2}
# {'台新': 2, '玉山': 5, '國泰': 2, '中信': 1, 'Richart': 4}
# {'台新': 1}
# {'台新': 2, 'Richart': 2, '花旗': 1}
# {'台新': 3, '花旗': 1, '聯邦': 2, 'Richart': 1}
# {'台新': 2, 'Richart': 1}
# {'台新': 8, '兆豐': 5, '國泰': 5, '土地': 2, 'Richart': 2}
# {'台新': 1}
# {'台新': 1, '國泰': 1}
# {'台新': 1}
# {'台新': 2, '聯邦': 3, 'Richart': 2}
# {'玉山': 1}
# {'國泰': 3, 'KOKO': 2, '中信': 2, '台新': 2}
# {'國泰': 4, '中信': 2, '玉山': 1, 'KOKO': 1}
# {'國泰': 2}
# {'國泰': 2}
# {'元大': 1}
# {'兆豐': 1, '花旗': 1, '國泰': 1, 'KOKO': 1, '中信': 1, '台新': 1}
# {'台新': 6, '中信': 1, '國泰': 1, '花旗': 2, 'Richart': 1}
# {'富邦': 4}
# {'富邦': 1}
# {'澳盛': 1}
# {'元大': 3}
# {'台新': 2, '國泰': 1, 'Richart': 1, '華南': 1}
# {'Richart': 3}
# {'星展': 5, '匯豐': 4}
# {'中信': 8, '永豐': 4, '台新': 3}
# {}
# {'中信': 8, '玉山': 5, '華南': 3}
# {}
# {'中信': 1}
# {'新光': 5, '永豐': 6, 'KOKO': 1, 'Richart': 1, '富邦': 2, '玉山': 3, '國泰': 1, '星展': 1, '兆豐': 1, '元大': 1, '台新': 1, '中信': 1}
# {}
# {'中信': 6, '國泰': 6, '台新': 5, '玉山': 5, '高雄銀行': 1}
# {'匯豐': 1}
# {'玉山': 1, '國泰': 1, 'KOKO': 1, '渣打': 1, '匯豐': 1}
# {'星展': 2}
# {'星展': 3, '中信': 4, '花旗': 5, '台新': 1, 'Richart': 1}
# {'星展': 2, '匯豐': 2, '澳盛': 4, '台新': 2, '花旗': 1, '中信': 2, '國泰': 1, 'KOKO': 1}
# {'星展': 7, '玉山': 4, '澳盛': 2}
# {}
# {'匯豐': 1}
# {'澳盛': 2, '星展': 3}
# {'台新': 1}
# {'富邦': 1, '台新': 1}
# {}
# {}
# {}
# {}
# {}
# {'富邦': 1}
# {'永豐': 3, '中信': 2, '台新': 1, '國泰': 1, 'KOKO': 1, '富邦': 1, '兆豐': 1, '元大': 1}
# {'匯豐': 2}
# {'玉山': 3, '中信': 2}
# {'渣打': 3, '中信': 1, '玉山': 2}
# {'渣打': 2}
# {'渣打': 2, '台新': 1, '國泰': 1, '花旗': 1, '匯豐': 1, '星展': 1}
# {'國泰': 2, 'KOKO': 4, '台新': 2, '中信': 1, '玉山': 1}
# {'玉山': 2, 'Richart': 1, '台新': 1, '國泰': 1, '花旗': 1}
# {'玉山': 7, '台新': 2, '花旗': 1}
# {'玉山': 6, '國泰': 1, '中信': 1, '富邦': 2, '台新': 1}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 5, '台新': 2, '富邦': 1}
# {'玉山': 3}
# {'玉山': 2}
# {'玉山': 2}
# {'玉山': 1}
# {'玉山': 6}
# {}
# {'一銀': 1, '合作金庫': 1}
# {'一銀': 2, '台新': 1, '渣打': 1}
# {}
# {'國泰': 1}
# {'聯邦': 1}
# {'聯邦': 4, '中信': 1}
# {'玉山': 9, '富邦': 7, '國泰': 2, '中信': 1, '台新': 1}
# {'花旗': 3}
# {'花旗': 3}
# {'花旗': 2}
# {'花旗': 5, '國泰': 3, '元大': 1}
# {'花旗': 4}
# {'花旗': 3}
# {'花旗': 3, '中信': 2}
# {'花旗': 3}
# {'花旗': 3}
# {'華南': 6, '中信': 1, '富邦': 1, '玉山': 1, '台新': 1, '國泰': 1, '渣打': 1, '聯邦': 1, '元大': 1, '星展': 1, '花旗': 1}
# {'玉山': 1, '台新': 2}
# {}
# {'兆豐': 2}
# {'中信': 1}
# {}
# {'花旗': 3, '中信': 1}
# {'台新': 1}
# {'花旗': 1}
# {}
# {'台新': 1}
# {'台新': 1}
# {}
# {'新光': 1, '國泰': 3, '永豐': 4, '匯豐': 4, '合作金庫': 2, '台新': 4, '玉山': 10, '中信': 1, '王道': 1, '富邦': 3, '聯邦': 5, '凱基': 1, '兆豐': 1, '華南': 1, 'KOKO': 1}
# {'花旗': 1}
# {'聯邦': 1, '國泰': 2, '富邦': 1}
# {}
# {'台新': 1}
# {'永豐': 3, '中信': 2, '玉山': 3, '國泰': 1, 'KOKO': 1}
# {'元大': 2}
# {'兆豐': 3, '國泰': 4, 'KOKO': 3, '玉山': 1, '華南': 1, '新光': 1}
# {}
# {'元大': 1}
# {'玉山': 6, '台新': 2}
# {'富邦': 9}
# {'台新': 1}

# %%
for article in range(len(df)):
    article_card={}
    for word in df['斷詞'][article]:
        if word in card:
            if card[word] not in article_card:
                article_card[card[word]] = 1
            else:
                article_card[card[word]] += 1
    print(article_card)
    df['卡片'][article]=article_card
# Out:
# {'e秒刷鈦金卡': 1}
# {'Ubear': 1}
# {'Flygo': 4, 'Pi': 3, 'GoGo': 2}
# {'GoGo': 5, 'LINEPay': 1, '饗樂卡': 2}
# {}
# {'GoGo': 4}
# {'小小兵信用卡': 3, 'My樂現金回饋卡': 1}
# {'饗樂卡': 2, 'GoGo': 3}
# {'Pi': 2, '世界卡': 1, 'Flygo': 2, 'GoGo': 2, 'Gogoro聯名卡': 1, '簡單卡': 1}
# {'樂天信用卡': 1, 'LINEPay': 1}
# {'GoGo': 2}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 5}
# {'無限卡': 2}
# {'Flygo': 1}
# {'Flygo': 1}
# {'Flygo': 1}
# {}
# {'KOKO': 1}
# {'KOKO': 3}
# {'KOKO': 1}
# {'KOKO': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'Pi': 1}
# {'Pi': 1}
# {'Pi': 1}
# {'Pi': 1}
# {'GoGo': 2}
# {}
# {'Ubear': 1}
# {}
# {}
# {'KOKO': 2}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {}
# {}
# {}
# {'LINEPay': 3, '鼎極卡': 2}
# {'饗樂卡': 1, 'Ubear': 2, '微風聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'icash聯名卡': 1, '鑽金': 1}
# {'Flygo': 1}
# {}
# {'LINEPay': 2}
# {}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {}
# {'GoGo': 1}
# {'GoGo': 3}
# {'台灣銀行': 1}
# {'icash聯名卡': 2, 'KOKO': 1}
# {'世界卡': 2}
# {'GoGo': 2, 'LINEPay': 1}
# {'LINEPay': 4, '鼎極卡': 1}
# {'現金回饋御璽卡': 2}
# {'KOKO': 7}
# {'GoGo': 3, '炫晶御璽卡': 1}
# {'KOKO': 3}
# {'鑽金': 1}
# {'dawho': 1}
# {}
# {'法拉利無限卡': 1}
# {'LINEPay': 2, 'GoGo': 1}
# {'美國運通': 2}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {'Pi': 1, 'LINEPay': 2}
# {'無限卡': 1}
# {}
# {'鼎極卡': 1, 'LINEPay': 1}
# {}
# {}
# {'KOKO': 5}
# {'數位生活卡': 2, '無限卡': 1, '富邦尊御世界卡': 1}
# {}
# {'Pi': 1, 'LINEPay': 2, '法拉利無限卡': 1}
# {'GoGo': 3, 'LINEPay': 1, 'KOKO': 1}
# {'世界卡': 1}
# {'KOKO': 2, 'GoGo': 16, 'LINEPay': 3}
# {}
# {'KOKO': 3, 'GoGo': 4, 'LINEPay': 2}
# {'LINEPay': 2}
# {}
# {}
# {'GoGo': 5, 'KOKO': 3, '富邦數位生活卡': 1}
# {'KOKO': 2}
# {'LINEPay': 1}
# {}
# {'KOKO': 2, 'LINEPay': 3, 'e秒刷鈦金卡': 1, '樂天信用卡': 1, 'icash聯名卡': 1}
# {'GoGo': 3}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {'悠遊聯名卡': 1}
# {'KOKO': 2}
# {}
# {'LINEPay': 3}
# {}
# {'GoGo': 2, '鑽金': 1}
# {'GoGo': 1}
# {'GoGo': 3, 'Flygo': 1}
# {'GoGo': 4}
# {'GoGo': 1}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 3}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 2, '太陽卡': 1, 'e秒刷鈦金卡': 1}
# {'GoGo': 2, '太陽卡': 1, 'e秒刷鈦金卡': 1}
# {}
# {'美國運通': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 2}
# {}
# {}
# {'GoGo': 2}
# {'炫晶御璽卡': 2}
# {}
# {'LINEPay': 1}
# {'鑽金': 1, 'Flygo': 1}
# {'鑽金': 1}
# {}
# {}
# {'美國運通': 1}
# {}
# {}
# {'ANA聯名卡': 2}
# {}
# {'無限卡': 1}
# {}
# {}
# {'LINEPay': 2}
# {'GoGo': 1}
# {}
# {'LINEPay': 2}
# {'GoGo': 4}
# {}
# {}
# {}
# {'LINEPay': 1, '炫晶御璽卡': 1}
# {'LINEPay': 1, '鑽金': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 2}
# {}
# {}
# {'玉山eTag悠遊聯名卡': 1, '法拉利無限卡': 1, '無限卡': 1}
# {'全家Fish悠遊聯名卡': 1, 'LINEPay': 1}
# {}
# {}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 2, 'KOKO': 2}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {'e秒刷鈦金卡': 2}
# {'Flygo': 2}
# {}
# {}
# {'Flygo': 1}
# {'Flygo': 2}
# {'Flygo': 4}
# {'Flygo': 2, 'GoGo': 1}
# {'Flygo': 4}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 1}
# {'Flygo': 1}
# {'Flygo': 1}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 4, 'GoGo': 3}
# {'Flygo': 1}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 3}
# {'Flygo': 3}
# {'Flygo': 2}
# {}
# {}
# {'LINEPay': 3}
# {}
# {'LINEPay': 2}
# {'e秒刷鈦金卡': 3, 'LINEPay': 1, 'GoGo': 1}
# {'GoGo': 3}
# {'GoGo': 2, 'Flygo': 2}
# {'Gogoro聯名卡': 3}
# {'GoGo': 1, 'Gogoro聯名卡': 1, 'KOKO': 1, '數位生活卡': 1}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 3}
# {'GoGo': 3}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 3, 'LINEPay': 2}
# {'GoGo': 2}
# {'GoGo': 2, 'LINEPay': 1}
# {'GoGo': 4}
# {'GoGo': 2}
# {'GoGo': 3, 'Flygo': 2, 'Ubear': 2}
# {'GoGo': 3}
# {'GoGo': 2}
# {'GoGo': 5, 'KOKO': 6, '一卡通聯名卡': 1, 'icash聯名卡': 1}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 3}
# {'KOKO': 1}
# {}
# {'GoGo': 2, 'Ubear': 2}
# {}
# {'e秒刷鈦金卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'e秒刷鈦金卡': 1, 'LINEPay': 1}
# {}
# {}
# {'悠遊聯名卡': 1, 'LINEPay': 1, 'icash聯名卡': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'icash聯名卡': 2}
# {}
# {'icash聯名卡': 1}
# {'icash聯名卡': 1}
# {'GoGo': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {}
# {}
# {}
# {'哆啦A夢JCB聯名卡': 1}
# {}
# {}
# {'悠遊聯名卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 1}
# {'GoGo': 1, 'KOKO': 1, 'LINEPay': 1}
# {}
# {'KOKO': 3}
# {'KOKO': 4, 'GoGo': 2}
# {'KOKO': 1, 'LINEPay': 1}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 5}
# {'KOKO': 1, 'icash聯名卡': 1}
# {'KOKO': 2, 'icash聯名卡': 2}
# {'KOKO': 1, 'icash聯名卡': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 5}
# {'KOKO': 2, 'icash聯名卡': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 5, 'icash聯名卡': 1}
# {'KOKO': 8}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 7}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 3, 'LINEPay': 4}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 4}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 4}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2, '星燦卡': 4, '數位生活卡': 5}
# {'KOKO': 4, 'dawho': 1}
# {'KOKO': 3, 'LINEPay': 4}
# {'KOKO': 3, 'GoGo': 1}
# {'KOKO': 2}
# {'KOKO': 5, 'LINEPay': 5}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 3}
# {'KOKO': 1}
# {'KOKO': 1}
# {'LINEPay': 2}
# {'LINEPay': 3}
# {'LINEPay': 1}
# {'LINEPay': 1, '鼎極卡': 2}
# {'LINEPay': 1, '鼎極卡': 2}
# {'LINEPay': 6, '鼎極卡': 4}
# {'LINEPay': 8, '數位生活卡': 4}
# {'LINEPay': 4}
# {'LINEPay': 3}
# {'LINEPay': 4}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 3, '鼎極卡': 3}
# {'LINEPay': 3, 'GoGo': 3}
# {'LINEPay': 3}
# {'LINEPay': 3}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {'LINEPay': 1, '鼎極卡': 2}
# {'LINEPay': 1, '鼎極卡': 1}
# {'LINEPay': 3, '鼎極卡': 2}
# {'LINEPay': 3, '鼎極卡': 2}
# {'LINEPay': 1, '無限卡': 1}
# {'LINEPay': 4, 'GoGo': 2}
# {'LINEPay': 4}
# {'LINEPay': 4, 'e秒刷鈦金卡': 1}
# {'LINEPay': 8, 'Pi': 2}
# {'LINEPay': 4}
# {'LINEPay': 3, '鼎極卡': 4}
# {'LINEPay': 8, 'e秒刷鈦金卡': 3}
# {'LINEPay': 4}
# {'LINEPay': 4}
# {'LINEPay': 5}
# {'LINEPay': 6}
# {'LINEPay': 1}
# {'LINEPay': 3}
# {'LINEPay': 2, 'GoGo': 1}
# {'LINEPay': 3}
# {'LINEPay': 2}
# {'LINEPay': 6, '鼎極卡': 1}
# {'LINEPay': 3}
# {'LINEPay': 2}
# {'LINEPay': 4, '鼎極卡': 2}
# {'LINEPay': 2}
# {'LINEPay': 5, 'GoGo': 2, 'Flygo': 2}
# {'LINEPay': 5, 'GoGo': 2, 'Flygo': 2}
# {'Pi': 1}
# {'KOKO': 3, 'LINEPay': 2}
# {'鼎極卡': 2}
# {}
# {}
# {}
# {'鑽金': 1}
# {}
# {'鑽金': 1, 'Flygo': 1}
# {'世界卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {}
# {'GoGo': 1}
# {'Ubear': 1, 'GoGo': 2, 'KOKO': 1}
# {'GoGo': 1}
# {}
# {}
# {'Only': 1}
# {}
# {'KOKO': 3}
# {'icash聯名卡': 1}
# {}
# {}
# {'美國運通': 1}
# {}
# {}
# {}
# {}
# {'Only': 1}
# {'GoGo': 1}
# {}
# {'賴點卡': 1, 'dawho': 1}
# {'GoGo': 1}
# {}
# {'LINEPay': 5}
# {}
# {}
# {'e秒刷鈦金卡': 1, 'KOKO': 1}
# {}
# {}
# {}
# {'Pi': 1}
# {}
# {'LINEPay': 4}
# {}
# {}
# {}
# {}
# {'LINEPay': 5}
# {}
# {'Pi': 1}
# {'Pi': 2}
# {'Pi': 1}
# {'Pi': 1}
# {'Pi': 4}
# {'Pi': 3}
# {}
# {'Pi': 4}
# {}
# {'Pi': 3}
# {'GoGo': 4}
# {'鑽金': 1}
# {'Pi': 1}
# {'Ubear': 2}
# {}
# {'世界卡': 1, '無限卡': 1, '悠遊聯名卡': 1}
# {'LINEPay': 2}
# {}
# {}
# {'GoGo': 2}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {'GoGo': 1}
# {'Flygo': 1}
# {}
# {}
# {}
# {'GoGo': 2, 'Pi': 1, 'KOKO': 1}
# {'LINEPay': 1, 'GoGo': 3, 'Flygo': 3, 'KOKO': 2}
# {}
# {}
# {'GoGo': 2}
# {}
# {'GoGo': 1}
# {}
# {}
# {'Flygo': 1}
# {}
# {}
# {'鑽金': 1}
# {'KOKO': 1, 'LINEPay': 1}
# {'dawho': 2, 'GoGo': 2}
# {}
# {'GoGo': 1}
# {}
# {}
# {'Ubear': 1}
# {'Ubear': 2}
# {}
# {'Ubear': 1}
# {'Ubear': 2, 'LINEPay': 1, 'Pi': 2}
# {'Ubear': 1}
# {'Ubear': 1}
# {'Ubear': 3, 'Only': 2, 'Pi': 2}
# {'Ubear': 2}
# {'Ubear': 4}
# {'Ubear': 2, 'Pi': 1}
# {'Ubear': 3, 'GoGo': 1}
# {'Ubear': 1}
# {'Ubear': 2}
# {'Ubear': 1, 'dawho': 1}
# {'Ubear': 2}
# {'LINEPay': 1}
# {'悠遊聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 2}
# {}
# {}
# c:\users\big data\pycharmprojects\py\venv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# {}
# {'鑽金': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 4}
# {'LINEPay': 1, '一卡通聯名卡': 2}
# {'哆啦A夢JCB聯名卡': 1, '富邦財神卡': 1}
# {}
# {}
# {}
# {'icash聯名卡': 2}
# {'星燦卡': 1, '一卡通聯名卡': 1}
# {'星燦卡': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2, '鑽金': 1, 'Pi': 2, '元大鑽金卡': 1}
# {'Pi': 4}
# {}
# {}
# {'鑽金': 1}
# {}
# {}
# {'鑽金': 2, '簡單卡': 2, '元大鑽金icash聯名卡': 1}
# {'簡單卡': 2, 'GoGo': 1, 'Flygo': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {'悠遊聯名卡': 1}
# {'LINEPay': 2}
# {'LINEPay': 2, '鼎極卡': 3}
# {'LINEPay': 2}
# {'LINEPay': 3}
# {'LINEPay': 1}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 3, 'ANA聯名卡': 1}
# {'無限卡': 3}
# {'ANA聯名卡': 1}
# {}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {'LINEPay': 3}
# {'LINEPay': 3, '鼎極卡': 1, '無限卡': 2}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'LINEPay': 4}
# {'LINEPay': 3}
# {'LINEPay': 2}
# {'LINEPay': 6}
# {'LINEPay': 3}
# {'LINEPay': 4}
# {'LINEPay': 2, '鼎極卡': 1}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'LINEPay': 3}
# {'LINEPay': 7}
# {'LINEPay': 2}
# {'LINEPay': 3, '富邦數位生活卡': 1}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {'LINEPay': 3, '鼎極卡': 3}
# {'LINEPay': 5, '鼎極卡': 3}
# {'LINEPay': 2}
# {'LINEPay': 9}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 19}
# {'LINEPay': 2}
# {'LINEPay': 3}
# {'LINEPay': 4}
# {'LINEPay': 3}
# {'LINEPay': 6}
# {'LINEPay': 2}
# {'LINEPay': 6}
# {'LINEPay': 8, 'GoGo': 6}
# {'LINEPay': 2, '鼎極卡': 1}
# {}
# {'Flygo': 2, 'GoGo': 3, 'Pi': 1, 'LINEPay': 2}
# {}
# {}
# {'鼎極卡': 2, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'LINEPay': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'鼎極卡': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {}
# {'酷玩卡': 3, 'LINEPay': 1}
# {'無限卡': 4}
# {}
# {}
# {'商務卡': 2, 'LINEPay': 1}
# {'無限卡': 1}
# {}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1, 'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {}
# {'無限卡': 2}
# {'LINEPay': 1, '鼎極卡': 2}
# {'LINEPay': 1, '鼎極卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {}
# {}
# {'元大鑽金卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'中信兄弟聯名卡': 1, 'LINEPay': 2}
# {'LINEPay': 1}
# {}
# {}
# {'LINEPay': 3}
# {}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {}
# {}
# {'LINEPay': 1}
# {'鼎極卡': 2}
# {'鼎極卡': 5, 'LINEPay': 5}
# {'LINEPay': 3}
# {}
# {}
# {'ANA聯名卡': 1}
# {'無限卡': 4, '鼎極卡': 1}
# {}
# {}
# {'LINEPay': 2}
# {'LINEPay': 4}
# {'LINEPay': 4}
# {}
# {}
# {}
# {'酷玩卡': 1}
# {'LINEPay': 1}
# {'酷玩卡': 1, 'GoGo': 1, 'Flygo': 1}
# {}
# {}
# {'LINEPay': 2}
# {'LINEPay': 4}
# {}
# {'LINEPay': 1}
# {'商務卡': 1}
# {}
# {}
# {}
# {}
# {'Pi': 2}
# {}
# {'LINEPay': 2}
# {}
# {'GoGo': 1, 'Pi': 1}
# {}
# {'現金回饋御璽卡': 2, '數位生活卡': 1, '富邦悍將聯名卡': 1, '悠遊聯名卡': 3, '樂天信用卡': 1}
# {}
# {}
# {}
# {}
# {'e秒刷鈦金卡': 1, '數位生活卡': 1, '星燦卡': 1}
# {'KOKO': 1}
# {'饗樂卡': 2, 'GoGo': 3, '鑽金': 1}
# {'饗樂卡': 1, 'GoGo': 1, 'LINEPay': 1}
# {'LINEPay': 2, 'KOKO': 1, 'Omiyage': 1}
# {}
# {}
# {}
# {'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {}
# {'LINEPay': 1, 'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, '太陽卡': 1}
# {}
# {'GoGo': 4}
# {'Pi': 2, 'LINEPay': 1}
# {}
# {}
# {'玉山eTag悠遊聯名卡': 1, 'GoGo': 1}
# {}
# {}
# {'富邦數位生活卡': 3}
# {'鑽金': 1, 'GoGo': 1, '數位生活卡': 1, 'LINEPay': 4, 'KOKO': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2, 'Ubear': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {}
# {'無限卡': 1, 'Only': 1}
# {'統一獅聯名卡': 1}
# {}
# {}
# {}
# {'LINEPay': 1, '無限卡': 1}
# {'富邦數位生活卡': 1, 'GoGo': 2, 'icash聯名卡': 3}
# {}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {'鑽金': 3, '現金回饋悠遊鈦金卡': 1, '饗樂卡': 1, '數位生活卡': 1, 'LINEPay': 6, '酷玩卡': 1, '鼎極卡': 2, 'GoGo': 1}
# {'Flygo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2, 'GoGo': 1}
# {}
# {'分享卡': 1}
# {}
# {'分享卡': 1}
# {}
# {'星燦卡': 1}
# {'GoGo': 1}
# {}
# {'饗樂卡': 1, 'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {'LINEPay': 1}
# {'饗樂卡': 1, 'LINEPay': 2, '現金回饋悠遊鈦金卡': 1, 'Flygo': 3, 'Pi': 1, 'GoGo': 1, 'KOKO': 1, '簡單卡': 1}
# {}
# {'Pi': 1, '超級現金回饋卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'元大鑽金一卡通聯名卡': 1, '元大鑽金卡': 1, '富邦數位生活卡': 1, '鈦金商旅卡': 1, '無限卡': 1}
# {}
# {'富邦數位生活卡': 2, '元大鑽金卡': 1, 'LINEPay': 1, 'KOKO': 3, '鑽金': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 1, 'Flygo': 1, 'dawho': 2, 'Ubear': 1}
# {}
# {}
# {}
# {}
# {'享購鈦金卡': 1, 'KOKO': 1}
# {'GoGo': 1}
# {'富貴無限卡': 1}
# {'元大鑽金卡': 1, '太陽卡': 1}
# {}
# {}
# {'世界卡': 2, '樂天信用卡': 1, '現金回饋御璽卡': 1, '炫晶御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'數位生活卡': 1, 'LINEPay': 1}
# {}
# {'GoGo': 2}
# {}
# {'鑽金': 1}
# {}
# {}
# {}
# {'鑽金': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {'鑽金': 1}
# {}
# {}
# {'無限卡': 3}
# {}
# {'元大鑽金卡': 1}
# {}
# {'鑽金': 1}
# {'分享卡': 2}
# {}
# {}
# {'鑽金': 1}
# {'鑽金': 6}
# {'鑽金': 2}
# {'鑽金': 2}
# {'鑽金': 4, 'icash聯名卡': 2}
# {'鑽金': 1}
# {'鑽金': 2}
# {'鑽金': 1}
# {'元大鑽金卡': 3, '現金回饋御璽卡': 3, '鑽金': 2, 'icash聯名卡': 1, '酷玩卡': 1, '饗樂卡': 1}
# {'元大鑽金卡': 2}
# {'元大鑽金卡': 1}
# {'元大鑽金卡': 2}
# {'元大鑽金卡': 1}
# {'元大鑽金卡': 1}
# {'元大鑽金卡': 1}
# {'鑽金': 1}
# {'鑽金': 1}
# {'鑽金': 1}
# {}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'世界卡': 1, '無限卡': 1}
# {'e秒刷鈦金卡': 2, 'KOKO': 3, '鑽金': 1, 'icash聯名卡': 1}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 2}
# {'KOKO': 3, 'GoGo': 2, 'LINEPay': 1, 'e秒刷鈦金卡': 1}
# {'GoGo': 1}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 4, 'KOKO': 4, 'LINEPay': 1, 'GoGo': 1, '悠遊聯名卡': 1}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 1}
# {'KOKO': 1, '統一獅聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'商旅卡': 1, '一卡通聯名卡': 1, 'e秒刷鈦金卡': 3, '悠遊聯名卡': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 1}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'法拉利無限卡': 1, '無限卡': 2, '富邦尊御世界卡': 1}
# {}
# {'KOKO': 2, 'GoGo': 4, 'e秒刷鈦金卡': 2, 'LINEPay': 1}
# {'GoGo': 2}
# {'LINEPay': 1, 'GoGo': 1}
# {'KOKO': 3}
# {'GoGo': 1, 'Ubear': 1}
# {'KOKO': 2}
# {'GoGo': 5, 'LINEPay': 1}
# {}
# {'KOKO': 1}
# {}
# {}
# {'Pi': 1, 'Ubear': 1}
# {'KOKO': 2, 'LINEPay': 1}
# {}
# {'一卡通聯名卡': 3}
# {'LINEPay': 1, '悠遊聯名卡': 1, '一卡通聯名卡': 1}
# {'太陽卡': 1}
# {'KOKO': 3}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {'LINEPay': 16, 'KOKO': 2, 'Pi': 2}
# {'LINEPay': 16, 'KOKO': 2, 'Pi': 2}
# {}
# {}
# {'悠遊聯名卡': 3}
# {}
# {}
# {'凱基無限卡': 1, '無限卡': 1}
# {}
# {}
# {}
# {}
# {'dawho': 6, 'Flygo': 6}
# {}
# {'富邦數位生活卡': 1, 'KOKO': 1, 'GoGo': 1, '現金回饋御璽卡': 1}
# {'元大鑽金卡': 1, '饗樂卡': 1, '美國運通': 2}
# {'富邦鑽保卡': 1}
# {'LINEPay': 1}
# {'Gogoro聯名卡': 3}
# {'分享卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 2, 'GoGo': 1, '饗樂卡': 1}
# {'KOKO': 1}
# {'悠遊聯名卡': 1}
# {}
# {'GoGo': 1}
# {}
# {'e秒刷鈦金卡': 2}
# {'LINEPay': 1}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'新光三越聯名卡': 1, '元大鑽金卡': 1, '現金回饋御璽卡': 1, 'GoGo': 1}
# {'Pi': 2, 'dawho': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {'GoGo': 3}
# {'世界卡': 2, '簡單卡': 1}
# {'Flygo': 1, 'GoGo': 1, '現金回饋御璽卡': 1, 'Pi': 1}
# {'Flygo': 1, '商務卡': 1}
# {}
# {'世界卡': 1}
# {'LINEPay': 5, '世界卡': 1}
# {'LINEPay': 1}
# {'GoGo': 2, '樂天信用卡': 1}
# {'世界卡': 1}
# {}
# {'鑽金': 1, 'LINEPay': 1}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'富邦數位生活卡': 1, '元大鑽金卡': 1}
# {'元大鑽金卡': 1, '現金回饋御璽卡': 1, 'GoGo': 1, 'LINEPay': 2}
# {'澳盛現金回饋卡': 1, 'GoGo': 1}
# {'GoGo': 2}
# {}
# {'KOKO': 1, 'GoGo': 1, '現金回饋御璽卡': 1, '凱基無限卡': 2, '無限卡': 1}
# {}
# {}
# {'Pi': 1}
# {'icash聯名卡': 1}
# {}
# {}
# {'LINEPay': 1, 'Pi': 1, 'GoGo': 1}
# {'GoGo': 1}
# {'無限卡': 4}
# {'KOKO': 2, 'GoGo': 2, 'LINEPay': 4, '富邦數位生活卡': 1, 'Pi': 2, 'Flygo': 2, '元大鑽金一卡通聯名卡': 1, 'icash聯名卡': 1}
# {'KOKO': 1, '現金回饋御璽卡': 2}
# {'Pi': 1, 'Ubear': 1, 'Only': 1}
# {'樂天信用卡': 1}
# {}
# {'悠遊聯名卡': 1, 'Ubear': 1}
# {'GoGo': 1, 'Ubear': 1, 'Pi': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'鑽金': 2}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 2}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 2}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'Flygo': 2}
# {}
# {'饗樂卡': 2, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 2, 'KOKO': 2, '世界卡': 1}
# {'GoGo': 9, '鑽金': 5, 'LINEPay': 3}
# {'饗樂卡': 1, 'KOKO': 1, 'LINEPay': 1, 'e秒刷鈦金卡': 1, 'GoGo': 3, '簡單卡': 1}
# {'LINEPay': 1, '現金回饋御璽卡': 2, '悠遊聯名卡': 1}
# {'LINEPay': 1, 'KOKO': 1}
# {}
# {}
# {'新光三越聯名卡': 1, 'GoGo': 2}
# {'LINEPay': 2}
# {}
# {'數位生活卡': 1, 'GoGo': 1, '饗樂卡': 1, '鑽金': 1, 'LINEPay': 1, 'KOKO': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {'KOKO': 3}
# {'dawho': 2}
# {'世界卡': 2, 'Flygo': 1}
# {'icash聯名卡': 3}
# {'dawho': 1, 'KOKO': 1, 'Flygo': 1, 'GoGo': 1}
# {'鑽金': 1}
# {'KOKO': 4, 'LINEPay': 1}
# {}
# {'KOKO': 2, 'icash聯名卡': 1}
# {}
# {}
# {'美國運通': 1, '世界卡': 1}
# {}
# {}
# {}
# {'富邦悍將聯名卡': 1}
# {'世界卡': 1}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {'Pi': 1}
# {}
# {'GoGo': 2, 'LINEPay': 1}
# {}
# {'哆啦A夢晶緻卡': 1, '哆啦A夢JCB聯名卡': 2}
# {'悠遊聯名卡': 2}
# {}
# {'LINEPay': 1}
# {'商旅卡': 3}
# {'世界卡': 1}
# {'富邦財神卡': 1}
# {}
# {'Pi': 2}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'Ubear': 1}
# {'悠遊聯名卡': 2, 'Pi': 2}
# {'悠遊聯名卡': 2}
# {'悠遊聯名卡': 1}
# {'Ubear': 1, 'Pi': 1, '數位生活卡': 2}
# {'悠遊聯名卡': 2}
# {'GoGo': 1}
# {}
# {'GoGo': 2}
# {'Flygo': 2}
# {'GoGo': 3}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {'玫瑰卡': 2}
# {}
# {}
# {'GoGo': 2, 'LINEPay': 2}
# {'GoGo': 1}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 4}
# {'GoGo': 2, 'Flygo': 3}
# {'GoGo': 2}
# {'GoGo': 3, 'LINEPay': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 6}
# {'GoGo': 2}
# {'GoGo': 3}
# {}
# {'GoGo': 2}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 3}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 2}
# {'Flygo': 5, 'GoGo': 2}
# {'Flygo': 2, 'LINEPay': 1}
# {'Flygo': 5, '商務卡': 2}
# {'Flygo': 2}
# {'Flygo': 2}
# {}
# {'GoGo': 1}
# {'GoGo': 3, 'LINEPay': 5}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 1, 'e秒刷鈦金卡': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 3, 'Flygo': 1}
# {'GoGo': 2}
# {'GoGo': 2, '富邦數位生活卡': 1}
# {'GoGo': 2}
# {'GoGo': 3}
# {'GoGo': 2, '饗樂卡': 1}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 3}
# {'GoGo': 3}
# {'GoGo': 2, '玫瑰卡': 1, '太陽卡': 1}
# {'GoGo': 1}
# {'GoGo': 1, '現金回饋御璽卡': 1}
# {'GoGo': 1}
# {'GoGo': 1}
# {'GoGo': 2, 'LINEPay': 2}
# {'GoGo': 2}
# {'GoGo': 4}
# {'GoGo': 2}
# {'GoGo': 1}
# {'GoGo': 4}
# {}
# {}
# {'GoGo': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {}
# {}
# {}
# {'Flygo': 3, 'GoGo': 2}
# {}
# {'Flygo': 2}
# {}
# {'GoGo': 1}
# {'GoGo': 1}
# {'LINEPay': 2}
# {'玫瑰卡': 1}
# {'世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'太陽卡': 1, '玫瑰卡': 1, 'GoGo': 3}
# {'世界卡': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {'KOKO': 2, 'GoGo': 1}
# {}
# {}
# {'Flygo': 2, 'GoGo': 1}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {'GoGo': 3, '太陽卡': 1}
# {'玫瑰卡': 2, '太陽卡': 1, 'GoGo': 1}
# {}
# {}
# {'商務卡': 1, 'GoGo': 1}
# {'商務卡': 1, 'Flygo': 1}
# {'GoGo': 1}
# {}
# {'GoGo': 1}
# {'玫瑰卡': 2}
# {'GoGo': 1}
# {'新光三越聯名卡': 2}
# {'GoGo': 1}
# {}
# {'GoGo': 1}
# {'GoGo': 1}
# {'LINEPay': 4, 'GoGo': 1}
# {'玫瑰卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'台新財富無限卡': 3, '無限卡': 3, 'GoGo': 1}
# {}
# {}
# {'Flygo': 2, 'GoGo': 3, 'LINEPay': 1}
# {'玫瑰卡': 1}
# {'太陽卡': 2, '玫瑰卡': 1}
# {'太陽卡': 2, '世界卡': 1, '法拉利無限卡': 1, '無限卡': 2, 'LINEPay': 1, '元大鑽金卡': 1}
# {'Flygo': 1}
# {'GoGo': 2, 'LINEPay': 1, 'KOKO': 3}
# {'GoGo': 1}
# {'GoGo': 5}
# {'GoGo': 2}
# {'GoGo': 2, 'LINEPay': 2, 'KOKO': 1, 'Pi': 1, 'Flygo': 1, '饗樂卡': 3}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 3, 'Flygo': 3}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {}
# {}
# {'GoGo': 1}
# {'KOKO': 2}
# {'GoGo': 1, 'Ubear': 1}
# {}
# {'GoGo': 1}
# {'GoGo': 1}
# {'LINEPay': 1}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {'LINEPay': 1, '元大鑽金卡': 1}
# {}
# {}
# {'GoGo': 1}
# {'GoGo': 1}
# {'Only': 3, 'Pi': 1, 'Flygo': 1, 'GoGo': 1}
# {'鼎極卡': 1}
# {'LINEPay': 1, '鼎極卡': 1, '世界卡': 2, '富邦數位生活卡': 1, '永豐鈦豐卡': 1, '法拉利無限卡': 1, '無限卡': 2, '樂天信用卡': 1, 'GoGo': 1, '元大鑽金卡': 1}
# {'世界卡': 2}
# {'無限卡': 1, 'GoGo': 3, 'KOKO': 1}
# {'無限卡': 2}
# {}
# {'世界卡': 2, '無限卡': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'台灣銀行': 1}
# {}
# {'LINEPay': 7}
# {'LINEPay': 1}
# {}
# {'GoGo': 1, '現金回饋御璽卡': 1, 'LINEPay': 1, '無限卡': 1}
# {'GoGo': 1}
# {'現金回饋御璽卡': 2, 'LINEPay': 2, '鑽金': 1, '簡單卡': 1}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 2, 'dawho': 1}
# {'Flygo': 1}
# {'饗樂卡': 1, '現金回饋御璽卡': 1}
# {}
# {}
# {'Ubear': 1, 'dawho': 2, 'Flygo': 1}
# {'KOKO': 1, '元大鑽金卡': 1, '現金回饋御璽卡': 1}
# {}
# {'鑽金': 1, 'LINEPay': 1, '炫晶御璽卡': 1, '一卡通聯名卡': 1}
# {'饗樂卡': 2, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 8, 'icash聯名卡': 2}
# {'KOKO': 2}
# {'KOKO': 1}
# {}
# {}
# {'KOKO': 4}
# {'KOKO': 2, 'icash聯名卡': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2, '數位生活卡': 1}
# {'KOKO': 5, 'iCash聯名卡': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 5}
# {'KOKO': 5}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 6}
# {'KOKO': 1}
# {'KOKO': 2, 'GoGo': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 1, 'GoGo': 2}
# {'KOKO': 3, 'icash聯名卡': 1}
# {'KOKO': 3}
# {'KOKO': 6, 'GoGo': 3, 'LINEPay': 2}
# {'KOKO': 2, '悠遊聯名卡': 1}
# {'KOKO': 2}
# {'KOKO': 4, '悠遊聯名卡': 3, '一卡通聯名卡': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 4, 'LINEPay': 3}
# {'KOKO': 3}
# {}
# {}
# {'無限卡': 4}
# {'世界卡': 1}
# {'世界卡': 2}
# {}
# {}
# {}
# {}
# {'KOKO': 1, 'icash聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'享購鈦金卡': 1, 'KOKO': 1}
# {'KOKO': 1}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {'無限卡': 2}
# {}
# {'無限卡': 3}
# {'無限卡': 1}
# {}
# {}
# {'Flygo': 3, '鑽金': 1}
# {'icash聯名卡': 1}
# {}
# {'玫瑰卡': 1}
# {'玫瑰卡': 1}
# {}
# {'KOKO': 4}
# {}
# {}
# {}
# {'KOKO': 2}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1, 'icash聯名卡': 1, '享購鈦金卡': 1}
# {}
# {'KOKO': 2, 'NFC手機信用卡': 1}
# {'KOKO': 3, '鈦金商務卡': 1, '現金回饋御璽卡': 1, '享購鈦金卡': 1}
# {'KOKO': 4, 'icash聯名卡': 1}
# {}
# {'KOKO': 1}
# {}
# {'KOKO': 9}
# {'KOKO': 3}
# {'KOKO': 5}
# {}
# {}
# {'無限卡': 1}
# {'世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 2}
# {'無限卡': 2}
# {'無限卡': 1}
# {'無限卡': 1}
# {'無限卡': 1}
# {'無限卡': 1}
# {'無限卡': 1}
# {}
# {'無限卡': 1, 'LINEPay': 1}
# {'Flygo': 1, '無限卡': 1}
# {'無限卡': 2}
# {'無限卡': 1}
# {'無限卡': 2}
# {}
# {}
# {}
# {'e秒刷鈦金卡': 1, 'GoGo': 1, 'Pi': 1}
# {}
# {}
# {}
# {'LINEPay': 2, '星燦卡': 1, 'GoGo': 1}
# {'GoGo': 2}
# {}
# {'LINEPay': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {'饗樂卡': 1}
# {'元大鑽金卡': 1}
# {'樂天信用卡': 1}
# {'GoGo': 1}
# {}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'鑽金': 1, 'LINEPay': 1}
# {'PChome Prime聯名卡': 1}
# {}
# {'無限卡': 1, '世界卡': 1, '鼎極卡': 1}
# {}
# {'無限卡': 1, 'LINEPay': 2}
# {}
# {'法拉利無限卡': 1, '無限卡': 1}
# {}
# {'GoGo': 1}
# {}
# {'LINEPay': 4}
# {}
# {}
# {}
# {'樂天信用卡': 1}
# {'Pi': 1}
# {'Only': 1}
# {'太陽卡': 1}
# {'dawho': 2}
# {'dawho': 3}
# {'dawho': 2}
# {'dawho': 1}
# {'dawho': 3, 'Flygo': 3, '台灣銀行': 2}
# {'dawho': 2}
# {'dawho': 2}
# {'dawho': 4}
# {'dawho': 2}
# {'美國運通': 1}
# {}
# {}
# {'元大鑽金卡': 1}
# {'永豐鈦豐卡': 1, '饗樂卡': 1, '元大鑽金卡': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'GoGo': 2, 'Flygo': 1}
# {}
# {}
# {'世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 1}
# {'鼎極卡': 2, 'LINEPay': 1}
# {}
# {'LINEPay': 1}
# {'KOKO': 1}
# {'悠遊聯名卡': 1}
# {}
# {'鑽金': 1}
# {'ANA聯名卡': 1, 'LINEPay': 1}
# {'樂天信用卡': 4}
# {'LINEPay': 1, '悠遊聯名卡': 3, '饗樂卡': 1}
# {'世界卡': 2, 'GoGo': 1, 'KOKO': 1, 'LINEPay': 3}
# {'KOKO': 1, 'GoGo': 1}
# {}
# {'GoGo': 1}
# {'富邦數位生活卡': 1, 'KOKO': 1}
# {}
# {'GoGo': 3}
# {'GoGo': 3}
# {}
# {'饗樂卡': 2, 'KOKO': 2, 'iCash聯名卡': 1, 'GoGo': 4, 'Pi': 2, 'e秒刷鈦金卡': 2}
# {'Pi': 1, 'Ubear': 1}
# {}
# {'icash聯名卡': 2}
# {'GoGo': 1, 'Only': 3, 'Pi': 1, 'Ubear': 1}
# {}
# {'Pi': 2, 'LINEPay': 1, 'Flygo': 1, 'GoGo': 1}
# {'ANA聯名卡': 2, '商務卡': 3}
# {'LINEPay': 2}
# {'GoGo': 1, 'KOKO': 1}
# {'GoGo': 1}
# {'KOKO': 2, 'GoGo': 1, 'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'元大鑽金卡': 1, 'GoGo': 1, '悠遊聯名卡': 1, 'icash聯名卡': 1}
# {}
# {'LINEPay': 4, 'KOKO': 1}
# {'LINEPay': 2}
# {}
# {}
# {'LINEPay': 3}
# {}
# {'手機信用卡': 1}
# {'LINEPay': 2}
# {}
# {}
# {}
# {'LINEPay': 6}
# {}
# {'Omiyage': 2, '哆啦A夢卡': 1, '簡單卡': 1, 'dawho': 1, 'Flygo': 1, '哆啦A夢晶緻卡': 1, 'LINEPay': 4, 'Ubear': 1}
# {'GoGo': 1, 'LINEPay': 1}
# {'富邦數位生活卡': 2, 'GoGo': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'鑽金': 2, 'COSTCO聯名卡': 1, 'dawho': 2, 'GoGo': 2, 'KOKO': 1}
# {'富邦尊御世界卡': 1, '台新財富無限卡': 1, 'dawho': 1}
# {'富邦尊御世界卡': 1, '鼎極卡': 2}
# {'富邦尊御世界卡': 1}
# {}
# {}
# {'富邦數位生活卡': 2}
# {'富邦數位生活卡': 2}
# {'富邦數位生活卡': 2}
# {'富邦數位生活卡': 1, '數位生活卡': 1}
# {'富邦數位生活卡': 3, 'Flygo': 1}
# {'富邦數位生活卡': 1}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {'KOKO': 2, 'dawho': 1, 'GoGo': 1, 'Flygo': 1, 'LINEPay': 1, 'Ubear': 1}
# {}
# {}
# {}
# {'GoGo': 1, '鑽金': 1, 'KOKO': 1}
# {'Pi': 1}
# {'小小兵信用卡': 2}
# {'酷玩卡': 1}
# {}
# {'饗樂卡': 1, 'KOKO': 1, 'GoGo': 1}
# {'GoGo': 2}
# {'LINEPay': 1}
# {'饗樂卡': 2}
# {'Ubear': 3}
# {}
# {'GoGo': 2}
# {'Ubear': 3, 'GoGo': 1}
# {'KOKO': 4, 'Pi': 3, 'GoGo': 2}
# {'LINEPay': 4, 'KOKO': 2, '現金回饋御璽卡': 1}
# {'GoGo': 2}
# {'鑽金': 1, 'GoGo': 1}
# {'GoGo': 2}
# {}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'LINEPay': 1, '鼎極卡': 1}
# {}
# {'GoGo': 2, 'Flygo': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1, 'LINEPay': 1}
# {}
# {}
# {'無限卡': 1}
# {'一卡通聯名卡': 3, '悠遊聯名卡': 1, 'LINEPay': 1, 'GoGo': 2, '現金回饋御璽卡': 1}
# {'e秒刷鈦金卡': 1}
# {'鈦豐卡': 1, '一卡通聯名卡': 2, 'KOKO': 1}
# {}
# {'LINEPay': 2, 'KOKO': 1, 'GoGo': 1, '鑽金': 1}
# {'GoGo': 2, 'Flygo': 2, 'Only': 1}
# {'簡單卡': 1, '炫晶御璽卡': 1, '鑽金': 1}
# {'世界卡': 2}
# {}
# {'悠遊聯名卡': 1}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {'無限卡': 1, 'LINEPay': 2, '鼎極卡': 1}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'LINEPay': 3}
# {'Flygo': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'無限卡': 1}
# {}
# {'KOKO': 1}
# {}
# {'Pi': 4}
# {'悠遊聯名卡': 1}
# {}
# {'悠遊聯名卡': 1, '新光三越悠遊聯名卡': 1, 'GoGo': 1}
# {}
# {'悠遊聯名卡': 1}
# {'Pi': 1, '悠遊聯名卡': 1}
# {'悠遊聯名卡': 3}
# {'悠遊聯名卡': 2}
# {'悠遊聯名卡': 2}
# {'悠遊聯名卡': 2, 'dawho': 1}
# {'悠遊聯名卡': 2}
# {'悠遊聯名卡': 1, 'LINEPay': 1}
# {'悠遊聯名卡': 1, '酷玩卡': 1}
# {'悠遊聯名卡': 2, '鑽金': 1, '哆啦A夢JCB聯名卡': 1}
# {'悠遊聯名卡': 1}
# {'悠遊聯名卡': 1, 'GoGo': 1}
# {'悠遊聯名卡': 2}
# {}
# {}
# {'LINEPay': 2, 'KOKO': 2, 'GoGo': 2}
# {'Ubear': 1, 'Pi': 1}
# {}
# {'無限卡': 1}
# {'LINEPay': 1, '無限卡': 1}
# {'饗樂卡': 1, 'GoGo': 1, '鑽金': 1}
# {'GoGo': 1, 'KOKO': 1, '樂天信用卡': 1, 'LINEPay': 1, '鑽金': 1, '現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 7, 'LINEPay': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 4, 'Flygo': 1, 'GoGo': 1}
# {'Pi': 3, 'LINEPay': 3}
# {'GoGo': 1}
# {}
# {}
# {'LINEPay': 4, 'KOKO': 1}
# {}
# {'Flygo': 5}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {'現金回饋御璽卡': 2}
# {'GoGo': 1}
# {}
# {}
# {'Pi': 1}
# {'KOKO': 1}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {'Ubear': 2}
# {'GoGo': 1, 'LINEPay': 1, 'KOKO': 1}
# {}
# {}
# {'法拉利無限卡': 1, '無限卡': 1}
# {}
# {'世界卡': 1}
# {}
# {'鼎極卡': 1, 'LINEPay': 1}
# {}
# {'饗樂卡': 1}
# {'LINEPay': 2, 'GoGo': 1, 'KOKO': 1, '簡單卡': 1, 'Flygo': 2}
# {'LINEPay': 4}
# {}
# {}
# {}
# {'GoGo': 4, 'Ubear': 3}
# {}
# {}
# {'LINEPay': 2, '鼎極卡': 5}
# {}
# {}
# {'LINEPay': 2}
# {}
# {'世界卡': 3}
# {'世界卡': 4}
# {}
# {}
# {}
# {}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {'鑽金': 1}
# {'鑽金': 1}
# {'Flygo': 1, 'LINEPay': 1, '炫晶御璽卡': 1}
# {}
# {}
# {'GoGo': 1, 'KOKO': 1}
# {}
# {'星燦卡': 1}
# {'GoGo': 3, 'KOKO': 1}
# {}
# {}
# {'Pi': 1, 'Ubear': 3}
# {'現金回饋御璽卡': 1, '鑽金': 1}
# {}
# {'樂天信用卡': 1, 'Flygo': 1, 'e秒刷鈦金卡': 1}
# {'GoGo': 5, 'icash聯名卡': 1}
# {'KOKO': 3, 'e秒刷鈦金卡': 4, 'GoGo': 1}
# {'鑽金': 1, '炫晶御璽卡': 1}
# {}
# {}
# {'KOKO': 5, 'GoGo': 5}
# {'LINEPay': 2}
# {'GoGo': 1, 'Pi': 1, 'LINEPay': 2, '鑽金': 1}
# {'Ubear': 1, 'GoGo': 1, 'KOKO': 1}
# {'Flygo': 4, 'dawho': 3, 'GoGo': 2}
# {}
# {}
# {'LINEPay': 1, '鑽金': 1}
# {}
# {}
# {}
# {}
# {'Flygo': 4, 'GoGo': 1}
# {'LINEPay': 1}
# {}
# {'富邦數位生活卡': 1, '超級現金回饋卡': 1}
# {'LINEPay': 2, '鑽金': 1}
# {}
# {'無限卡': 3, '樂天信用卡': 1}
# {'Flygo': 7}
# {'Flygo': 1}
# {'元大鑽金卡': 2, '鑽金': 1}
# {}
# {'超級現金回饋卡': 1, '永豐鈦豐卡': 1, '鈦豐卡': 1}
# {'簡單卡': 1, '鑽金': 1}
# {'鑽金': 1}
# {}
# {}
# {}
# {'dawho': 1}
# {}
# {'無限卡': 1}
# {'GoGo': 2}
# {'無限卡': 2}
# {'無限卡': 1}
# {}
# {}
# {}
# {'世界卡': 1, 'Flygo': 1}
# {'GoGo': 2}
# {'LINEPay': 1}
# {}
# {'GoGo': 2, 'Flygo': 1}
# {}
# {}
# {}
# {'世界卡': 2}
# {}
# {}
# {}
# {'GoGo': 1}
# {'炫晶御璽卡': 1}
# {'炫晶御璽卡': 1}
# {'現金回饋御璽卡': 2}
# {'炫晶御璽卡': 1}
# {'世界卡': 4}
# {'無限卡': 6, '世界卡': 6}
# {}
# {'炫晶御璽卡': 2}
# {}
# {'世界卡': 2, 'LINEPay': 3}
# {'世界卡': 3}
# {'世界卡': 1}
# {}
# {'法拉利無限卡': 1}
# {'元大鑽金卡': 2}
# {}
# {}
# {'數位生活卡': 1, '饗樂卡': 1, 'GoGo': 1, 'LINEPay': 1}
# {'Pi': 1}
# {}
# {}
# {}
# {'dawho': 2, 'Ubear': 2}
# {'KOKO': 2, '鑽金': 4, 'LINEPay': 1}
# {'Ubear': 3, 'dawho': 2, 'KOKO': 1}
# {}
# {'饗樂卡': 2}
# {'Omiyage': 1, 'GoGo': 1, 'Flygo': 1, 'Pi': 2, 'Ubear': 1, 'KOKO': 1, 'LINEPay': 1}
# {'微風聯名卡': 1}
# {'GoGo': 1}
# {}
# {'KOKO': 3}
# {'Flygo': 3, '商務卡': 2}
# {'樂天信用卡': 2}
# {}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'富邦數位生活卡': 1, '數位生活卡': 1, 'GoGo': 1}
# {'Flygo': 1, '無限卡': 1}
# {'元大鑽金卡': 1}
# {'饗樂卡': 1}
# {'LINEPay': 2, '法拉利無限卡': 1, '無限卡': 3, '世界卡': 1}
# {'新光三越聯名卡': 1}
# {}
# {}
# {'世界卡': 1}
# {}
# {}
# {'dawho': 2}
# {}
# {}
# {}
# {'Pi': 1, 'KOKO': 2, 'GoGo': 1}
# {}
# {}
# {}
# {'KOKO': 1}
# {'KOKO': 3}
# {}
# {'LINEPay': 5}
# {}
# {}
# {}
# {}
# {'Flygo': 1, 'GoGo': 1}
# {}
# {}
# {'樂天信用卡': 1}
# {'GoGo': 1}
# {'饗樂卡': 2, 'GoGo': 1, 'KOKO': 1, 'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 3, 'GoGo': 2}
# {}
# {}
# {'GoGo': 1, 'e秒刷鈦金卡': 1}
# {}
# {'KOKO': 2}
# {}
# {'LINEPay': 5}
# {'LINEPay': 4}
# {'Flygo': 1}
# {}
# {'GoGo': 1, 'KOKO': 1}
# {}
# {'KOKO': 1, 'Ubear': 1, 'dawho': 1, '數位生活卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'樂天信用卡': 1}
# {'樂天信用卡': 3}
# {'樂天信用卡': 3}
# {'樂天信用卡': 7}
# {'樂天信用卡': 1}
# {'樂天信用卡': 2}
# {'樂天信用卡': 4}
# {}
# {}
# {'樂天信用卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {'鑽金': 1, '數位生活卡': 1}
# {}
# {}
# {'無限卡': 1}
# {'現金回饋御璽卡': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {}
# {'Ubear': 2, 'e秒刷鈦金卡': 2, 'GoGo': 1}
# {'KOKO': 1, 'LINEPay': 1, 'GoGo': 1}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {'Flygo': 2, '炫晶御璽卡': 2, 'everyday鈦金卡': 1, 'dawho': 1, '鑽金': 2, 'LINEPay': 2}
# {}
# {'炫晶御璽卡': 1}
# {'鑽金': 4}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'dawho': 1}
# {}
# {'永豐鈦豐卡': 1, '鈦豐卡': 1}
# {}
# {'SPORT卡': 3, 'dawho': 1}
# {'SPORT卡': 2}
# {}
# {}
# {'dawho': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 2}
# {'dawho': 2, '數位生活卡': 2, '鑽金': 1, 'KOKO': 1, 'GoGo': 2}
# {'dawho': 1}
# {'dawho': 2}
# {'dawho': 1}
# {'dawho': 1}
# {'dawho': 4, 'Pi': 1}
# {'dawho': 3, 'Flygo': 1}
# {'dawho': 1}
# {'dawho': 2}
# {'dawho': 2}
# {'dawho': 2, 'Ubear': 2, 'GoGo': 1, 'Flygo': 1}
# {'dawho': 3}
# {'dawho': 1}
# {'dawho': 3, 'GoGo': 2}
# {'dawho': 1}
# {'dawho': 1}
# {'dawho': 3}
# {'dawho': 3}
# {'dawho': 2, 'LINEPay': 2}
# {'dawho': 4}
# {'dawho': 5}
# {'dawho': 1}
# {'dawho': 1}
# {'dawho': 3}
# {'LINEPay': 2}
# {'dawho': 1}
# {}
# {'LINEPay': 1}
# {'dawho': 2}
# {}
# {}
# {'永豐財富無限卡': 1}
# {}
# {'LINEPay': 2}
# {}
# {'GoGo': 5, '現金回饋御璽卡': 1, '元大鑽金卡': 1, 'LINEPay': 6, '鑽金': 1, 'Flygo': 1}
# {}
# {}
# {'鑽金': 1, '饗樂卡': 1, 'KOKO': 1, 'GoGo': 1}
# {'Pi': 4, 'GoGo': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {'法拉利無限卡': 2, '無限卡': 2}
# {'法拉利無限卡': 1, '無限卡': 3}
# {'KOKO': 1, 'GoGo': 2, '鑽金': 1, '簡單卡': 1, '一卡通聯名卡': 1}
# {}
# {}
# {'GoGo': 1}
# {'LINEPay': 5, '炫晶御璽卡': 1, '現金回饋御璽卡': 2}
# {'LINEPay': 3, '無限卡': 3}
# {'鑽金': 1}
# {'Flygo': 2}
# {}
# {}
# {}
# {'簡單卡': 2, 'Flygo': 1}
# {'鑽金': 1}
# {'dawho': 1, 'Flygo': 2}
# {}
# {'dawho': 2, 'Flygo': 1}
# {}
# {'LINEPay': 3, '元大鑽金卡': 1}
# {'鑽金': 1, '富邦數位生活卡': 1}
# {}
# {'玫瑰卡': 2, 'GoGo': 3, 'LINEPay': 2, '元大鑽金卡': 2}
# {}
# {}
# {'LINEPay': 3, '數位生活卡': 2, 'KOKO': 1, 'GoGo': 3, 'Flygo': 1}
# {'KOKO': 1}
# {'Ubear': 1}
# {'KOKO': 2}
# {}
# {}
# {'KOKO': 1}
# {}
# {}
# {'台灣銀行': 1}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {'GoGo': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {'無限卡': 3}
# {'現金回饋御璽卡': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 2}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 2}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1, 'KOKO': 2}
# {'現金回饋御璽卡': 1, '元大鑽金卡': 1}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 2, '鼎極卡': 2}
# {}
# {}
# {}
# {'澳盛現金回饋卡': 1, 'GoGo': 1}
# {'商務白金卡': 1, '世界卡': 1}
# {}
# {}
# {'澳盛現金回饋卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'Pi': 2}
# {}
# {'無限卡': 2}
# {}
# {}
# {}
# {'GoGo': 1, '鑽金': 1}
# {'GoGo': 2}
# {}
# {}
# {}
# {}
# {'GoGo': 2, '鑽金': 1}
# {'美國運通': 2}
# {}
# {'新光三越聯名卡': 1, 'GoGo': 1}
# {}
# {'GoGo': 1, 'KOKO': 1, 'LINEPay': 1}
# {'LINEPay': 1, 'e秒刷鈦金卡': 1}
# {'無限卡': 7, '商務卡': 1}
# {}
# {'元大鑽金卡': 1, 'GoGo': 3, 'KOKO': 3}
# {}
# {'LINEPay': 2}
# {}
# {}
# {}
# {}
# {'Pi': 1}
# {}
# {'Ubear': 2, 'Only': 3, 'Pi': 1}
# {'Pi': 2, '悠遊聯名卡': 1}
# {'Ubear': 3, 'LINEPay': 1}
# {'Ubear': 2}
# {}
# {}
# {'Pi': 1}
# {}
# {}
# {'icash聯名卡': 4}
# {'icash聯名卡': 4}
# {'icash聯名卡': 2}
# {}
# {}
# {'LINEPay': 3}
# {}
# {'Only': 1}
# {'Only': 2, 'KOKO': 1, 'dawho': 1}
# {'Only': 2}
# {'Only': 2}
# {'Only': 4, '無限卡': 1}
# {'Only': 4, 'Pi': 1}
# {'Only': 3, 'dawho': 3, 'KOKO': 2, 'Flygo': 2}
# {'Only': 2}
# {}
# {'LINEPay': 2}
# {'Pi': 1}
# {}
# {}
# {'Pi': 1}
# {'KOKO': 2, '元大鑽金卡': 1, 'LINEPay': 1, '現金回饋御璽卡': 1}
# {'Pi': 2}
# {'Pi': 1}
# {'Pi': 1}
# {}
# {'Pi': 1}
# {'Pi': 6, 'GoGo': 1, '鑽金': 2}
# {'Pi': 2}
# {'Pi': 2}
# {'LINEPay': 1, '鼎極卡': 1, 'Pi': 1}
# {'Only': 3}
# {'LINEPay': 3}
# {'Pi': 4}
# {'Pi': 1}
# {'Pi': 1}
# {'Pi': 1}
# {}
# {'Pi': 1, 'GoGo': 2, 'KOKO': 1}
# {'Pi': 1}
# {'Pi': 1}
# {}
# {'Pi': 1}
# {}
# {'Ubear': 2, 'Pi': 1}
# {'Ubear': 1}
# {'Ubear': 2, 'GoGo': 1}
# {}
# {}
# {'Ubear': 1, 'GoGo': 2}
# {'Pi': 2, 'Ubear': 1}
# {}
# {'Ubear': 1, 'icash聯名卡': 1, 'GoGo': 1, 'KOKO': 1}
# {'Ubear': 2}
# {'Ubear': 1}
# {'Ubear': 2}
# {'Ubear': 4, 'LINEPay': 1, 'Pi': 1}
# {'Ubear': 2}
# {'Ubear': 1}
# {'Ubear': 1}
# {'Ubear': 2}
# {'Ubear': 2}
# {'Ubear': 2, 'dawho': 1}
# {'Ubear': 2}
# {'Ubear': 2}
# {'Ubear': 1}
# {'Ubear': 3, 'LINEPay': 5}
# {}
# {}
# {'Ubear': 1}
# {'Ubear': 4}
# {}
# {'Ubear': 1}
# {'世界卡': 5}
# {'世界卡': 1, '無限卡': 1}
# {'世界卡': 3, '悠遊聯名卡': 1}
# {'世界卡': 2}
# {'世界卡': 3}
# {'世界卡': 2}
# {'世界卡': 1}
# {'世界卡': 4, '醫師尊榮無限卡': 1}
# {'世界卡': 3, '無限卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'Only': 2}
# {'無限卡': 1}
# {'台灣銀行': 1}
# {'世界卡': 2}
# {'Pi': 2, 'Ubear': 1, 'KOKO': 1}
# {'LINEPay': 1}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 1}
# {}
# {'GoGo': 1}
# {}
# {}
# {'Pi': 1}
# {}
# {}
# {}
# {'Ubear': 1}
# {'Pi': 1}
# {}
# {'Only': 1}
# {'Ubear': 4, 'Pi': 1}
# {'Pi': 3, '悠遊聯名卡': 1}
# {}
# {}
# {'LINEPay': 6}
# {}
# {}
# {}
# {'Pi': 1}
# {'世界卡': 1}
# {}
# {'icash聯名卡': 1, 'LINEPay': 1}
# {'Ubear': 3}
# {}
# {}
# {}
# {'Pi': 2}
# {'幸運PLUS鈦金卡': 2}
# {}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'Ubear': 2}
# {}
# {'Only': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {'Flygo': 2, 'LINEPay': 1, 'GoGo': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 5, 'Ubear': 1, 'Flygo': 2, '無限卡': 2, 'Only': 4}
# {'KOKO': 1, '數位生活卡': 1, '鑽金': 1, 'LINEPay': 1}
# {'元大鑽金卡': 1}
# {}
# {}
# {'LINEPay': 4, 'GoGo': 3}
# {'LINEPay': 1, 'Pi': 1}
# {'LINEPay': 5}
# {}
# {'GoGo': 6, '炫晶御璽卡': 2, 'KOKO': 1}
# {'GoGo': 1, 'Flygo': 1}
# {}
# {'商務卡': 1}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'無限卡': 2}
# {}
# {'無限卡': 3}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'炫晶御璽卡': 2, 'everyday鈦金卡': 1, '現金回饋御璽卡': 1}
# {'世界卡': 2}
# {'饗樂卡': 1}
# {'饗樂卡': 3}
# {'美國運通': 2}
# {'無限卡': 1}
# {}
# {}
# {}
# {'GoGo': 3}
# {}
# {}
# {}
# {}
# {'數位生活卡': 1, '炫晶御璽卡': 1, 'Flygo': 2, 'Pi': 2}
# {'新光三越聯名卡': 1}
# {'元大鑽金卡': 1, '現金回饋御璽卡': 1, '微風聯名卡': 2, '新光三越聯名卡': 1, '悠遊聯名卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'GoGo': 2, 'LINEPay': 2, 'KOKO': 1}
# {}
# {'LINEPay': 1}
# {}
# {'LINEPay': 2}
# {}
# {}
# {'鑽金': 1}
# {}
# {}
# {'KOKO': 1}
# {'美國運通': 1, '世界卡': 2}
# {}
# {'饗樂卡': 1, '世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'Only': 1, 'dawho': 1}
# {'簡單卡': 3, 'dawho': 1}
# {'鑽金': 1, 'GoGo': 3, 'KOKO': 2, 'e秒刷鈦金卡': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {'LINEPay': 1}
# {}
# {'亞洲無限卡': 2, '世界卡': 3, '無限卡': 2}
# {}
# {'世界卡': 1, '台新財富無限卡': 1, 'LINEPay': 3}
# {}
# {'Pi': 2}
# {'GoGo': 2}
# {'饗樂卡': 1}
# {}
# {'KOKO': 1}
# {'Omiyage': 1}
# {'GoGo': 1}
# {'e秒刷鈦金卡': 9, 'LINEPay': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {'Pi': 1}
# {}
# {}
# {}
# {'LINEPay': 2}
# {'LINEPay': 1, 'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {'KOKO': 1}
# {'Flygo': 1, 'e秒刷鈦金卡': 2, 'GoGo': 1}
# {'樂天信用卡': 2}
# {}
# {}
# {}
# {}
# {'Only': 1, 'GoGo': 1, 'Ubear': 1, 'LINEPay': 1}
# {'Pi': 1}
# {}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {'美國運通': 1}
# {'鑽金': 1}
# {'鑽金': 1, 'GoGo': 1, '現金回饋御璽卡': 1}
# {}
# {}
# {'Flygo': 2}
# {'鑽金': 2, 'KOKO': 1, 'e秒刷鈦金卡': 1, 'LINEPay': 1}
# {'故宮之友卡': 1, '鈦金商旅卡': 2}
# {'美國運通': 2}
# {}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 2}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 3}
# {'美國運通': 3}
# {}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 2}
# {'美國運通': 1}
# {'美國運通': 2}
# {'美國運通': 3}
# {'美國運通': 2}
# {'美國運通': 2}
# {'美國運通': 1}
# {'美國運通': 4}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 3, 'Pi': 1}
# {'美國運通': 2}
# {'美國運通': 6, '世界卡': 1}
# {'美國運通': 1}
# {'LINEPay': 1, '世界卡': 4, '無限卡': 1, '商旅卡': 1, '現金回饋御璽卡': 1}
# {}
# {'美國運通': 2}
# {'美國運通': 1}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 8, 'GoGo': 2, 'LINEPay': 1, 'Gogoro聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'法拉利無限卡': 2, '無限卡': 1}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {'LINEPay': 1}
# {'LINEPay': 1}
# {'鑽金': 1}
# {}
# {'法拉利無限卡': 2, '無限卡': 2}
# {'法拉利無限卡': 2, '無限卡': 2}
# {'法拉利無限卡': 1, '無限卡': 1}
# {'理財型白金卡': 1}
# {}
# {}
# {'LINEPay': 1}
# {'賴點卡': 2, '微風聯名卡': 1, '鑽金': 2}
# {}
# {}
# {'賴點卡': 2, 'LINEPay': 2}
# {'賴點卡': 2}
# {'賴點卡': 2}
# {}
# {}
# {'無限卡': 6, '法拉利無限卡': 3, '大立無限卡': 1}
# {}
# {'美安悠遊聯名卡': 1}
# {}
# {'LINEPay': 4}
# {}
# {}
# {'悠遊聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 2}
# {'GoGo': 1, 'LINEPay': 1, 'Pi': 1}
# {'富邦數位生活卡': 1}
# {}
# {}
# {'GoGo': 1}
# {}
# {'GoGo': 2}
# {'Ubear': 3, '超級現金回饋卡': 3, '悠遊聯名卡': 1, '哆啦A夢JCB聯名卡': 1, 'Pi': 3}
# {}
# {}
# {}
# {}
# {'LINEPay': 4}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'LINEPay': 3}
# {}
# {'LINEPay': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {'饗樂卡': 1, 'PChome Prime聯名卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'PChome Prime聯名卡': 1}
# {}
# {}
# {'現金回饋御璽卡': 1, 'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {'饗樂卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 1}
# {}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {}
# {'悠遊聯名卡': 2}
# {}
# {}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 2}
# {'世界卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 2, 'Flygo': 1}
# {'無限卡': 3}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'饗樂卡': 1}
# {}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {'世界卡': 3, '元大鑽金卡': 1, '無限卡': 2}
# {}
# {}
# {}
# {'COSTCO聯名卡': 1}
# {'饗樂卡': 3}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 2}
# {'饗樂卡': 2}
# {'饗樂卡': 3}
# {'饗樂卡': 1}
# {}
# {'e秒刷鈦金卡': 3}
# {}
# {}
# {}
# {'世界卡': 2}
# {}
# {}
# {}
# {}
# {'LINEPay': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {'手機信用卡': 3}
# {}
# {}
# {}
# {'簡單卡': 2, 'GoGo': 3, '鑽金': 1}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {'LINEPay': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {'e秒刷鈦金卡': 2}
# {'KOKO': 2, 'LINEPay': 5, 'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 3, 'KOKO': 1}
# {'GoGo': 1, 'LINEPay': 1}
# {}
# {'Flygo': 2, 'GoGo': 1, 'Only': 4, 'Ubear': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 2, 'LINEPay': 1, 'Pi': 1}
# {}
# {}
# {'LINEPay': 2}
# {}
# {'GoGo': 1}
# {'ANA聯名卡': 3}
# {}
# {'Pi': 4}
# {'GoGo': 1, 'Flygo': 1, 'LINEPay': 1}
# {'GoGo': 1, 'KOKO': 1, '鑽金': 3, '中華電信感恩卡': 2}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'樂天信用卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {'LINEPay': 1}
# {}
# {}
# {'ANA聯名卡': 1}
# {'LINEPay': 2}
# {}
# {}
# {'法拉利無限卡': 1, '無限卡': 1, 'LINEPay': 1}
# {'KOKO': 2, 'GoGo': 2, 'LINEPay': 3, '鑽金': 1}
# {}
# {}
# {}
# {'GoGo': 1}
# {'無限卡': 1}
# {'e秒刷鈦金卡': 2}
# {}
# {}
# {'KOKO': 1}
# {'KOKO': 4}
# {'KOKO': 2}
# {'KOKO': 1}
# {'LINEPay': 3, 'Pi': 1}
# {'LINEPay': 3}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'KOKO': 4, 'Pi': 2, 'LINEPay': 1}
# {}
# {'GoGo': 2}
# {'GoGo': 2}
# {}
# {'樂天信用卡': 1}
# {'世界卡': 1}
# {}
# {'一卡通聯名卡': 1}
# {'無限卡': 3, 'ANA聯名卡': 1}
# {}
# {}
# {'LINEPay': 1}
# {'富邦數位生活卡': 1}
# {'數位生活卡': 2, 'GoGo': 3, 'LINEPay': 1}
# {}
# {}
# {'Only': 1, 'Ubear': 1}
# {}
# {}
# {}
# {}
# {}
# {'Pi': 2}
# {}
# {'鑽金': 1}
# {'元大鑽金icash聯名卡': 2}
# {'元大鑽金卡': 2}
# {'元大鑽金卡': 2}
# {}
# {}
# {}
# {'Pi': 2}
# {'KOKO': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {'LINEPay': 1}
# {}
# {'LINEPay': 2, '鼎極卡': 2, 'KOKO': 1, 'GoGo': 1}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {'Pi': 2}
# {'Pi': 1}
# {}
# {'KOKO': 1, 'GoGo': 1}
# {'LINEPay': 1}
# {}
# {'富邦數位生活卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'炫晶御璽卡': 1}
# {}
# {}
# {'無限卡': 3, 'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {'世界卡': 1}
# {'GoGo': 1, 'LINEPay': 1, '元大鑽金卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {}
# {'Ubear': 1}
# {'世界卡': 2}
# {}
# {'Pi': 1, 'Ubear': 1}
# {}
# {}
# {}
# {}
# {'Ubear': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 1, 'KOKO': 1}
# {'LINEPay': 1}
# {'悠遊聯名卡': 1}
# {}
# {}
# {}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {'LINEPay': 2}
# {'法拉利無限卡': 2, '無限卡': 2}
# {}
# {}
# {'饗樂卡': 2}
# {'超級現金回饋卡': 2}
# {'ANA聯名卡': 1, '無限卡': 1, 'Flygo': 2}
# {}
# {}
# {'KOKO': 3, 'LINEPay': 2, '鼎極卡': 1}
# {'元大鑽金卡': 2}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'LINEPay': 3, '現金回饋御璽卡': 1}
# {'KOKO': 4, 'LINEPay': 3}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'dawho': 1}
# {}
# {'世界卡': 5}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'LINEPay': 3}
# {}
# {'元大鑽金卡': 1}
# {'Ubear': 3, 'Pi': 2}
# {}
# {'GoGo': 8, 'LINEPay': 1, '玫瑰卡': 1, 'KOKO': 1, '數位生活卡': 1}
# {'LINEPay': 1}
# {}
# {'LINEPay': 1}
# {}
# {'LINEPay': 1, 'KOKO': 1, 'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 4}
# {'Pi': 1}
# {}
# {}
# {'饗樂卡': 1, '酷玩卡': 1}
# {'Flygo': 1}
# {}
# {'dawho': 1, 'Ubear': 1}
# {'富邦數位生活卡': 1, '元大鑽金卡': 1, '樂天信用卡': 1}
# {'饗樂卡': 1, '悠遊聯名卡': 1, '太陽卡': 2, '新光三越聯名卡': 2, 'icash聯名卡': 2, '統一獅聯名卡': 3, 'Flygo': 2, 'Pi': 5, '星燦卡': 1, 'GoGo': 3, 'LINEPay': 3, 'e秒刷鈦金卡': 1, 'KOKO': 1}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'Flygo': 1, 'e秒刷鈦金卡': 1}
# {}
# {}
# {'LINEPay': 4}
# {'GoGo': 3, 'Pi': 2}
# {'LINEPay': 1}
# {}
# {'Pi': 1}
# {}
# {'dawho': 1, 'Flygo': 1}
# {'KOKO': 1}
# {}
# {'KOKO': 1}
# {}
# {'Ubear': 1}
# {'KOKO': 2, 'LINEPay': 1}
# {}
# {'KOKO': 1}
# {}
# {'GoGo': 1, '鑽金': 2, 'KOKO': 1}
# {}
# {'Pi': 1}
# {'e秒刷鈦金卡': 2, 'icash聯名卡': 2, 'GoGo': 4, 'KOKO': 2, 'LINEPay': 2, '現金回饋御璽卡': 2}
# {}
# {'無限卡': 1}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {'法拉利無限卡': 2, 'icash聯名卡': 1}
# {'GoGo': 5, 'LINEPay': 1}
# {'KOKO': 1}
# {}
# {}
# {'icash聯名卡': 1}
# {'Flygo': 1}
# {}
# {}
# {'太陽卡': 2}
# {'GoGo': 2, 'KOKO': 1, 'LINEPay': 1}
# {'GoGo': 1, 'Flygo': 1}
# {}
# {'GoGo': 2, 'LINEPay': 3}
# {}
# {'Ubear': 1}
# {}
# {'富邦數位生活卡': 1}
# {}
# {'樂購卡': 1}
# {}
# {}
# {'KOKO': 1, '炫晶御璽卡': 1, '簡單卡': 1}
# {}
# {'Pi': 2, 'GoGo': 1}
# {'Ubear': 2, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 3}
# {}
# {'世界卡': 1}
# {'鑽金': 1}
# {'鑽金': 1, 'icash聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'理財型白金卡': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'樂天信用卡': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {'KOKO': 2, '悠遊聯名卡': 3, '元大鑽金卡': 1, '鈦金商務卡': 1}
# {'酷玩卡': 1}
# {'酷玩卡': 2}
# {'LINEPay': 1, 'GoGo': 1}
# {'Pi': 2, 'LINEPay': 1}
# {}
# {'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {}
# {}
# {'鑽金': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'無限卡': 1}
# {'無限卡': 1}
# {}
# {'KOKO': 1, 'GoGo': 1}
# {}
# {}
# {'LINEPay': 2, '元大鑽金卡': 1, 'KOKO': 1}
# {'GoGo': 1}
# {'LINEPay': 1}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {'世界卡': 6, '鼎極卡': 2, '商務卡': 1}
# {'LINEPay': 2}
# {}
# {'鼎極卡': 1}
# {}
# {}
# {}
# {'鑽金': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'鑽金': 2}
# {'鑽金': 2}
# {}
# {'鑽金': 1, 'KOKO': 1, 'GoGo': 1}
# {}
# {}
# {'KOKO': 4, 'GoGo': 2, 'LINEPay': 8}
# {}
# {'Pi': 2}
# {}
# {}
# {}
# {'GoGo': 3}
# {}
# {'KOKO': 2, 'icash聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'一卡通聯名卡': 1}
# {'星燦卡': 1, '數位生活卡': 1}
# {'LINEPay': 2}
# {'dawho': 1}
# {'元大鑽金卡': 1}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 2, 'icash聯名卡': 2}
# {'Ubear': 1}
# {'Only': 2}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 5}
# {}
# {'無限卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 3, '玫瑰卡': 1, 'LINEPay': 1}
# {}
# {'ANA聯名卡': 1, '無限卡': 1, 'KOKO': 1, '饗樂卡': 1}
# {'KOKO': 1, 'LINEPay': 3}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'玫瑰卡': 1}
# {'無限卡': 1, 'GoGo': 1, 'LINEPay': 1, '富邦數位生活卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 3}
# {}
# {}
# {}
# {'KOKO': 1}
# {}
# {'Ubear': 2}
# {'Flygo': 1}
# {}
# {'鑽金': 1, '無限卡': 2, '世界卡': 1}
# {'世界卡': 1}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 4}
# {'美國運通': 1}
# {'美國運通': 1}
# {'e秒刷鈦金卡': 1, 'LINEPay': 1, 'Flygo': 2}
# {'e秒刷鈦金卡': 1, 'LINEPay': 1, 'Flygo': 2}
# {}
# {}
# {'KOKO': 1}
# {'GoGo': 1}
# {}
# {'LINEPay': 1, 'Flygo': 1}
# {'LINEPay': 1, 'KOKO': 1, 'GoGo': 1}
# {}
# {'Flygo': 1}
# {'商務卡': 1}
# {'國民旅遊卡': 1, 'LINEPay': 2}
# {'Ubear': 1}
# {'e秒刷鈦金卡': 1}
# {'兆豐世界卡': 1, '無限卡': 1}
# {'dawho': 1}
# {'GoGo': 1, 'Pi': 1, 'dawho': 1}
# {}
# {}
# {'GoGo': 1, 'LINEPay': 1, 'KOKO': 1}
# {'LINEPay': 1, 'GoGo': 1}
# {'Pi': 1}
# {}
# {'LINEPay': 3}
# {'GoGo': 1}
# {}
# {}
# {'GoGo': 3}
# {'LINEPay': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {'鑽金': 1}
# {'LINEPay': 5}
# {'dawho': 5, 'Ubear': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'KOKO': 1, 'GoGo': 1, 'e秒刷鈦金卡': 1, 'LINEPay': 1}
# {}
# {'鑽金': 1}
# {}
# {'e秒刷鈦金卡': 1, '鑽金': 1}
# {'GoGo': 1}
# {}
# {'Ubear': 1}
# {}
# {'GoGo': 3}
# {'GoGo': 2}
# {'GoGo': 5, 'e秒刷鈦金卡': 1, '太陽卡': 1}
# {'無限卡': 1, '世界卡': 1}
# {}
# {'GoGo': 1, 'Flygo': 2}
# {'LINEPay': 4}
# {}
# {'現金回饋御璽卡': 1}
# {'KOKO': 1}
# {'澳盛現金回饋卡': 1}
# {'Pi': 1}
# {'Pi': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 2, '富邦財神卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 2, '商務卡': 1, 'KOKO': 1}
# {}
# {}
# {'Pi': 1}
# {'LINEPay': 1}
# {'LINEPay': 1, 'KOKO': 1}
# {'LINEPay': 2, 'GoGo': 1, 'KOKO': 1}
# {'無限卡': 1}
# {'數位生活卡': 1}
# {'鑽金': 1, 'Flygo': 4, 'GoGo': 1}
# {}
# {'LINEPay': 5, 'Ubear': 5}
# {}
# {'LINEPay': 2, 'GoGo': 1, 'Flygo': 1}
# {'國民旅遊卡': 1, '饗樂卡': 2, '悠遊聯名卡': 1, '大甲媽祖認同卡': 1, '哆啦A夢卡': 1}
# {'e秒刷鈦金卡': 2}
# {'GoGo': 1, 'LINEPay': 1}
# {'LINEPay': 2, 'ANA聯名卡': 1}
# {}
# {'GoGo': 2, '現金回饋御璽卡': 1, '饗樂卡': 1}
# {}
# {'美國運通': 1}
# {}
# {}
# {'dawho': 2, 'Flygo': 1}
# {'饗樂卡': 1, 'GoGo': 1, '富邦數位生活卡': 1, 'LINEPay': 1, 'KOKO': 1, '樂購卡': 1, '個人商旅卡': 1}
# {'一卡通聯名卡': 1}
# {'Ubear': 1}
# {'饗樂卡': 1}
# {'饗樂卡': 1}
# {'KOKO': 1, 'GoGo': 2, 'e秒刷鈦金卡': 1, '簡單卡': 1}
# {'KOKO': 1, 'LINEPay': 1, 'GoGo': 1, '鑽金': 1, '饗樂卡': 1}
# {}
# {'富邦鑽保卡': 1, 'LINEPay': 1}
# {}
# {'商務卡': 1, '無限卡': 1}
# {'鑽金': 2}
# {'現金回饋御璽卡': 2, 'LINEPay': 1, '鈦金商務卡': 1, '樂天信用卡': 1, '鑽金': 1, 'KOKO': 1}
# {'KOKO': 2, 'icash聯名卡': 2}
# {'LINEPay': 1, 'KOKO': 1}
# {'e秒刷鈦金卡': 1, 'KOKO': 1}
# {'台灣銀行': 2}
# {'簡單卡': 1, 'KOKO': 1}
# {'LINEPay': 1}
# {'iCash聯名卡': 2, '酷玩卡': 1, 'LINEPay': 1, 'GoGo': 2, '悠遊聯名卡': 2, '富邦數位生活卡': 1}
# {'GoGo': 1, 'KOKO': 1}
# {'GoGo': 3, 'icash聯名卡': 1, '饗樂卡': 2, 'LINEPay': 2}
# {'GoGo': 1, 'Pi': 2, 'Ubear': 2}
# {'LINEPay': 1, '饗樂卡': 3}
# {'鑽金': 4, 'icash聯名卡': 2, '一卡通聯名卡': 2}
# {'GoGo': 4, 'KOKO': 1}
# {}
# {'GoGo': 3}
# {'LINEPay': 2}
# {'LINEPay': 1, '悠遊聯名卡': 1, '饗樂卡': 1}
# {'GoGo': 1, '現金回饋御璽卡': 1}
# {'LINEPay': 1, '現金回饋御璽卡': 1, 'GoGo': 1}
# {'鑽金': 2}
# {'dawho': 3, 'Ubear': 1, 'KOKO': 1}
# {'KOKO': 1, 'icash聯名卡': 1, '富邦數位生活卡': 1, 'Ubear': 1}
# {}
# {'iCash聯名卡': 1, 'KOKO': 4, 'LINEPay': 2, 'Flygo': 3}
# {'無限卡': 3, '世界卡': 2}
# {'饗樂卡': 3, 'KOKO': 2, 'GoGo': 2}
# {'饗樂卡': 1, '鑽金': 1}
# {'GoGo': 2, '鑽金': 1}
# {'LINEPay': 1, 'KOKO': 1}
# {'KOKO': 1, 'LINEPay': 1}
# {'新光三越聯名卡': 2, 'LINEPay': 1, '鑽金': 1, 'KOKO': 1, 'GoGo': 1}
# {}
# {}
# {'ANA聯名卡': 2, 'GoGo': 2}
# {}
# {'鑽金': 2}
# {'樂天信用卡': 1}
# {'無限卡': 1}
# {'KOKO': 1, 'LINEPay': 1}
# {'GoGo': 2, 'LINEPay': 1}
# {'鑽金': 1}
# {'GoGo': 5, '鑽金': 1}
# {'GoGo': 4, '炫晶御璽卡': 3}
# {'數位生活卡': 2, 'GoGo': 1}
# {'元大鑽金卡': 1, '商務卡': 3}
# {'e秒刷鈦金卡': 1, 'KOKO': 1}
# {'GoGo': 1, 'LINEPay': 1}
# {'元大鑽金卡': 1, '現金回饋御璽卡': 1}
# {'富邦數位生活卡': 1}
# {'無限卡': 1, 'LINEPay': 1}
# {'元大鑽金卡': 1, 'GoGo': 1}
# {'KOKO': 4, 'icash聯名卡': 1, 'GoGo': 4, 'LINEPay': 2}
# {'台灣銀行': 1, '無限卡': 1}
# {'e秒刷鈦金卡': 1, 'GoGo': 2}
# {}
# {}
# {'Flygo': 1}
# {'超級現金回饋卡': 1}
# {'商務卡': 1}
# {'GoGo': 1, '現金回饋御璽卡': 1, '鑽金': 1}
# {'KOKO': 1, 'GoGo': 1}
# {'Pi': 1, 'GoGo': 2, 'Ubear': 3}
# {'LINEPay': 3, '富邦數位生活卡': 1, '饗樂卡': 1, 'Pi': 1}
# {'Ubear': 2, 'GoGo': 2, 'KOKO': 1, 'LINEPay': 1}
# {'Only': 10}
# {'無限卡': 3, '世界卡': 3, '美國運通': 1}
# {'GoGo': 2, '元大鑽金卡': 2, '悠遊聯名卡': 1}
# {'元大鑽金icash聯名卡': 1, '鑽金': 2}
# {'GoGo': 4}
# {'數位生活卡': 1, 'dawho': 2}
# {}
# {}
# {'饗樂卡': 1}
# {}
# {'KOKO': 2, 'GoGo': 1}
# {}
# {'LINEPay': 3, 'GoGo': 1, '元大鑽金卡': 1, '炫晶御璽卡': 2, 'e秒刷鈦金卡': 1, 'KOKO': 1, '簡單卡': 1}
# {'鑽金': 2, 'KOKO': 1}
# {'數位生活卡': 2, 'KOKO': 6, 'e秒刷鈦金卡': 1, 'LINEPay': 4, 'GoGo': 3, 'PChome Prime聯名卡': 1}
# {'數位生活卡': 1, '鑽金': 1, '酷玩卡': 1, '美國運通': 1, 'KOKO': 1, 'icash聯名卡': 1, '鼎極卡': 2, '世界卡': 2}
# {'商務卡': 1, 'icash聯名卡': 1}
# {'Only': 1, 'LINEPay': 1}
# {'LINEPay': 5, '悠遊聯名卡': 4, '一卡通聯名卡': 1, 'KOKO': 2, '超級現金回饋卡': 1}
# {'KOKO': 1, 'icash聯名卡': 1, '一卡通聯名卡': 1}
# {'Gogoro聯名卡': 2}
# {'數位生活卡': 2, 'LINEPay': 1}
# {'KOKO': 6, '富邦數位生活卡': 1}
# {'LINEPay': 2}
# {'Pi': 1, 'LINEPay': 2}
# {'Ubear': 4, 'dawho': 5}
# {}
# {'icash聯名卡': 1, 'LINEPay': 2, 'GoGo': 1}
# {'LINEPay': 3}
# {'LINEPay': 1, '無限卡': 1}
# {}
# {'鑽金': 2, '無限卡': 1, '個人商旅卡': 1, '元大鑽金卡': 1}
# {'鑽金': 2}
# {'e秒刷鈦金卡': 4, 'dawho': 2, '饗樂卡': 1, '統一獅聯名卡': 1}
# {'LINEPay': 4, 'Pi': 2}
# {'無限卡': 3, 'KOKO': 1}
# {'GoGo': 2, 'LINEPay': 2, '數位生活卡': 1}
# {'GoGo': 4, 'LINEPay': 2}
# {'Flygo': 4, '現金回饋御璽卡': 1, '微風聯名卡': 1, 'GoGo': 1}
# {'GoGo': 2, 'Flygo': 2, '鑽金': 1}
# {'GoGo': 4}
# {'GoGo': 5, '學學認同卡': 1, '無限卡': 1, '世界卡': 2, 'LINEPay': 2, 'KOKO': 1, '悠遊聯名卡': 1, '美國運通': 1, '現金回饋御璽卡': 1, '全家Fish悠遊聯名卡': 1}
# {'鈦金商務卡': 2}
# {'GoGo': 5, 'KOKO': 7}
# {'GoGo': 3}
# {'LINEPay': 3, 'GoGo': 3}
# {'GoGo': 7, 'Flygo': 8, 'Pi': 7}
# {'GoGo': 3}
# {'KOKO': 2}
# {'饗樂卡': 1, 'e秒刷鈦金卡': 1, 'LINEPay': 1, '數位生活卡': 1, 'KOKO': 1}
# {'dawho': 3, '現金回饋御璽卡': 2, 'LINEPay': 1, 'KOKO': 1, 'GoGo': 1}
# {'dawho': 4, 'GoGo': 2, 'Flygo': 1, 'KOKO': 2, '街口聯名卡': 1}
# {'dawho': 3}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 2, '元大鑽金卡': 1, 'GoGo': 1, '世界卡': 1}
# {'現金回饋御璽卡': 2, 'e秒刷鈦金卡': 2, 'LINEPay': 1}
# {'饗樂卡': 1}
# {'Only': 6, 'Ubear': 7, '數位生活卡': 1, 'GoGo': 3}
# {'Pi': 2, '悠遊聯名卡': 1, 'LINEPay': 1, 'KOKO': 1}
# {'Pi': 1, 'KOKO': 1, 'GoGo': 2}
# {'Flygo': 7, 'GoGo': 1, '鑽金': 1}
# {'Ubear': 3, 'GoGo': 2, 'Flygo': 2, 'dawho': 2}
# {'Pi': 1, 'GoGo': 2, 'Flygo': 2, 'KOKO': 1, '饗樂卡': 1}
# {'Ubear': 3, 'GoGo': 3, 'dawho': 1}
# {'Ubear': 1}
# {'dawho': 2, 'Ubear': 1}
# {'鑽金': 1, 'GoGo': 1}
# {'現金回饋御璽卡': 1, 'LINEPay': 1}
# {'KOKO': 6, 'LINEPay': 1}
# {'現金回饋御璽卡': 1, '炫晶御璽卡': 1, 'LINEPay': 6}
# {'酷玩卡': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {}
# {}
# {}
# {'LINEPay': 3, '數位生活卡': 1, '鑽金': 1, 'GoGo': 1}
# {'世界卡': 2, '無限卡': 1}
# {'KOKO': 1}
# {'世界卡': 3, 'LINEPay': 1, '無限卡': 4, '饗樂卡': 1, 'KOKO': 1, 'GoGo': 1, '鑽金': 1}
# {'酷玩卡': 3, '世界卡': 2, 'Pi': 2, '美國運通': 1}
# {'酷玩卡': 3, '世界卡': 3}
# {'現金回饋御璽卡': 1, 'e秒刷鈦金卡': 1, 'LINEPay': 4, 'KOKO': 1, '鑽金': 1}
# {}
# {'KOKO': 4, 'LINEPay': 3, 'GoGo': 6, '星燦卡': 2, '法拉利無限卡': 1, '無限卡': 1, '理財型白金卡': 1, 'e秒刷鈦金卡': 1, 'Pi': 2}
# {'數位生活卡': 2, 'LINEPay': 4, 'KOKO': 1, '現金回饋御璽卡': 1, '鼎極卡': 2, 'GoGo': 2}
# {}
# {'鼎極卡': 11, 'LINEPay': 11, 'MUJI無印良品聯名卡': 3, '富邦數位生活卡': 5, 'GoGo': 11, '玫瑰卡': 3, '新光三越聯名卡': 5, 'ETC聯名卡': 11, '世界卡': 4, '一卡通聯名卡': 6, 'KOKO': 22, '悠遊聯名卡': 9, '現金回饋御璽卡': 20, 'icash聯名卡': 3, '大甲媽祖認同卡': 11, '超級現金回饋卡': 2, '鈦金商旅卡': 7, '法拉利無限卡': 4, '無限卡': 4, '理財型白金卡': 4, '微風聯名卡': 4, 'Pi': 5}
# {'GoGo': 2, 'KOKO': 1, '鑽金': 1, 'e秒刷鈦金卡': 2, 'LINEPay': 2}
# {'鈦金商務卡': 2, '悠遊聯名卡': 1, '無限卡': 2, '美國運通': 2, '世界卡': 3, 'KOKO': 10, 'GoGo': 7, '現金回饋御璽卡': 4, 'Pi': 9, '悠遊晶緻卡': 1, 'LINEPay': 6, 'dawho': 1}
# {}
# {'無限卡': 6, '世界卡': 5, '富邦尊御世界卡': 1, '凱基無限卡': 1, '美國運通': 1}
# {'數位生活卡': 1, 'KOKO': 2, 'LINEPay': 1, 'GoGo': 1}
# {'無限卡': 1}
# {'Pi': 13, 'KOKO': 4, 'GoGo': 1, 'Flygo': 1, 'e秒刷鈦金卡': 1, 'LINEPay': 2, 'dawho': 8}
# {'世界卡': 4, '賴點卡': 3, 'GoGo': 4, '台灣銀行': 1, '現金回饋御璽卡': 1, '星燦卡': 1, 'LINEPay': 1, '無限卡': 1, 'Pi': 1}
# {'GoGo': 2, 'LINEPay': 1, 'Flygo': 1, 'SPORT卡': 1}
# {'Only': 17, 'KOKO': 3, '悠遊聯名卡': 2, '酷玩卡': 3}
# {'法拉利無限卡': 1, '無限卡': 1, '統一獅聯名卡': 1, 'GoGo': 1, '世界卡': 1}
# {'悠遊聯名卡': 5, 'Ubear': 4, 'KOKO': 4, 'icash聯名卡': 3, 'Pi': 6, 'LINEPay': 1, 'GoGo': 1, '一卡通聯名卡': 1, 'dawho': 2, 'Only': 1, 'Flygo': 1}
# {'KOKO': 4, '悠遊聯名卡': 2, 'Pi': 1, 'dawho': 4, '賴點卡': 2, 'LINEPay': 2, '無限卡': 1, '理財型白金卡': 1, 'GoGo': 1, '簡單卡': 1, 'Flygo': 1, '炫晶御璽卡': 1}
# {'KOKO': 4, '悠遊聯名卡': 2, 'Pi': 1, 'dawho': 4, '賴點卡': 2, 'LINEPay': 2, '無限卡': 1, '理財型白金卡': 1, 'GoGo': 1, '簡單卡': 1, 'Flygo': 1, '炫晶御璽卡': 1}
# {'Flygo': 5, 'GoGo': 8, 'KOKO': 2, '悠遊聯名卡': 7, 'Pi': 8, '一卡通聯名卡': 1, 'LINEPay': 1, 'icash聯名卡': 1}
# {'世界卡': 3, 'LINEPay': 1, '無限卡': 3, '饗樂卡': 1, 'KOKO': 4, 'GoGo': 3, '鑽金': 1}
# {'世界卡': 14, '無限卡': 18, '富邦尊御世界卡': 1, '美國運通': 1, '永豐財富無限卡': 1}
# {'炫晶御璽卡': 1, '簡單卡': 2, 'Flygo': 3}
# {}
# {'無限卡': 1, '理財型白金卡': 1, 'GoGo': 3, '簡單卡': 1, 'Omiyage': 1, 'Flygo': 1, 'LINEPay': 8, '炫晶御璽卡': 1, 'KOKO': 1, 'e秒刷鈦金卡': 1, '數位生活卡': 1, '星燦卡': 1, 'Pi': 1}
# {'手機信用卡': 1, '台灣銀行': 1}
# {}
# {'富邦數位生活卡': 1, 'Pi': 1, 'KOKO': 1, 'icash聯名卡': 1, 'GoGo': 1}
# {'LINEPay': 1, '中信兄弟聯名卡': 1, '導盲犬認同卡': 1, '無限卡': 3, 'GoGo': 1, '新光三越聯名卡': 1, 'Lamigo聯名卡': 1, '分享卡': 1, '法拉利無限卡': 1, '富邦悍將聯名卡': 1, 'KOKO': 1, 'e秒刷鈦金卡': 1, '世界卡': 1}
# {'dawho': 3}
# {'現金回饋御璽卡': 6, '無限卡': 4}
# {}
# {'GoGo': 1}
# {'數位生活卡': 1}
# {'GoGo': 3}
# {'鑽金': 4, '富邦數位生活卡': 1, '饗樂卡': 3, 'Pi': 6, '簡單卡': 7, 'GoGo': 3, '數位生活卡': 3, 'LINEPay': 2, '炫晶御璽卡': 1}
# {'GoGo': 4, '饗樂卡': 5, '太陽卡': 3, '鑽金': 2, '元大鑽金卡': 1, 'icash聯名卡': 2}
# {'GoGo': 6, '現金回饋御璽卡': 4, '數位生活卡': 2, 'KOKO': 3, 'LINEPay': 6, 'Pi': 3}
# {'GoGo': 3}
# {'GoGo': 5, 'KOKO': 7, '富邦鑽保卡': 2, 'LINEPay': 1}
# {'GoGo': 3}
# {'GoGo': 3}
# {'GoGo': 3, '饗樂卡': 3, '微風聯名卡': 2}
# {'GoGo': 1}
# {'GoGo': 1}
# {'GoGo': 1, 'LINEPay': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {'GoGo': 3}
# {'富邦鑽保卡': 1}
# {'美國運通': 1}
# ...
# {}
# {}
# {}
# {}
# {'鼎極卡': 1}
# {'LINEPay': 1}
# {}
# {}
# {'鼎極卡': 1}
# {}
# {'鼎極卡': 2, '商務卡': 1}
# {}
# {'KOKO': 1, 'Pi': 1, 'LINEPay': 1}
# {}
# {}
# {}
# {'KOKO': 2, 'LINEPay': 1}
# {'LINEPay': 1}
# {}
# {}
# {'KOKO': 2, 'Pi': 1}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'KOKO': 1, 'e秒刷鈦金卡': 1}
# {}
# {'LINEPay': 6}
# {}
# {'鑽金': 1, '世界卡': 1}
# {}
# {}
# {}
# {'元大鑽金卡': 1}
# {'鑽金': 1, '世界卡': 1}
# {'Gogoro聯名卡': 2}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 3}
# {}
# {}
# {}
# {'澳盛現金回饋卡': 2, '炫晶御璽卡': 4, 'Pi': 1}
# {}
# {'LINEPay': 1}
# {'Flygo': 1}
# {'GoGo': 2}
# {'GoGo': 2}
# {}
# {}
# {'Flygo': 1}
# {'GoGo': 3}
# {}
# {}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'太陽卡': 1, '玫瑰卡': 1}
# {}
# {}
# {'LINEPay': 1}
# {'GoGo': 1, 'Flygo': 1}
# {'GoGo': 1}
# {'GoGo': 1}
# {'美國運通': 4}
# {'KOKO': 1, '世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {'KOKO': 1}
# {}
# {'商務卡': 3}
# {}
# {}
# {}
# {'無限卡': 1}
# {}
# {'KOKO': 20, 'icash聯名卡': 4}
# {'KOKO': 1}
# {}
# {'炫晶御璽卡': 1}
# {}
# {}
# {}
# {'dawho': 2, 'Flygo': 1}
# {'dawho': 3}
# {'dawho': 4}
# {}
# {'哆啦A夢JCB聯名卡': 1}
# {}
# {'GoGo': 1}
# {}
# {'Flygo': 3}
# {}
# {}
# {}
# {}
# {'理財型白金卡': 1, 'KOKO': 1, 'GoGo': 1, '富邦數位生活卡': 1, '數位生活卡': 1, '美國運通': 1}
# {}
# {'世界卡': 5, '無限卡': 2}
# {'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {}
# {'美國運通': 2}
# {}
# {}
# {'KOKO': 1, 'GoGo': 3}
# {}
# {'Flygo': 1, 'GoGo': 1, '手機信用卡': 2}
# {'饗樂卡': 1}
# {'玫瑰卡': 2}
# {'LINEPay': 3}
# {}
# {'GoGo': 2, 'e秒刷鈦金卡': 1}
# {'世界卡': 2}
# {}
# {'e秒刷鈦金卡': 3, 'dawho': 1, 'Ubear': 1, 'Flygo': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 2, 'GoGo': 2, 'LINEPay': 1}
# {}
# {}
# {'LINEPay': 1, '鼎極卡': 1}
# {'世界卡': 2}
# {'世界卡': 1}
# {}
# {'LINEPay': 2}
# {'饗樂卡': 1, 'GoGo': 1}
# {}
# {}
# {'LINEPay': 1}
# {'LINEPay': 2, '元大鑽金卡': 1, 'Pi': 1, '現金回饋御璽卡': 2, '炫晶御璽卡': 1, '富邦數位生活卡': 1, '太陽卡': 1}
# {}
# {}
# {'dawho': 4}
# {}
# {'樂天信用卡': 1}
# {'樂天信用卡': 1}
# {'樂天信用卡': 3}
# {}
# {}
# {}
# {'商務卡': 1, '商務白金卡': 1}
# {'dawho': 4}
# {}
# {'dawho': 1}
# {'dawho': 2}
# {'dawho': 2}
# {'dawho': 1}
# {'dawho': 1}
# {'dawho': 1}
# {'dawho': 2}
# {'dawho': 4}
# {'dawho': 1}
# {}
# {}
# {}
# {}
# {'e秒刷鈦金卡': 1, 'Flygo': 2}
# {'Only': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'賴點卡': 1}
# {'Pi': 1, 'GoGo': 1}
# {}
# {}
# {}
# {}
# {'icash聯名卡': 2}
# {'icash聯名卡': 3, 'LINEPay': 1}
# {}
# {'Only': 1, 'dawho': 1}
# {'Only': 2}
# {}
# {}
# {'Ubear': 3, 'Pi': 2}
# {'Ubear': 2, 'GoGo': 1}
# {'Ubear': 3, 'GoGo': 2}
# {'Ubear': 3}
# {'Ubear': 1, '商務卡': 3}
# {'Ubear': 1}
# {'Ubear': 1}
# {'KOKO': 1, 'LINEPay': 1, 'GoGo': 1}
# {}
# {'LINEPay': 1}
# {'KOKO': 1, 'Flygo': 1}
# {}
# {'世界卡': 2}
# {'台灣黑熊認同卡': 1}
# {'GoGo': 3, 'KOKO': 1}
# {'樂天信用卡': 1, 'GoGo': 2}
# {'樂天信用卡': 1, 'GoGo': 2}
# {'KOKO': 3}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1}
# {'美國運通': 3}
# {'美國運通': 2}
# {}
# {'GoGo': 3, '太陽卡': 1, 'Flygo': 1}
# {'LINEPay': 5}
# {}
# {}
# {}
# {'台灣銀行': 2}
# {}
# {}
# {}
# {'世界卡': 4}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2, 'GoGo': 1, 'dawho': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {'饗樂卡': 2}
# {'Flygo': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 2, 'dawho': 1, '賴點卡': 1}
# {}
# {}
# {'GoGo': 2}
# {}
# {}
# {'無限卡': 2}
# {'Ubear': 1}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {'GoGo': 2}
# {}
# {}
# {'Pi': 2, 'LINEPay': 1}
# {}
# {'富邦數位生活卡': 1}
# {'LINEPay': 2, 'Pi': 1, 'Flygo': 1, 'Ubear': 1, 'GoGo': 1}
# {}
# {'LINEPay': 1}
# {}
# {'世界卡': 1}
# {'GoGo': 1}
# {'icash聯名卡': 2, '悠遊聯名卡': 1}
# {}
# {'GoGo': 1}
# {}
# {}
# {'LINEPay': 1, 'Pi': 1}
# {}
# {'LINEPay': 1}
# {'玫瑰卡': 1}
# {}
# {}
# {'Flygo': 3}
# {'LINEPay': 1}
# {'LINEPay': 2, '鼎極卡': 1}
# {'GoGo': 4}
# {}
# {}
# {'LINEPay': 4, 'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Only': 1, 'dawho': 1}
# {'Pi': 1}
# {'LINEPay': 1, '數位生活卡': 1}
# {}
# {}
# {}
# {}
# {'KOKO': 1, 'icash聯名卡': 2, 'GoGo': 1, '玫瑰卡': 1, 'LINEPay': 3, '鼎極卡': 1, '世界卡': 2, '分享卡': 1}
# {}
# {'LINEPay': 4, 'GoGo': 2, '玫瑰卡': 1, '世界卡': 5, '悠遊聯名卡': 1, '饗樂卡': 3, 'Pi': 1}
# {'悠遊聯名卡': 1, 'GoGo': 2, 'LINEPay': 1, 'KOKO': 1}
# {}
# {'LINEPay': 1}
# {'無限卡': 1, 'LINEPay': 1, '鼎極卡': 2, 'dawho': 1}
# {'KOKO': 1}
# {'太陽卡': 1, 'GoGo': 1}
# {'鼎極卡': 1, 'LINEPay': 2}
# {'KOKO': 1, 'LINEPay': 2, '鑽金': 1}
# {'Pi': 8, '世界卡': 2, 'KOKO': 4, 'LINEPay': 6, '享購鈦金卡': 1, 'e秒刷鈦金卡': 1, 'GoGo': 3, '星燦卡': 3, '簡單卡': 1}
# {'饗樂卡': 5}
# {'饗樂卡': 8, 'Ubear': 11}
# {'炫晶御璽卡': 1, 'ANA聯名卡': 1, '美國運通': 1}
# {'世界卡': 2}
# {}
# {'鑽金': 1, 'LINEPay': 2}
# {}
# {'GoGo': 2, 'LINEPay': 2}
# {'GoGo': 1, 'Flygo': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 2}
# {}
# {}
# {'LINEPay': 1, '鼎極卡': 3}
# {'無限卡': 3, 'ANA聯名卡': 3}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 6}
# {}
# {}
# {'Pi': 3, 'LINEPay': 2, 'e秒刷鈦金卡': 1}
# {'Pi': 1}
# {'e秒刷鈦金卡': 2}
# {'GoGo': 1}
# {'Flygo': 3}
# {'GoGo': 1, 'KOKO': 2}
# {'GoGo': 2, 'LINEPay': 1}
# {'GoGo': 1}
# {'GoGo': 2}
# {'KOKO': 1, 'GoGo': 2, '無限卡': 4, '法拉利無限卡': 1, '世界卡': 2, 'LINEPay': 2}
# {}
# {}
# {'GoGo': 5, 'Pi': 2}
# {'icash聯名卡': 1, '一卡通聯名卡': 1}
# {'KOKO': 2}
# {'饗樂卡': 1}
# {'哆啦A夢JCB聯名卡': 1}
# {}
# {}
# {'KOKO': 2}
# {'KOKO': 1}
# {'KOKO': 4}
# {'KOKO': 3}
# {'KOKO': 1}
# {'KOKO': 3}
# {'KOKO': 1, 'LINEPay': 2}
# {'KOKO': 1}
# {'KOKO': 5}
# {'KOKO': 3}
# {'KOKO': 4}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 4, 'GoGo': 1}
# {'KOKO': 7, 'GoGo': 1}
# {'KOKO': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 3, 'GoGo': 1}
# {'LINEPay': 2, '鼎極卡': 5}
# {'LINEPay': 1, 'Pi': 4}
# {'LINEPay': 2, 'KOKO': 2, 'GoGo': 1}
# {'LINEPay': 1, '鼎極卡': 2}
# {'LINEPay': 4, '鼎極卡': 4}
# {'LINEPay': 1, '鼎極卡': 1}
# {}
# {'世界卡': 2}
# {'LINEPay': 1}
# {}
# {'鑽金': 1}
# {'LINEPay': 1}
# {}
# {}
# {'Pi': 1}
# {'Pi': 1}
# {}
# {'悠遊聯名卡': 2, '富邦數位生活卡': 1}
# {}
# {}
# {'GoGo': 2}
# {}
# {'KOKO': 2, '無限卡': 1}
# {'GoGo': 3, 'LINEPay': 1}
# {}
# {'GoGo': 1, 'e秒刷鈦金卡': 1}
# {'Pi': 1}
# {'Ubear': 1}
# {'Ubear': 5, 'dawho': 4, 'LINEPay': 2}
# {}
# {'Ubear': 1}
# {'Ubear': 2, 'LINEPay': 1}
# {'Ubear': 3, 'LINEPay': 1}
# {'悠遊聯名卡': 5, 'Pi': 1}
# {}
# {'icash聯名卡': 1, '悠遊聯名卡': 2, 'KOKO': 1}
# {'LINEPay': 1, 'KOKO': 2}
# {}
# {}
# {}
# {'簡單卡': 5}
# {}
# {}
# {}
# {}
# {}
# {}
# {'星燦卡': 1}
# {}
# {}
# {'世界卡': 1, '簡單卡': 1}
# {'簡單卡': 3}
# {'LINEPay': 1}
# {}
# {'世界卡': 1}
# {'無限卡': 2}
# {}
# {'LINEPay': 2}
# {'LINEPay': 5, '鼎極卡': 1, '無限卡': 1}
# {'LINEPay': 2, '鑽金': 1, '饗樂卡': 1}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2}
# {'LINEPay': 2, 'dawho': 1}
# {'LINEPay': 1, '鼎極卡': 2, '無限卡': 1, '世界卡': 1}
# {'鼎極卡': 3}
# {}
# {'世界卡': 1}
# {}
# {'LINEPay': 1, '無限卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {'世界卡': 1}
# {}
# {}
# {'LINEPay': 5}
# {'鼎極卡': 2}
# {}
# {'鼎極卡': 8}
# {'鼎極卡': 1}
# {}
# {}
# {'LINEPay': 6}
# {'LINEPay': 2}
# {}
# {}
# {}
# {'鼎極卡': 2}
# {}
# {'LINEPay': 1}
# {'鼎極卡': 1, 'LINEPay': 3, '無限卡': 1, '世界卡': 1}
# {}
# {}
# {}
# {'鑽金': 1}
# {'GoGo': 2}
# {}
# {}
# {'KOKO': 3}
# {'LINEPay': 11, 'KOKO': 1, 'e秒刷鈦金卡': 1, '樂天信用卡': 1}
# {}
# {'Ubear': 1}
# {'Pi': 2, 'LINEPay': 1, 'KOKO': 1, '數位生活卡': 1}
# {}
# {}
# {'GoGo': 2}
# {}
# {'LINEPay': 1}
# {}
# {}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {'鼎極卡': 1, 'LINEPay': 1, '無限卡': 1}
# {'GoGo': 1, 'KOKO': 1}
# {'饗樂卡': 1}
# {}
# {}
# {}
# {'饗樂卡': 1, 'GoGo': 1}
# {'世界卡': 1}
# {'GoGo': 2}
# {'鑽金': 1}
# {'鑽金': 3}
# {}
# {}
# {}
# {'icash聯名卡': 1}
# {}
# {}
# {}
# {'鑽金': 1}
# {}
# {}
# {}
# {'鑽金': 1, '元大鑽金卡': 1}
# {'鑽金': 1}
# {'鑽金': 1}
# {'元大鑽金卡': 1}
# {'元大鑽金卡': 2}
# {'元大鑽金卡': 1}
# {}
# {'e秒刷鈦金卡': 2}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {'e秒刷鈦金卡': 1}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 5}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'台灣銀行': 1, '導盲犬認同卡': 1, '台灣黑熊認同卡': 1}
# {}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {}
# {'悠遊聯名卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'兆豐無限卡': 1}
# {'分享卡': 3}
# {'GoGo': 3}
# {}
# {}
# {}
# {'Only': 1}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'Flygo': 4}
# {}
# {}
# {}
# {'世界卡': 1, 'GoGo': 1, '商務卡': 1, 'Flygo': 1, '無限卡': 2, 'LINEPay': 2, '台灣黑熊認同卡': 1, 'KOKO': 1, '享購鈦金卡': 1, '饗樂卡': 1, '數位生活卡': 1}
# {'現金回饋御璽卡': 3}
# {'現金回饋御璽卡': 1}
# {'LINEPay': 1, '鼎極卡': 1}
# {'LINEPay': 1, 'GoGo': 1, '遠傳friDay聯名卡': 1, '無限卡': 1, '富邦悍將聯名卡': 1, 'PChome Prime聯名卡': 1, 'e秒刷鈦金卡': 1, 'e秒萬事通金融信用卡': 2, 'KOKO': 2, 'icash聯名卡': 2, 'Pi': 1, '鑽金': 1, '台新財富無限卡': 1}
# {'澳盛現金回饋卡': 2, 'GoGo': 2, 'LINEPay': 1, '富邦數位生活卡': 1}
# {}
# {}
# {'GoGo': 8, 'Flygo': 1, 'dawho': 1}
# {'LINEPay': 4}
# {'GoGo': 8}
# {'GoGo': 1}
# {'GoGo': 2, 'icash聯名卡': 1}
# {'GoGo': 1}
# {'GoGo': 1}
# {'GoGo': 5, '永豐鈦豐卡': 1, 'KOKO': 2}
# {'GoGo': 2, '悠遊聯名卡': 1}
# {'Flygo': 2, 'GoGo': 1}
# {'Flygo': 2}
# {'Flygo': 3}
# {'GoGo': 1}
# {'GoGo': 3, 'LINEPay': 2}
# {'GoGo': 1}
# {'GoGo': 2}
# {'GoGo': 2, '悠遊聯名卡': 1}
# {'GoGo': 1}
# {'GoGo': 2}
# {}
# {'悠遊聯名卡': 1}
# {}
# {'Ubear': 1, 'GoGo': 2, 'Flygo': 1}
# {}
# {'玫瑰卡': 4, 'GoGo': 3}
# {'商務卡': 2, 'GoGo': 1}
# {}
# {'世界卡': 1}
# {'Flygo': 1}
# {}
# {'太陽卡': 2, '新光三越聯名卡': 1}
# {}
# {'GoGo': 2, '悠遊聯名卡': 1}
# {'無限卡': 1}
# {}
# {'無限卡': 5, '世界卡': 1}
# {}
# {'Flygo': 1}
# {}
# {}
# {}
# {'街口聯名卡': 1, 'Pi': 4}
# {}
# {}
# {}
# {'玫瑰卡': 1}
# {'Flygo': 2}
# {'鈦金商旅卡': 1}
# {'台灣銀行': 1}
# {}
# {}
# {}
# {'美國運通': 2}
# {}
# {'Pi': 3}
# {}
# {}
# {}
# {'美國運通': 1, '鼎極卡': 1, 'Pi': 1, '世界卡': 1, '無限卡': 1}
# {'Ubear': 3}
# {'LINEPay': 1}
# {'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {}
# {'LINEPay': 2}
# {'KOKO': 1}
# {}
# {'鑽金': 1}
# {'LINEPay': 8, 'GoGo': 2, 'e秒刷鈦金卡': 1, 'KOKO': 1}
# {'KOKO': 1, 'icash聯名卡': 1}
# {'KOKO': 2, 'COSTCO聯名卡': 1}
# {}
# {}
# {'無限卡': 2}
# {'KOKO': 2, 'GoGo': 2, 'LINEPay': 1}
# {'KOKO': 3, '饗樂卡': 1}
# {'KOKO': 1}
# {'KOKO': 2}
# {'KOKO': 2}
# {'KOKO': 3}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {'無限卡': 5}
# {}
# {'LINEPay': 1}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 2}
# {}
# {}
# {}
# {'無限卡': 2}
# {'無限卡': 1, 'KOKO': 1}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {'LINEPay': 2}
# {}
# {'新光三越聯名卡': 1}
# {}
# {'元大鑽金卡': 1, 'GoGo': 1}
# {}
# {'世界卡': 3}
# {'世界卡': 1, '富貴無限卡': 1}
# {}
# {}
# {}
# {'世界卡': 2, '無限卡': 2}
# {}
# {'鼎極卡': 5}
# {}
# {}
# {}
# {'哆啦A夢JCB聯名卡': 1}
# {}
# {'富邦數位生活卡': 1, '數位生活卡': 1}
# {}
# {}
# {}
# {'LINEPay': 7, '富邦數位生活卡': 1, '數位生活卡': 5}
# {}
# {'一卡通聯名卡': 2}
# {'LINEPay': 1}
# {'富邦悍將聯名卡': 6, '悠遊聯名卡': 1}
# {'數位生活卡': 3}
# {'富邦數位生活卡': 3, 'LINEPay': 1}
# {'數位生活卡': 1}
# {}
# {}
# {}
# {'Flygo': 2, 'GoGo': 1}
# {'饗樂卡': 2}
# {}
# {}
# {'LINEPay': 1, '鼎極卡': 1}
# {'悠遊晶緻卡': 1}
# {}
# {}
# {}
# {'LINEPay': 1, '鼎極卡': 1, 'KOKO': 2}
# {}
# {'哆啦A夢JCB聯名卡': 1}
# {'台灣銀行': 1, '世界卡': 1}
# {'無限卡': 2, '世界卡': 1}
# {'悠遊聯名卡': 2}
# {'LINEPay': 1, '鼎極卡': 1, 'Pi': 1, '無限卡': 1}
# {'GoGo': 1, '世界卡': 2, '炫晶御璽卡': 1, '簡單卡': 1}
# {'世界卡': 7, '鼎極卡': 1}
# {}
# {'饗樂卡': 1, '商旅卡': 1, '元大鑽金卡': 2, '現金回饋御璽卡': 3, '鑽金': 1, 'LINEPay': 1, 'GoGo': 1, 'icash聯名卡': 2, 'KOKO': 1, '樂天信用卡': 1}
# {}
# {'GoGo': 5}
# {'無限卡': 4}
# {'dawho': 4, '鈦豐卡': 1}
# {'Flygo': 2}
# {'LINEPay': 1}
# {}
# {}
# {'GoGo': 2}
# {}
# {}
# {'樂天信用卡': 1}
# {'KOKO': 1}
# {'鼎極卡': 1, '商務卡': 1}
# {'LINEPay': 3, '鼎極卡': 1}
# {'LINEPay': 1, '無限卡': 1}
# {'LINEPay': 3, '鼎極卡': 1}
# {}
# {}
# {'街口聯名卡': 1, 'Ubear': 1}
# {'街口聯名卡': 1}
# {}
# {'新光三越聯名卡': 1}
# {'世界卡': 2}
# {}
# {}
# {'KOKO': 3}
# {}
# {'美國運通': 3}
# {'無限卡': 1}
# {}
# {}
# {'無限卡': 2}
# {'KOKO': 1, 'GoGo': 2, 'LINEPay': 1, 'dawho': 1}
# {'Ubear': 2, 'GoGo': 3}
# {'everyday鈦金卡': 1}
# {'炫晶御璽卡': 1}
# {}
# {'炫晶御璽卡': 1}
# {}
# {'炫晶御璽卡': 1, 'LINEPay': 1, '饗樂卡': 1, '鑽金': 2}
# {}
# {}
# {}
# {}
# {'世界卡': 2}
# {'世界卡': 2}
# {}
# {}
# {'KOKO': 3}
# {}
# {}
# {}
# {'LINEPay': 3}
# {'LINEPay': 3, 'GoGo': 3}
# {'KOKO': 3}
# {}
# {}
# {'鼎極卡': 1, '法拉利無限卡': 1, '無限卡': 2}
# {'悠遊聯名卡': 1}
# {}
# {}
# {'悠遊聯名卡': 1}
# {}
# {}
# {'鼎極卡': 1, '無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'樂天信用卡': 2}
# {'樂天信用卡': 2}
# {'樂天信用卡': 3, '富邦數位生活卡': 1, 'KOKO': 1, 'LINEPay': 1}
# {'樂天信用卡': 2}
# {'樂天信用卡': 1}
# {'樂天信用卡': 1}
# {}
# {'樂天信用卡': 2}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 3, 'LINEPay': 1}
# {}
# {'LINEPay': 1}
# {}
# {'Pi': 4}
# {'KOKO': 1, 'Flygo': 2, 'Pi': 1, 'GoGo': 1, '鑽金': 1}
# {'Gogoro聯名卡': 10, 'GoGo': 1}
# {}
# {'世界卡': 2, '中興大學認同卡': 1, 'SPORT卡': 1}
# {'dawho': 2}
# {}
# {}
# {}
# {'dawho': 3}
# {'dawho': 9}
# {'dawho': 3}
# {}
# {'SPORT卡': 1, 'LINEPay': 1, 'Pi': 1}
# {}
# {}
# {}
# {'法拉利無限卡': 4, '無限卡': 3}
# {}
# {'dawho': 1, 'KOKO': 1, 'GoGo': 1}
# {'GoGo': 1, 'Pi': 1}
# {'Only': 4, '美國運通': 1}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 2}
# {}
# {'無限卡': 1}
# {}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 1, '無限卡': 2}
# {}
# {'現金回饋御璽卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'Flygo': 2, 'KOKO': 1}
# {}
# {}
# {'LINEPay': 1, 'GoGo': 1}
# {'LINEPay': 25, '數位生活卡': 1}
# {'Only': 2, 'dawho': 2}
# {'Ubear': 3}
# {'Ubear': 1}
# {'Ubear': 1}
# {}
# {'Pi': 1}
# {'GoGo': 1, 'KOKO': 1}
# {'Only': 3, 'dawho': 1, 'Pi': 1, 'Ubear': 1, '世界卡': 1}
# {'Only': 2}
# {'Only': 1}
# {'KOKO': 3, 'Pi': 1}
# {'Pi': 1}
# {'Pi': 2, 'GoGo': 1}
# {'GoGo': 2, 'LINEPay': 1}
# {'Pi': 1}
# {'Ubear': 1}
# {'Ubear': 2}
# {'Ubear': 2, 'LINEPay': 1}
# {}
# {'世界卡': 4, '商務卡': 1}
# {}
# {}
# {'愛心卡': 1}
# {}
# {'Ubear': 2, 'Only': 2, 'Pi': 1}
# {}
# {}
# {'悠遊聯名卡': 1}
# {'醫師尊榮無限卡': 1, '世界卡': 1}
# {}
# {'新光三越聯名卡': 1, '微風聯名卡': 5}
# {'Pi': 1, 'Only': 1}
# {}
# {'世界卡': 1}
# {'麗寶悠遊聯名卡': 1}
# {'LINEPay': 4}
# {}
# {}
# {'KOKO': 4}
# {'GoGo': 4, '現金回饋御璽卡': 6, '鑽金': 6, '富邦數位生活卡': 1}
# {}
# {'KOKO': 4, 'LINEPay': 1}
# {}
# {'分享卡': 1}
# {'GoGo': 3, 'LINEPay': 2}
# {}
# {'LINEPay': 2}
# {'分享卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'炫晶御璽卡': 1, 'Pi': 2}
# {'鑽金': 5, 'GoGo': 1, 'KOKO': 1}
# {}
# {'LINEPay': 3, '鼎極卡': 3}
# {'鑽金': 1, '無限卡': 1, 'GoGo': 1}
# {'元大鑽金卡': 1, 'KOKO': 2}
# {}
# {'鼎極卡': 4, 'LINEPay': 1, '世界卡': 1}
# {}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {'美國運通': 1}
# {'美國運通': 1}
# {}
# {'美國運通': 1}
# {'美國運通': 5}
# {'美國運通': 3}
# {'美國運通': 1}
# {'美國運通': 1}
# {'LINEPay': 1}
# {}
# {}
# {}
# {}
# {}
# {'微風聯名卡': 1}
# {'法拉利無限卡': 1}
# {'無限卡': 1, '微風聯名卡': 2}
# {'無限卡': 1}
# {'賴點卡': 6}
# {'LINEPay': 1}
# {}
# {'富邦數位生活卡': 1}
# {}
# {}
# {'法拉利無限卡': 1, '無限卡': 1}
# {'法拉利無限卡': 4, '無限卡': 9, '世界卡': 2, '大立無限卡': 2}
# {}
# {'LINEPay': 1}
# {}
# {'無限卡': 2}
# {}
# {'無限卡': 1, '世界卡': 1}
# {}
# {}
# {}
# {'饗樂卡': 2}
# {'Gogoro聯名卡': 1}
# {'GoGo': 1}
# {}
# {}
# {'饗樂卡': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {'分享卡': 1, '無限卡': 2, '世界卡': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'無限卡': 1}
# {'饗樂卡': 1, 'GoGo': 1}
# {'法拉利無限卡': 2}
# {}
# {}
# {'無限卡': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'PChome Prime聯名卡': 1}
# {}
# {'饗樂卡': 2}
# {'現金回饋御璽卡': 1}
# {'LINEPay': 1}
# {'icash聯名卡': 2}
# {}
# {'KOKO': 1}
# {}
# {}
# {}
# {'iCash聯名卡': 1, 'Pi': 1}
# {}
# {}
# {}
# {}
# {}
# {'Ubear': 2}
# {}
# {}
# {}
# {}
# {'高雄going鈦金卡': 1}
# {'LINEPay': 1}
# {}
# {'Pi': 3, 'KOKO': 1, 'GoGo': 1, 'Flygo': 1}
# {}
# {'LINEPay': 1, '酷玩卡': 1}
# {}
# {'GoGo': 1, 'LINEPay': 2}
# {}
# {'dawho': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'KOKO': 1}
# {'現金回饋御璽卡': 1}
# {'現金回饋御璽卡': 2, 'LINEPay': 1}
# {'KOKO': 1}
# {}
# {}
# {}
# {'超級現金回饋卡': 1, '永豐鈦豐卡': 1, '現金回饋御璽卡': 1, '元大鑽金卡': 2, '鑽金': 1, 'LINEPay': 1, 'GoGo': 1, 'KOKO': 1}
# {}
# {}
# {}
# {'法拉利無限卡': 1}
# {'KOKO': 1}
# {}
# {'遠傳friDay聯名卡': 1}
# {}
# {}
# {'樂購卡': 1}
# {'LINEPay': 2, 'Flygo': 3, 'GoGo': 1}
# {'元大樂遊卡': 2}
# {'樂天信用卡': 1}
# {'LINEPay': 1, 'Flygo': 1, 'GoGo': 2, '小小兵信用卡': 1}
# {'LINEPay': 1, 'Flygo': 1, 'GoGo': 2, '小小兵信用卡': 1}
# {}
# {'LINEPay': 4}
# {}
# {'dawho': 3}
# {'Ubear': 3}
# {'icash聯名卡': 1}
# {}
# {}
# {}
# {'Flygo': 1, 'GoGo': 1}
# {}
# {'LINEPay': 1}
# {}
# {'悠遊聯名卡': 4}
# {}
# {}
# {}
# {'LINEPay': 1}
# {'美國運通': 1}
# {}
# {'Gogoro聯名卡': 1, 'e秒刷鈦金卡': 2}
# {'GoGo': 2}
# {}
# {}
# {}
# {'鼎極卡': 6}
# {}
# {}
# {}
# {'LINEPay': 3, 'KOKO': 1}
# {'LINEPay': 4}
# {}
# {}
# {'Ubear': 2}
# {'Ubear': 1, 'Only': 8, 'Pi': 2}
# {'KOKO': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'LINEPay': 2, 'Pi': 1}
# {'GoGo': 1}
# {'鼎極卡': 2}
# {'無限卡': 2}
# {'LINEPay': 4}
# {'LINEPay': 6, 'icash聯名卡': 2}
# {'LINEPay': 3}
# {'LINEPay': 2}
# {'LINEPay': 1}
# {'LINEPay': 2, 'KOKO': 1, '數位生活卡': 1, 'e秒刷鈦金卡': 1, '鑽金': 1, '簡單卡': 1, 'dawho': 1}
# {'LINEPay': 2}
# {}
# {}
# {'KOKO': 1, '數位生活卡': 1}
# {'Ubear': 1}
# {}
# {'LINEPay': 2}
# {}
# {'鑽金': 2, '元大鑽金卡': 1, '現金回饋御璽卡': 1, '富邦數位生活卡': 1, 'GoGo': 1}
# {}
# {'e秒刷鈦金卡': 4, 'dawho': 2}
# {'e秒刷鈦金卡': 1, 'LINEPay': 1}
# {'樂天信用卡': 2, 'Flygo': 1}
# {'LINEPay': 1}
# {}
# {'LINEPay': 1}
# {'現金回饋御璽卡': 3}
# {'現金回饋御璽卡': 2, '新光三越聯名卡': 1, '悠遊聯名卡': 1}
# {'世界卡': 3, '無限卡': 6, 'KOKO': 1, '個人商旅卡': 1}
# {}
# {'Ubear': 1}
# {'GoGo': 5, 'KOKO': 1, 'LINEPay': 1, '饗樂卡': 1}
# {'GoGo': 5, 'Pi': 4, 'COSTCO聯名卡': 2, '富邦財神卡': 1, 'LINEPay': 1}
# {'GoGo': 2}
# {'GoGo': 3, '饗樂卡': 1}
# {'GoGo': 2}
# {'GoGo': 3}
# {'GoGo': 6, 'e秒刷鈦金卡': 6, 'LINEPay': 2}
# {}
# {}
# {}
# {'GoGo': 2, '微風聯名卡': 1}
# {'悠遊聯名卡': 2}
# {'KOKO': 2, '酷玩卡': 1, '玫瑰卡': 1}
# {'無限卡': 2, 'LINEPay': 2, 'KOKO': 1, '享購鈦金卡': 1}
# {'無限卡': 2}
# {}
# {}
# {'饗樂卡': 1, 'KOKO': 1, 'LINEPay': 1, 'GoGo': 1}
# {'GoGo': 2, 'LINEPay': 1, 'KOKO': 1, '現金回饋御璽卡': 1, '饗樂卡': 1}
# {'樂天信用卡': 3}
# {'富邦數位生活卡': 1}
# {}
# {'鑽金': 2}
# {'GoGo': 5}
# {'GoGo': 2}
# {'炫晶御璽卡': 2, '現金回饋御璽卡': 1}
# {'LINEPay': 6, 'dawho': 5, 'GoGo': 2}
# {}
# {'LINEPay': 5, 'Pi': 3}
# {}
# {}
# {'KOKO': 1, 'dawho': 1}
# {'Ubear': 2}
# {}
# {'現金回饋御璽卡': 1}
# {'KOKO': 1, 'Pi': 1}
# {'炫晶御璽卡': 2}
# {'炫晶御璽卡': 2, '饗樂卡': 2, 'LINEPay': 2}
# {'現金回饋御璽卡': 1, 'GoGo': 1, '饗樂卡': 1, 'LINEPay': 1, 'KOKO': 1}
# {'世界卡': 2}
# {'LINEPay': 1}
# {}
# {'炫晶御璽卡': 2}
# {'LINEPay': 2, 'GoGo': 1}
# {'數位生活卡': 1, 'GoGo': 1}
# {}
# {}
# {}
# {}
# {}
# {'GoGo': 1, 'KOKO': 1}
# {'dawho': 2, 'LINEPay': 2, 'KOKO': 1, '數位生活卡': 1, 'e秒刷鈦金卡': 1, '鑽金': 1, '簡單卡': 1, 'GoGo': 1}
# {}
# {}
# {'現金回饋御璽卡': 1, '酷玩卡': 2}
# {}
# {'現金回饋御璽卡': 2, 'GoGo': 1, '美國運通': 1, '炫晶御璽卡': 1}
# {'KOKO': 4, 'GoGo': 1, 'LINEPay': 1, '鼎極卡': 1}
# {'Pi': 2, 'GoGo': 1, '饗樂卡': 1}
# {'Ubear': 2, 'Flygo': 1, 'Pi': 1, 'GoGo': 1}
# {'GoGo': 1}
# {}
# {'Pi': 1}
# {'Ubear': 3, 'Pi': 5, 'GoGo': 1, '富邦鑽保卡': 1}
# {'世界卡': 5}
# {'世界卡': 2}
# {}
# {}
# {'Ubear': 1, 'Only': 1}
# {}
# {}
# {}
# {}
# {'美國運通': 1}
# {'法拉利無限卡': 1, '無限卡': 1}
# {'賴點卡': 2}
# {}
# {}
# {}
# {}
# {'世界卡': 2, '元大鑽金卡': 1}
# {'現金回饋御璽卡': 2}
# {'饗樂卡': 2}
# {'饗樂卡': 4, 'LINEPay': 1}
# {'饗樂卡': 2}
# {'饗樂卡': 2}
# {'鼎極卡': 1, '世界卡': 1, 'GoGo': 1, '法拉利無限卡': 1}
# {'LINEPay': 2}
# {'GoGo': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'dawho': 2, '太陽卡': 1, 'GoGo': 2, 'Ubear': 2, 'Only': 2, 'LINEPay': 2, '無限卡': 1, 'Pi': 1, 'e秒刷鈦金卡': 1, 'KOKO': 1, '數位生活卡': 1}
# {'LINEPay': 1}
# {'無限卡': 3}
# {}
# {}
# {'dawho': 2, 'LINEPay': 2, 'Only': 1, 'KOKO': 1}
# {}
# {'e秒刷鈦金卡': 3, 'KOKO': 3, '新光三越聯名卡': 1}
# {'dawho': 2, 'Ubear': 1}
# {}
# {'Pi': 7, 'Ubear': 6}
# {'LINEPay': 1}
# {}

# %%
for article in range(len(df)):
    article_behavior={}
    for word in df['斷詞'][article]:
        if word in behavior:
            if behavior[word] not in article_behavior:
                article_behavior[behavior[word]] = 1
            else:
                article_behavior[behavior[word]] += 1
    print(article_behavior)
    df['行為'][article]=article_behavior
# Out:
# {}
# {}
# {'旅遊': 2, '行動支付': 1, '網購': 1, '國外': 1}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'行動支付': 5, '量販店': 2, '紅利': 2, '超商': 2, '旅遊': 2, '百貨': 1}
# {'量販店': 3}
# {'網購': 2}
# {}
# {'航空哩程': 2}
# {'航空哩程': 2}
# {}
# {}
# {'電影': 2}
# {}
# {'旅遊': 2}
# {'旅遊': 2}
# {'旅遊': 2}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'加油': 1}
# {'超商': 1}
# {}
# {}
# {'行動支付': 3}
# {'行動支付': 3}
# {'行動支付': 3}
# {'保險': 2}
# {}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {'行動支付': 2}
# {'行動支付': 2}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'行動支付': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {'行動支付': 2, '航空哩程': 1}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 13, '航空哩程': 1}
# {'電影': 4}
# {'行動支付': 1}
# {}
# {'超商': 2}
# {'航空哩程': 3}
# {}
# {}
# {}
# {}
# {'國外': 4, '網購': 4, '旅遊': 6}
# {'旅遊': 1}
# {}
# {}
# {'紅利': 1}
# {'旅遊': 1}
# {'超商': 2}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'旅遊': 2, '網購': 3, '電影': 1}
# {}
# {'國外': 3, '旅遊': 2}
# {}
# {}
# {'加油': 1}
# {'旅遊': 4}
# {'旅遊': 3, '國外': 2, '保險': 1}
# {}
# {}
# {}
# {}
# {'保險': 1, '超商': 1, '網購': 1, '量販店': 2}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'旅遊': 1}
# {}
# {'保險': 4, '行動支付': 1, '網購': 1, '航空哩程': 4, '國外': 1}
# {'保險': 9}
# {'旅遊': 5}
# {'國外': 1, '行動支付': 3, '超商': 4, '網購': 1, '加油': 2, '超市': 2, '量販店': 1}
# {'電影': 1}
# {'超商': 3, '網購': 1, '行動支付': 2}
# {}
# {}
# {}
# {'網購': 5, '量販店': 2, '超市': 1, '加油': 3, '電影': 1, '旅遊': 1}
# {'超商': 1}
# {'旅遊': 1}
# {}
# {'網購': 5, '行動支付': 3, '保險': 2, '超商': 1}
# {'加油': 1, '超商': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超市': 1}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'超商': 3, '網購': 1}
# {'超商': 5, '行動支付': 1}
# {}
# {'國外': 2}
# {'網購': 1}
# {}
# {'加油': 6, '紅利': 1}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'旅遊': 4, '國外': 1, '航空哩程': 1}
# {'藥妝': 1, '行動支付': 1, '旅遊': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {'國外': 1}
# {'旅遊': 6, '網購': 1, '國外': 2, '航空哩程': 1, '超商': 1, '行動支付': 1}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'國外': 2, '旅遊': 1}
# {'旅遊': 7}
# {'國外': 2}
# {'旅遊': 6}
# {'旅遊': 1}
# {'旅遊': 2, '國外': 3}
# {'國外': 1}
# {'網購': 6, '國外': 1}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 7, '航空哩程': 4}
# {'航空哩程': 2}
# {}
# {'超商': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 1}
# {'國外': 4, '旅遊': 2}
# {}
# {'旅遊': 1}
# {}
# {}
# {'國外': 2}
# {'加油': 1, '國外': 1}
# {'國外': 1, '運動': 3, '網購': 1, '超市': 1}
# {}
# {}
# {'加油': 2}
# {'超商': 1, '百貨': 2}
# {'航空哩程': 4, '旅遊': 3}
# {'旅遊': 2}
# {'網購': 4}
# {}
# {}
# {'超商': 1}
# {'國外': 3, '網購': 2}
# {}
# {}
# {}
# {'旅遊': 4}
# {'旅遊': 1}
# {'旅遊': 5}
# {}
# {'旅遊': 5}
# {'旅遊': 5}
# {'旅遊': 1, '國外': 1}
# {'航空哩程': 4}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {'國外': 1}
# {}
# {'國外': 2}
# {}
# {'旅遊': 1}
# {'旅遊': 2}
# {'國外': 3, '旅遊': 1}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {'行動支付': 1}
# {'網購': 2}
# {}
# {'國外': 2}
# {}
# {'超商': 1}
# {}
# {'網購': 3}
# {'電影': 1}
# {}
# {}
# {}
# {'旅遊': 4, '保險': 1}
# {}
# {'網購': 3}
# {'網購': 1}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {'旅遊': 4}
# {'行動支付': 1, '保險': 2}
# {'保險': 4}
# {'網購': 7, '超市': 2, '超商': 1}
# {}
# {}
# {'行動支付': 2, '超市': 3}
# {}
# {}
# {'國外': 2}
# {'國外': 1}
# {}
# {}
# {}
# {'超商': 2}
# {'百貨': 1}
# {}
# {}
# {'國外': 2}
# {'旅遊': 1, '國外': 1}
# {'國外': 2}
# {}
# {'量販店': 3}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'量販店': 1}
# {}
# {'電影': 3}
# {'國外': 1}
# {}
# {}
# {}
# {'旅遊': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'國外': 1}
# {}
# {}
# {'超商': 1, '網購': 3, '行動支付': 4}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {'網購': 1}
# {}
# {}
# {'超商': 3}
# {}
# {}
# {}
# {'加油': 2}
# {'旅遊': 1}
# {'電影': 3}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'超商': 4}
# {}
# {}
# {'網購': 3, '超商': 3, '行動支付': 1}
# {}
# {}
# {}
# {}
# {'行動支付': 4}
# {}
# {'超商': 4, '行動支付': 2}
# {'超商': 2}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'保險': 5, '網購': 1}
# {}
# {}
# {'保險': 4}
# {'網購': 3}
# {}
# {'超商': 4, '網購': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'運動': 1, '網購': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'超商': 1}
# {'超商': 1}
# {'旅遊': 2, '國外': 1}
# {}
# {'網購': 10}
# {}
# {'百貨': 5}
# {'網購': 1, '超商': 2}
# {'行動支付': 2}
# {'超商': 1}
# {}
# {}
# {}
# {'超商': 3}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {}
# {'量販店': 3}
# {'旅遊': 1}
# {}
# {}
# {}
# {'加油': 2}
# {'國外': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {'行動支付': 1}
# {}
# {'網購': 1}
# {}
# {'電影': 3}
# {}
# {'網購': 1}
# {'旅遊': 1}
# {'超市': 1, '超商': 1}
# {}
# {'百貨': 1}
# {'超市': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2, '國外': 2, '網購': 1}
# {'旅遊': 2, '國外': 2, '網購': 1}
# {'行動支付': 2, '網購': 1, '超商': 2}
# {'航空哩程': 1, '網購': 1}
# {}
# {'航空哩程': 1}
# {'超商': 2}
# {'國外': 1}
# {}
# {}
# {'國外': 1}
# {'旅遊': 3}
# {'網購': 2}
# {'網購': 2}
# {'網購': 2}
# {'網購': 2}
# {'網購': 3}
# {'網購': 1}
# {'網購': 3}
# {'網購': 2}
# {'網購': 3}
# {'網購': 9}
# {'網購': 1}
# {'網購': 1}
# {}
# {}
# {'超市': 2}
# {}
# {}
# {'超商': 2}
# {}
# {'國外': 1}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {'國外': 1}
# {}
# {'網購': 2}
# {'網購': 3}
# {'網購': 2}
# {'網購': 2}
# {'網購': 2}
# {'網購': 4}
# {'網購': 3}
# {'網購': 2}
# {}
# {'網購': 5, '行動支付': 6}
# {'網購': 1}
# {'網購': 2}
# {'網購': 5}
# {'網購': 2}
# {}
# {'網購': 2}
# {'網購': 3, '行動支付': 2}
# {'網購': 1}
# {}
# {}
# {'超商': 1}
# {'國外': 1}
# {'行動支付': 1}
# {'超商': 1}
# {'網購': 2}
# {'超商': 1}
# {'行動支付': 6, '網購': 4}
# {'行動支付': 4, '超商': 2}
# {'行動支付': 4, '加油': 2}
# {'行動支付': 4}
# {'行動支付': 5}
# {'行動支付': 3, '量販店': 2}
# {'行動支付': 3}
# {'旅遊': 1}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 3}
# {}
# {}
# {}
# {}
# {'網購': 3, '行動支付': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2}
# {}
# {'量販店': 1}
# {}
# {'國外': 3, '網購': 5}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'網購': 2}
# {'行動支付': 3, '超市': 1, '網購': 4, '藥妝': 2, '量販店': 1}
# {'行動支付': 1}
# {}
# {}
# {'電影': 3}
# {'量販店': 2}
# {'行動支付': 1}
# {'網購': 2, '超商': 1}
# {}
# {'電影': 2}
# c:\users\big data\pycharmprojects\py\venv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# {}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'旅遊': 3}
# {}
# {'旅遊': 5}
# {}
# {}
# {}
# {'國外': 1, '網購': 1}
# {'旅遊': 3}
# {}
# {}
# {'網購': 8}
# {}
# {}
# {'網購': 1, '保險': 1}
# {'網購': 1, '保險': 1}
# {}
# {}
# {'旅遊': 3, '國外': 2}
# {}
# {}
# {'電影': 1}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 4}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'運動': 1}
# {'旅遊': 2, '國外': 2}
# {}
# {}
# {}
# {}
# {'國外': 5, '旅遊': 1}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {'超市': 1}
# {'超商': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'保險': 5, '超商': 2, '旅遊': 5, '國外': 2}
# {'百貨': 1, '加油': 1}
# {}
# {'航空哩程': 3}
# {'國外': 6, '航空哩程': 2, '旅遊': 1}
# {'旅遊': 2, '國外': 1}
# {'國外': 1}
# {'航空哩程': 3, '國外': 2}
# {'旅遊': 1}
# {'超商': 1}
# {}
# {'超商': 2}
# {'超市': 1}
# {}
# {'保險': 3, '超商': 3}
# {}
# {'加油': 2}
# {'網購': 1}
# {}
# {}
# {'紅利': 2}
# {'加油': 1}
# {'網購': 1}
# {'國外': 1}
# {}
# {}
# {'超市': 1, '加油': 1}
# {}
# {'超商': 1}
# {}
# {}
# {'加油': 1, '行動支付': 1}
# {'超商': 1}
# {}
# {}
# {'保險': 1}
# {'保險': 3}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {}
# {'旅遊': 1, '量販店': 1}
# {'國外': 2}
# {'網購': 2}
# {'超商': 6, '行動支付': 1, '網購': 1, '超市': 4, '加油': 1}
# {'保險': 1}
# {}
# {'國外': 2, '行動支付': 3, '超商': 1}
# {}
# {'藥妝': 1}
# {}
# {'旅遊': 1}
# {}
# {'國外': 2, '紅利': 2}
# {}
# {}
# {'加油': 9}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'保險': 3}
# {}
# {'加油': 2}
# {}
# {}
# {'電影': 2}
# {'電影': 2}
# {}
# {}
# {}
# {}
# {'保險': 2}
# {}
# {'國外': 4, '加油': 1, '網購': 1}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {'國外': 1}
# {'旅遊': 2, '航空哩程': 3, '國外': 1}
# {'旅遊': 2}
# {'航空哩程': 3}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {'保險': 3}
# {}
# {'旅遊': 2}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 4}
# {'旅遊': 2}
# {'旅遊': 1, '國外': 2}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 5}
# {}
# {}
# {'紅利': 1}
# {}
# {}
# {'電影': 1}
# {}
# {}
# {'紅利': 2}
# {'紅利': 2}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {'旅遊': 3}
# {}
# {'旅遊': 1}
# {}
# {'國外': 3}
# {'旅遊': 2}
# {'超商': 1, '航空哩程': 2, '旅遊': 3}
# {}
# {'國外': 1}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 2}
# {'旅遊': 1}
# {'網購': 2}
# {}
# {}
# {'電影': 1, '國外': 1}
# {}
# {'旅遊': 4}
# {'旅遊': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {'旅遊': 2}
# {}
# {'國外': 1}
# {}
# {'國外': 1}
# {}
# {}
# {'加油': 5, '國外': 1, '網購': 1}
# {'加油': 5}
# {'加油': 6}
# {'加油': 5}
# {}
# {'網購': 3, '行動支付': 1}
# {'超商': 1}
# {'旅遊': 2, '電影': 1, '網購': 1}
# {}
# {}
# {}
# {'國外': 6}
# {'國外': 2}
# {'國外': 1}
# {'國外': 1}
# {}
# {}
# {}
# {'量販店': 2}
# {}
# {'超商': 1}
# {'旅遊': 1}
# {'國外': 1}
# {'行動支付': 1}
# {'旅遊': 2, '國外': 2}
# {}
# {'電影': 3}
# {}
# {'國外': 5, '超商': 1}
# {'網購': 1, '國外': 1}
# {}
# {'保險': 3}
# {'保險': 3}
# {'保險': 8, '國外': 1}
# {'保險': 4}
# {}
# {}
# {}
# {'國外': 1}
# {'保險': 1}
# {}
# {'行動支付': 2, '網購': 5, '超商': 1}
# {}
# {}
# {}
# {'百貨': 2}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2, '航空哩程': 1}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {'旅遊': 8, '國外': 2}
# {}
# {'國外': 4, '電影': 3, '超商': 2, '行動支付': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'網購': 1, '旅遊': 2}
# {'保險': 2}
# {}
# {}
# {'旅遊': 2, '紅利': 1}
# {'旅遊': 3}
# {'保險': 3}
# {'超商': 2}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 2, '超市': 2, '超商': 3, '網購': 2, '行動支付': 1, '國外': 2, '旅遊': 2}
# {}
# {'旅遊': 3}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 4}
# {'國外': 3}
# {'保險': 1, '旅遊': 9}
# {'加油': 1}
# {'網購': 4, '行動支付': 5}
# {'網購': 1, '旅遊': 1, '國外': 1, '超商': 3, '電影': 1}
# {}
# {'電影': 4, '行動支付': 3}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1, '行動支付': 1}
# {'運動': 3}
# {'運動': 3, '超商': 2}
# {'運動': 2}
# {'量販店': 1}
# {}
# {}
# {}
# {'加油': 4}
# {}
# {}
# {}
# {'加油': 1, '超商': 1}
# {'網購': 3}
# {}
# {'旅遊': 1, '國外': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {'旅遊': 2, '國外': 2}
# {}
# {}
# {'旅遊': 1}
# {'國外': 1}
# {'加油': 1, '旅遊': 1, '國外': 1}
# {'保險': 2}
# {}
# {'國外': 2, '旅遊': 1, '加油': 1}
# {'旅遊': 1}
# {}
# {'行動支付': 2, '超商': 1}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {'電影': 4}
# {}
# {'網購': 8, '超商': 2}
# {}
# {'網購': 3}
# {'網購': 3}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {'網購': 1, '量販店': 4, '藥妝': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'網購': 6}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'網購': 2, '國外': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'紅利': 1, '旅遊': 2}
# {'旅遊': 6}
# {'網購': 5, '行動支付': 2, '國外': 4, '超商': 1, '旅遊': 9}
# {}
# {'加油': 2}
# {'超商': 1}
# {'超商': 3, '網購': 1}
# {'超商': 1}
# {'超商': 7}
# {'超商': 3}
# {'超商': 2}
# {'超商': 2, '行動支付': 4}
# {'超商': 4, '超市': 1, '量販店': 2}
# {'超商': 2, '行動支付': 1}
# {'超商': 1, '行動支付': 1}
# {'超市': 2}
# {'超市': 2}
# {'超市': 3}
# {'超市': 3}
# {}
# {'網購': 2}
# {'超商': 1}
# {}
# {}
# {'旅遊': 1, '保險': 1}
# {'旅遊': 1}
# {}
# {'紅利': 1, '超市': 1, '超商': 5}
# {'紅利': 1, '超市': 1, '超商': 5}
# {'電影': 2}
# {'電影': 2}
# {'超商': 1}
# {'電影': 2}
# {'電影': 4}
# {}
# {}
# {'電影': 2}
# {'保險': 4, '電影': 1}
# {'電影': 1}
# {'旅遊': 4, '國外': 2}
# {'旅遊': 4}
# {'旅遊': 5, '國外': 2}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1, '國外': 1, '保險': 1}
# {'電影': 2, '超商': 1, '超市': 1, '量販店': 1, '旅遊': 1}
# {}
# {'國外': 2}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'國外': 2, '旅遊': 5, '網購': 1}
# {}
# {}
# {'旅遊': 2}
# {}
# {'旅遊': 7}
# {'國外': 2, '網購': 2, '保險': 1}
# {'國外': 1}
# {'國外': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {'保險': 2, '紅利': 3, '百貨': 1}
# {'保險': 3}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {'旅遊': 3}
# {}
# {'網購': 1}
# {'旅遊': 2}
# {'旅遊': 2}
# {'超商': 1}
# {}
# {}
# {}
# {'旅遊': 10}
# {'旅遊': 7, '國外': 1}
# {'旅遊': 5}
# {'旅遊': 4, '國外': 3}
# {'網購': 1}
# {'國外': 2}
# {}
# {'國外': 3}
# {}
# {}
# {'百貨': 2}
# {}
# {}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'航空哩程': 1, '網購': 6, '旅遊': 2, '加油': 1, '國外': 1, '百貨': 2}
# {}
# {}
# {}
# {}
# {'加油': 3}
# {'加油': 7}
# {'加油': 4, '超商': 2}
# {'加油': 2}
# {}
# {'網購': 5, '行動支付': 2, '超商': 2, '超市': 1, '加油': 3, '保險': 2, '國外': 2, '旅遊': 3}
# {'國外': 1}
# {}
# {'旅遊': 1, '網購': 1}
# {'旅遊': 2}
# {'網購': 1}
# {}
# {}
# {'超商': 2}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'國外': 5}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {'量販店': 2}
# {'超市': 1}
# {'保險': 1}
# {}
# {'國外': 2}
# {'加油': 2, '電影': 1, '旅遊': 4, '網購': 2, '國外': 2}
# {'國外': 2, '超商': 1, '行動支付': 3, '網購': 1, '保險': 1, '旅遊': 1}
# {'網購': 1, '行動支付': 1}
# {'保險': 5, '超市': 3, '超商': 1, '旅遊': 2, '電影': 1, '國外': 2}
# {'量販店': 1, '加油': 1, '超市': 1}
# {}
# {}
# {'百貨': 1}
# {'行動支付': 3}
# {}
# {'網購': 2, '量販店': 3, '電影': 1, '旅遊': 2, '加油': 1}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 1}
# {'超商': 1, '行動支付': 2}
# {}
# {}
# {}
# {'旅遊': 1, '航空哩程': 2}
# {'旅遊': 1}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {'旅遊': 1}
# {'保險': 1}
# {}
# {'行動支付': 1, '超市': 1, '量販店': 1}
# {'旅遊': 1, '國外': 1}
# {'電影': 2}
# {}
# {'國外': 2}
# {'百貨': 1}
# {'加油': 3, '紅利': 1}
# {'加油': 1, '超市': 3}
# {}
# {'加油': 6}
# {'加油': 2}
# {'旅遊': 9}
# {}
# {'超市': 1}
# {}
# {}
# {}
# {}
# {}
# {'紅利': 1}
# {'網購': 1}
# {'網購': 2, '超商': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {'旅遊': 6}
# {}
# {'網購': 1}
# {}
# {'航空哩程': 2}
# {}
# {'網購': 3}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 4}
# {}
# {'旅遊': 4}
# {'網購': 2}
# {}
# {'旅遊': 8, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {'網購': 2}
# {'國外': 1}
# {'超商': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 5, '國外': 5}
# {'旅遊': 3}
# {}
# {}
# {'保險': 1}
# {}
# {'旅遊': 6, '保險': 1}
# {'加油': 2}
# {'旅遊': 1, '超商': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {}
# {}
# {'旅遊': 5}
# {'紅利': 1, '加油': 1}
# {}
# {'行動支付': 1}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 4, '網購': 1}
# {}
# {'量販店': 2}
# {}
# {'網購': 2, '國外': 1}
# {'行動支付': 4, '運動': 1, '超市': 1, '網購': 1}
# {}
# {'網購': 3}
# {'網購': 1}
# {}
# {}
# {'網購': 1}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {'保險': 6}
# {'旅遊': 5}
# {'行動支付': 3, '超商': 1}
# {}
# {}
# {'電影': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 3}
# {'網購': 2}
# {}
# {}
# {}
# {'旅遊': 5}
# {}
# {'超商': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'保險': 1}
# {'航空哩程': 1}
# {'旅遊': 3, '保險': 1}
# {'航空哩程': 1, '國外': 1, '旅遊': 1}
# {}
# {}
# {'航空哩程': 1}
# {}
# {'旅遊': 2}
# {'電影': 1}
# {'電影': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2}
# {}
# {'行動支付': 1}
# {}
# {'國外': 1}
# {'國外': 5, '網購': 1, '旅遊': 1}
# {'旅遊': 1}
# {'加油': 1, '網購': 1, '保險': 1, '旅遊': 1}
# {}
# {'網購': 2}
# {}
# {}
# {'超商': 1, '超市': 2}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 3, '國外': 2}
# {}
# {'行動支付': 1}
# {}
# {'保險': 4, '旅遊': 3}
# {}
# {}
# {'旅遊': 1}
# {}
# {'國外': 2, '量販店': 1}
# {}
# {}
# {}
# {}
# {'行動支付': 9, '超商': 1}
# {}
# {}
# {}
# {'行動支付': 4}
# {'國外': 2}
# {}
# {'國外': 2}
# {'國外': 2}
# {'國外': 1}
# {}
# {'超商': 1}
# {'旅遊': 2}
# {'旅遊': 1}
# {}
# {'網購': 1, '超商': 1}
# {}
# {}
# {}
# {'網購': 3}
# {}
# {'網購': 1}
# {}
# {'紅利': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'超商': 4, '加油': 1}
# {'超商': 4, '加油': 1}
# {'航空哩程': 6, '旅遊': 5, '國外': 2}
# {'航空哩程': 5, '國外': 3, '旅遊': 7}
# {'航空哩程': 3, '旅遊': 8, '國外': 2}
# {'航空哩程': 9, '行動支付': 1, '超商': 1}
# {'航空哩程': 3, '旅遊': 2, '國外': 1, '網購': 1, '保險': 1}
# {'航空哩程': 3, '旅遊': 1}
# {'航空哩程': 3, '旅遊': 1}
# {'航空哩程': 6, '旅遊': 1}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {}
# {'超市': 1}
# {}
# {}
# {}
# {}
# {'超市': 1}
# {'國外': 1, '旅遊': 1}
# {'旅遊': 1}
# {}
# {'保險': 2, '網購': 1, '國外': 1}
# {}
# {}
# {}
# {'量販店': 2}
# {'加油': 9}
# {}
# {}
# {'旅遊': 3}
# {'國外': 1}
# {'旅遊': 13, '國外': 1}
# {'國外': 1}
# {'國外': 1, '旅遊': 1}
# {'國外': 1}
# {'國外': 1}
# {'國外': 1, '旅遊': 1}
# {'國外': 3}
# {'國外': 2}
# {'國外': 1, '旅遊': 2}
# {'國外': 2}
# {'國外': 1, '旅遊': 1}
# {'國外': 1}
# {'國外': 4, '旅遊': 5}
# {'國外': 2, '網購': 1, '保險': 1}
# {'國外': 2, '旅遊': 1}
# {'國外': 3}
# {'國外': 1, '旅遊': 1}
# {'國外': 3}
# {'國外': 3, '旅遊': 3}
# {'國外': 7, '旅遊': 3, '電影': 1, '網購': 1}
# {'國外': 1}
# {'國外': 6, '旅遊': 3}
# {'國外': 3, '航空哩程': 2}
# {'國外': 3}
# {'國外': 4, '超商': 4}
# {'國外': 1, '超市': 2}
# {'國外': 1, '旅遊': 1}
# {'國外': 2}
# {}
# {'旅遊': 4}
# {'網購': 5, '超商': 5, '電影': 2}
# {'行動支付': 1, '網購': 3, '超商': 2}
# {}
# {'網購': 2, '超商': 3, '行動支付': 3}
# {}
# {'航空哩程': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'紅利': 2}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {'超商': 1}
# {'網購': 2}
# {}
# {'網購': 1}
# {'網購': 1}
# {}
# {'行動支付': 3}
# {}
# {'超商': 2}
# {'超商': 1, '網購': 1}
# {}
# {'超商': 4}
# {}
# {}
# {}
# {'行動支付': 2}
# {'網購': 2}
# {'百貨': 2}
# {'百貨': 5}
# {'旅遊': 1}
# {'旅遊': 2}
# {'國外': 2}
# {'百貨': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2, '國外': 4}
# {'加油': 4}
# {}
# {'國外': 1, '加油': 3}
# {'國外': 2}
# {'國外': 2, '旅遊': 2}
# {'旅遊': 2}
# {'網購': 1}
# {'航空哩程': 3, '國外': 5, '旅遊': 3}
# {'航空哩程': 2}
# {}
# {'航空哩程': 2}
# {}
# {'保險': 1, '運動': 1}
# {}
# {'超市': 2}
# {'網購': 3}
# {'保險': 2}
# {'保險': 2}
# {}
# {'加油': 1}
# {}
# {}
# {}
# {'網購': 1}
# {'網購': 3}
# {'超商': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 2}
# {}
# {'電影': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'網購': 1, '超商': 1}
# {'網購': 1}
# {}
# {}
# {'航空哩程': 2, '國外': 3}
# {}
# {}
# {'航空哩程': 1}
# {'網購': 2, '國外': 5, '旅遊': 4}
# {'航空哩程': 3, '網購': 1, '旅遊': 2}
# {'航空哩程': 1}
# {'百貨': 3}
# {}
# {'航空哩程': 1}
# {'旅遊': 4}
# {}
# {'國外': 2, '旅遊': 3}
# {}
# {'航空哩程': 1, '超商': 4, '行動支付': 2}
# {'旅遊': 1}
# {'旅遊': 1, '航空哩程': 1}
# {'旅遊': 1}
# {'旅遊': 3}
# {}
# {'網購': 2}
# {}
# {'電影': 7}
# {'電影': 3}
# {'電影': 3}
# {'電影': 2}
# {'國外': 3}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {'國外': 3}
# {'百貨': 1}
# {'行動支付': 4, '國外': 2}
# {'超商': 2, '國外': 2}
# {'國外': 3}
# {}
# {'加油': 1}
# {'航空哩程': 1}
# {'網購': 1, '國外': 8}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'網購': 1}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'量販店': 5, '加油': 1}
# {}
# {}
# {'超商': 2}
# {}
# {'加油': 4}
# {}
# {'網購': 2, '加油': 1}
# {}
# {'旅遊': 7, '國外': 1}
# {'旅遊': 1}
# {'國外': 3, '旅遊': 1}
# {'旅遊': 2}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'量販店': 1}
# {}
# {'國外': 3}
# {'網購': 5}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {'量販店': 1}
# {'旅遊': 3}
# {'旅遊': 3}
# {}
# {}
# {'網購': 2}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {'量販店': 2, '電影': 1, '超市': 1, '網購': 1}
# {}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {'行動支付': 2}
# {'行動支付': 2}
# {'旅遊': 1}
# {'電影': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2, '行動支付': 1}
# {'保險': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {'量販店': 9}
# {}
# {'行動支付': 2}
# {'量販店': 2}
# {}
# {}
# {}
# {'超市': 1}
# {'加油': 7, '行動支付': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {'網購': 3}
# {'旅遊': 1}
# {'保險': 2}
# {'保險': 3}
# {}
# {}
# {}
# {}
# {'保險': 12}
# {'紅利': 1, '保險': 3, '國外': 3, '旅遊': 9, '網購': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {'國外': 1}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'超商': 1, '行動支付': 4, '網購': 1}
# {}
# {}
# {}
# {'量販店': 1, '國外': 1}
# {}
# {'國外': 1}
# {'超商': 1, '量販店': 2}
# {'百貨': 1}
# {'量販店': 1}
# {}
# {'網購': 1}
# {'電影': 1, '加油': 1, '旅遊': 1}
# {}
# {'量販店': 2}
# {'量販店': 3, '旅遊': 1}
# {}
# {'網購': 4, '行動支付': 3, '超商': 1}
# {'旅遊': 4, '國外': 1, '加油': 2, '超商': 2, '保險': 1, '網購': 5, '航空哩程': 1}
# {}
# {'加油': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {'超市': 2}
# {'旅遊': 5, '國外': 2}
# {'網購': 2}
# {'網購': 1}
# {'百貨': 3, '網購': 1, '旅遊': 1}
# {'量販店': 1}
# {'網購': 1, '運動': 1, '超商': 2, '加油': 2, '旅遊': 1, '紅利': 1, '行動支付': 1}
# {}
# {'國外': 6, '旅遊': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'旅遊': 1, '保險': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 1}
# {'超商': 2}
# {'國外': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'電影': 4}
# {'行動支付': 5}
# {'超商': 1, '網購': 1}
# {'保險': 2}
# {'航空哩程': 2, '旅遊': 2}
# {}
# {'超商': 2}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'超市': 1, '加油': 1}
# {}
# {}
# {}
# {'電影': 1}
# {'超商': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 3, '保險': 1}
# {}
# {}
# {'旅遊': 1, '國外': 2, '運動': 1}
# {'保險': 2, '超商': 3, '網購': 5, '國外': 9, '旅遊': 3, '行動支付': 1, '百貨': 1}
# {}
# {}
# {}
# {}
# {'網購': 1, '超商': 1, '行動支付': 2, '加油': 1, '旅遊': 1}
# {'國外': 4, '旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {'百貨': 1, '國外': 1}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2}
# {'超商': 1, '行動支付': 1}
# {}
# {'超商': 4}
# {}
# {}
# {}
# {}
# {'量販店': 1, '行動支付': 1}
# {'保險': 3}
# {'量販店': 1}
# {'旅遊': 1, '保險': 1}
# {}
# {'紅利': 6, '旅遊': 2, '加油': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 3, '國外': 2}
# {}
# {}
# {'電影': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 4}
# {}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 1, '航空哩程': 1}
# {'旅遊': 2, '國外': 1}
# {}
# {'旅遊': 1, '網購': 2, '保險': 2, '超商': 1}
# {'保險': 2, '行動支付': 3, '國外': 2, '網購': 2}
# {}
# {'旅遊': 1}
# {'行動支付': 1, '網購': 2}
# {}
# {}
# {'行動支付': 6, '超商': 2}
# {'保險': 4, '運動': 2, '網購': 2, '加油': 2, '旅遊': 1, '紅利': 1, '國外': 3}
# {}
# {}
# {'網購': 1}
# {'加油': 1, '量販店': 1, '航空哩程': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超市': 1, '網購': 3}
# {}
# {'旅遊': 2}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {'旅遊': 1, '國外': 2}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 3}
# {'旅遊': 1, '國外': 7}
# {'旅遊': 1}
# {'旅遊': 2}
# {}
# {'網購': 2}
# {}
# {'超市': 2}
# {}
# {'旅遊': 3}
# {}
# {'國外': 2}
# {'旅遊': 3, '國外': 1}
# {}
# {'旅遊': 1}
# {'網購': 2}
# {}
# {'網購': 2}
# {'保險': 2}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {'國外': 3}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {'航空哩程': 3, '旅遊': 1, '國外': 3}
# {'旅遊': 1}
# {}
# {'國外': 2}
# {}
# {'保險': 1, '旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'保險': 2}
# {'旅遊': 3}
# {'國外': 2}
# {}
# {}
# {'國外': 3, '旅遊': 1}
# {'加油': 1, '行動支付': 1}
# {}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {'電影': 2}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 8, '航空哩程': 4, '國外': 1}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {'超商': 2}
# {}
# {}
# {'網購': 1}
# {'超商': 3}
# {'超商': 2}
# {'國外': 1}
# {}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {'行動支付': 1}
# {'網購': 1}
# {}
# {}
# {'旅遊': 1}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 3}
# {'加油': 2}
# {'超市': 1}
# {'旅遊': 2}
# {}
# {}
# {'運動': 2}
# {}
# {'行動支付': 4}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 1}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'國外': 1}
# {'旅遊': 1}
# {'國外': 1}
# {'國外': 1, '旅遊': 1}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'加油': 1, '網購': 1}
# {'行動支付': 1}
# {}
# {}
# {'國外': 1}
# {'旅遊': 4}
# {'旅遊': 1}
# {'旅遊': 6}
# {'旅遊': 4}
# {'旅遊': 5}
# {'旅遊': 6}
# {'旅遊': 2, '國外': 1}
# {'旅遊': 1}
# {'旅遊': 3}
# {'旅遊': 7}
# {'旅遊': 6}
# {'旅遊': 2}
# {'旅遊': 2, '航空哩程': 1}
# {'旅遊': 3}
# {'量販店': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 6, '旅遊': 2}
# {'旅遊': 2, '國外': 2}
# {'旅遊': 2, '國外': 6}
# {'旅遊': 2}
# {}
# {}
# {}
# {'行動支付': 1}
# {'國外': 1, '超商': 2}
# {}
# {'超商': 1}
# {}
# {}
# {'運動': 2}
# {}
# {'旅遊': 3}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {'網購': 7}
# {'網購': 3}
# {'超商': 6, '網購': 2}
# {}
# {'國外': 3}
# {}
# {}
# {}
# {'電影': 3, '行動支付': 1, '超商': 1}
# {'旅遊': 1}
# {'旅遊': 2}
# {'電影': 2, '行動支付': 1}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {}
# {'國外': 3, '藥妝': 1, '旅遊': 1}
# {'國外': 1}
# {'國外': 3}
# {}
# {}
# {}
# {'網購': 3}
# {}
# {}
# {'保險': 1, '超商': 1}
# {}
# {}
# {}
# {}
# {'超市': 2, '量販店': 1}
# {'網購': 6, '旅遊': 3, '超商': 1, '國外': 3}
# {'國外': 1}
# {'國外': 1, '旅遊': 1}
# {'保險': 1, '運動': 1, '超商': 1, '旅遊': 1, '國外': 1, '網購': 6, '行動支付': 1}
# {'行動支付': 1}
# {}
# {'加油': 1}
# {'網購': 2}
# {}
# {}
# {'航空哩程': 1}
# {}
# {'旅遊': 3}
# {}
# {}
# {'保險': 2}
# {}
# {'國外': 5}
# {}
# {}
# {}
# {'國外': 7, '旅遊': 2, '航空哩程': 1}
# {'國外': 3, '網購': 3, '旅遊': 1}
# {'國外': 2, '旅遊': 1}
# {'國外': 1, '旅遊': 3}
# {'國外': 3}
# {'國外': 1}
# {'國外': 4}
# {'國外': 8, '旅遊': 2}
# {'國外': 2}
# {'國外': 4}
# {'國外': 2}
# {'國外': 2, '旅遊': 3}
# {'國外': 2, '網購': 1}
# {'國外': 5, '旅遊': 2}
# {'國外': 4, '旅遊': 1}
# {'國外': 1}
# {'國外': 5, '網購': 3}
# {'國外': 1}
# {'國外': 5}
# {'國外': 2, '行動支付': 1, '超商': 1}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超市': 1}
# {}
# {}
# {'超商': 1, '網購': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 3, '國外': 1}
# {'運動': 1}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'電影': 2}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {'加油': 4}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {'國外': 1, '旅遊': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'超商': 4}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {}
# {'網購': 3, '超市': 1, '量販店': 1, '保險': 3, '超商': 1, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1, '超商': 2, '行動支付': 1, '紅利': 1, '旅遊': 2}
# {'旅遊': 3}
# {'超商': 7}
# {'電影': 2}
# {'超商': 2}
# {}
# {'網購': 1}
# {}
# {}
# {'網購': 2}
# {'超商': 2}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1}
# {'量販店': 1}
# {'旅遊': 3}
# {'紅利': 1}
# {}
# {}
# {'藥妝': 1}
# {'百貨': 2, '紅利': 1, '旅遊': 1}
# {'旅遊': 2, '網購': 1}
# {}
# {'保險': 1}
# {}
# {'行動支付': 1}
# {}
# {'網購': 1}
# {}
# {'行動支付': 2, '量販店': 1, '網購': 1}
# {}
# {}
# {'超市': 2, '行動支付': 1}
# {'行動支付': 1}
# {'行動支付': 2, '旅遊': 1}
# {'網購': 4, '行動支付': 3, '保險': 2, '超商': 1, '超市': 1, '加油': 1, '紅利': 1}
# {'超商': 4, '行動支付': 2}
# {'行動支付': 2, '加油': 3}
# {}
# {}
# {'行動支付': 1}
# {'行動支付': 2, '保險': 1}
# {'保險': 2}
# {}
# {'保險': 3}
# {}
# {}
# {}
# {}
# {'保險': 2, '行動支付': 2}
# {'行動支付': 2, '網購': 1}
# {'行動支付': 2}
# {}
# {}
# {'網購': 1}
# {'旅遊': 1}
# {}
# {'保險': 1, '超商': 2, '行動支付': 1, '網購': 1}
# {'國外': 1}
# {}
# {'網購': 2}
# {}
# {'行動支付': 1}
# {}
# {'網購': 3, '藥妝': 1, '行動支付': 3, '量販店': 1, '保險': 1, '超商': 1}
# {}
# {'網購': 2}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'超商': 1}
# {'超商': 2}
# {'旅遊': 1}
# {'行動支付': 2}
# {'行動支付': 3, '超商': 1}
# {}
# {'超商': 1}
# {'旅遊': 5, '國外': 1}
# {'旅遊': 1, '超商': 1}
# {'旅遊': 4}
# {}
# {}
# {}
# {'旅遊': 7}
# {'旅遊': 14, '加油': 1, '國外': 2}
# {}
# {}
# {}
# {'紅利': 2}
# {}
# {'超商': 3, '保險': 1}
# {}
# {'旅遊': 7}
# {}
# {}
# {}
# {'國外': 2}
# {'加油': 2}
# {'加油': 1, '旅遊': 4}
# {'加油': 5}
# {}
# {'加油': 3}
# {'旅遊': 7}
# {}
# {}
# {'旅遊': 5}
# {'旅遊': 5}
# {}
# {'國外': 1}
# {'量販店': 1}
# {'量販店': 1}
# {'行動支付': 2}
# {}
# {'量販店': 1, '行動支付': 1}
# {'保險': 1}
# {'網購': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {'網購': 1}
# {}
# {'紅利': 3}
# {}
# {'網購': 2}
# {'網購': 7, '紅利': 2, '量販店': 1}
# {}
# {}
# {'國外': 1}
# {'保險': 1}
# {'加油': 3}
# {}
# {'國外': 1}
# {'旅遊': 3}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2, '網購': 1}
# {'網購': 2, '超市': 1, '加油': 1, '行動支付': 1, '電影': 1, '運動': 1, '百貨': 2, '旅遊': 5, '國外': 3, '保險': 2}
# {'網購': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {'加油': 3}
# {}
# {}
# {'國外': 1, '網購': 1}
# {}
# {}
# {'網購': 1}
# {'旅遊': 1, '網購': 1}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {'網購': 4}
# {}
# {'旅遊': 1, '保險': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {'國外': 2}
# {'行動支付': 1}
# {}
# {}
# {}
# {'網購': 3}
# {'藥妝': 1}
# {'百貨': 1}
# {'百貨': 2}
# {'行動支付': 2}
# {'百貨': 3}
# {'網購': 2, '國外': 1, '行動支付': 1, '超商': 1, '加油': 1}
# {'國外': 1}
# {'國外': 2}
# {}
# {'行動支付': 4, '超商': 5}
# {}
# {'超商': 5}
# {'電影': 2}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {'超商': 2}
# {'國外': 1, '保險': 1}
# {}
# {'網購': 2, '旅遊': 1, '國外': 1}
# {'國外': 1}
# {'保險': 1}
# {}
# {}
# {'旅遊': 2}
# {}
# {'旅遊': 1}
# {'網購': 4, '保險': 1, '加油': 1, '旅遊': 1, '超商': 1, '紅利': 1}
# {}
# {}
# {'國外': 1}
# {}
# {'超市': 2}
# {}
# {}
# {'航空哩程': 4, '旅遊': 2}
# {}
# {}
# {'行動支付': 3}
# {'旅遊': 5}
# {}
# {'超商': 1}
# {}
# {}
# {'網購': 1}
# {}
# {'網購': 2}
# {'網購': 3, '國外': 3}
# {'網購': 1, '旅遊': 1}
# {'網購': 3}
# {'網購': 12, '行動支付': 2}
# {'網購': 1}
# {'網購': 2}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 4}
# {'超商': 1, '行動支付': 1}
# {}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {}
# {'超市': 1}
# {'行動支付': 1}
# {'行動支付': 1}
# {'電影': 1, '加油': 1}
# {}
# {'超商': 2}
# {}
# {'國外': 1}
# {'行動支付': 1, '網購': 1, '國外': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1, '國外': 3, '網購': 2}
# {'國外': 4, '旅遊': 4}
# {'旅遊': 1, '航空哩程': 1}
# {}
# {'旅遊': 3}
# {}
# {}
# {'國外': 1}
# {'航空哩程': 2}
# {}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 3}
# {}
# {'旅遊': 2}
# {'國外': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 6}
# {'航空哩程': 2}
# {'旅遊': 7}
# {'旅遊': 1}
# {}
# {'紅利': 1}
# {'網購': 2}
# {}
# {'國外': 1}
# {'國外': 2}
# {}
# {'旅遊': 4}
# {'旅遊': 1, '航空哩程': 5}
# {'國外': 9, '旅遊': 11, '保險': 4}
# {'旅遊': 4, '國外': 1}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'保險': 1, '網購': 1, '超商': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'保險': 2}
# {'行動支付': 2}
# {'加油': 2}
# {'加油': 3}
# {'加油': 2}
# {'加油': 1}
# {}
# {'百貨': 1}
# {'量販店': 4}
# {'超商': 1}
# {}
# {'超商': 2}
# {}
# {'國外': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {'國外': 3}
# {'超市': 2}
# {'航空哩程': 1}
# {'網購': 2}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 3}
# {}
# {}
# {}
# {'國外': 3}
# {}
# {'超商': 2}
# {}
# {}
# {'超商': 1}
# {'旅遊': 2}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 9}
# {}
# {}
# {}
# {'網購': 4, '加油': 2, '超商': 2}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'航空哩程': 1}
# {}
# {'網購': 3}
# {'國外': 1, '旅遊': 3}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {'加油': 3}
# {}
# {'國外': 1}
# {}
# {}
# {'紅利': 1, '旅遊': 1}
# {}
# {'網購': 1}
# {}
# {'旅遊': 1, '網購': 1}
# {}
# {'國外': 2}
# {'旅遊': 1}
# {'行動支付': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'加油': 2}
# {'電影': 2, '國外': 1, '網購': 4}
# {}
# {}
# {'航空哩程': 2}
# {'電影': 1}
# {}
# {'運動': 1}
# {}
# {}
# {}
# {'旅遊': 1, '保險': 2}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'電影': 1}
# {}
# {}
# {'航空哩程': 1}
# {'行動支付': 3, '超商': 2, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 6}
# {}
# {}
# {'超商': 1, '加油': 1, '紅利': 1, '保險': 1}
# {'紅利': 1}
# {}
# {}
# {}
# {'網購': 5}
# {}
# {}
# {'超市': 2, '超商': 2}
# {}
# {}
# {'網購': 1}
# {'旅遊': 2}
# {'電影': 1}
# {}
# {}
# {'電影': 2}
# {}
# {'旅遊': 4, '國外': 1}
# {'超市': 4}
# {}
# {}
# {}
# {'旅遊': 1}
# {'國外': 3}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'加油': 1}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {}
# {}
# {'保險': 2}
# {}
# {'紅利': 5, '網購': 4}
# {'行動支付': 2}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {'電影': 4}
# {}
# {}
# {'行動支付': 1, '超市': 1, '加油': 1}
# {}
# {'網購': 2}
# {'國外': 3, '旅遊': 4, '百貨': 2, '保險': 2}
# {}
# {}
# {}
# {'旅遊': 3, '電影': 2}
# {}
# {'網購': 3}
# {'網購': 2}
# {}
# {}
# {'網購': 2}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 4, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'網購': 1}
# {'行動支付': 6}
# {'網購': 4}
# {'網購': 4}
# {'網購': 2, '行動支付': 3}
# {'網購': 4}
# {}
# {}
# {}
# {'旅遊': 2}
# {'國外': 2}
# {}
# {'旅遊': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'加油': 1, '國外': 1, '旅遊': 1}
# {'旅遊': 4}
# {}
# {'網購': 2}
# {'網購': 6, '行動支付': 2}
# {}
# {}
# {'旅遊': 1}
# {'超商': 1}
# {}
# {}
# {'網購': 1}
# {'國外': 1}
# {}
# {'超商': 2, '紅利': 1}
# {}
# {'行動支付': 6}
# {'電影': 2}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {'國外': 3, '旅遊': 1}
# {'保險': 1, '旅遊': 3}
# {'網購': 2}
# {'網購': 1}
# {}
# {'行動支付': 3}
# {'行動支付': 3, '網購': 2, '超市': 1}
# {}
# {'行動支付': 4}
# {'行動支付': 2, '超商': 1, '國外': 1}
# {'行動支付': 2}
# {'行動支付': 2}
# {'行動支付': 3}
# {'行動支付': 2}
# {'行動支付': 4}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {'行動支付': 1}
# {'國外': 5}
# {}
# {'運動': 1}
# {}
# {'量販店': 1}
# {}
# {'旅遊': 3, '國外': 1}
# {'旅遊': 1}
# {'旅遊': 1, '超商': 2, '加油': 1, '行動支付': 1}
# {'航空哩程': 4, '國外': 2}
# {}
# {'航空哩程': 1, '旅遊': 2}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {'行動支付': 1, '網購': 1, '電影': 1, '加油': 2, '旅遊': 5}
# {}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 4}
# {'電影': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 9, '行動支付': 1}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {}
# {}
# {'超商': 4}
# {'行動支付': 6, '超商': 5}
# {}
# {'國外': 1}
# {'旅遊': 5}
# {'旅遊': 4}
# {'超商': 3, '保險': 2}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {'加油': 2, '紅利': 1}
# {'超商': 1}
# {'網購': 1}
# {}
# {'電影': 2}
# {}
# {'網購': 1}
# {'加油': 3}
# {'國外': 1}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'行動支付': 1}
# {}
# {'網購': 2}
# {'旅遊': 3}
# {'網購': 1, '旅遊': 1}
# {'加油': 3}
# {'網購': 3, '國外': 2}
# {}
# {}
# {}
# {'行動支付': 2, '網購': 1}
# {'行動支付': 1}
# {'旅遊': 2, '保險': 1}
# {'行動支付': 1}
# {}
# {'旅遊': 4}
# {}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1, '百貨': 1}
# {'旅遊': 3, '保險': 2}
# {'國外': 3}
# {'旅遊': 2}
# {}
# {'旅遊': 2, '國外': 1}
# {'量販店': 4}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 1}
# {'旅遊': 2}
# {'旅遊': 5}
# {}
# {'航空哩程': 2}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {'國外': 1, '保險': 1}
# {'旅遊': 6}
# {'超市': 3}
# {}
# {}
# {'旅遊': 6, '國外': 1}
# {'量販店': 2}
# {'加油': 1}
# {}
# {'網購': 1}
# {'旅遊': 2, '國外': 1}
# {}
# {'保險': 2}
# {}
# {'旅遊': 1, '量販店': 1}
# {}
# {'網購': 4}
# {}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1, '網購': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 2, '航空哩程': 1}
# {}
# {}
# {'旅遊': 3, '國外': 1}
# {'國外': 2}
# {'電影': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1, '國外': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'網購': 5}
# {'國外': 2}
# {}
# {}
# {}
# {'保險': 2}
# {'旅遊': 4}
# {}
# {}
# {'旅遊': 2}
# {'加油': 1, '旅遊': 1, '保險': 1}
# {}
# {'保險': 1, '國外': 1}
# {}
# {'加油': 3}
# {}
# {'行動支付': 2, '超商': 1, '保險': 2, '加油': 2}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {'超商': 1}
# {'保險': 2}
# {}
# {'超商': 1}
# {'旅遊': 2}
# {'旅遊': 1, '紅利': 2}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'行動支付': 1}
# {'航空哩程': 7, '電影': 1, '網購': 1, '旅遊': 1, '國外': 1}
# {'加油': 21, '網購': 3, '量販店': 12, '電影': 1, '行動支付': 5, '超商': 5, '保險': 1, '超市': 1, '百貨': 3, '紅利': 1, '藥妝': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {'旅遊': 2, '國外': 1}
# {'旅遊': 4}
# {'旅遊': 2}
# {'國外': 2, '旅遊': 6}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {}
# {'網購': 3}
# {}
# {'國外': 3}
# {'超商': 4, '網購': 1, '行動支付': 1}
# {'超商': 1}
# {'超商': 4}
# {'超商': 5, '網購': 2}
# {'超商': 1}
# {'超商': 3}
# {'旅遊': 2}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {'藥妝': 1, '量販店': 1, '超商': 1, '保險': 5}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2, '網購': 3}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 1}
# {'旅遊': 1}
# {}
# {'網購': 1}
# {'旅遊': 3}
# {'旅遊': 1, '航空哩程': 3}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'網購': 1}
# {}
# {'航空哩程': 4, '旅遊': 2}
# {}
# {}
# {'電影': 1}
# {'超商': 3, '保險': 1}
# {}
# {}
# {'旅遊': 4, '量販店': 1}
# {'旅遊': 1, '網購': 1, '紅利': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'百貨': 3}
# {}
# {}
# {'網購': 1}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {}
# {}
# {'國外': 2}
# {'國外': 1}
# {'國外': 5}
# {}
# {'國外': 3}
# {}
# {}
# {}
# {'網購': 3, '超商': 1, '加油': 1, '國外': 3, '旅遊': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 3}
# {'旅遊': 1}
# {}
# {'加油': 1, '國外': 1}
# {'旅遊': 3, '國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {'量販店': 2}
# {'網購': 1}
# {}
# {}
# {'國外': 1}
# {'國外': 1, '電影': 1, '旅遊': 3}
# {'國外': 1, '電影': 1, '旅遊': 3}
# {'航空哩程': 3, '旅遊': 6}
# {}
# {'超商': 1}
# {'網購': 1}
# {'國外': 2}
# {}
# {}
# {'旅遊': 2}
# {'加油': 3}
# {}
# {'超商': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'旅遊': 4}
# {'超商': 1}
# {}
# {}
# {'行動支付': 1}
# {'旅遊': 1}
# {'旅遊': 4}
# {'旅遊': 3, '國外': 1}
# {}
# {'超商': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {'量販店': 1}
# {}
# {'超商': 4, '網購': 1}
# {'旅遊': 2}
# {'超市': 1, '加油': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {'保險': 1, '超商': 1, '超市': 1, '網購': 1}
# {}
# {}
# {}
# {'超市': 2, '加油': 1}
# {'行動支付': 2}
# {'量販店': 3}
# {'量販店': 2}
# {'超商': 1}
# {}
# {}
# {'網購': 3}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'保險': 4, '國外': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'旅遊': 2, '保險': 3, '百貨': 1, '網購': 1}
# {'網購': 7}
# {'網購': 2}
# {'旅遊': 4}
# {}
# {}
# {}
# {}
# {'電影': 1}
# {}
# {'旅遊': 2}
# {'旅遊': 2}
# {'超商': 1}
# {}
# {'網購': 2}
# {'旅遊': 2}
# {'超商': 1}
# {'網購': 4, '超商': 4, '行動支付': 5}
# {'電影': 2}
# {'電影': 5, '加油': 1}
# {}
# {'旅遊': 8}
# {'行動支付': 2}
# {}
# {'量販店': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {'旅遊': 3}
# {'旅遊': 4}
# {'旅遊': 1}
# {'旅遊': 9}
# {'旅遊': 9}
# {'旅遊': 2}
# {'旅遊': 5}
# {}
# {}
# {}
# {}
# {'國外': 1, '航空哩程': 4, '超商': 1, '行動支付': 1, '旅遊': 1}
# {}
# {'網購': 1, '旅遊': 1}
# {'國外': 1, '旅遊': 3, '航空哩程': 1}
# {'國外': 1}
# {'網購': 3}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {}
# {}
# {'行動支付': 1}
# {'電影': 2}
# {}
# {'超商': 1}
# {}
# {}
# {'行動支付': 1, '保險': 1}
# {'國外': 1, '旅遊': 2}
# {}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'網購': 1}
# {'國外': 9}
# {}
# {'行動支付': 3, '超商': 1}
# {'網購': 2, '國外': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'量販店': 1, '航空哩程': 1}
# {}
# {}
# {'網購': 3, '運動': 1}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {'網購': 1}
# {'行動支付': 1}
# {}
# {}
# {'保險': 2, '網購': 4}
# {'國外': 2, '旅遊': 1}
# {}
# {'旅遊': 3}
# {'國外': 1}
# {}
# {'行動支付': 2}
# {'行動支付': 1}
# {'加油': 4}
# {'超商': 1, '國外': 1, '旅遊': 2}
# {'行動支付': 2, '網購': 2}
# {'航空哩程': 4, '旅遊': 4}
# {'國外': 1}
# {'國外': 4, '旅遊': 3}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'加油': 1, '網購': 2, '超商': 1, '超市': 1}
# {}
# {'國外': 3, '旅遊': 1, '保險': 1, '加油': 1, '電影': 1}
# {'旅遊': 2, '電影': 1}
# {'量販店': 1, '超市': 1}
# {}
# {'國外': 3}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 6, '量販店': 1}
# {'旅遊': 2, '加油': 1, '國外': 2}
# {'旅遊': 1}
# {'國外': 1, '運動': 1, '電影': 1}
# {'電影': 1, '加油': 1, '網購': 2, '超市': 1}
# {'旅遊': 2, '網購': 3}
# {'國外': 4, '量販店': 1, '網購': 1}
# {'加油': 4, '保險': 1}
# {'加油': 1, '量販店': 2}
# {}
# {'航空哩程': 1}
# {'國外': 1, '旅遊': 1, '航空哩程': 1}
# {'國外': 1, '旅遊': 6}
# {}
# {}
# {'網購': 1, '國外': 1}
# {'國外': 1}
# {}
# {'量販店': 1}
# {'量販店': 1}
# {'旅遊': 1, '國外': 4, '保險': 1}
# {'旅遊': 1, '網購': 1}
# {'量販店': 2, '網購': 1, '運動': 1}
# {'電影': 1, '旅遊': 1, '保險': 1}
# {'旅遊': 2, '國外': 1}
# {'網購': 1}
# {}
# {'加油': 6, '網購': 1, '百貨': 1, '旅遊': 4, '保險': 1}
# {'加油': 2}
# {'量販店': 1}
# {'電影': 1, '網購': 1}
# {'旅遊': 1, '國外': 1, '行動支付': 1}
# {'旅遊': 3, '國外': 1, '保險': 1}
# {'加油': 4, '網購': 2}
# {'國外': 1, '加油': 1, '超商': 1, '網購': 2}
# {}
# {'網購': 3, '國外': 5, '超商': 1, '保險': 1, '旅遊': 3}
# {'保險': 2, '旅遊': 3}
# {'超商': 1, '超市': 1, '量販店': 1, '行動支付': 1, '網購': 1}
# {'國外': 2}
# {'網購': 1}
# {'運動': 1, '網購': 1, '旅遊': 1}
# {'運動': 1, '加油': 2, '超市': 1, '量販店': 1, '網購': 1}
# {'加油': 1, '旅遊': 3}
# {}
# {'量販店': 1, '網購': 2}
# {'電影': 1, '旅遊': 1, '國外': 1}
# {}
# {'國外': 1, '旅遊': 1}
# {}
# {'旅遊': 4, '國外': 1}
# {'旅遊': 5, '超市': 1, '量販店': 1, '保險': 1}
# {'國外': 5, '旅遊': 4}
# {'國外': 4, '旅遊': 2}
# {'國外': 4, '旅遊': 2, '保險': 1}
# {'國外': 2, '網購': 2}
# {'國外': 4, '網購': 1}
# {'國外': 3, '旅遊': 1}
# {}
# {'網購': 1}
# {'網購': 1, '加油': 1, '保險': 1}
# {}
# {'航空哩程': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {'網購': 2, '運動': 1}
# {'旅遊': 3, '加油': 1}
# {}
# {'加油': 2, '網購': 1, '保險': 1}
# {'旅遊': 2, '加油': 3, '量販店': 1, '電影': 1}
# {'國外': 3}
# {'旅遊': 3}
# {'加油': 2, '網購': 1}
# {'超商': 1, '國外': 1}
# {'行動支付': 4, '運動': 1}
# {'網購': 1}
# {'航空哩程': 1, '國外': 1}
# {'航空哩程': 1}
# {'旅遊': 5, '電影': 2, '國外': 1}
# {'國外': 1, '旅遊': 2}
# {'網購': 2, '超市': 2, '量販店': 1, '超商': 1, '運動': 1}
# {'國外': 3, '旅遊': 1}
# {}
# {}
# {'網購': 2}
# {}
# {'超商': 2, '網購': 1, '行動支付': 2, '旅遊': 6, '國外': 3}
# {}
# {'旅遊': 2, '網購': 6, '紅利': 3, '國外': 4, '超商': 1}
# {'加油': 1, '網購': 1}
# {'網購': 12, '航空哩程': 6, '超商': 2, '行動支付': 6, '國外': 1, '紅利': 2}
# {'旅遊': 7, '國外': 5, '網購': 3}
# {}
# {}
# {'行動支付': 1, '超商': 6, '航空哩程': 1, '網購': 1, '量販店': 1, '百貨': 1, '紅利': 1, '加油': 1}
# {}
# {'量販店': 4, '加油': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'旅遊': 2}
# {'行動支付': 1}
# {'加油': 6}
# {}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'旅遊': 2}
# {}
# {'百貨': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'行動支付': 1, '超商': 2}
# {}
# {'網購': 2, '超商': 1, '行動支付': 2, '藥妝': 1}
# {'量販店': 1}
# {'旅遊': 1}
# {'網購': 1, '行動支付': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 2, '保險': 2}
# {}
# {'超商': 1}
# {'行動支付': 2, '國外': 1}
# {}
# {'行動支付': 1}
# {'網購': 1, '電影': 1}
# {}
# {}
# {'量販店': 1}
# {}
# {'網購': 1, '超商': 1, '行動支付': 2, '加油': 1}
# {'旅遊': 1, '國外': 3, '網購': 2, '行動支付': 1}
# {'保險': 2}
# {'網購': 3}
# {'網購': 3}
# {'量販店': 3}
# {'量販店': 3}
# {'旅遊': 1, '電影': 1}
# {}
# {'旅遊': 3, '國外': 1}
# {}
# {'加油': 1, '國外': 1, '百貨': 1, '旅遊': 2}
# {'旅遊': 9, '航空哩程': 1, '超商': 1, '紅利': 1, '網購': 1, '國外': 1}
# {'航空哩程': 1, '保險': 3, '網購': 1, '加油': 1}
# {'國外': 5, '旅遊': 1}
# {'電影': 1, '旅遊': 1}
# {'保險': 3, '行動支付': 10}
# {}
# {}
# {'航空哩程': 1, '旅遊': 8, '量販店': 11, '百貨': 16, '國外': 2, '行動支付': 22, '超商': 2, '超市': 1, '電影': 2, '加油': 8, '保險': 3}
# {'超商': 1, '行動支付': 2}
# {'國外': 9, '航空哩程': 7, '旅遊': 7, '網購': 10, '百貨': 2, '保險': 4, '超商': 5}
# {'國外': 3, '旅遊': 1}
# {'旅遊': 33, '航空哩程': 1, '國外': 3}
# {'旅遊': 1, '百貨': 1, '行動支付': 1, '量販店': 1, '網購': 1, '超商': 1}
# {}
# {'網購': 25, '國外': 2, '超商': 3, '電影': 4, '行動支付': 8, '旅遊': 3, '藥妝': 2, '超市': 2, '量販店': 3, '加油': 2}
# {'百貨': 1}
# {'網購': 1, '行動支付': 2, '國外': 2, '旅遊': 1, '運動': 2, '紅利': 1}
# {'航空哩程': 3, '保險': 1, '超商': 2, '電影': 1, '國外': 1, '網購': 3, '旅遊': 3, '行動支付': 2}
# {'保險': 1}
# {'行動支付': 15, '網購': 5, '超商': 3, '保險': 1, '加油': 3, '國外': 1, '旅遊': 2}
# {'行動支付': 2, '運動': 1, '網購': 1, '國外': 2}
# {'行動支付': 2, '運動': 1, '網購': 1, '國外': 2}
# {'行動支付': 24, '網購': 8, '加油': 3, '超商': 3, '國外': 1, '旅遊': 1}
# {'加油': 1, '網購': 1, '旅遊': 2, '國外': 4, '百貨': 1}
# {'旅遊': 95, '航空哩程': 1, '國外': 20}
# {'國外': 12, '旅遊': 3}
# {}
# {'網購': 5, '國外': 1, '行動支付': 6, '超商': 6, '加油': 4}
# {'行動支付': 2, '超商': 5}
# {}
# {}
# {'量販店': 3, '網購': 1, '百貨': 1}
# {'國外': 3, '電影': 1}
# {'保險': 2}
# {'電影': 1}
# {}
# {'超商': 1}
# {}
# {'行動支付': 5, '電影': 1, '加油': 3, '網購': 1, '超商': 1, '國外': 3}
# {'旅遊': 1, '國外': 1}
# {'行動支付': 2, '超商': 1, '網購': 2, '旅遊': 1}
# {'電影': 1}
# {'量販店': 2, '網購': 1, '行動支付': 1, '保險': 1}
# {}
# {}
# {}
# {}
# {'行動支付': 2}
# {'超商': 1, '行動支付': 1}
# {}
# {}
# {'網購': 1, '行動支付': 1}
# {'國外': 2, '航空哩程': 2, '旅遊': 4, '保險': 2}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 3}
# {'航空哩程': 1, '旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 2}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 2, '國外': 3}
# {'國外': 4}
# {'旅遊': 1}
# {'國外': 1, '旅遊': 1}
# {'國外': 2}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {'國外': 3}
# {'旅遊': 1}
# {'加油': 1, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {'旅遊': 1, '保險': 1}
# {}
# {'旅遊': 3, '網購': 2, '保險': 1}
# {'加油': 1, '國外': 1, '網購': 1}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 4, '國外': 1}
# {'旅遊': 7}
# {'國外': 1}
# {'旅遊': 7}
# {}
# {'國外': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {'國外': 1}
# {}
# {'國外': 1}
# {}
# {}
# {'超商': 3}
# {'網購': 1}
# {'國外': 1}
# {}
# {'百貨': 2, '量販店': 1, '超商': 1}
# {'紅利': 2}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 2, '網購': 1, '超商': 1}
# {}
# {}
# {'網購': 2}
# {}
# {'量販店': 1}
# {}
# {'超商': 1, '網購': 1}
# {'行動支付': 1}
# {}
# {'量販店': 1}
# {'行動支付': 1, '超商': 1}
# {'網購': 1}
# {'超商': 3, '網購': 1}
# {}
# {'超商': 4, '行動支付': 1}
# {}
# {'電影': 1, '超市': 1, '國外': 5, '網購': 4, '運動': 1, '旅遊': 1}
# {}
# {'加油': 1}
# {}
# {}
# {'航空哩程': 1}
# {'保險': 1}
# {'超商': 1, '網購': 1}
# {'量販店': 1}
# {}
# {'行動支付': 1}
# {}
# {'旅遊': 7, '國外': 1, '網購': 1}
# {}
# {'網購': 1}
# {}
# {'旅遊': 2, '超商': 1, '國外': 1}
# {'國外': 1, '網購': 1, '超商': 1, '旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 1, '網購': 1, '超商': 1}
# {'量販店': 2}
# {}
# {'旅遊': 1}
# {'旅遊': 2}
# {'超商': 3}
# {}
# {}
# {'網購': 2, '加油': 1, '國外': 1}
# {'網購': 1}
# {'百貨': 1}
# {'加油': 2}
# {'網購': 2}
# {'旅遊': 1}
# {}
# {}
# {'國外': 2, '網購': 1}
# {}
# {'網購': 1}
# {}
# {'加油': 1}
# {}
# {}
# {}
# {}
# {'網購': 4}
# {}
# {}
# {'國外': 2, '保險': 1}
# {'網購': 3, '行動支付': 2}
# {'紅利': 1}
# {'網購': 2}
# {'網購': 1, '國外': 1}
# {'網購': 6}
# {'國外': 1, '網購': 2, '行動支付': 3, '超商': 2, '加油': 3}
# {'量販店': 9}
# {'行動支付': 1}
# {'行動支付': 4}
# {'行動支付': 4}
# {'網購': 3, '行動支付': 1, '超商': 1}
# {}
# {'保險': 1}
# {'量販店': 1}
# {'網購': 4}
# {'旅遊': 1}
# {'運動': 1}
# {}
# {'電影': 1, '網購': 2, '旅遊': 1}
# {}
# {'網購': 2}
# {}
# {'網購': 1, '行動支付': 1}
# {'紅利': 2}
# {'網購': 1}
# {}
# {'網購': 3, '超商': 2}
# {'電影': 1}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'網購': 7}
# {'加油': 2}
# {'網購': 3, '超商': 5, '加油': 2, '旅遊': 1, '國外': 4, '行動支付': 1}
# {'行動支付': 2, '網購': 3, '超商': 1}
# {'國外': 2, '行動支付': 2, '網購': 1}
# {}
# {}
# {'國外': 2, '加油': 2, '網購': 1, '行動支付': 3}
# {}
# {}
# {'行動支付': 2}
# {'量販店': 1, '網購': 1, '國外': 1, '旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 1, '加油': 1, '保險': 1, '行動支付': 1}
# {}
# {}
# {'加油': 1, '超商': 1}
# {'百貨': 1, '超商': 1, '行動支付': 1}
# {}
# {}
# {}
# {'行動支付': 1, '量販店': 1}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'行動支付': 1}
# {'旅遊': 1}
# {}
# {'超商': 3, '紅利': 1, '百貨': 1}
# {}
# {'保險': 2, '百貨': 2, '網購': 2, '旅遊': 7}
# {}
# {'行動支付': 5, '超商': 2}
# {'量販店': 1, '國外': 4, '旅遊': 2}
# {'旅遊': 1}
# {'量販店': 1}
# {}
# {'超市': 1}
# {'網購': 1}
# {'量販店': 1, '國外': 1}
# {'旅遊': 1, '行動支付': 2, '加油': 1, '保險': 1, '國外': 1}
# {}
# {'行動支付': 1, '網購': 3, '國外': 1}
# {'加油': 1, '網購': 1}
# {'國外': 2}
# {'網購': 1, '旅遊': 1}
# {'行動支付': 1, '網購': 1, '電影': 1}
# {'行動支付': 1, '電影': 1, '保險': 1}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 2}
# {'量販店': 1}
# {'網購': 2, '旅遊': 2, '國外': 1}
# {}
# {'百貨': 3}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 4, '旅遊': 1}
# {'國外': 1}
# {}
# {'百貨': 2, '保險': 1}
# {'旅遊': 1}
# {'航空哩程': 4, '旅遊': 4}
# {}
# {'國外': 1}
# {}
# {}
# {'行動支付': 2, '網購': 1}
# {'超商': 2}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {}
# {'旅遊': 3}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {'網購': 1, '旅遊': 2}
# {}
# {}
# {'國外': 4}
# {}
# {}
# {}
# {}
# {'量販店': 1, '運動': 1}
# {'量販店': 1, '運動': 1}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 1}
# {'百貨': 1}
# {'旅遊': 2, '保險': 1, '網購': 1}
# {'加油': 2}
# {}
# {}
# {'保險': 1}
# {'國外': 1}
# {}
# {}
# {'百貨': 1}
# {}
# {}
# {'超商': 1, '加油': 1, '旅遊': 1}
# {'保險': 1}
# {}
# {}
# {}
# {'行動支付': 1}
# {'加油': 3}
# {}
# {}
# {'加油': 3, '百貨': 1, '量販店': 1}
# {}
# {}
# {}
# {'量販店': 1}
# {'百貨': 2, '網購': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {'量販店': 1}
# {'旅遊': 1}
# {'國外': 1}
# {'旅遊': 1, '網購': 2, '保險': 1, '加油': 1, '行動支付': 1}
# {}
# {'行動支付': 1, '旅遊': 1}
# {}
# {'量販店': 1}
# {'旅遊': 1}
# {}
# {}
# {'超商': 1}
# {'運動': 1}
# {'國外': 1, '旅遊': 4}
# {'旅遊': 1, '航空哩程': 2}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {'加油': 5, '保險': 1}
# {}
# {'超商': 1, '行動支付': 1}
# {}
# {'國外': 2, '旅遊': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {'加油': 4, '超市': 3, '電影': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {'國外': 1, '網購': 1}
# {'網購': 1, '行動支付': 1}
# {}
# {}
# {'量販店': 1}
# {'加油': 1, '網購': 1, '超市': 1}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {'旅遊': 1}
# {}
# {'網購': 1, '國外': 1}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {'航空哩程': 2, '保險': 2}
# {}
# {}
# {'保險': 1}
# {}
# {'旅遊': 4, '網購': 1}
# {}
# {}
# {'網購': 1}
# {}
# {'超商': 1}
# {'百貨': 1}
# {}
# {'量販店': 1}
# {}
# {}
# {'加油': 3}
# {}
# {}
# {}
# {}
# {'電影': 1}
# {}
# {}
# {'保險': 1}
# {'超商': 2, '行動支付': 2}
# {}
# {}
# {'旅遊': 1}
# {'超商': 1}
# {}
# {'網購': 1, '旅遊': 3}
# {}
# {'網購': 1, '旅遊': 2}
# {'百貨': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'百貨': 2}
# {'電影': 1, '超商': 1, '旅遊': 1}
# {'加油': 2, '國外': 1, '超商': 1, '網購': 1}
# {'加油': 2, '量販店': 1, '百貨': 1}
# {'國外': 1, '網購': 1}
# {}
# {'國外': 3, '超商': 1}
# {'行動支付': 1, '旅遊': 3}
# {'電影': 1, '旅遊': 1}
# {'量販店': 1}
# {'運動': 2}
# {}
# {}
# {}
# {'網購': 1, '超商': 1, '國外': 1}
# {'航空哩程': 1}
# {'加油': 2, '網購': 1}
# {'國外': 1}
# {}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {'百貨': 2}
# {'量販店': 1, '旅遊': 1, '保險': 1}
# {}
# {}
# {'旅遊': 4, '國外': 1}
# {}
# {'加油': 3}
# {'加油': 3}
# {'量販店': 1}
# {'旅遊': 37, '保險': 3, '國外': 2}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'百貨': 1}
# {}
# {}
# {'國外': 1, '加油': 1, '百貨': 1, '藥妝': 1}
# {'網購': 1, '電影': 1, '國外': 1}
# {}
# {'加油': 9, '行動支付': 1}
# {'量販店': 1}
# {'保險': 1}
# {'量販店': 2, '行動支付': 3}
# {'國外': 1, '旅遊': 1}
# {'國外': 1, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 2, '量販店': 1}
# {'網購': 2, '量販店': 1}
# {}
# {'保險': 1}
# {'保險': 1}
# {}
# {'旅遊': 3}
# {'旅遊': 1}
# {'保險': 1, '旅遊': 2}
# {'旅遊': 4, '國外': 2, '網購': 2, '行動支付': 2}
# {}
# {'保險': 1, '航空哩程': 2, '旅遊': 1}
# {'量販店': 3}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {'旅遊': 1}
# {}
# {'網購': 1}
# {'電影': 2}
# {'電影': 1}
# {'電影': 1}
# {'加油': 1, '量販店': 1, '超市': 1}
# {}
# {'紅利': 2}
# {'加油': 1}
# {'國外': 4, '旅遊': 2}
# {'國外': 1}
# {'國外': 2}
# {'網購': 1}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'國外': 1}
# {'保險': 1}
# {}
# {'行動支付': 1}
# {}
# {'網購': 3, '航空哩程': 1, '紅利': 1}
# {}
# {'網購': 1}
# {}
# {'量販店': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {'網購': 1, '加油': 2, '超商': 2, '保險': 2}
# {'加油': 1}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {'行動支付': 3}
# {}
# {'旅遊': 1, '航空哩程': 1}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2, '旅遊': 1}
# {}
# {}
# {'國外': 1}
# {'超商': 1, '網購': 1}
# {}
# {'加油': 2}
# {}
# {}
# {}
# {'國外': 1, '旅遊': 1, '加油': 1}
# {'電影': 1, '網購': 1, '超市': 1, '旅遊': 3}
# {'超商': 1}
# {}
# {}
# {'保險': 1}
# {'旅遊': 2}
# {}
# {'旅遊': 4, '國外': 8}
# {'行動支付': 1}
# {'加油': 45}
# {'加油': 3, '百貨': 2}
# {}
# {}
# {}
# {}
# {'網購': 1, '旅遊': 4, '保險': 1, '超商': 2}
# {'旅遊': 1}
# {'國外': 2, '旅遊': 2, '保險': 1}
# {'旅遊': 7, '航空哩程': 1, '國外': 3}
# {}
# {'旅遊': 3}
# {'國外': 6, '紅利': 1, '旅遊': 17}
# {}
# {}
# {'旅遊': 6}
# {}
# {'旅遊': 4, '行動支付': 1, '保險': 1, '超商': 2, '國外': 2, '量販店': 2}
# {'保險': 8, '旅遊': 9}
# {}
# {}
# {'國外': 8, '旅遊': 1}
# {}
# {'行動支付': 2}
# {'旅遊': 1}
# {}
# {'國外': 2}
# {}
# {'旅遊': 2}
# {'旅遊': 1, '國外': 1}
# {'加油': 1, '保險': 1}
# {}
# {'量販店': 1, '加油': 1, '旅遊': 5, '國外': 1}
# {'量販店': 1, '加油': 1, '旅遊': 5, '國外': 1}
# {'旅遊': 6, '國外': 1}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 1}
# {}
# {'加油': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 2, '旅遊': 1, '網購': 2}
# {'網購': 1}
# {'國外': 1}
# {'旅遊': 2}
# {'國外': 2, '旅遊': 1}
# {'旅遊': 3}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'國外': 1, '旅遊': 1}
# {}
# {'加油': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 2, '國外': 1}
# {'旅遊': 1}
# {'國外': 1, '旅遊': 3}
# {'旅遊': 1}
# {'旅遊': 2}
# {'國外': 3, '旅遊': 3}
# {'國外': 1, '旅遊': 1}
# {'電影': 1}
# {'旅遊': 1}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {'保險': 1}
# {'網購': 1}
# {'旅遊': 2, '保險': 1, '百貨': 1, '國外': 2}
# {'旅遊': 1}
# {'國外': 1, '旅遊': 2}
# {'百貨': 1, '加油': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 3}
# {}
# {}
# {'超商': 1}
# {'網購': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 5, '量販店': 1}
# {'國外': 1}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {'網購': 1, '旅遊': 3, '航空哩程': 1}
# {}
# {'網購': 3, '旅遊': 1}
# {'量販店': 1}
# {}
# {'電影': 1}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 3, '國外': 1}
# {}
# {'保險': 1}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 3, '國外': 2}
# {'旅遊': 1}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {'保險': 1}
# {'百貨': 1, '旅遊': 1}
# {}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {'網購': 1}
# {'旅遊': 1}
# {'國外': 1}
# {'國外': 1, '旅遊': 2}
# {'國外': 1}
# {}
# {'國外': 1, '百貨': 1, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1, '量販店': 2}
# {}
# {}
# {'國外': 1, '旅遊': 3}
# {'加油': 1, '網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1, '網購': 3, '超商': 1}
# {'行動支付': 1, '超商': 1}
# {'行動支付': 1}
# {'保險': 2}
# {'網購': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 3, '網購': 7}
# {'加油': 1, '量販店': 1}
# {'網購': 1, '旅遊': 1}
# {'行動支付': 1, '網購': 1, '旅遊': 1}
# {}
# {'量販店': 1}
# {}
# {'行動支付': 2}
# {'量販店': 3, '網購': 2, '百貨': 2}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {}
# {'國外': 1}
# {}
# {'量販店': 1}
# {'網購': 2}
# {'網購': 1, '旅遊': 1}
# {'國外': 2, '電影': 1, '網購': 8, '旅遊': 6, '航空哩程': 2, '藥妝': 2, '量販店': 1, '保險': 1, '行動支付': 1}
# {'國外': 1, '旅遊': 1}
# {'量販店': 1}
# {}
# {'網購': 1}
# {'網購': 1}
# {}
# {}
# {'網購': 3}
# {'網購': 1}
# {'旅遊': 1, '國外': 1, '網購': 1}
# {'量販店': 2}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {'國外': 2, '旅遊': 1}
# {'電影': 3}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 2, '網購': 2, '行動支付': 1, '國外': 1, '保險': 1}
# {}
# {'量販店': 1, '網購': 2}
# {}
# {'行動支付': 1}
# {}
# {}
# {}
# {'超商': 3, '行動支付': 1}
# {'旅遊': 22, '國外': 2}
# {'超市': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {'超商': 4, '超市': 1}
# {}
# {'量販店': 1, '行動支付': 2}
# {'旅遊': 1}
# {'旅遊': 2}
# {'國外': 1, '旅遊': 1, '加油': 2, '保險': 1, '網購': 1}
# {'網購': 2, '國外': 1}
# {}
# {}
# {'電影': 1}
# {'網購': 1}
# {'電影': 3, '旅遊': 1}
# {'電影': 2}
# {'保險': 1}
# {'量販店': 1}
# {'國外': 1, '旅遊': 1}
# {'國外': 1}
# {'量販店': 5}
# {}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'電影': 1}
# {'旅遊': 1}
# {'行動支付': 5}
# {}
# {}
# {'超商': 3}
# {'加油': 1}
# {'行動支付': 1}
# {}
# {'量販店': 2, '旅遊': 4}
# {'百貨': 1}
# {'網購': 1}
# {}
# {}
# {'網購': 1}
# {'超商': 1, '旅遊': 2}
# {'百貨': 2}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {'量販店': 1, '行動支付': 1, '加油': 1}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {'國外': 1, '旅遊': 1}
# {'國外': 1, '旅遊': 1, '網購': 1, '保險': 2}
# {'加油': 1, '網購': 1, '國外': 2, '旅遊': 1}
# {'網購': 2}
# {}
# {'旅遊': 7, '國外': 1}
# {}
# {}
# {'旅遊': 1, '保險': 1, '國外': 2}
# {'量販店': 1, '旅遊': 4}
# {'國外': 2, '量販店': 1}
# {}
# {'旅遊': 1, '超商': 1}
# {'旅遊': 2, '加油': 1}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {'百貨': 2, '網購': 1}
# {'國外': 3}
# {'百貨': 1}
# {}
# {}
# {'國外': 2}
# {}
# {'旅遊': 2, '國外': 2, '保險': 1}
# {'加油': 1, '量販店': 3}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {'電影': 1}
# {'旅遊': 5}
# {'保險': 1}
# {}
# {'量販店': 1, '加油': 1}
# {'旅遊': 1}
# {'旅遊': 2}
# {}
# {'航空哩程': 1, '旅遊': 1}
# {'網購': 1}
# {'旅遊': 1}
# {}
# {'運動': 1, '量販店': 1, '百貨': 2, '加油': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {'加油': 1, '運動': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 3}
# {'旅遊': 2}
# {'量販店': 3}
# {}
# {}
# {'加油': 2}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'電影': 1, '旅遊': 3, '國外': 1}
# {'國外': 1}
# {}
# {}
# {'行動支付': 1, '加油': 1}
# {'電影': 1}
# {'電影': 1}
# {'加油': 1}
# {'網購': 1, '百貨': 1}
# {'旅遊': 4}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {'行動支付': 1}
# {'國外': 2}
# {'行動支付': 1, '國外': 5, '網購': 3, '旅遊': 1}
# {'行動支付': 3, '百貨': 1, '網購': 2, '國外': 1, '旅遊': 2}
# {'保險': 1}
# {}
# {}
# {'網購': 3, '超商': 1}
# {'行動支付': 4, '網購': 3, '超商': 2}
# {'行動支付': 1}
# {}
# {}
# {}
# {}
# {'量販店': 2, '國外': 1}
# {}
# {'電影': 1, '超市': 1}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {}
# {}
# {'網購': 1}
# {'網購': 1}
# {}
# {'旅遊': 1}
# {'加油': 1}
# {'旅遊': 1}
# {'網購': 1}
# {}
# {}
# {}
# {'國外': 1, '超商': 1}
# {}
# {}
# {}
# {'百貨': 2}
# {'旅遊': 1}
# {'旅遊': 3, '國外': 2, '網購': 1}
# {'網購': 2, '旅遊': 1, '國外': 1}
# {}
# {'國外': 1, '網購': 2, '行動支付': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 3}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1, '網購': 1}
# {'旅遊': 1}
# {'國外': 1, '旅遊': 3}
# {}
# {'旅遊': 3}
# {'國外': 2, '網購': 1, '電影': 3, '保險': 1}
# {}
# {'百貨': 4}
# {'超商': 1, '保險': 1}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 2}
# {}
# {'網購': 1}
# {'網購': 1}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {'百貨': 8, '國外': 2}
# {}
# {}
# {'百貨': 1, '電影': 1}
# {'加油': 3, '網購': 3, '旅遊': 1, '國外': 1}
# {'加油': 1, '網購': 1}
# {'保險': 1}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1, '網購': 4}
# {'國外': 1, '旅遊': 1}
# {'網購': 1, '國外': 1}
# {}
# {'國外': 2}
# {'行動支付': 1, '量販店': 1}
# {}
# {}
# {'旅遊': 1}
# {'網購': 1, '加油': 1}
# {}
# {}
# {}
# {'超市': 2}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'百貨': 1, '旅遊': 4, '行動支付': 1}
# {'電影': 1, '旅遊': 1, '保險': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {'量販店': 1, '加油': 1}
# {'電影': 3}
# {'網購': 1}
# {}
# {}
# {}
# {'行動支付': 2}
# {'量販店': 1, '超商': 1}
# {}
# {}
# {}
# {'網購': 1}
# {'百貨': 1}
# {'行動支付': 1}
# {'網購': 2}
# {}
# {'國外': 1, '旅遊': 2}
# {'行動支付': 1, '旅遊': 1}
# {}
# {}
# {'國外': 1, '旅遊': 4, '行動支付': 1}
# {'網購': 1, '超商': 1}
# {}
# {}
# {'旅遊': 2, '國外': 1, '網購': 2}
# {'量販店': 2}
# {}
# {'行動支付': 2}
# {'行動支付': 4, '旅遊': 2}
# {'行動支付': 1, '電影': 1}
# {}
# {'量販店': 3}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 6, '加油': 2}
# {'加油': 2, '行動支付': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {'網購': 1, '行動支付': 1}
# {}
# {}
# {}
# {'保險': 1, '旅遊': 2}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {'網購': 1}
# {'行動支付': 2, '旅遊': 1}
# {}
# {}
# {}
# {}
# {'超商': 5, '行動支付': 3, '超市': 2, '網購': 2, '國外': 3}
# {}
# {'量販店': 2}
# {'網購': 1}
# {'超市': 1}
# {}
# {'量販店': 1}
# {'網購': 3, '國外': 1}
# {}
# {'國外': 1, '旅遊': 2}
# {}
# {}
# {'行動支付': 1, '國外': 1, '超市': 1, '網購': 1}
# {}
# {'超市': 2, '網購': 1}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1, '旅遊': 1, '國外': 2}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {'電影': 2, '旅遊': 2}
# {}
# {'旅遊': 1, '國外': 2}
# {'加油': 5, '網購': 1}
# {'旅遊': 1}
# {'旅遊': 2, '網購': 1}
# {'旅遊': 2, '國外': 1}
# {'保險': 1, '旅遊': 1}
# {'行動支付': 2, '超商': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {'電影': 1, '旅遊': 1, '國外': 1, '行動支付': 1, '網購': 1}
# {'旅遊': 2, '加油': 3}
# {'網購': 2}
# {'旅遊': 4, '電影': 1}
# {'旅遊': 1}
# {'行動支付': 1, '加油': 1, '網購': 2, '旅遊': 1}
# {}
# {'網購': 1}
# {}
# {'旅遊': 2, '網購': 1, '加油': 1, '行動支付': 1}
# {}
# {'旅遊': 1}
# {}
# {'行動支付': 1}
# {'行動支付': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {'旅遊': 5, '國外': 2}
# {'旅遊': 8}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {'國外': 4}
# {'網購': 2}
# {}
# {}
# {'電影': 1, '百貨': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'行動支付': 1, '國外': 1}
# {}
# {'國外': 3, '旅遊': 2}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {'網購': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {'加油': 2, '旅遊': 2, '行動支付': 1}
# {}
# {}
# {'行動支付': 1}
# {'行動支付': 6, '百貨': 2, '旅遊': 4, '國外': 1}
# {}
# {}
# {'行動支付': 3}
# {}
# {}
# {'量販店': 2}
# {'旅遊': 1, '保險': 1, '國外': 1}
# {'超商': 1}
# {'國外': 1}
# {}
# {'網購': 1, '超商': 1, '行動支付': 1}
# {}
# {}
# {'網購': 6}
# {}
# {'旅遊': 2, '國外': 1}
# {'加油': 1}
# {}
# {'旅遊': 2}
# {}
# {'國外': 1}
# {}
# {'旅遊': 1}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {'網購': 1}
# {'超商': 1}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'量販店': 1}
# {}
# {}
# {}
# {}
# {'網購': 1}
# {'加油': 3}
# {}
# {'加油': 1}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1, '加油': 1}
# {}
# {'網購': 1}
# {'紅利': 1, '超商': 2}
# {'網購': 3}
# {}
# {'量販店': 2}
# {}
# {'保險': 1, '百貨': 1, '旅遊': 1}
# {}
# {'保險': 1, '量販店': 1}
# {}
# {'網購': 2, '旅遊': 1, '國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'行動支付': 1, '保險': 3, '網購': 2, '加油': 1}
# {}
# {'網購': 4}
# {'加油': 1, '旅遊': 1}
# {'加油': 1}
# {'國外': 1}
# {'網購': 1}
# {'加油': 2}
# {'行動支付': 2}
# {'百貨': 2, '行動支付': 3, '保險': 1}
# {}
# {}
# {'網購': 1}
# {'百貨': 3}
# {'量販店': 1, '旅遊': 1}
# {}
# {'百貨': 1}
# {'行動支付': 1, '旅遊': 4, '國外': 1}
# {'航空哩程': 5, '保險': 5, '國外': 9, '旅遊': 3}
# {'旅遊': 1}
# {'旅遊': 3, '網購': 1}
# ...
# {'百貨': 18}
# {'超市': 8}
# {'紅利': 1, '國外': 3}
# {}
# {'電影': 1}
# {'國外': 1}
# {'旅遊': 1, '行動支付': 1}
# {'超市': 2, '旅遊': 1, '保險': 1}
# {}
# {'行動支付': 24, '網購': 3, '超商': 2}
# {'國外': 1}
# {}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 6, '網購': 11, '國外': 6, '超商': 2, '行動支付': 1}
# {'行動支付': 2}
# {'保險': 1}
# {'行動支付': 1}
# {'旅遊': 3}
# {'旅遊': 6}
# {'旅遊': 5, '國外': 2}
# {'加油': 7}
# {'行動支付': 1}
# {'國外': 5, '行動支付': 2, '旅遊': 1, '超商': 2}
# {'網購': 1}
# {'國外': 14, '旅遊': 7}
# {'國外': 8, '旅遊': 6, '網購': 1}
# {'國外': 4, '旅遊': 1}
# {'旅遊': 1, '國外': 3}
# {'國外': 3, '網購': 2, '旅遊': 11}
# {}
# {'網購': 16}
# {'超市': 1}
# {'行動支付': 7, '旅遊': 3, '國外': 2, '網購': 1, '超商': 3}
# {'行動支付': 14, '網購': 6, '超商': 1}
# {'超商': 8, '行動支付': 3}
# {'行動支付': 3, '國外': 1, '旅遊': 1}
# {'旅遊': 8, '國外': 3, '網購': 1}
# {'超商': 1, '國外': 5, '網購': 2}
# {}
# {}
# {'百貨': 4, '國外': 1, '量販店': 1}
# {'行動支付': 5}
# {}
# {'行動支付': 2, '網購': 4, '國外': 1, '超商': 3}
# {'保險': 1}
# {}
# {'旅遊': 6, '網購': 2}
# {'行動支付': 3}
# {'旅遊': 1, '加油': 2, '百貨': 1, '量販店': 1, '行動支付': 2, '網購': 2}
# {'網購': 17, '行動支付': 1, '超商': 4}
# {'保險': 9}
# {'網購': 1, '旅遊': 1}
# {}
# {'國外': 3}
# {'超商': 9}
# {'加油': 5, '超市': 1}
# {'旅遊': 6, '航空哩程': 11, '加油': 1, '國外': 2, '紅利': 1}
# {}
# {'行動支付': 3, '網購': 13, '加油': 1}
# {'旅遊': 3, '航空哩程': 2, '網購': 2}
# {'行動支付': 1}
# {}
# {}
# {'網購': 20, '超商': 2}
# {'網購': 1}
# {}
# {'超商': 3}
# {'網購': 10}
# {'國外': 13, '旅遊': 8, '保險': 1, '網購': 3}
# {'超商': 14, '紅利': 10, '超市': 3}
# {'超商': 6, '行動支付': 2}
# {'超商': 8}
# {'航空哩程': 1, '電影': 6, '行動支付': 1}
# {'網購': 8}
# {'旅遊': 6, '國外': 2}
# {'網購': 1, '行動支付': 1}
# {}
# {}
# {'旅遊': 1, '國外': 1}
# {}
# {'保險': 1}
# {}
# {'旅遊': 1, '行動支付': 1}
# {'行動支付': 1}
# {'旅遊': 7, '國外': 5, '行動支付': 1}
# {'加油': 1}
# {}
# {}
# {'旅遊': 1}
# {'國外': 5}
# {'國外': 3, '旅遊': 8, '行動支付': 1}
# {}
# {'電影': 6, '行動支付': 1}
# {'運動': 2, '國外': 1, '網購': 1}
# {'國外': 1}
# {'航空哩程': 1, '電影': 1, '保險': 1, '國外': 2, '旅遊': 1}
# {'行動支付': 1}
# {'行動支付': 2}
# {'旅遊': 5, '保險': 9, '國外': 2}
# {'網購': 7, '國外': 10, '電影': 1, '加油': 1, '行動支付': 1, '旅遊': 5, '超市': 1}
# {'行動支付': 3}
# {'國外': 1}
# {'紅利': 2, '國外': 2}
# {'航空哩程': 1, '旅遊': 9, '國外': 1}
# {'國外': 1}
# {}
# {'網購': 3, '紅利': 1, '超商': 2, '行動支付': 3, '運動': 1}
# {'超市': 14, '行動支付': 1}
# {'保險': 1, '旅遊': 3}
# {'旅遊': 3, '量販店': 3, '超市': 1, '加油': 1}
# {'行動支付': 1, '超市': 1}
# {'網購': 8, '超商': 4, '量販店': 2, '超市': 1}
# {'網購': 4, '量販店': 5, '超市': 1, '行動支付': 2}
# {'網購': 1}
# {'國外': 1, '網購': 1}
# {'運動': 4, '超商': 3, '紅利': 2, '旅遊': 1}
# {'國外': 5, '旅遊': 2}
# {'網購': 2, '超商': 1}
# {'百貨': 3, '超商': 1, '紅利': 1}
# {'電影': 12}
# {'行動支付': 1, '超商': 1}
# {'網購': 2, '旅遊': 1}
# {}
# {'網購': 2, '超商': 2, '國外': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {'行動支付': 1}
# {}
# {}
# {'國外': 1, '航空哩程': 1}
# {'國外': 2, '超商': 5, '旅遊': 1, '行動支付': 1}
# {'旅遊': 11, '保險': 2, '國外': 1}
# {'網購': 24, '國外': 5, '旅遊': 3, '超商': 1}
# {'量販店': 2}
# {'保險': 1}
# {'旅遊': 2, '行動支付': 2}
# {'旅遊': 4}
# {'國外': 7, '旅遊': 4, '行動支付': 1}
# {'旅遊': 4}
# {'超商': 5, '行動支付': 2, '紅利': 3}
# {'旅遊': 1}
# {'行動支付': 10, '超商': 2, '國外': 4, '網購': 1}
# {'網購': 2, '保險': 5, '旅遊': 1}
# {'網購': 2, '旅遊': 2, '國外': 3, '超商': 1}
# {'國外': 3, '旅遊': 2}
# {}
# {'國外': 4, '旅遊': 1, '航空哩程': 2}
# {'旅遊': 6, '保險': 1, '國外': 1}
# {'旅遊': 7, '國外': 3}
# {'旅遊': 4, '國外': 4}
# {'旅遊': 2, '國外': 4}
# {'行動支付': 2}
# {}
# {'旅遊': 13, '航空哩程': 3, '運動': 1, '國外': 2}
# {'旅遊': 3}
# {'網購': 18}
# {'保險': 13}
# {'航空哩程': 10, '紅利': 4, '國外': 2}
# {'超商': 1, '網購': 1, '行動支付': 1}
# {'超商': 1}
# {'超商': 1, '國外': 1}
# {'旅遊': 9, '國外': 1}
# {}
# {'網購': 3}
# {'加油': 2, '電影': 5, '國外': 1, '網購': 1}
# {'網購': 7, '國外': 1, '旅遊': 2}
# {'網購': 3, '國外': 1, '行動支付': 2, '加油': 1, '旅遊': 3}
# {'網購': 5, '超商': 9}
# {'國外': 1}
# {}
# {'紅利': 3, '旅遊': 1}
# {'國外': 5, '旅遊': 7}
# {'量販店': 6, '超商': 3}
# {'國外': 1}
# {}
# {'行動支付': 7}
# {'旅遊': 6}
# {'藥妝': 1, '超市': 2, '量販店': 1, '加油': 2}
# {'航空哩程': 7, '紅利': 1, '網購': 3, '國外': 1, '行動支付': 1, '超商': 1}
# {'旅遊': 3}
# {}
# {'網購': 1, '行動支付': 1}
# {'旅遊': 9, '國外': 2}
# {}
# {'紅利': 9}
# {'超商': 1}
# {'百貨': 12}
# {'旅遊': 12, '國外': 5}
# {'百貨': 4, '量販店': 2, '行動支付': 1}
# {'百貨': 9}
# {'運動': 6, '網購': 1, '旅遊': 1}
# {'國外': 6, '旅遊': 5}
# {'旅遊': 8, '國外': 8, '保險': 3, '量販店': 1}
# {}
# {}
# {'百貨': 12, '旅遊': 2}
# {}
# {'國外': 1, '網購': 1, '超商': 1, '紅利': 1}
# {'行動支付': 1}
# {'行動支付': 1, '旅遊': 1}
# {'旅遊': 1}
# {'行動支付': 1}
# {}
# {'國外': 2}
# {'國外': 1, '旅遊': 3}
# {}
# {'旅遊': 1, '超商': 1, '國外': 1}
# {'國外': 1}
# {'旅遊': 1, '國外': 1}
# {'國外': 3, '旅遊': 6, '保險': 1}
# {}
# {'國外': 1}
# {'旅遊': 1, '國外': 2, '保險': 2, '航空哩程': 1, '行動支付': 2}
# {}
# {}
# {'網購': 2}
# {'網購': 1}
# {}
# {'行動支付': 6}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {'國外': 2, '超商': 1, '行動支付': 1}
# {}
# {'加油': 3, '保險': 5, '旅遊': 12, '國外': 7, '行動支付': 1, '網購': 1}
# {}
# {}
# {'網購': 1, '行動支付': 1}
# {'網購': 3, '電影': 1, '保險': 2, '行動支付': 2, '超商': 6, '藥妝': 1, '超市': 1}
# {'行動支付': 7, '國外': 1, '超商': 7, '藥妝': 1, '加油': 4, '網購': 1}
# {'國外': 2}
# {}
# {'網購': 1}
# {'網購': 8, '超商': 8, '行動支付': 3, '加油': 3, '保險': 2}
# {'超商': 1}
# {'行動支付': 2}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 1, '網購': 2}
# {}
# {'旅遊': 1}
# {'旅遊': 3}
# {}
# {'旅遊': 1}
# {}
# {}
# {'網購': 1}
# {'行動支付': 2, '超商': 1}
# {}
# {'網購': 1}
# {'國外': 3}
# {'國外': 3}
# {'超市': 1, '網購': 3, '旅遊': 2}
# {'國外': 1}
# {}
# {'網購': 3, '超商': 2}
# {}
# {'網購': 1}
# {'超商': 1, '行動支付': 1}
# {'行動支付': 3}
# {'行動支付': 1}
# {}
# {}
# {'網購': 4}
# {}
# {'網購': 3, '行動支付': 1}
# {}
# {'網購': 3}
# {'行動支付': 1, '網購': 2}
# {'行動支付': 1, '網購': 2}
# {'行動支付': 3, '超商': 2, '量販店': 3}
# {}
# {}
# {'網購': 1}
# {'網購': 2, '超商': 2, '電影': 1}
# {}
# {'國外': 2}
# {'加油': 1}
# {}
# {}
# {'保險': 1, '國外': 1, '紅利': 3, '旅遊': 1}
# {'保險': 1}
# {'國外': 5}
# {}
# {'保險': 1}
# {'藥妝': 4, '國外': 1}
# {'國外': 2}
# {'旅遊': 3}
# {'加油': 3}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'加油': 2}
# {'網購': 1}
# {}
# {}
# {'保險': 2}
# {'超商': 2, '網購': 2, '旅遊': 4, '國外': 2}
# {'量販店': 2, '網購': 4, '行動支付': 4}
# {}
# {}
# {'行動支付': 2, '超商': 1, '網購': 2, '量販店': 1}
# {}
# {}
# {'保險': 2}
# {}
# {'行動支付': 1}
# {}
# {}
# {'旅遊': 1}
# {'超商': 2}
# {'保險': 2}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 1, '行動支付': 2}
# {}
# {}
# {}
# {'電影': 2, '紅利': 2}
# {'網購': 4}
# {}
# {'百貨': 3}
# {}
# {}
# {'國外': 2, '旅遊': 1}
# {'國外': 1}
# {'超市': 1}
# {'加油': 4}
# {'國外': 6, '旅遊': 4}
# {'電影': 1}
# {'保險': 3}
# {'超商': 1}
# {}
# {'國外': 1}
# {'網購': 4}
# {}
# {'保險': 2}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {}
# {'保險': 3}
# {}
# {}
# {'旅遊': 3, '加油': 2}
# {'保險': 1}
# {'國外': 1}
# {'行動支付': 1, '電影': 1}
# {}
# {}
# {'網購': 2, '保險': 1}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {'旅遊': 9}
# {'國外': 1}
# {}
# {'超商': 2}
# {}
# {'量販店': 1}
# {'藥妝': 1}
# {}
# {}
# {'旅遊': 2, '國外': 1}
# {}
# {'旅遊': 2}
# {'國外': 1}
# {'網購': 1}
# {}
# {'超商': 1, '行動支付': 1}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 2, '量販店': 1}
# {}
# {'網購': 1}
# {'國外': 3, '網購': 1}
# {'行動支付': 1}
# {'旅遊': 5}
# {'網購': 3, '藥妝': 1}
# {'航空哩程': 7, '旅遊': 3}
# {'網購': 2, '旅遊': 3, '行動支付': 1, '保險': 1}
# {}
# {'超商': 2, '紅利': 1, '行動支付': 1}
# {'國外': 1, '旅遊': 1, '保險': 1}
# {'網購': 1}
# {'國外': 1}
# {}
# {'網購': 4}
# {}
# {}
# {'旅遊': 2, '網購': 1}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'網購': 1, '行動支付': 1, '旅遊': 2, '國外': 3, '加油': 1, '電影': 1}
# {'國外': 1, '紅利': 1}
# {}
# {'國外': 4}
# {}
# {'航空哩程': 4, '旅遊': 1}
# {}
# {'加油': 3}
# {}
# {'超商': 1}
# {}
# {'電影': 3}
# {'量販店': 2, '行動支付': 2, '超商': 1}
# {}
# {'國外': 3}
# {}
# {'航空哩程': 1}
# {'超商': 1, '行動支付': 1}
# {}
# {}
# {}
# {}
# {'旅遊': 4}
# {'加油': 2}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {'國外': 1}
# {}
# {'行動支付': 1}
# {'行動支付': 2, '旅遊': 1}
# {}
# {'運動': 7}
# {'保險': 2, '國外': 2, '旅遊': 3}
# {}
# {'行動支付': 1}
# {'國外': 5, '旅遊': 8, '網購': 1}
# {'國外': 5, '旅遊': 2}
# {}
# {}
# {}
# {}
# {'量販店': 2, '藥妝': 1, '電影': 2, '網購': 3, '國外': 2}
# {'加油': 1}
# {}
# {'網購': 1}
# {'電影': 1}
# {}
# {'行動支付': 4}
# {'加油': 1}
# {'網購': 1, '藥妝': 1, '行動支付': 1}
# {}
# {'網購': 1}
# {'網購': 3}
# {'網購': 3}
# {}
# {'國外': 2}
# {'保險': 3, '網購': 9}
# {'百貨': 1}
# {'行動支付': 1}
# {}
# {'網購': 1}
# {}
# {}
# {'網購': 1, '旅遊': 1}
# {'電影': 3}
# {'行動支付': 1, '藥妝': 1, '量販店': 1}
# {'量販店': 1}
# {}
# {}
# {'網購': 1, '國外': 1}
# {}
# {'量販店': 2}
# {}
# {'加油': 2, '網購': 1, '量販店': 1, '旅遊': 1}
# {}
# {}
# {'超商': 1, '網購': 1}
# {}
# {}
# {'網購': 13}
# {}
# {}
# {'網購': 2}
# {'保險': 4}
# {'保險': 2}
# {'加油': 5}
# {}
# {}
# {}
# {'超商': 2}
# {'加油': 2}
# {}
# {}
# {}
# {'網購': 2}
# {'旅遊': 9, '國外': 2}
# {'航空哩程': 3, '旅遊': 1, '國外': 2}
# {}
# {'超商': 1, '加油': 1}
# {'國外': 4}
# {}
# {}
# {'國外': 4}
# {'加油': 1}
# {}
# {'紅利': 1}
# {}
# {}
# {'紅利': 2}
# {}
# {}
# {'網購': 9, '行動支付': 3}
# {}
# {}
# {'網購': 3}
# {'量販店': 2}
# {}
# {'網購': 6}
# {'網購': 2}
# {'網購': 6, '行動支付': 1}
# {}
# {'網購': 1, '量販店': 2, '電影': 4, '國外': 2, '旅遊': 1, '超市': 1}
# {}
# {'行動支付': 1}
# {'航空哩程': 3, '旅遊': 2}
# {'國外': 1}
# {'網購': 3}
# {}
# {'超商': 2, '行動支付': 1}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'行動支付': 2, '旅遊': 2, '國外': 1}
# {}
# {}
# {}
# {'航空哩程': 3, '旅遊': 2, '保險': 2, '國外': 1}
# {}
# {'行動支付': 2, '超商': 1}
# {'超商': 1}
# {}
# {}
# {}
# {'行動支付': 3}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'網購': 4}
# {}
# {'旅遊': 4}
# {'網購': 2}
# {'行動支付': 1}
# {'超商': 1}
# {'旅遊': 1, '國外': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 2}
# {'旅遊': 1}
# {'網購': 1}
# {}
# {}
# {'網購': 1, '紅利': 1, '量販店': 1}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {'加油': 2, '超商': 3, '網購': 6, '百貨': 2, '行動支付': 5, '量販店': 3, '超市': 1}
# {'超商': 1}
# {'旅遊': 2, '電影': 6, '行動支付': 4, '網購': 6, '量販店': 1, '百貨': 2, '保險': 1, '加油': 1}
# {'加油': 3, '超市': 1, '超商': 5, '量販店': 1, '百貨': 3}
# {}
# {}
# {'航空哩程': 1, '旅遊': 1}
# {'網購': 2}
# {'旅遊': 1, '國外': 1, '保險': 1}
# {}
# {'網購': 1, '超商': 1, '電影': 1, '旅遊': 1}
# {'網購': 22, '超商': 2, '行動支付': 2, '電影': 1}
# {'電影': 2, '百貨': 1}
# {'電影': 8}
# {'網購': 1, '加油': 2, '國外': 2, '電影': 1}
# {'旅遊': 4}
# {}
# {'旅遊': 2, '行動支付': 1}
# {}
# {'超商': 2}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {'國外': 1}
# {}
# {}
# {'旅遊': 4}
# {'國外': 1}
# {}
# {'航空哩程': 1}
# {}
# {}
# {}
# {}
# {'國外': 3}
# {}
# {}
# {'行動支付': 1, '網購': 1}
# {'國外': 2}
# {}
# {'超市': 1}
# {'旅遊': 3, '國外': 1}
# {'行動支付': 1, '網購': 1}
# {}
# {}
# {}
# {'加油': 1}
# {'加油': 2}
# {}
# {'行動支付': 1}
# {'電影': 2}
# {}
# {'電影': 4}
# {'行動支付': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'行動支付': 2}
# {}
# {'超商': 4, '超市': 2}
# {}
# {}
# {}
# {'網購': 3, '超商': 1, '行動支付': 1}
# {'網購': 1}
# {}
# {'國外': 1, '旅遊': 1}
# {'網購': 4}
# {'網購': 2}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {'加油': 3}
# {'超商': 3, '行動支付': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'加油': 5}
# {}
# {}
# {}
# {'行動支付': 2}
# {'行動支付': 2, '紅利': 1}
# {'超市': 1}
# {}
# {}
# {}
# {'網購': 1}
# {'國外': 1}
# {'百貨': 1, '行動支付': 1}
# {}
# {'行動支付': 1, '電影': 1}
# {'國外': 1, '行動支付': 1}
# {}
# {'超商': 1, '超市': 2, '網購': 4, '行動支付': 2, '旅遊': 3, '國外': 1, '保險': 1}
# {'網購': 3}
# {'電影': 2}
# {'超商': 1, '網購': 1}
# {'網購': 3, '超商': 1, '電影': 1, '行動支付': 1}
# {'網購': 2, '超商': 1, '電影': 1, '紅利': 1}
# {}
# {'網購': 2, '旅遊': 1}
# {'網購': 3}
# {'網購': 1}
# {'網購': 1}
# {'量販店': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'電影': 1}
# {}
# {'網購': 1}
# {'國外': 3, '旅遊': 9}
# {}
# {'旅遊': 1, '超商': 1}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'藥妝': 1}
# {}
# {}
# {}
# {'旅遊': 1}
# {'旅遊': 2}
# {'網購': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'國外': 1, '行動支付': 1, '超市': 1}
# {'加油': 2, '保險': 1, '網購': 2}
# {}
# {'航空哩程': 3}
# {}
# {'旅遊': 5}
# {}
# {'旅遊': 1, '國外': 1}
# {'電影': 1}
# {'國外': 2}
# {}
# {'旅遊': 1}
# {'旅遊': 3}
# {'國外': 3, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 7}
# {'加油': 4}
# {'加油': 8}
# {}
# {'加油': 1}
# {}
# {}
# {'旅遊': 2}
# {'保險': 1}
# {}
# {}
# {'保險': 2}
# {'網購': 2}
# {'旅遊': 1}
# {'網購': 1, '保險': 1, '行動支付': 1}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1, '保險': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {'旅遊': 5}
# {'超商': 1}
# {'網購': 2, '保險': 2}
# {}
# {'網購': 6, '行動支付': 1}
# {'網購': 6, '行動支付': 1}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'國外': 1}
# {}
# {}
# {'國外': 1}
# {'旅遊': 1}
# {'國外': 2, '網購': 1, '旅遊': 2}
# {'量販店': 1}
# {}
# {'網購': 2}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'電影': 1, '旅遊': 1}
# {'國外': 4}
# {}
# {'加油': 1}
# {'超商': 2}
# {'超商': 3}
# {'超商': 2}
# {'超商': 4}
# {'超市': 14, '超商': 1}
# {'超市': 3}
# {}
# {'紅利': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {}
# {}
# {}
# {'電影': 2}
# {}
# {'網購': 2}
# {}
# {'國外': 3}
# {'電影': 2}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {}
# {}
# {'電影': 1}
# {'航空哩程': 2, '旅遊': 1}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {}
# {}
# {}
# {}
# {'行動支付': 1, '旅遊': 2}
# {}
# {}
# {}
# {'網購': 1, '行動支付': 1}
# {'加油': 2}
# {}
# {}
# {}
# {'國外': 3, '網購': 1, '電影': 1, '超商': 1, '行動支付': 1}
# {'網購': 6, '行動支付': 2}
# {'網購': 4}
# {'量販店': 3}
# {'加油': 1}
# {'網購': 3}
# {'網購': 2}
# {}
# {'旅遊': 1}
# {}
# {'旅遊': 6, '國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'網購': 15}
# {'網購': 7}
# {'國外': 1, '旅遊': 2}
# {'旅遊': 3}
# {'旅遊': 2}
# {}
# {}
# {'旅遊': 5, '百貨': 1, '國外': 1}
# {}
# {'保險': 7}
# {}
# {'網購': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 3}
# {'網購': 1}
# {'旅遊': 1}
# {'網購': 3, '電影': 1}
# {'行動支付': 9, '超商': 7, '網購': 2, '電影': 3}
# {}
# {'保險': 4}
# {'百貨': 1}
# {}
# {}
# {'旅遊': 5, '量販店': 1}
# {'國外': 4, '加油': 1, '旅遊': 2}
# {}
# {'國外': 1, '超市': 1, '超商': 1}
# {'量販店': 1, '百貨': 1}
# {}
# {'網購': 2}
# {'加油': 4, '保險': 1}
# {'紅利': 3}
# {}
# {}
# {}
# {'網購': 3}
# {}
# {'行動支付': 1}
# {}
# {}
# {}
# {'國外': 1, '網購': 1}
# {}
# {'網購': 1}
# {'保險': 1}
# {}
# {}
# {'超商': 1}
# {}
# {'紅利': 5}
# {'旅遊': 2}
# {'超商': 1, '紅利': 1}
# {}
# {}
# {}
# {}
# {}
# {'量販店': 1, '旅遊': 2}
# {}
# {'超商': 1}
# {}
# {'超商': 5, '網購': 3, '量販店': 1}
# {}
# {}
# {}
# {'百貨': 2, '紅利': 1}
# {'百貨': 5}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {'旅遊': 2, '國外': 2}
# {'加油': 3}
# {'藥妝': 1, '保險': 1}
# {'保險': 3}
# {}
# {'國外': 1}
# {}
# {}
# {'百貨': 4}
# {}
# {'國外': 1}
# {}
# {'旅遊': 2}
# {}
# {}
# {}
# {'電影': 2}
# {'國外': 1}
# {}
# {'網購': 2, '加油': 3, '量販店': 2, '行動支付': 1}
# {}
# {}
# {'網購': 2}
# {'旅遊': 8, '航空哩程': 1}
# {'量販店': 5}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'百貨': 2}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {'量販店': 4, '行動支付': 1}
# {'量販店': 3}
# {'超商': 2, '保險': 1}
# {'保險': 1, '旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {'網購': 1}
# {'超市': 2}
# {}
# {}
# {}
# {}
# {'紅利': 2, '網購': 1}
# {}
# {}
# {'國外': 1}
# {}
# {}
# {'超市': 1}
# {}
# {'旅遊': 2}
# {'行動支付': 2}
# {}
# {}
# {}
# {}
# {}
# {'加油': 1}
# {'電影': 1}
# {}
# {}
# {'旅遊': 1}
# {'運動': 1, '量販店': 1, '保險': 1}
# {}
# {}
# {'國外': 2, '加油': 2, '旅遊': 3}
# {'紅利': 1}
# {'加油': 2}
# {'航空哩程': 1}
# {}
# {'超商': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'網購': 1, '超商': 1}
# {}
# {}
# {}
# {}
# {}
# {'電影': 2}
# {'行動支付': 2, '網購': 1}
# {}
# {}
# {'百貨': 1}
# {'旅遊': 2}
# {'旅遊': 1}
# {}
# {'超市': 2}
# {'國外': 1}
# {}
# {}
# {'行動支付': 2}
# {}
# {}
# {'國外': 1, '網購': 1}
# {'網購': 4, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 1, '加油': 1}
# {'國外': 2}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 4, '國外': 1, '網購': 1}
# {}
# {}
# {'行動支付': 3}
# {}
# {}
# {'網購': 2}
# {'超商': 1, '量販店': 1, '旅遊': 2}
# {}
# {'加油': 1, '量販店': 2, '超商': 2}
# {}
# {}
# {}
# {'行動支付': 1}
# {'網購': 1}
# {'旅遊': 2}
# {}
# {}
# {}
# {'加油': 1}
# {'網購': 2}
# {}
# {}
# {}
# {}
# {'超商': 5}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 3}
# {'旅遊': 6, '國外': 1}
# {'旅遊': 7}
# {}
# {'行動支付': 3, '國外': 1}
# {'保險': 2, '網購': 1, '國外': 1}
# {}
# {}
# {'旅遊': 3}
# {}
# {'保險': 4, '超商': 2, '超市': 1}
# {}
# {'超市': 2, '超商': 1}
# {}
# {'保險': 3, '超市': 2, '行動支付': 5, '國外': 1, '超商': 2}
# {}
# {}
# {'運動': 1}
# {}
# {}
# {}
# {'加油': 1}
# {'國外': 2}
# {'國外': 4}
# {'國外': 3}
# {'國外': 3, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {'行動支付': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'電影': 4, '百貨': 2}
# {}
# {'旅遊': 2}
# {}
# {'超商': 1, '行動支付': 3}
# {}
# {}
# {'旅遊': 5, '國外': 3}
# {}
# {}
# {}
# {'行動支付': 10}
# {'航空哩程': 9, '保險': 2, '國外': 9}
# {'網購': 2, '加油': 1}
# {'超商': 5, '電影': 3}
# {'網購': 1}
# {}
# {}
# {'網購': 4, '紅利': 1, '量販店': 1}
# {'航空哩程': 6, '保險': 2, '超商': 2, '國外': 2, '行動支付': 1}
# {}
# {'旅遊': 1}
# {'加油': 1}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'超商': 1}
# {'網購': 2, '旅遊': 1}
# {'超商': 1}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'加油': 1, '網購': 1, '行動支付': 1}
# {}
# {}
# {'量販店': 1, '網購': 1}
# {'加油': 1}
# {'行動支付': 2}
# {}
# {'行動支付': 1}
# {}
# {'電影': 1}
# {}
# {}
# {}
# {'網購': 2}
# {}
# {'電影': 6, '加油': 8, '國外': 10, '旅遊': 7, '網購': 5}
# {'旅遊': 2}
# {}
# {}
# {}
# {'加油': 2, '網購': 1, '量販店': 2}
# {}
# {}
# {'量販店': 1}
# {'超商': 2, '行動支付': 2}
# {'旅遊': 1}
# {'網購': 1}
# {}
# {'旅遊': 1}
# {'加油': 2, '量販店': 2, '網購': 2, '國外': 2}
# {'行動支付': 1, '旅遊': 1, '國外': 1}
# {}
# {'國外': 1}
# {}
# {'旅遊': 3, '超商': 1}
# {'國外': 1, '旅遊': 3}
# {}
# {}
# {}
# {}
# {'網購': 7}
# {}
# {}
# {'旅遊': 8}
# {}
# {}
# {}
# {}
# {'國外': 3}
# {'保險': 2, '旅遊': 1}
# {}
# {}
# {'加油': 1}
# {}
# {'旅遊': 1, '加油': 2}
# {'加油': 1}
# {'加油': 2}
# {'超商': 1}
# {}
# {}
# {'旅遊': 3}
# {}
# {'超商': 4, '行動支付': 4}
# {}
# {'超市': 6}
# {}
# {'網購': 3}
# {}
# {}
# {}
# {'網購': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'行動支付': 3}
# {}
# {'超商': 1, '網購': 1}
# {'電影': 1}
# {}
# {'百貨': 1}
# {}
# {}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'航空哩程': 1}
# {}
# {}
# {'量販店': 2}
# {}
# {'國外': 2}
# {}
# {'國外': 1}
# {}
# {}
# {'電影': 1, '國外': 2}
# {}
# {}
# {'網購': 1}
# {'國外': 3}
# {}
# {}
# {}
# {'紅利': 1}
# {}
# {'國外': 1}
# {}
# {}
# {}
# {'保險': 2}
# {'網購': 2}
# {'旅遊': 2}
# {}
# {'紅利': 1, '網購': 1}
# {'網購': 1, '國外': 1}
# {'藥妝': 1, '網購': 2, '超商': 1}
# {}
# {}
# {'國外': 3}
# {}
# {}
# {}
# {}
# {'網購': 3}
# {'電影': 3}
# {'網購': 4, '國外': 2}
# {}
# {'紅利': 2}
# {'國外': 2}
# {}
# {}
# {'超商': 6}
# {}
# {'行動支付': 5}
# {}
# {}
# {}
# {'超商': 1}
# {'網購': 1}
# {}
# {'國外': 2}
# {}
# {}
# {'超商': 4}
# {'超商': 3, '行動支付': 1}
# {}
# {}
# {}
# {'國外': 1}
# {}
# {'行動支付': 2}
# {}
# {'旅遊': 1}
# {}
# {'航空哩程': 11, '旅遊': 3}
# {'旅遊': 1, '網購': 1}
# {'網購': 7, '量販店': 1}
# {'旅遊': 1, '紅利': 1}
# {'網購': 3}
# {}
# {}
# {}
# {}
# {'電影': 2}
# {}
# {'國外': 2, '航空哩程': 1, '旅遊': 2}
# {'加油': 4}
# {'網購': 1}
# {}
# {}
# {'旅遊': 2}
# {'超商': 4, '量販店': 3}
# {'旅遊': 1}
# {'國外': 2}
# {'電影': 3}
# {'量販店': 6, '行動支付': 2}
# {'網購': 2}
# {}
# {'旅遊': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {'行動支付': 1}
# {'電影': 2}
# {}
# {}
# {}
# {}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {'超商': 1}
# {'旅遊': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {'加油': 2}
# {'網購': 1}
# {'國外': 6}
# {'超商': 2}
# {'保險': 3}
# {}
# {}
# {}
# {'旅遊': 3}
# {}
# {}
# {'國外': 2}
# {}
# {}
# {}
# {'旅遊': 4}
# {}
# {'藥妝': 3, '加油': 2}
# {}
# {}
# {'行動支付': 1, '超商': 2}
# {}
# {}
# {'旅遊': 1}
# {'電影': 3}
# {'旅遊': 9}
# {}
# {'網購': 1}
# {}
# {}
# {'旅遊': 2}
# {'旅遊': 2, '國外': 1}
# {}
# {'網購': 2}
# {'行動支付': 1}
# {'旅遊': 5, '國外': 1, '超商': 1, '網購': 2, '保險': 1}
# {'旅遊': 3, '國外': 1}
# {'旅遊': 6}
# {'行動支付': 1}
# {'旅遊': 1, '國外': 1, '電影': 1}
# {}
# {}
# {}
# {'超商': 1, '電影': 1}
# {}
# {}
# {'運動': 1}
# {}
# {'電影': 1}
# {}
# {'網購': 3, '旅遊': 1}
# {}
# {'旅遊': 1}
# {}
# {}
# {}
# {}
# {'航空哩程': 3, '國外': 1, '旅遊': 3}
# {'旅遊': 2}
# {}
# {}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'旅遊': 1}
# {}
# {}
# {'國外': 1, '旅遊': 1}
# {'網購': 2}
# {}
# {'行動支付': 3}
# {}
# {}
# {'行動支付': 1}
# {'旅遊': 3}
# {}
# {'旅遊': 1}
# {'國外': 5}
# {}
# {'旅遊': 1}
# {}
# {'行動支付': 1, '旅遊': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'國外': 2}
# {}
# {'保險': 5}
# {}
# {}
# {'超商': 1, '網購': 1}
# {'行動支付': 1}
# {}
# {'保險': 1}
# {'量販店': 1}
# {'國外': 2}
# {'保險': 1, '行動支付': 1}
# {'國外': 4}
# {'旅遊': 2}
# {}
# {}
# {'旅遊': 1}
# {}
# {'藥妝': 3, '航空哩程': 2, '超商': 1}
# {'保險': 1}
# {}
# {}
# {}
# {}
# {'保險': 2}
# {}
# {'加油': 7}
# {'航空哩程': 1}
# {'旅遊': 1, '國外': 1}
# {}
# {}
# {'網購': 3}
# {'網購': 1}
# {}
# {}
# {'行動支付': 4, '網購': 1}
# {'行動支付': 2}
# {}
# {}
# {'超商': 1}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'旅遊': 2}
# {}
# {}
# {'國外': 3, '旅遊': 1}
# {'國外': 2}
# {}
# {'國外': 3}
# {}
# {'保險': 1}
# {'量販店': 4}
# {'旅遊': 2}

# %%
df
# Out:
#           編號                            標題              時間  \
# 0          1                   [問題] 關於學歷問題   Thu Sep 21 01
# 1          2           [心得] Ubear 網路消費回饋分享   Sun Sep 22 13
# 2          3          [心得] 台新Flygo、玉山pi 核卡   Sat Feb  2 23
# 3          4          [心得] 台新黑狗悠遊卡脫白任務再度失敗   Tue Sep  4 15
# 4          5              [心得] 國泰長榮聯名卡調額失敗   Fri Apr 26 00
# ...      ...                           ...             ...
# 11414  11415           [情報] 確定大戶卡刷淘寶只有2%回饋   Fri Nov  1 21
# 11415  11416                  大眾（元大）客服無人接聽   Tue Jan 23 11
# 11416  11417         ?心得?玉山 PI UBEAR 無照會核卡   Thu Aug  1 22
# 11417  11418   富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14   Thu Sep  5 11
# 11418  11419                     贈送 寰宇商務通關   Mon Oct  7 10
#
#                                                       網址  \
# 0       https://www.ptt.cc/bbs/creditcard/M.150592954...
# 1       https://www.ptt.cc/bbs/creditcard/M.156913024...
# 2       https://www.ptt.cc/bbs/creditcard/M.154912240...
# 3       https://www.ptt.cc/bbs/creditcard/M.153604658...
# 4       https://www.ptt.cc/bbs/creditcard/M.155620843...
# ...                                                  ...
# 11414   https://www.ptt.cc/bbs/creditcard/M.157261425...
# 11415   https://www.ptt.cc/bbs/creditcard/M.151667690...
# 11416   https://www.ptt.cc/bbs/creditcard/M.156467139...
# 11417   https://www.ptt.cc/bbs/creditcard/M.156765417...
# 11418   https://www.ptt.cc/bbs/creditcard/M.157041459...
#
#                                                       內文  \
# 0      [問題] 關於學歷問題時間Thu Sep 21 01:45:44 2017\n手機排版，請見...
# 1       [心得] Ubear 網路消費回饋分享時間Sun Sep 22 13:30:40 2019...
# 2       [心得] 台新Flygo、玉山pi 核卡時間Sat Feb  2 23:46:42 201...
# 3       [心得] 台新黑狗悠遊卡脫白任務再度失敗時間Tue Sep  4 15:36:24 201...
# 4       [心得] 國泰長榮聯名卡調額失敗時間Fri Apr 26 00:07:15 2019\n\...
# ...                                                  ...
# 11414  [情報] 確定大戶卡刷淘寶只有2%回饋時間Fri Nov  1 21:17:28 2019\...
# 11415  大眾（元大）客服無人接聽時間Tue Jan 23 11:08:22 2018\n最近因?大眾...
# 11416  ?心得?玉山 PI UBEAR 無照會核卡時間Thu Aug  1 22:56:37 201...
# 11417  富邦J卡 中秋快閃愛買/家樂福10%回饋9/12-14時間Thu Sep  5 11:29:...
# 11418  贈送 寰宇商務通關時間Mon Oct  7 10:16:29 2019\n手機發文找不到 贈...
#
#                                                       斷詞  \
# 0      [[, 問題, ],  , 關於, 學歷, 問題, 時間, Thu,  , Sep,  , ...
# 1      [ , [, 心得, ],  , Ubear,  , 網路, 消費, 回饋, 分享, 時間,...
# 2      [ , [, 心得, ],  , 台新, Flygo, 、, 玉山, pi,  , 核卡, ...
# 3      [ , [, 心得, ],  , 台新, 黑狗, 悠遊卡, 脫白, 任務, 再度, 失敗, ...
# 4      [ , [, 心得, ],  , 國泰, 長榮, 聯名卡, 調額, 失敗, 時間, Fri,...
# ...                                                  ...
# 11414  [[, 情報, ],  , 確定, 大戶, 卡刷, 淘, 寶, 只有, 2%, 回饋, 時間...
# 11415  [大眾, （, 元大, ）, 客服, 無人, 接聽, 時間, Tue,  , Jan,  ,...
# 11416  [?, 心得, ?, 玉山,  , PI,  , UBEAR,  , 無照, 會, 核卡, ...
# 11417  [富邦, J, 卡,  , 中秋, 快, 閃, 愛買, /, 家樂福, 10%, 回饋, 9...
# 11418  [贈送,  , 寰宇, 商務, 通關, 時間, Mon,  , Oct,  ,  , 7, ...
#
#                                                       詞頻  \
# 0      {'[': 1, '問題': 2, ']': 1, ' ': 5, '關於': 1, '學歷...
# 1      {' ': 9, '[': 1, '心得': 2, ']': 1, 'Ubear': 1, ...
# 2      {' ': 39, '[': 11, '心得': 2, ']': 11, '台新': 1, ...
# 3      {' ': 30, '[': 13, '心得': 1, ']': 13, '台新': 7, ...
# 4      {' ': 6, '[': 5, '心得': 1, ']': 5, '國泰': 2, '長榮...
# ...                                                  ...
# 11414  {'[': 1, '情報': 1, ']': 1, ' ': 10, '確定': 1, '大...
# 11415  {'大眾': 4, '（': 2, '元大': 1, '）': 2, '客服': 3, '無...
# 11416  {'?': 2, '心得': 2, '玉山': 6, ' ': 30, 'PI': 4, '...
# 11417  {'富邦': 8, 'J': 8, '卡': 8, ' ': 10, '中秋': 2, '快...
# 11418  {'贈送': 2, ' ': 11, '寰宇': 1, '商務': 3, '通關': 3, ...
#
#                                                       銀行  \
# 0                                              {'兆豐': 1}
# 1                                              {'玉山': 1}
# 2              {'台新': 2, '玉山': 8, 'Richart': 2, '中信': 1}
# 3      {'台新': 7, '中信': 1, 'Richart': 2, '華南': 1, '花旗'...
# 4                                              {'國泰': 2}
# ...                                                  ...
# 11414                                                 {}
# 11415                                          {'元大': 1}
# 11416                                 {'玉山': 6, '台新': 2}
# 11417                                          {'富邦': 9}
# 11418                                          {'台新': 1}
#
#                                         卡片  \
# 0                            {'e秒刷鈦金卡': 1}
# 1                             {'Ubear': 1}
# 2         {'Flygo': 4, 'Pi': 3, 'GoGo': 2}
# 3      {'GoGo': 5, 'LINEPay': 1, '饗樂卡': 2}
# 4                                       {}
# ...                                    ...
# 11414             {'dawho': 2, 'Ubear': 1}
# 11415                                   {}
# 11416                {'Pi': 7, 'Ubear': 6}
# 11417                       {'LINEPay': 1}
# 11418                                   {}
#
#                                            行為
# 0                                          {}
# 1                                          {}
# 2      {'旅遊': 2, '行動支付': 1, '網購': 1, '國外': 1}
# 3                                   {'網購': 2}
# 4                                          {}
# ...                                       ...
# 11414                               {'國外': 3}
# 11415                                      {}
# 11416                               {'保險': 1}
# 11417                              {'量販店': 4}
# 11418                               {'旅遊': 2}
#
# [11419 rows x 10 columns]

# %%
df.to_json(r'./ptt_creditcard_tag.json', orient='index', force_ascii=False)

# %%
writer = pd.ExcelWriter('ptt_tag.xlsx', engine='xlsxwriter')
df.to_excel(writer, sheet_name='Sheet1')
writer.save()
