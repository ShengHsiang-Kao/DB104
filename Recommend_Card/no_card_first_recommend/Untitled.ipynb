# %%
import pandas as pd
import json
import re
import pymongo
import jieba
import operator
import numpy as np

# %%
carddf=pd.read_excel(r'./data_card_feature_for_reccommend_1st.xlsx',encoding='utf-16')

# %%
carddf[carddf['現金回饋']==0]
# Out:
#                              Unnamed: 0  卡活動  保險  加油  行動支付  超商  交通  電影  \
# 5                            土地銀行-白金商務卡    0   0   0     0   0   0   0
# 7                         中國信託-ANA晶緻聯名卡    0   0   0     0   0   0   0
# 8                         中國信託-ANA極緻聯名卡    0   0   0     0   0   0   0
# 9                  中國信託-Global Mall 聯名卡    0   0   0     0   0   0   0
# 14                中國信託-TAIPEI 101 夜光聯名卡    0   0   0     0   0   0   0
# 18                        中國信託-中油VIP聯名卡    0   0   0     0   0   0   0
# 21              中國信託-中國信託寰遊美國運通卡AMEX_金卡    0   0   0     0   0   0   0
# 22                       中國信託-中華電信聯名白金卡    0   0   0     0   0   0   0
# 34                       中國信託-蘭城新月廣場聯名卡    0   0   0     0   0   0   0
# 35                      元大銀行-iCash樂享晶緻卡    0   0   0     0   0   0   0
# 38                 元大銀行-Wi-Ho!Online聯名卡    0   0   0     0   0   0   0
# 39                             元大銀行-一番卡    0   0   6     0   0   0   3
# ...
