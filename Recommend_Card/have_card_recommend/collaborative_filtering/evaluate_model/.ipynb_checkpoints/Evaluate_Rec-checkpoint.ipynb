# %%
import numpy as np
import random
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import pymongo
import json
from sklearn.metrics import mean_squared_error
from random import sample

# %%
sample()

# %%
#從xlsx匯入資料
rec_data= pd.read_excel(r'./melt_data.xlsx',encoding='utf-16',index_col=0)

# %%
#sample train test data

train_idx=sample(rec_data.index.to_list(),int(len(rec_data)*0.7))
train_data=rec_data.loc[train_idx]
test_tmp=rec_data.index.isin(train_idx)
test_data=rec_data[~test_tmp]

# %%
train_data.head()
# Out:
#         user      variable  value
# 466263    39      聯邦銀行-紅利卡      0
# 30409   1270  中國信託-中信兄弟聯名卡      0
# 368425   214    凱基銀行-中壽聯名卡      0
# 254505   201      合作金庫-雙幣卡      0
# 253968  2313  合作金庫-漢來美食聯名卡      0

# %%
#melt data to df and fillna with 0
train_df=train_data.pivot_table(values='value',index='user',columns='variable').fillna(0)

# %%
train_df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-d6abf523d18d> in <module>
# ----> 1 train_df[1]
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1

# %%
indices = pd.Series(train_df.columns)   #所有卡series
#card_index_list=indices[train_df.loc[1]==1]

print(train_df.columns[train_df.loc[0]==1].to_list())
print(train_df.columns[train_df.loc[1]==1].to_list())
# Out:
# ['中國信託-LINE Pay卡', '台新銀行-FlyGo卡']
# ['中國信託-LINE Pay卡', '台新銀行-@GoGo iCash御璽卡', '花旗銀行-新世代花旗饗樂生活悠遊卡']

# %%
#item_base_rec
def CF_Item_Based_Evaluate(train,TopN):
    #imput data type:df
    #轉置df
    traindata=train
    traindata_T=traindata.T
    #計算各卡間的相似度
    card_sim=cosine_similarity(traindata_T,traindata_T)
    
    #找出已持有卡index
    rec_list={}
    for user in traindata.index:
           #所有卡series
        my_card=traindata.columns[traindata.loc[user]==1].to_list()#找持有卡
        indices = pd.Series(traindata_T.index)
        card_index_list=[indices[indices == name].index[0] for name in my_card]  #找出各卡index
        weighted_card_rec=np.zeros(len(traindata_T.index))   #創全0且為卡片數量長度的array
        for  i in card_index_list:
            weighted_card_rec +=card_sim[i]           #將持有卡於其他卡的相似度相加成推薦權重
        #排列相似度最高前TopN名卡片
        weighted_score=pd.Series(weighted_card_rec).sort_values(ascending = False)
        TopN_indexes=weighted_score.iloc[len(my_card):len(my_card)+TopN].index
        rec_card=[]
        for i in TopN_indexes:
            rec_card.append(indices[i])
        rec_list[user]=rec_card
    return rec_list

# %%
CF_Item_Based_Evaluate(train_df,10)
# Out:
# {0: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '台北富邦-J卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '安泰銀行-鈦金卡'],
#  1: ['國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-晶緻卡'],
#  2: ['新光銀行-Lamigo信用卡',
#   '上海商銀-小小兵Bello回饋卡',
#   '渣打銀行-TheShoppingCard分期卡',
#   '中國信託-寰遊美國運通卡',
#   '國泰世華-尊榮御璽卡',
#   '台新銀行-ETC聯名卡',
#   '中國信託-酷玩卡',
#   '聯邦銀行-法拉利無限卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '凱基銀行-無限卡'],
#  3: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  4: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  5: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  6: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  7: ['台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡'],
#  8: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  9: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡'],
#  10: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '彰化銀行-商旅御璽卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '上海商銀-TeresaCard'],
#  11: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡'],
#  12: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-大中華攜手飛聯名卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-燦坤生活聯名卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台北富邦-數位生活卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '臺灣企銀-悠遊聯名卡'],
#  13: ['聯邦銀行-賴點一卡通御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-玉山Only卡',
#   '凱基銀行-中國人壽聯名卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-台新街口聯名卡',
#   '玉山銀行-商務御璽卡'],
#  14: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  15: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  16: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-U Bear信用卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  17: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-商務御璽卡',
#   '國泰世華-鈦金商務卡'],
#  18: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  19: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  20: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '匯豐銀行-現金回饋御璽卡'],
#  21: ['台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '台北富邦-J卡',
#   '台新銀行-商務卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '上海商銀-小小兵Bello回饋卡'],
#  22: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  23: ['台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '永豐銀行-保倍卡'],
#  24: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  25: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  26: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-U Bear信用卡',
#   '永豐銀行-現金回饋卡',
#   '華南銀行-i網購生活卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '臺灣企銀-悠遊聯名卡'],
#  27: ['台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '凱基銀行-無限卡'],
#  28: ['國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡'],
#  29: ['台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-U Bear信用卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-保倍卡',
#   '元大銀行-鑽金卡',
#   '華南銀行-i網購生活卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  30: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-商務御璽卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '元大銀行-鑽金卡'],
#  31: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡'],
#  32: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡'],
#  33: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  34: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  35: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-保倍卡'],
#  36: ['玉山銀行-U Bear信用卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-台新街口聯名卡',
#   '上海商銀-小小兵Bello回饋卡',
#   '華南銀行-i網購生活卡'],
#  37: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-U Bear信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台北富邦-J卡',
#   '華南銀行-i網購生活卡',
#   '永豐銀行-現金回饋卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  38: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-U Bear信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  39: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡'],
#  40: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-酷玩卡'],
#  41: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  42: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  43: ['國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-商務御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  44: ['安泰銀行-晶緻卡',
#   '凱基銀行-無限卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-iCash聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '星展銀行-飛行世界卡'],
#  45: ['國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-U Bear信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡'],
#  46: ['國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-商務御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '美國運通-簽帳金卡',
#   '永豐銀行-現金回饋卡',
#   '台北富邦-富邦悍將悠遊聯名卡'],
#  47: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-世界卡',
#   '永豐銀行-保倍卡',
#   '第一銀行-Wonderful星璨卡'],
#  48: ['安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '美國運通-簽帳金卡',
#   '中國信託-Yahoo聯名卡'],
#  49: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  50: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-玉山世界卡'],
#  51: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '第一銀行-一卡通聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡'],
#  52: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  53: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  54: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-雙幣卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '聯邦銀行-紅利卡',
#   '玉山銀行-eTag悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '中國信託-酷玩卡',
#   '中國信託-秀泰廣場影城聯名卡'],
#  55: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡'],
#  56: ['國泰世華-鈦金商務卡',
#   '中國信託-Yahoo聯名卡',
#   '安泰銀行-鈦金卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '兆豐銀行-世界卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-玉山世界卡'],
#  57: ['中國信託-Yahoo聯名卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-iCash聯名卡',
#   '凱基銀行-無限卡',
#   '聯邦銀行-全國加油聯名卡',
#   '兆豐銀行-世界卡',
#   '台新銀行-遠傳friDay聯名卡',
#   '美國運通-信用白金卡',
#   '玉山銀行-玉山世界卡'],
#  58: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡',
#   '永豐銀行-現金回饋卡'],
#  59: ['中國信託-大中華攜手飛聯名卡',
#   '台新銀行-燦坤生活聯名卡',
#   '新光銀行-Lamigo信用卡',
#   '安泰銀行-分期卡',
#   '台新銀行-太陽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '聯邦銀行-法拉利無限卡',
#   '第一銀行-icash聯名卡',
#   '第一銀行-一卡通聯名卡'],
#  60: ['國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-玉山世界卡',
#   '中國信託-Yahoo聯名卡',
#   '玉山銀行-商務御璽卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡'],
#  61: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  62: ['兆豐銀行-世界卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-Yahoo聯名卡',
#   '中國信託-學學認同卡',
#   '安泰銀行-鈦金卡',
#   '中國信託-鼎極卡',
#   '中國信託-LINE Pay卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-商務御璽卡'],
#  63: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '中國信託-Yahoo聯名卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡'],
#  64: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '國泰世華-鈦金商務卡',
#   '美國運通-信用白金卡',
#   '美國運通-簽帳金卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  65: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '國泰世華-鈦金商務卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '新光銀行-Lamigo信用卡',
#   '台中商銀-JCB哆啦A夢晶緻卡'],
#  66: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '華南銀行-i網購生活卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-一卡通聯名卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡'],
#  67: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-U Bear信用卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '華南銀行-i網購生活卡'],
#  68: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '匯豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣銀行-鈦金商旅卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-晶緻卡'],
#  69: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  70: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡',
#   '永豐銀行-現金回饋卡'],
#  71: ['國泰世華-雙幣卡',
#   '中國信託-秀泰廣場影城聯名卡',
#   '聯邦銀行-紅利卡',
#   '玉山銀行-eTag悠遊聯名卡',
#   '玉山銀行-家樂福悠遊聯名卡',
#   '台北富邦-鑽保卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '中國信託-酷玩卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-商務御璽卡'],
#  72: ['國泰世華-鈦金商務卡',
#   '安泰銀行-鈦金卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-玉山世界卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  73: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-玉山世界卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡'],
#  74: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  75: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  76: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  77: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  78: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡'],
#  79: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  80: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  81: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡'],
#  82: ['國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  83: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-Wonderful星璨卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡'],
#  84: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  85: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  86: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡'],
#  87: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡'],
#  88: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  89: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '華南銀行-i網購生活卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  90: ['元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡'],
#  91: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '玉山銀行-商務御璽卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '國泰世華-鈦金商務卡',
#   '臺灣企銀-悠遊聯名卡'],
#  92: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '凱基銀行-無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '中國信託-Yahoo聯名卡'],
#  93: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  94: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  95: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '中國信託-Yahoo聯名卡',
#   '永豐銀行-現金回饋卡'],
#  96: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡'],
#  97: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '陽信銀行-一卡通聯名鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-iCash聯名卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '安泰銀行-鈦金卡',
#   '新光銀行-寰宇現金回饋卡'],
#  98: ['兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '中國信託-Yahoo聯名卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡'],
#  99: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  100: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '台新銀行-FlyGo卡'],
#  101: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡'],
#  102: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  103: ['國泰世華-鈦金商務卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '中國信託-LINE Pay卡',
#   '聯邦銀行-法拉利無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '台新銀行-@GoGo iCash御璽卡'],
#  104: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-玉山世界卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '美國運通-簽帳金卡'],
#  105: ['國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  106: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  107: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  108: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-玉山世界卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '美國運通-簽帳金卡'],
#  109: ['台新銀行-@GoGo iCash御璽卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-晶緻卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡'],
#  110: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡',
#   '永豐銀行-現金回饋卡'],
#  111: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-晶緻卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  112: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  113: ['國泰世華-遠東SOGO悠遊聯名卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '美國運通-長榮航空簽帳金卡',
#   '臺灣銀行-導盲犬認同卡',
#   '中國信託-寰遊美國運通卡',
#   '新光銀行-魔法少女一卡通鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台北富邦-J卡',
#   '玉山銀行-eTag悠遊聯名卡',
#   '中國信託-LINE Pay卡'],
#  114: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-FlyGo卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-U Bear信用卡'],
#  115: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  116: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '聯邦銀行-賴點一卡通御璽卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-玉山Only卡'],
#  117: ['玉山銀行-U Bear信用卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '玉山銀行-玉山Only卡',
#   '彰化銀行-商旅御璽卡',
#   '台新銀行-台新街口聯名卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '凱基銀行-中國人壽聯名卡'],
#  118: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '聯邦銀行-賴點一卡通御璽卡'],
#  119: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-世界卡',
#   '永豐銀行-現金回饋卡'],
#  120: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '聯邦銀行-賴點一卡通御璽卡',
#   '安泰銀行-鈦金卡',
#   '元大銀行-鑽金卡'],
#  121: ['台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '聯邦銀行-賴點一卡通御璽卡',
#   '台新銀行-FlyGo卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-玉山Only卡',
#   '凱基銀行-中國人壽聯名卡'],
#  122: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡'],
#  123: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '台北富邦-數位生活卡'],
#  124: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  125: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  126: ['凱基銀行-現金回饋鈦金卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '陽信銀行-一卡通聯名鈦金卡',
#   '安泰銀行-鈦金卡',
#   '聯邦銀行-法拉利無限卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-iCash聯名卡'],
#  127: ['中國信託-Yahoo聯名卡',
#   '美國運通-簽帳金卡',
#   '台新銀行-遠傳friDay聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-玉山世界卡',
#   '聯邦銀行-全國加油聯名卡',
#   '彰化銀行-商旅御璽卡',
#   '星展銀行-飛行世界卡'],
#  128: ['兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-世界卡',
#   '第一銀行-icash聯名卡',
#   '彰化銀行-商旅御璽卡',
#   '凱基銀行-無限卡'],
#  129: ['中國信託-秀泰聯名卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '台新銀行-FlyGo卡',
#   '凱基銀行-無限卡'],
#  130: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-鈦金卡',
#   '上海商銀-小小兵Bello回饋卡',
#   '玉山銀行-U Bear信用卡',
#   '國泰世華-鈦金商務卡',
#   '上海商銀-簡單卡',
#   '玉山銀行-玉山Only卡',
#   '玉山銀行-商務御璽卡'],
#  131: ['台新銀行-@GoGo iCash御璽卡',
#   '彰化銀行-商旅御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-遠東SOGO悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '星展銀行-飛行世界卡',
#   '中國信託-寰遊美國運通卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  132: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  133: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-晶緻卡',
#   '聯邦銀行-法拉利無限卡',
#   '彰化銀行-商旅御璽卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  134: ['國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-商務御璽卡',
#   '中國信託-LINE Pay卡',
#   '美國運通-簽帳金卡',
#   '中國信託-Yahoo聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  135: ['玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡'],
#  136: ['台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-U Bear信用卡',
#   '台北富邦-數位生活卡',
#   '安泰銀行-晶緻卡',
#   '凱基銀行-無限卡'],
#  137: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '聯邦銀行-全國加油聯名卡',
#   '美國運通-簽帳金卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-鈦豐卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡'],
#  138: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '匯豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡'],
#  139: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '中國信託-Yahoo聯名卡'],
#  140: ['安泰銀行-鈦金卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-商務御璽卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '美國運通-簽帳金卡',
#   '中國信託-Yahoo聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡'],
#  141: ['國泰世華-尊榮御璽卡',
#   '新光銀行-義大世界聯名卡',
#   '上海商銀-TeresaCard',
#   '永豐銀行-保倍卡',
#   '元大銀行-指定卡',
#   '新光銀行-Lamigo信用卡',
#   '中國信託-寰遊美國運通卡',
#   '渣打銀行-TheShoppingCard分期卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-飛行世界卡'],
#  142: ['國泰世華-鈦金商務卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-晶緻卡',
#   '彰化銀行-商旅御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  143: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '中國信託-酷玩卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  144: ['中國信託-Yahoo聯名卡',
#   '美國運通-簽帳金卡',
#   '台新銀行-遠傳friDay聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-玉山世界卡',
#   '聯邦銀行-全國加油聯名卡',
#   '彰化銀行-商旅御璽卡',
#   '星展銀行-飛行世界卡'],
#  145: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-U Bear信用卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '凱基銀行-無限卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  146: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-一卡通聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '國泰世華-鈦金商務卡'],
#  147: ['台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-U Bear信用卡'],
#  148: ['兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-商務御璽卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-玉山世界卡',
#   '中國信託-LINE Pay卡',
#   '中國信託-Yahoo聯名卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '台新銀行-@GoGo iCash御璽卡'],
#  149: ['凱基銀行-無限卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-玉山世界卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-商務御璽卡',
#   '臺灣銀行-鈦金商旅卡'],
#  150: ['兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡',
#   '凱基銀行-無限卡',
#   '永豐銀行-保倍卡',
#   '安泰銀行-晶緻卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  151: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡'],
#  152: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '上海商銀-TeresaCard',
#   '玉山銀行-公務人員國民旅遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡'],
#  153: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  154: ['國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-玉山世界卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  155: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡'],
#  156: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '華南銀行-i網購生活卡'],
#  157: ['兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-玉山世界卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '第一銀行-Wonderful星璨卡',
#   '第一銀行-icash聯名卡'],
#  158: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '安泰銀行-鈦金卡'],
#  159: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '安泰銀行-鈦金卡'],
#  160: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  161: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  162: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  163: ['玉山銀行-公務人員國民旅遊卡',
#   '上海商銀-TeresaCard',
#   '兆豐銀行-e秒刷鈦金卡',
#   '彰化銀行-商旅御璽卡',
#   '星展銀行-飛行世界卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-玉山Only卡',
#   '玉山銀行-商務御璽卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '台新銀行-@GoGo iCash御璽卡'],
#  164: ['凱基銀行-無限卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-玉山世界卡',
#   '中國信託-LINE Pay卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '中國信託-Yahoo聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  165: ['凱基銀行-無限卡',
#   '兆豐銀行-世界卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-晶緻卡',
#   '台北富邦-IMPERIAL尊御世界卡',
#   '玉山銀行-商務御璽卡',
#   '中國信託-LINE Pay卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '中國信託-Yahoo聯名卡'],
#  166: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台中商銀-JCB哆啦A夢晶緻卡'],
#  167: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '台新銀行-FlyGo卡'],
#  168: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  169: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡'],
#  170: ['台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '台新銀行-FlyGo卡'],
#  171: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '台新銀行-FlyGo卡'],
#  172: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  173: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡',
#   '永豐銀行-現金回饋卡'],
#  174: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  175: ['中國信託-LINE Pay卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-世界卡',
#   '美國運通-新加坡航空天宇信用卡',
#   '台新銀行-ETC聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '中國信託-學學認同卡',
#   '台新銀行-台新財富無限卡'],
#  176: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  177: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-玉山世界卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  178: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  179: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  180: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  181: ['匯豐銀行-現金回饋御璽卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '永豐銀行-現金回饋卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '陽信銀行-一卡通聯名鈦金卡',
#   '臺灣銀行-鈦金商旅卡',
#   '兆豐銀行-世界卡'],
#  182: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '台新銀行-FlyGo卡'],
#  183: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  184: ['凱基銀行-無限卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '聯邦銀行-法拉利無限卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-商務御璽卡'],
#  185: ['台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-世界卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '凱基銀行-無限卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡'],
#  186: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '中國信託-鼎極卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡'],
#  187: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '凱基銀行-無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-世界卡'],
#  188: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-商務御璽卡',
#   '元大銀行-鑽金卡'],
#  189: ['台新銀行-@GoGo iCash御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡'],
#  190: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '國泰世華-鈦金商務卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡'],
#  191: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '匯豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-保倍卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  192: ['玉山銀行-U Bear信用卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-商務御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡'],
#  193: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '玉山銀行-玉山世界卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '玉山銀行-商務御璽卡'],
#  194: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  195: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '新光銀行-Lamigo信用卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  196: ['國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '中國信託-LINE Pay卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-商務御璽卡',
#   '中國信託-Yahoo聯名卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台北富邦-富邦悍將悠遊聯名卡'],
#  197: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  198: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-晶緻卡',
#   '臺灣企銀-悠遊聯名卡'],
#  199: ['中國信託-LINE Pay卡',
#   '凱基銀行-無限卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '中國信託-學學認同卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡'],
#  200: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  201: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '凱基銀行-無限卡'],
#  202: ['兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡'],
#  203: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-eTag悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡'],
#  204: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡'],
#  205: ['國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡'],
#  206: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-玉山世界卡'],
#  207: ['安泰銀行-鈦金卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '星展銀行-飛行世界卡',
#   '聯邦銀行-法拉利無限卡'],
#  208: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  209: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-晶緻卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-世界卡',
#   '臺灣企銀-悠遊聯名卡',
#   '凱基銀行-無限卡'],
#  210: ['兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '國泰世華-鈦金商務卡'],
#  211: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡'],
#  212: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  213: ['台新銀行-@GoGo iCash御璽卡',
#   '凱基銀行-無限卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-商務御璽卡',
#   '中國信託-鼎極卡'],
#  214: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  215: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  216: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '凱基銀行-無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '中國信託-Yahoo聯名卡'],
#  217: ['台新銀行-@GoGo iCash御璽卡',
#   '兆豐銀行-世界卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡'],
#  218: ['玉山銀行-玉山世界卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-商務御璽卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-LINE Pay卡',
#   '中國信託-鼎極卡',
#   '臺灣銀行-鈦金商旅卡',
#   '聯邦銀行-法拉利無限卡',
#   '星展銀行-飛行世界卡'],
#  219: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡'],
#  220: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡'],
#  221: ['凱基銀行-無限卡',
#   '兆豐銀行-世界卡',
#   '台北富邦-IMPERIAL尊御世界卡',
#   '中國信託-鼎極卡',
#   '中國信託-Yahoo聯名卡',
#   '台新銀行-ETC聯名卡',
#   '中國信託-LINE Pay卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-公務人員國民旅遊卡'],
#  222: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  223: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '彰化銀行-商旅御璽卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡'],
#  224: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '台北富邦-J卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '安泰銀行-鈦金卡'],
#  225: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡'],
#  226: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '國泰世華-鈦金商務卡',
#   '兆豐銀行-世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  227: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-晶緻卡',
#   '匯豐銀行-現金回饋御璽卡'],
#  228: ['台新銀行-@GoGo iCash御璽卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-玉山世界卡',
#   '國泰世華-鈦金商務卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '美國運通-簽帳金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡'],
#  229: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  230: ['國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '台北富邦-富邦悍將悠遊聯名卡'],
#  231: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台北富邦-財神卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '美國運通-長榮航空簽帳金卡'],
#  232: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '台新銀行-FlyGo卡',
#   '星展銀行-炫晶御璽卡',
#   '永豐銀行-現金回饋卡'],
#  233: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  234: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  235: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  236: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  237: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-世界卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡'],
#  238: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  239: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡'],
#  240: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  241: ['國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-幸運鈦金卡',
#   '第一銀行-Wonderful星璨卡',
#   '彰化銀行-商旅御璽卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '台北富邦-鑽保卡',
#   '彰化銀行-JCB悠遊晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-PChome Prime聯名卡'],
#  242: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '台北富邦-J卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '國泰世華-遠東SOGO悠遊聯名卡'],
#  243: ['國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-玉山世界卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  244: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  245: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡'],
#  246: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-icash聯名卡'],
#  247: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '台新銀行-FlyGo卡'],
#  248: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  249: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  250: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  251: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  252: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
# ...
#   '安泰銀行-鈦金卡'],
#  916: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  917: ['中國信託-LINE Pay卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '兆豐銀行-世界卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡'],
#  918: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '上海商銀-簡單卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-統一7-ELEVEn獅聯名卡',
#   '臺灣銀行-鈦金商旅卡',
#   '兆豐銀行-Gogoro 聯名卡'],
#  919: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '安泰銀行-鈦金卡',
#   '匯豐銀行-現金回饋御璽卡',
#   '兆豐銀行-世界卡',
#   '臺灣企銀-悠遊聯名卡'],
#  920: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  921: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '匯豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  922: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '台北富邦-數位生活卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  923: ['國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-幸運鈦金卡',
#   '第一銀行-Wonderful星璨卡',
#   '彰化銀行-商旅御璽卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '台北富邦-鑽保卡',
#   '彰化銀行-JCB悠遊晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-PChome Prime聯名卡'],
#  924: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '兆豐銀行-世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '陽信銀行-一卡通聯名鈦金卡',
#   '聯邦銀行-法拉利無限卡',
#   '元大銀行-鑽金卡',
#   '台中商銀-JCB哆啦A夢晶緻卡'],
#  925: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  926: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台北富邦-數位生活卡'],
#  927: ['中國信託-LINE Pay卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡',
#   '國泰世華-鈦金商務卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡'],
#  928: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '新光銀行-Lamigo信用卡',
#   '台新銀行-FlyGo卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '台新銀行-ETC聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  929: ['凱基銀行-無限卡',
#   '聯邦銀行-法拉利無限卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '國泰世華-鈦金商務卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '元大銀行-鑽金卡',
#   '永豐銀行-現金回饋卡'],
#  930: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  931: ['兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-LINE Pay卡',
#   '中國信託-Yahoo聯名卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-鈦金卡',
#   '中國信託-學學認同卡',
#   '中國信託-鼎極卡'],
#  932: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡'],
#  933: ['兆豐銀行-世界卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-Yahoo聯名卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-商務御璽卡',
#   '美國運通-簽帳金卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '中國信託-鼎極卡',
#   '臺灣企銀-悠遊聯名卡'],
#  934: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  935: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡'],
#  936: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-晶緻卡'],
#  937: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  938: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '永豐銀行-現金回饋卡'],
#  939: ['安泰銀行-鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '第一銀行-Wonderful星璨卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '渣打銀行-優先理財無限卡',
#   '台新銀行-遠傳friDay聯名卡',
#   '兆豐銀行-世界卡',
#   '星展銀行-飛行世界卡'],
#  940: ['安泰銀行-鈦金卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-世界卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '凱基銀行-無限卡',
#   '元大銀行-鑽金卡',
#   '新光銀行-Lamigo信用卡',
#   '彰化銀行-商旅御璽卡'],
#  941: ['花旗銀行-PChome Prime聯名卡',
#   '安泰銀行-晶緻卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '永豐銀行-現金回饋卡',
#   '聯邦銀行-法拉利無限卡',
#   '國泰世華-鈦金商務卡',
#   '元大銀行-鑽金卡'],
#  942: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '凱基銀行-無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡'],
#  943: ['凱基銀行-無限卡',
#   '國泰世華-鈦金商務卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-商務御璽卡',
#   '玉山銀行-玉山世界卡',
#   '聯邦銀行-法拉利無限卡',
#   '臺灣銀行-鈦金商旅卡',
#   '台中商銀-JCB哆啦A夢晶緻卡',
#   '凱基銀行-現金回饋鈦金卡'],
#  944: ['台新銀行-@GoGo iCash御璽卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '國泰世華-鈦金商務卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  945: ['永豐銀行-DAWHO現金回饋信用卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '聯邦銀行-賴點一卡通御璽卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '凱基銀行-中國人壽聯名卡',
#   '兆豐銀行-e秒刷鈦金卡'],
#  946: ['花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡'],
#  947: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '永豐銀行-DAWHO現金回饋信用卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '合作金庫-漢來美食聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '安泰銀行-鈦金卡'],
#  948: ['凱基銀行-無限卡',
#   '美國運通-簽帳金卡',
#   '玉山銀行-玉山世界卡',
#   '中國信託-LINE Pay卡',
#   '台北富邦-富邦悍將悠遊聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '中國信託-Yahoo聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '凱基銀行-現金回饋鈦金卡'],
#  949: ['合作金庫-漢來美食聯名卡',
#   '新光銀行-寰宇現金回饋卡',
#   '臺灣銀行-鈦金商旅卡',
#   '星展銀行-飛行世界卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  950: ['凱基銀行-現金回饋鈦金卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '中國信託-LINE Pay卡',
#   '臺灣銀行-鈦金商旅卡',
#   '彰化銀行-商旅御璽卡',
#   '凱基銀行-無限卡',
#   '國泰世華-遠東SOGO悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-@GoGo iCash御璽卡'],
#  951: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  952: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '凱基銀行-現金回饋鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '上海商銀-簡單卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-統一7-ELEVEn獅聯名卡',
#   '臺灣銀行-鈦金商旅卡',
#   '兆豐銀行-Gogoro 聯名卡'],
#  953: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  954: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  955: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-晶緻卡'],
#  956: ['國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '元大銀行-鑽金一卡通聯名卡',
#   '台新銀行-燦坤生活聯名卡',
#   '中國信託-紅利御璽卡',
#   '第一銀行-一卡通聯名卡',
#   '臺灣銀行-導盲犬認同卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  957: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  958: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '凱基銀行-無限卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡'],
#  959: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  960: ['元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '臺灣企銀-悠遊聯名卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡',
#   '凱基銀行-無限卡'],
#  961: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '第一銀行-Wonderful星璨卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡'],
#  962: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '元大銀行-鑽金卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '中國信託-鼎極卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  963: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡'],
#  964: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  965: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡'],
#  966: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  967: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-公務人員國民旅遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '上海商銀-簡單卡'],
#  968: ['台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡'],
#  969: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  970: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡'],
#  971: ['台新銀行-@GoGo iCash御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '台北富邦-數位生活卡'],
#  972: ['台新銀行-@GoGo iCash御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '台新銀行-FlyGo卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台北富邦-數位生活卡'],
#  973: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  974: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '元大銀行-鑽金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡'],
#  975: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  976: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '彰化銀行-商旅御璽卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '元大銀行-鑽金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-鈦金卡'],
#  977: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  978: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-U Bear信用卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡'],
#  979: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡'],
#  980: ['中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '安泰銀行-晶緻卡',
#   '兆豐銀行-世界卡',
#   '臺灣企銀-悠遊聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-商務御璽卡',
#   '凱基銀行-無限卡',
#   '美國運通-簽帳金卡',
#   '永豐銀行-現金回饋卡'],
#  981: ['國泰世華-KOKO COMBO icash聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡',
#   '第一銀行-icash聯名卡'],
#  982: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '凱基銀行-無限卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '玉山銀行-玉山世界卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-商務御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡'],
#  983: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '安泰銀行-鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '彰化銀行-商旅御璽卡',
#   '第一銀行-Wonderful星璨卡',
#   '兆豐銀行-世界卡',
#   '凱基銀行-無限卡'],
#  984: ['台新銀行-@GoGo iCash御璽卡',
#   '台新銀行-燦坤生活聯名卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '第一銀行-icash聯名卡',
#   '台新銀行-ETC聯名卡'],
#  985: ['台新銀行-@GoGo iCash御璽卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-鈦金卡'],
#  986: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  987: ['國泰世華-KOKO COMBO icash聯名卡',
#   '玉山銀行-幸運鈦金卡',
#   '第一銀行-Wonderful星璨卡',
#   '彰化銀行-商旅御璽卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '台北富邦-鑽保卡',
#   '彰化銀行-JCB悠遊晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '花旗銀行-PChome Prime聯名卡'],
#  988: ['台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '元大銀行-鑽金卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '永豐銀行-現金回饋卡',
#   '安泰銀行-晶緻卡',
#   '玉山銀行-玉山世界卡',
#   '台新銀行-FlyGo卡'],
#  989: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '永豐銀行-現金回饋卡'],
#  990: ['國泰世華-鈦金商務卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-世界卡',
#   '安泰銀行-鈦金卡',
#   '安泰銀行-晶緻卡',
#   '凱基銀行-無限卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '永豐銀行-現金回饋卡'],
#  991: ['陽信銀行-曜晶卡',
#   '台新銀行-玫瑰卡',
#   '台新銀行-昇恆昌聯名卡',
#   '台新銀行-太陽卡',
#   '台新銀行-國泰航空鈦金卡',
#   '台新銀行-國泰航空翱翔鈦金卡',
#   '台新銀行-商務卡',
#   '台新銀行-台新財富無限卡',
#   '台新銀行-台新街口聯名卡',
#   '台新銀行-全家Fish悠遊聯名卡'],
#  992: ['中國信託-LINE Pay卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '台新銀行-FlyGo卡',
#   '永豐銀行-現金回饋卡',
#   '第一銀行-icash聯名卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '臺灣企銀-悠遊聯名卡',
#   '安泰銀行-鈦金卡',
#   '兆豐銀行-世界卡'],
#  993: ['國泰世華-雙幣卡',
#   '聯邦銀行-理財型白金卡',
#   '中國信託-MUJI無印良品聯名卡',
#   '王道銀行-簽帳金融卡',
#   '聯邦銀行-微風聯名卡',
#   '玉山銀行-雙幣信用卡',
#   '中國信託-秀泰聯名卡',
#   '玉山銀行-南山悠遊聯名卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡'],
#  994: ['中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '第一銀行-icash聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  995: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '臺灣企銀-悠遊聯名卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '台新銀行-FlyGo卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '新光銀行-Lamigo信用卡',
#   '永豐銀行-現金回饋卡',
#   '玉山銀行-Pi 拍錢包信用卡'],
#  996: ['中國信託-LINE Pay卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '台新銀行-FlyGo卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '第一銀行-icash聯名卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡',
#   '台北富邦-數位生活卡',
#   '安泰銀行-鈦金卡'],
#  997: ['玉山銀行-eTag悠遊聯名卡',
#   '上海商銀-小小兵Bello回饋卡',
#   '台新銀行-@GoGo iCash御璽卡',
#   '聯邦銀行-理財型白金卡',
#   '國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '中國信託-MUJI無印良品聯名卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '中國信託-秀泰廣場影城聯名卡'],
#  998: ['台新銀行-@GoGo iCash御璽卡',
#   '中國信託-LINE Pay卡',
#   '元大銀行-鑽金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '兆豐銀行-e秒刷鈦金卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '永豐銀行-現金回饋卡',
#   '台新銀行-FlyGo卡'],
#  999: ['國泰世華-KOKO COMBO icash聯名卡',
#   '中國信託-LINE Pay卡',
#   '台新銀行-FlyGo卡',
#   '元大銀行-鑽金卡',
#   '花旗銀行-新世代花旗饗樂生活悠遊卡',
#   '滙豐銀行-現金回饋御璽卡',
#   '玉山銀行-Pi 拍錢包信用卡',
#   '安泰銀行-鈦金卡',
#   '臺灣企銀-悠遊聯名卡',
#   '永豐銀行-現金回饋卡'],
#  ...}

# %%
#calculate TopN

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=2, _1=0, _2=0, _3=1, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=1, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=1, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=3, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=4, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=1, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=5, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=6, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=1, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=7, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=1, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=8, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=9, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=1, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=10, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=1, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=11, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=1, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=1, _135=0, _136=1, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=12, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=1, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=1, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=13, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=1, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=14, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=1, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=15, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=1, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=1, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=1, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=16, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=1, _88=0, _89=0, _90=0, _91=0, _92=1, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=17, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=1, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=18, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=19, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=20, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=1, _180=0)
# Pandas(Index=21, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=1, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=22, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=1, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=23, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=1, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=1, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=1, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=1, _102=1, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=1, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=24, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=25, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=26, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=27, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=1, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=1, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=28, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=1, _105=0, _106=0, _107=0, _108=0, _109=0, _110=1, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=29, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=1, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=1, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=30, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=1, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=31, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=1, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=1, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=32, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=1, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=1, _72=0, _73=0, _74=1, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=33, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=1, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=34, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# ...
# Pandas(Index=1434, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1435, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=1, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1436, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=1, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=1, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1437, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=1, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1438, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1439, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1440, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1441, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=1, _71=1, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=1, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1442, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1443, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=0, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=1, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=0, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=0, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=1, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=0, _118=0, _119=0, _120=0, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# Pandas(Index=1444, _1=0, _2=0, _3=0, _4=0, _5=0, _6=0, _7=1, _8=0, _9=0, _10=0, _11=0, _12=0, _13=0, _14=0, _15=0, _16=0, _17=0, _18=0, _19=0, _20=0, _21=0, _22=0, _23=0, _24=0, _25=0, _26=0, _27=0, _28=0, _29=0, _30=0, _31=0, _32=0, _33=0, _34=0, _35=0, _36=0, _37=0, _38=0, _39=0, _40=0, _41=0, _42=0, _43=0, _44=0, _45=0, _46=0, _47=0, _48=0, _49=0, _50=0, _51=0, _52=0, _53=0, _54=0, _55=0, _56=0, _57=0, _58=0, _59=0, _60=0, _61=1, _62=0, _63=0, _64=0, _65=0, _66=0, _67=0, _68=0, _69=0, _70=0, _71=1, _72=0, _73=0, _74=0, _75=0, _76=0, _77=0, _78=0, _79=0, _80=0, _81=0, _82=0, _83=0, _84=0, _85=0, _86=0, _87=0, _88=0, _89=0, _90=0, _91=0, _92=0, _93=0, _94=0, _95=0, _96=0, _97=0, 合庫JCB哆啦A夢=0, _99=0, _100=0, _101=0, _102=0, _103=0, _104=0, _105=0, _106=0, _107=0, _108=0, _109=0, _110=0, _111=0, _112=0, _113=0, _114=0, _115=0, _116=0, _117=1, _118=0, _119=0, _120=1, _121=0, _122=0, _123=0, _124=0, _125=0, _126=0, _127=0, _128=0, _129=0, _130=0, _131=0, _132=0, _133=0, _134=0, _135=0, _136=0, _137=0, _138=0, _139=0, _140=0, _141=0, _142=0, _143=0, _144=0, _145=0, _146=0, _147=0, _148=0, _149=0, _150=0, _151=0, _152=0, _153=0, _154=0, _155=0, _156=0, _157=0, _158=0, _159=0, _160=0, _161=0, _162=0, _163=0, _164=0, _165=0, _166=0, _167=0, _168=0, _169=0, _170=0, _171=0, _172=0, _173=0, _174=0, _175=0, _176=0, _177=0, _178=0, _179=0, _180=0)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
reader = Reader(rating_scale=(0.5, 5))
data = Dataset.load_from_df(df[['userId', 'title', 'rating']], reader)
trainSet, testSet = train_test_split(data, test_size=.25, random_state=0)
algo = SVD(random_state=0)
algo.fit(trainSet)
predictions = algo.test(testSet)

def MAE(predictions):
        return accuracy.mae(predictions, verbose=False)
def RMSE(predictions):
        return accuracy.rmse(predictions, verbose=False)
    
print("RMSE: ", RMSE(predictions))
print("MAE: ", MAE(predictions))

# %%
SVD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7db4305ad58e> in <module>
# ----> 1 SVD
#
# NameError: name 'SVD' is not defined
