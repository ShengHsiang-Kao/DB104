# %%
import pandas as pd
import json
import re
import pymongo
import jieba
import operator
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
import string
from sklearn.decomposition import LatentDirichletAllocation as LDA
from gensim import corpora, models, similarities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-88e5f8a0311b> in <module>
#      10 import string
#      11 from sklearn.decomposition import LatentDirichletAllocation as LDA
# ---> 12 from gensim import corpora, models, similarities
#
# ModuleNotFoundError: No module named 'gensim'

# %%
#連接 mongodb

client = pymongo.MongoClient(host='123.241.175.34', port=27017)
#mongodb帳號密碼

client.admin.authenticate('root', '1qaz@WSX3edc')
# Out:
# True

# %%
#設定名稱為test的資料庫 也可用 db = client['test']
client.database_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
# ['ETL', 'admin', 'config', 'local', 'raw_article', 'test']

# %%
db_ETL=client.ETL

# %%
#顯示db中所有collections
db_ETL.list_collection_names()
# Out:
# ['article_tag_soc',
#  'article_tag_news',
#  'article_news_seg',
#  'article_tag_web',
#  'article_web_seg',
#  'article_social_seg']

# %%
article_social=db_ETL.article_social_seg.find()
article_web=db_ETL.article_web_seg.find()
article_news=db_ETL.article_news_seg.find()

# %%
df_article_social=pd.DataFrame(list(article_social))
df_article_web=pd.DataFrame(list(article_web))
df_article_news=pd.DataFrame(list(article_news))

# %%
article_social_seg=df_article_social['seg']
article_web_seg=df_article_web['seg']
article_news_seg=df_article_news['seg']

# %%
tf_article=[]
punc="!#$%&\'()*+,-./:;<=>?@，。?～（｜＋★▉、＝…\ ●【】《》 ）＊？“”‘’！[\\]^_`{|}~]+'\#"
gar=['\\t','\n','\t ']
for i in range(len(article_web_seg)):
    word=''
    for w  in article_web_seg[i]:
        if w not in punc and gar:
            word+=w+' '
    tf_article.append(word)

# %%
tf_article[:10]
# Out:
# ['玉山 Pi 拍錢包 信用卡 國內 4.5% 海外 3% 繳稅 1% 持續 坐 穩神 卡寶座 May16Thu201923 12 玉山 Pi 拍錢包 信用卡 國內 4.5% 海外 3% 繳稅 1% 持續 坐 穩神 卡寶座 玉山 Pi 拍錢包 信用卡 從 去年 三季 推出 除了 基本 回饋 最高 4.5% 繳水電 也 有 回饋 的 強大 優勢 且 卡片 限定 短期 優惠 也 能 有效 提升 動卡率 讓 人 感覺 銀行 十足 誠 意在 經營 這張 卡片 也 因此 這 一年 來 討論度 不降反升 熱度 依舊 不管 到 哪個 信用卡 的 論壇 搜尋關鍵 字 每天 都 有人 在 分享 Pi 拍錢包 信用卡 分享 數多到 要 花 好 幾個 小時 消化 完 這張 卡 也 成為 我 跟 讀者 私訊 討論 次數 最 多 的 卡片 前 五名 有 網友 曾經 跟 我 討論 到 半夜 兩點 這個 經驗 真的 Neveragain 由 於 Pi 拍錢包 信用卡 也 是 我 今年 上半年 的 愛用 卡 之一 我會 透過 這 篇文章 整合 卡片 特性 使用 經驗 跟 評價 依序 幫 大家 整理 幾個 重點 ： 玉山 Pi 拍錢包 信用卡 是 什麼 什麼 類型 的 人 申辦 申辦 前須 知道 的 重要 事項 玉山 Pi 拍錢包 信用卡 重點 權益 近期 超強勢 必用 回饋 點數 折抵 攻略 Pi 拍錢包 信用卡 是 一張 主打 點數 回饋 的 卡片 回饋 的 幣別 叫做 Ｐ 幣的 有 價點數 而 1 點 P 幣 1 元現 金 點數 可以 在 指定 特約 店家 折 抵消 費 有 的 人覺 得 還是 現金回饋 更 直接 實用 但 Pi 拍錢包 合作 的 店家 有 非常 多 知名 連鎖 品牌 並且 吃喝 玩樂 都 有 兼 顧到 因此 能 折抵 的 機會 很多 有 的 人 覺得點 數折 抵消 費很麻煩 近期 上線 的 新 功能 「 拍 享券 」 能 幫助 卡友 輕 鬆 折抵 這個 新 功能 我 在 文章 後 面一點 會 提到 如果 覺得 點數 兌換 很 麻煩 一定 要 了解 這個 功能 Pi 拍錢包 信用卡 卡面 設計 有 四個 顏色 通常 較 多 人會 選擇 申辦 藍色 的 卡面 因為 有 附加 悠遊卡 的 功能 我 都 帶 著 這張 卡去 超商 消費 或 搭捷 運公車 再者 我 推薦 黑色 霧面 的 卡面 我 老公 是 持有 這張 卡面 很 耐看 許多人 申辦 信用卡 總會 擔心 核卡 速度 特別 是 急 著要 用 卡 真的 無法 等待 銀行 作業 流程 但 玉山 Pi 拍錢包 信用卡 的 核卡 速度 很快 我 跟 我 先生 不同 時間 送件 都 在 一週 左右 完成 核卡 有 的 網友 更 光速 送件 到 收到 核卡 簡訊 只要 ２ 天 對 於 急性子 的 人來 說 真的 很加分 貼心 提醒 ： 今年 刷 玉山 Pi 拍錢包 信用卡 繳稅 能享 1% P 幣回饋 ‧ 如果 你 尚未 繳稅 的 話 也 可以 現在線 上 申辦 或許 還來 得 及 在 06.02 前 收到 喔 申辦 前 一定 先 點此 下載 Pi 拍錢包 APP 了解 介面 也 很 好 操作 也 可 看 完整 的 優惠 列表 而且 申辦 後 一定 一定 移地 要 綁定 告訴 你 們 綁定 為 什麼 超 重要 我們 同步 來 看 玉山 Pi 拍錢包 信用卡 常態 權益 基本 一般 消費 ： 享 2.5% P 幣回饋 用 APP 綁定 後 回饋 ： 加碼 到 3.5% 回饋 小 提醒 ： 沒有 下載 綁定 的 話 到 全家 萊爾富 超商 消費 不會 有 回饋 連 基本 2.5% 都 沒 有 所以 一定 要 綁定 喔 繳水費 ： 享 3.5% 回饋 是 網友 力 讚 的 優 惠 之一 超級 推薦 外宿 族 或 一般 家庭 申辦 繳納 跟 折抵 另為 今年 雖然 繳電費 無 回饋 但 可以 用 Ｐ 幣 折抵 唷 指定 通路 用 Pi 拍錢包 付款 ： 享 4.5% P 幣回饋 如果 選用 同時 進行 付款 跟 折抵 的 通路 省錢 很 有感 又 方便 例如 我 每周 都 有 搭 計程車 的 需求 選台灣 大車隊 有 4.5% 下次 搭乘 可以 直接 扣抵 除了 上面 的 常態性 權益 外 五月份 推出 的 限定 限時 優惠 也 很 吸引 人 繳綜所 稅享 1% 回饋 2019.05 01 06.02 一次 付清 綜所 稅享 １ P 幣回饋 需登錄 回饋 上限 2 000P 幣 表示 稅額 20 萬以 內 都 可以
#  '信用卡 2019 海外 刷卡 消費 現金回饋 必備 推薦 TOP 7 手續費 優惠 選卡 小 技巧 Jul13Fri201816 23 信用卡 2019 海外 刷卡 消費 現金回饋 必備 推薦 TOP7 手續費 優惠 選卡 小 技巧 到 國外 旅遊 除了 換好 當地 的 幣值 現金 Renee 一定 會帶 3 張 信用卡 讓 消費時 更 便利 帶 對 信用卡 不 只 可以 減少 匯差 帶來 的 損失 甚至 可以 再 賺取 現金回饋 喔 選擇 出國 使用 的 信用卡 2 個 TIPS ： 注意 國際 組織 ： 台灣 主要 的 發卡 組織 有 VISA MasterCard JCB 三家 到 不同 國家 適用 不同 的 卡片 ： 日本 韓國 一定 要 帶 JCB 不僅 刷卡 方便 JCB 也 有 提供 額外 的 優惠 比方 說 指定 景點 門票 再享 折扣 歐美 非洲 建議 帶 VISA MasterCard 至少 各帶 一張 JCB 則不 一定 要 帶 因為 像 非洲 就 較 無法 辨識 JCB 卡片 容易 刷不過 注意 卡片 回饋 ： 由 於 到 國外 刷卡 消費 會先 扣除 1.5% 的 手續費 建議 攜帶 卡片 回饋 超過 1.5% 可 抵銷 手續費 若 希望 有 被 回饋 建議 選擇 國外 消費 回饋 有 2% 以上 的 信用卡 建議 的 信用卡 ： Renee 接下 來 會 根據 不同 需求 與 族群 建議 合適 的 信用卡 ： 國內外 消費 回饋 都 很 高 的 信用卡 匯豐 現金回饋 信用卡 現金回饋 國內 1.22% 國外 2.22% 無 上限 年費 正卡 2 000 元 附卡免 年費 \t \t \t 新戶 首年 免年費 申請 電子 帳單 期間 免年費 消費 12 次 或 金額 達 15 萬 適用 族群 有大額 消費者 試用 最新 優惠 兌換 哩程 或 轉換 4 大 電商 購物金 會員點數 最 優加碼 20% 點此 看 本季 最新 優惠 適 用活 動 新戶 申辦 永豐 大戶 銀行 信用卡 現金回饋 國內 1 ％ 國外 2 ％ 無 上限 搭配 加碼 方案 最高 享 8% 回饋 年費 正卡 3 000 元 附卡 1 500 元 \t \t \t 首年 免年費 申請 電子 帳單 期間 免年費 消費 12 次 或 金額 達 15 萬 適用 族群 有 使用 大戶 數位帳戶 者 最新 優惠 新戶 申辦 核卡 後 30 天內 刷 一般 消費 3 筆 599 元 含 以上 享 500 元 刷卡 金回饋 影 點此 看 2019 年 上半年 推薦 必備 信用卡 中國信託 商旅 鈦 金 信用卡 現金回饋 國內 1% 國外 2.5% 回饋 無 上限 年費 免年費 ： 首年 免年費 申請 電子 帳單 期間 免年費 適用 族群 年收入 達 20 萬 以上 最新 優惠 繳稅 學費 水電 瓦斯 0.3% 機場 接送 ２ 次 星展銀行 炫晶御璽卡 現金回饋 國內 1.2% 國外 2.5% 年費 正卡 3 000 元 附卡免 年費 \t \t \t 首年 免年費 申請 電子 帳單 期間 免年費 適用 族群 年收入 達 20 萬 以上 最新 優惠 新戶 成功 透過 數位 通路 申辦 星展 炫晶御璽卡 核卡 後 45 天內 累積 消費達 NT 3 000 可享 500 元 刷卡 金 以下 卡片 國外 消費 回饋 高 但須 動腦 留意 門檻 上海銀行 小小兵信用卡 現金回饋 國外 2.234% 國內 1.234% 回饋 上限 3234 元 年費 正卡 1200 元 附卡 600 元 \t \t \t 免年費 ： 首年 免年費 申請 上海銀行 帳戶 扣繳 消費 12 次 隔 年 免年費 適用 族群 喜歡 去 環球 影城 者 愛 出國 旅遊 最新 優惠 核卡 3 個 月 內 新卡友 刷 滿 3 000 元 ； 舊卡友 刷 滿 1 萬 享 限定 小小兵 首刷禮 2 選 1 影 點此 看 2019 年 上半年 推薦 必備 信用卡 台新銀行 FlyGo 信用卡 現金回饋 國內 1.2% 國外 2.8% 需綁定 Richart 帳戶 扣款 年費 正 附卡 4500 適用 族群 有訂 機票 需求者 ／ 有 使用 Richart 帳戶者 最新 優惠 ＞ ＞ 點此 看 最新 活動 ＜ ＜ 華南銀行 享利樂活 Combo 卡 現金回饋 國內 １ ％ 國外 符合 門檻 享 最高 2.5% 年費 正卡 2400 元 附卡免 年費 \t \t \t 首年 免年費 申請 電子 帳單 後 消費 任一 筆 次年 免年費 適用 族群 有 商務 出差 需求者 適合 最新 優惠 指定 稅費免 手續費 看 完 之 後 大家 有 選出 適合 的 卡片 了 嗎 記得 下次 要 掌握 文章 一開始 提到 的 2 個 選卡 TIPS 才能 找到 適合 的 卡片 並且 將優惠用 好 用 滿 喔 ： 提醒 大家 ： 謹慎理財 信用 至上 ',
#  '信用卡 2019 年 出國 刷卡 租借 wifi 分享 器上 網優惠 0508 更新 Jan05Fri201814 58 信用卡 2019 年 出國 刷卡 租借 wifi 分享 器上 網優惠 0508 更新 大家 的 生活 似乎 都 離不開 網路 不論 是 到 國外 洽公還 是 旅遊 租用 網路 分享 器 或是 上 網卡 的 人 這幾年 也 是 日益 漸長 呢 這次 列出 刷卡 租借 wifi 分享 器 的 優惠 建議 大家 租用 前 先試 想過 自己 的 需求 再 搭 配合 適的 刷卡 方案 喔 － － － － － － － － － － － － － － － － － － － － － － － － GLOBALWIFI 地址 ： 台北市 中山北路 二段 96 號 9 樓 N912 室 時間 ： 平日 09 00 18 00 假日 09 00 17 00 連絡 電話 ： 02 2564 1189 點此 預約 出租 優惠 適用 期間 ： 2019 01 01 2019 12 31 銀行 與 活動 內容 中國信託 ： 透過 活動 網頁 享有 日本 吃 到 飽 最低 85 元起 天 \t \t \t 優惠代碼 輸入 「 卡號 前六碼 」 享有 鈦 金 晶 緻 御璽 卡 以上 7 折 其他 卡 等 75 折 ； 免運費 玉山銀 行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 享有 世界 商務御璽 醫師 無限 雙幣 卡 全航線 7 折 其他 卡 等 75 折 ； 寄件 完全 免費 花旗銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 享有 全航線 7 折 寄件 完全 免費 優惠代碼 輸入 『 CITITW 』 享有 日韓 五天 以上 兩天 免費 台新銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 匯豐銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 聯邦銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 永豐銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 元大銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 華南銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 新光銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 兆豐銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 上海銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 星展銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 凱基銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 台北 富邦 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 第一銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 \t \t \t 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 日盛銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 彰化銀行 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費 萬事 達卡 ： 透過 活動 網頁 享有 日本 吃 到 飽 85 元起 天 優惠代碼 輸入 『 卡號 前六碼 』 即享 全航線 75 折 寄件 完全 免費
google ad region " test " google ad client " ca pub 8073120808654621 " google ad host " ca host pub 7449992691305813 " google ad host channel " 1942049901 " google ad slot " 8106458419 " google ad width 300 google ad height 250 google ad region " test " google ad client " ca pub ...
#  '信用卡 被 盜刷 怎麼 處理 如何 防止 遭盜 刷 快 做 這 三件 事補救 Oct12Thu201717 01 信用卡 被 盜刷 怎麼 處理 如何 防止 遭盜 刷 快 做 這 三件 事補救 前 兩天 Renee 接到 收到 一筆 可疑 交易 的 簡訊 馬 上 跟 客服 核對 後 發現 是 卡片 被 試圖 盜用 盜刷 啊 雖然 很 驚訝 但 好 在 事前 事後有 做好 妥善 的 處理 並沒有 讓 小人 盜刷 成功 有感 於 這個 經驗 太 可怕 Renee 趕緊 分享 防盜 刷 必 做 的 四件 事 以及 發現 被 盜 刷 了 該 做 這 三件 事 大家 快 認真 記下 來 喔 事前 ： 防盜 刷 4 件 必須 注意 的 事情 ㄧ 一定 要 常常 對帳 掌握 消費 ： Renee 的 做法 是 ： 1 下載 各銀行 信用卡 的 APP 可以 隨時 查詢 是否 有 可疑 消費 2 一定 一定 一定 要 申請 即 時 消費 通知 例如 簡訊 LINE 通知 二 卡片 資訊 不 外漏 卡片 背面 要 簽名 不要 同時 提供 卡號 授權碼 到期日 等 相關 資訊 也 不要 輕易 在 社群 網站 顯 露出 過多個資 因為 卡片 資訊 其實 也 包含 了 出生年月 日 就 讀 的 國小 例如 參加 小學 同學會 要 注意 不要 輕易將 校名 分享 於 社群 三 完成 消費 一定 要 刪除 信用卡 相關訊息 絕對 不要 儲存 卡片 資料 這點 是 我 曾 經犯 的 錯 我 曾 因為 覺得 方便 以 後 不用 再花 時間 重 複 輸入 卡片 訊息 於 是 在 訂房 網儲存 了 卡片 資訊 雖然 下次 消費 更 有效率 但 也 有 可能 因此 個 資外 洩 四 刷卡 時要 緊 盯 卡片 注意 是否 有人 側錄 或 記下 卡片 的 資料 對 就是 有 這種 小人 隨時 留心 事 後 ： 真 不幸 被 盜 刷 必須 立即 完成 此 三步 驟 一 立刻 打給 客服 立刻 打給 客服 立刻 打給 客服 各家 銀行 客服 專線 發現 有 可疑 消費紀 錄時 要 優先 打給 客服 人員 1 告知 有疑問 的 交易 2 客服 人員會 將此 交易 列為 「 爭議 帳款 」 3 簽立 爭議 帳款 聲明書 二 辦理 信用卡 掛失 被 盜 刷 之 後 舊卡號 基本上 已經 不 安全 了 因此 銀行 協助 辦理 掛失 並且 寄 發新 卡片 三 確認 爭議款 項處 理後續 銀行會 處理爭 議款 項 若證 實為 盜刷 交易 則卡友 就 不 需要 支付 該 筆金額 如若 不 放心 處理 進度 也 記得 要 報警 備案 這樣 會 加速 處理 流程 喔 總 之 也 是 希望 大家 都 不會 被 盜 刷 但現 在 網路 及個 資外 洩 太 猖狂 了 該 注意 的 防範步 驟 還是 一步 都 不要 少 喔 ',
#  '2018 年 請 假 攻略 最高 連休 23 天 台灣 日本 韓國 中國 連假 行事 曆 整理 避開 人潮 輕 鬆 玩 Jun13Tue201722 55 2018 年 請 假 攻略 最高 連休 23 天 台灣 日本 韓國 中國 連假 行事 曆 整理 避開 人潮 輕 鬆 玩 行政院 人事行政 總處 6 5 公布 了 2018 年 行事 曆 表 明年 總 共有 115 個 假日 其中 3 天 以上 的 連假 有 6 個 呢 如果 已經 在 規劃 2018 連假 活動 一定 要 看 Renee 這篇 請 假 攻略 除了 台灣 連假 之外 也 列出 了 日本 韓國 中國 的 2
#  '信用卡 想 剪卡 必知 攻略 簡單 4 步驟 剪卡 不吃 虧 Dec27Tue201613 30 信用卡 想 剪卡 必知 攻略 簡單 4 步驟 剪卡 不吃 虧 又 到 了 年底 要 檢查 皮 夾裡 的 信用卡 們 是否 能繼續 留存 在 身邊 的 殘酷 時刻 了 因為 明 年度 的 最新 權益 出來 有些 新權益 可能 不 符合 自己 的 使用 習慣 了 又 或者 新 發行 的 信用卡 權益 更好 更 適合 申辦 因此 每年 汰 舊換 新 是 非常 必要 的 事 唷 如何 評估 該 剪掉 哪些 卡片 又 該 怎麼 剪 5 分鐘 影音 超簡單 剪卡 4 步驟 教學 Q 首先 什麼 是 剪卡 要 用 剪刀 剪 嗎 A ： 不用 真的 用 剪刀 剪 囉 可以 致電給 銀行 客服 堅定 表達要 剪卡 就 可以 囉 查詢 各家 銀行 客服 電話 如果 覺得 只有 打電話 告知 太無感 用 剪刀 剪 更 有 紓 壓 的 fu 以下 列出 可用 來 剪卡 的 工具 請 斟酌 使用 偏 了 大誤 啊 歡迎 大家 分享 使用 工具 剪卡 心得 又誤 Q 剪卡 後 卡片 何去 何 從 A 可以 選擇 珍藏 啊 如果 要 殘忍 丟擲 垃圾桶 要 特別 注意 因為 信用卡 上 的 晶片 與 磁條區 包含 了 用戶 的 個資 記得 要 先破壞 或 刮 壞 卡片 上 的 磁條區 以防 被 有心人士 的 盜用 喔 刮磁條 工具 可 再 參照 上 圖 Q 重點 來 了 如何 評估 跟 信用卡 的 緣分 是否 該 就此 了 斷 或 繼續 恩愛 A 這邊 分享 四個 評估 小步 驟 1 是否 有 調整 的 必要 記得 先檢 查查 皮 夾空間 刷卡 消費 習慣 2 是否 有 超過 半年 沒有 使用 的 信用卡 如果 有 那 就 列入 剪卡候 選名 單 3 是否 有 正在 代扣 或 分期付款 的 款項 如 保費 或團費 如果 有 那 就要 注意 剪卡 後 可能 被 設定 成 一次 付清 而 突然 成為 負擔 或 需要 重新 申請 與 填寫 資料 喔 4 是否 有 尚未 使用 的 紅利點數 折抵 優惠 記得 先 兌換 完成 再剪 卡 喔 希望 今天 的 分享 能 幫助 大家 篩選出 最 適合 使用 的 卡片 一般 來 說 手中 持有 3 5 張 不同 功能 的 信用卡 就 很 足夠 囉 祝福 大家 都 能夠 善用 信用卡 每筆 消費 都 能 能 盡 可能 的 多省 一筆 錢 唷 5 分鐘 影音 超簡單 剪卡 4 步驟 教學 跟 此篇 相關 的 文章 銀行 客服 各家 銀行 24 小時 客服 專線 總 整理 點數 兌換 各 卡片 集點 兌換 折抵 攻略 HappyGo icash 一卡通 悠遊卡 網友票 選 10 大辦 卡熱門 刷卡 優惠 與 銀行 信用卡 ',
 愛用 卡 最新 活動 與 優惠 謹慎理財 信用 至上 豐 信用卡 循環 信用 利率 ： 5.68% 15.00% 循環 利率 基準 日 104 年 9 月 1 日 每筆 預借 現金 手續 費為 新 台幣 100 元 預借現 金金 額 3.5% ； 其他 費用 請洽 豐銀行 網站 查詢 花旗銀行 現金回饋 PLUS 御璽 卡 說明 主打 權益 新戶 最優 3% 回饋 ： \t \t \t 基本 回饋 0.5% 三大 指定 通路 回饋 1.5% 新戶 首年 加碼 回饋 1% 三大 指定 通路 ： 國內 加油 生鮮量販 超市 餐廳 刷 前 ２ 萬 上限 300 元 國外 加碼 3.5% 回饋 消費 無門檻 免登錄 回饋 無 上限 2019 12 31 歐洲 國家 不 適用 喔 適 用地 區請 查照 官網 公告 為主 威秀 平日 6 折起 假日 85 折 2020 01 31 年費 正卡 2 400 元 附卡免 年費 免年費 方案 ： 前 一年 累積 消費滿 6 萬元 消費 12 次 享 次年 免年費 最新 活動 新戶 好 禮四選 一 至 11 30 止 ： 1 首年 加碼 1% 回饋 最優 1 200 元 回饋 金 2.29 吋 行李箱 乙只 二色擇 一 3 米家 大方 智慧 攝影 機乙組 4 日本 NICOHHEPA 濾網 吸塵器 乙 只 好禮 2 4 需 符合 核卡 後 30 天內 刷 滿 3 000 元 適用 族群 通勤 族 菜 籃族 喜歡 到 威秀 影城 者 花旗 推出 的 首刷禮 都 很 有 競爭力 像是 行李箱 或 鍋具 全都 很 實用 最 新 活 動 與 詳 情 花旗 信用卡 循環 利率 6.88% 15% 循環 利率 基準 日 為 104 年 9 月 1 日 預借 現金 手續費 預借現 金金 額 乘以 3.5% 加上 新 臺 幣 100 元 其他 費用 請 上 花旗 網站 www citibank com tw 查詢 台新銀行 FlyGo 卡 內容 說明 主打 權益 機票 最高 5% 回饋 含原 權益 最高 2.8% ； 海外 消費 最高 2.8% 國內 一般 1.2% 回饋 無 上限 一卡通 儲值 金 支付 大眾 運輸享 1% 回饋 年費 正卡 附卡 4 500 申請 電子 帳單 期間 免年費 最新 活動 新 申辦 雙狗卡 9 30 前享 三大 優惠 核卡 30 天內刷 滿額享 18 吋 行李箱 適用 族群 今年 熱門 推薦 的 大勢 卡 \t \t \t 常 出國 消費者 會用 一卡通 搭捷 運公車者 必辦 卡 之一 最新 活動 與 詳情 台新 的 狗狗 系列 主打 不同 的 消費 族群 如果 是 出國 消費 需要 辦 上面 的 FlyGo 卡 如果 是 用 於 網購 消費 可 參考 下面 的 GoGo 卡 台新銀行 GoGo 卡 內容 說明 主打 權益 基本 回饋 ： 一般 消費 0.5% 無 上限 數位 通路 2.5% 綁定 Richart 帳戶 ： 一般 消費 1.5% 數位 通路 消費 3.5% 年費 正卡 3 000 附卡 1 500 免年費 條件擇 一 ： \t \t \t 年度 申請 電子 帳單 台新銀行 帳戶 自動 扣款 可享 免年費 \t \t \t 年度 累積 消費滿 6 萬 或 消費次 數達 6 次 次年 免年費 最新 活動 新 申辦 雙狗卡 9 30 前享 三大 優惠 核卡 30 天內刷 滿額享 18 吋 行李箱 適用 族群 常 網購 者 \t \t \t 有 申辦 Richart 數位帳戶 者 最新 活動 與 詳情 謹慎理財 信用 至上 ‧ 差別 循環 信用 利率 ： 一般 消費及 預借 現金為 6.75% 15% 依電腦 評等 而定 ‧ 預借 現金 手續費 ： 預借現 金金 額 x3% 不足 NT 100 以 NT 100 計算 ‧ 循環 利率 之基準 日 為 104 9 1 google ad region " test " google ad client " ca pub 8073120808654621 " google ad host " ca host pub 7449992691305813 " google ad host channel " 1942049901 " google ad slot " 8106458419 " google ad width 300 google ad height 250 google ad region " test " google ad client " ca pub 8073120808654621 " google ad host " ca host pub 7449992691305813 " google ad host chan ...

# %%
vectorizer = TfidfVectorizer(max_features=None,sublinear_tf=True,use_idf=True,max_df=0.8,min_df=20,ngram_range=(1,4))
tfidf=vectorizer.fit_transform(tf_article)

# %%
tfidf_array=tfidf.toarray()

# %%
tfidf_array.shape
# Out:
# (2830, 37042)

# %%
tf_feature_names =vectorizer.get_feature_names()

# %%
# Tweak the two parameters below
number_topics = 10
number_words = 10

# Print the topics found by the LDA model
print("Topics found via LDA:")
#print_topics(lda, count_vectorizer, number_words)

lda = LDA(n_components=15, n_jobs=-1)
lda.fit(tfidf)
# Print the topics found by the LDA model
print("Topics found via LDA:")
#print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
# Topics found via LDA:

# %%
print(lda.fit(tfidf))
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=10, n_jobs=-1,
#                           perp_tol=0.1, random_state=None,
#                           topic_word_prior=None, total_samples=1000000.0,
#                           verbose=0)

# %%
def show_topics(vectorizer=vectorizer, lda_model=lda, n_words=20):
    keywords = np.array(vectorizer.get_feature_names())
    topic_keywords = []
    for topic_weights in lda.components_:
        top_keyword_locs = (-topic_weights).argsort()[:n_words]
        topic_keywords.append(keywords.take(top_keyword_locs))
    return topic_keywords

# %%
n_top_words=50
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-74e8ebf2617e> in <module>
#       1 n_top_words=50
# ----> 2 print_top_words(lda, tf_feature_names, n_top_words)
#
# NameError: name 'print_top_words' is not defined

# %%
show_topics(vectorizer,lda,50)
# Out:
# [array(['借錢', '貸款 利率', '信貸', '借貸', '借款', '貸款', '民間', '代書', '不良', '貸款 代辦',
#         '小額', '潮霖', '潮霖 資產', '地下', '信用 不良', '融資', '資產', '二胎', '信用 貸款',
#         '忠訓', '錢莊', '地下 錢莊', '合法', '土地', 'ok 忠訓', '房貸 利率', '有限公司', '勞工',
#         '汽車 貸款', '資產 有限公司', '軍人', '潮霖 資產 有限公司', '評價 如何', '理債 一日', '利率 比較',
#         '貸款 潮霖', '勞工 貸款', '率利', '代辦', '房屋 貸款', '房貸', '銀行 貸款', '行房', '理債',
#         '高利', '房屋', '貸款 率利', '一日', '速配', 'ok'], dtype='<U42'),
#  array(['信用 利率', '循環 信用 利率', '每筆 預借 現金', '每筆 預借 現金 手續', '循環 信用',
#         '利率 68 15', '利率 68 15 00', '100 預借現', '100 預借現 金金', '循環 信用 利率 68',
#         '利率 68', '信用 利率 68', '68 15', '68 15 00', '信用 利率 68 15',
#         '104 每筆 預借', '基準 104 每筆', '基準 104 每筆 預借', '104 每筆 預借 現金',
#         '其他 費用 請洽', '68 15 00 循環', '15 00 循環', '費用 請洽', '104 每筆',
#         '15 00 循環 利率', '00 循環', '利率 基準 104 每筆', '00 循環 利率', '00 循環 利率 基準',
#         '信用卡 循環 信用 利率', 'nt 100', '15 00', '現金為', '循環 利率', '差別 循環 信用',
#         '差別 循環', '依電腦', '消費及 預借 現金為', '不足 nt 100', '依電腦 評等', '循環 信用 利率 一般',
#         '不足 nt', '一般 消費及 預借 現金為', '消費及 預借 現金為 75', '評等 而定', '信用 利率 一般',
#         '利率 一般 消費及', '利率 一般 消費及 預借', '依電腦 評等 而定', '預借 現金為'], dtype='<U42'),
#  array(['女友', '移送', '偵辦', '監視器', '樂天信用卡', '樂天卡', '天卡', '優惠 整理 持續 更新',
#         '優惠 整理 持續', '申請 心得', '文章 請見', '康及 優惠 整理 持續', '辦卡好 康及 優惠', '辦卡好 康及',
#         '新戶 辦卡好 康及 優惠', '康及 優惠', '康及 優惠 整理', '新戶 辦卡好 康及', '辦卡好 康及 優惠 整理',
#         '新戶 辦卡好', '康及', '罪嫌', '相關 文章 請見', '功能 介紹', '信用卡 相關 文章 請見',
#         '相關 文章 請見 信用卡', '文章 請見 信用卡', '各式 各樣 信用卡 相關', '各樣 信用卡 相關 文章',
#         '其他 各式 各樣 信用卡', '各樣 信用卡', '文章 請見 信用卡 資訊', '各式 各樣 信用卡', '各樣 信用卡 相關',
#         '辦卡好', '其他 各式 各樣', '樂天信用卡 新戶', '樂天信用卡 新戶 辦卡好', '樂天信用卡 新戶 辦卡好 康及',
#         '其他 各式', '信用卡 相關 文章', '現金回饋 哩程 加油', '整理 持續', '功能 現金回饋 哩程',
#         '哩程 加油 推薦 申辦', '哩程 加油 推薦', '加油 推薦 申辦', '現金回饋 哩程 加油 推薦',
#         '功能 現金回饋 哩程 加油', '加油 推薦 申辦 信用卡'], dtype='<U42'),
#  array(['js', '推薦 申辦 信用卡', '進度 查詢', '推薦 申辦', 'fjs', '驗證 消費', '驗證 消費 通知',
#         '消費 通知', '文章 整理', '進度', '各家', '請見', 'js fjs', 'id', '申辦 信用卡', '驗證',
#         '銀行 推薦', '信用卡 資訊 大全', '資訊 大全', '0800 客服', '華南', '相關 文章 整理',
#         '銀行 推薦 申辦', '各家 銀行 推薦', '各家 銀行 推薦 申辦', '銀行 推薦 申辦 信用卡', '現金回饋 電影',
#         '哩程 加油', '申請 進度', '信用卡 0800 客服', '推薦 整理', '活動 近期', '信用卡 相關 文章',
#         '申請 進度 查詢', '電影 哩程', '電影 哩程 加油', '現金回饋 電影 哩程 加油', '現金回饋 電影 哩程',
#         '各家 銀行', '整理 其他', '請見 信用卡', '優惠 活動 推薦 整理', '信用卡 優惠 活動 推薦',
#         '優惠 活動 推薦', '活動 推薦 整理', '通知 申請', '請見 信用卡 資訊 大全', '請見 信用卡 資訊', '大全',
#         '華南 信用卡'], dtype='<U42'),
#  array(['金管會', '億元', '台北 報導', 'money101', '記者', '金融', '民眾', '機構',
#         'money101 com tw', 'money101 com', '台北', '萬張', '統計', '業務', '中信銀',
#         '金額', '表示', '簽帳', '蔡怡', '記者 蔡怡', '蔡怡 台北', '記者 蔡怡 台北',
#         '記者 蔡怡 台北 報導', '蔡怡 台北 報導', '發卡', '銀行局', '宣布', '簽帳 金額', '立即 訂閱',
#         '總經理', '發展', '卡數', '金融 產品', '一銀', '發行', '戴瑞瑤', '記者 戴瑞瑤', '家銀行',
#         '循環 信用', '循環 利率', '新高', '發卡 機構', '信用卡 業務', '介紹 最新', '相關 情報',
#         '最新 金融', '拍賣', '理財 相關', '掌握 理財', '掌握 理財 相關'], dtype='<U42'),
#  array(['aspire', 'amex hilton', '蘋果 信用卡', 'thank', 'thank you',
#         'everyday', 'amex gold', '信用卡 日記 謝謝', '日記 謝謝', '老狐狸 信用卡 日記 謝謝',
#         'paypal', 'preferred', '三件', '信用卡 如何', '注意 不要', '只有 一個', '加速',
#         '客服 各家', '露出', '試圖', '有效率', '小學', '客服 人員', '銀行 客服', '盜用', '列為',
#         '代理', '這個 優惠', '回饋 神卡', '有感', '告知', '怎麼 申請', 'yu', '申請 條件', '法則',
#         'from', '謝謝 分享', '信用卡 apple', '信用 記錄', 'citi prestige', '女友',
#         '浪費 時間', '60k', '再試', '奇怪', '適合長', '知道 其他', '該卡', '活動 可以', '週轉'],
#        dtype='<U42'),
#  array(['借款', '借貸', '貸款 ptt', 'ptt', '利率 比較', '撇步', '信貸', '信貸 ptt', '借錢',
#         '秘密', '貸款', '借貸 ptt', '借款 ptt', '利率 最低', '過件', '銀行 快速', '各家 銀行 快速',
#         '忠訓', 'ok 忠訓', '借錢 ptt', 'ptt 小額', 'ptt 信用', '銀行 借款', '小額',
#         'ptt 各家', '超實用', '利率 最低 銀行', '銀行 借貸', 'ptt 各家 銀行', '快速 解決', '網友激',
#         '好過', 'ptt 信貸', '借錢 利率', '銀行 一家', '信用 借貸', '房貸', '哪些 銀行', '銀行 分享',
#         '銀行 ptt', '借款 利率', '哪間 銀行', '資證明', '工作 證明', '比較 ptt',
#         'ptt 各家 銀行 快速', 'ptt 工作', '信用 借錢', '方法 分享', '快速 借款'], dtype='<U42'),
#  array(['悠遊卡', '花旗 現金回饋 悠遊卡', '花旗', '現金回饋 悠遊卡', '花旗 現金回饋', '2018',
#         '2018 信用卡', '蘋果', '信用卡 比較', 'apple pay', '信用卡 信用卡', '現金回饋', '優惠比',
#         '比較', 'apple', '饗樂', '花旗 饗樂', 'pay', '而且', '比較 信用卡', '信用卡 各家',
#         '而且 現在', 'apple pay 進行', 'pay 進行', '匯豐 現金回饋御璽卡', '匯豐', '一下 這麼',
#         '不用 信用卡 出門', '蘋果 可以', '蘋果 手機', '可以 而且', 'pay 進行 行動支付',
#         'apple pay 進行 行動支付', '信用卡 出門', '分享 花旗 現金回饋', '分享 花旗', '綁定 花旗',
#         '現在 首刷禮', '進行 行動支付', '悠遊卡 匯豐', '花旗 現金回饋 悠遊卡 不用', '悠遊卡 算是 人性化 一張',
#         '只要 蘋果 手機', 'pay 綁定 花旗 現金回饋', 'pay 綁定 花旗', '手機 蘋果 可以', '而且 悠遊卡',
#         '而且 悠遊卡 功能', '悠遊卡 功能 一下 這麼', '手機 蘋果'], dtype='<U42'),
#  array(['紅利 哩程', '年息', '2010', '有所 幫助', '問題 方法', '管理 分析', '觀賞', '借錢 工作',
#         '法則', '餐廳 咖啡', '什麼 地方', '期盼', '之大', '從現', '利率 比較', '分期 交易', '遁形',
#         '工作 可以', '問題 銀行', '如何 拒絕', '低利', '信用卡 聯邦銀行', '真的 認真', '得不到',
#         '帳單 金額 回饋', '桃園 市民', '最高 額度', '銀行 貸款 利息', '社交', '三四', '缺錢', '低利率',
#         '急需', '以本 公司', '這兩年', '免財力', '牽手', '申請 房貸', '多少 整合', '農會',
#         '優惠 apple pay', '舊戶 申請', '新辦', '愛情', '詳見 活動', '漲價', '20 信用卡',
#         '比較 apple', '150 其他 相關', '客家'], dtype='<U42'),
#  array(['2019 信用卡', '2019', '還不賴', '信用卡 比較', '信用卡 2019', '還不賴 還不賴',
#         '還不賴 還不賴 還不賴', '現金回饋', 'https youtu', 'youtu', 'youtu be',
#         'https youtu be', '比較', '還不賴 還不賴 還不賴 還不賴', '現金回饋 信用卡',
#         'youtube com', 'www youtube', 'www youtube com', 'ptt',
#         'https www youtube', 'https www youtube com', '現金回饋 信用卡 2019',
#         '線上 申辦 https', '立即 線上', '8787 tw', 'https 8787', '8787',
#         '立即 線上 申辦', '立即 線上 申辦 https', '申辦 https 8787 tw', '申辦 https 8787',
#         'https 8787 tw', '線上 申辦 https 8787', '申辦 https', '信用卡 ptt',
#         '線上 申辦', '信用卡 推薦', '比較 2019', '2019 信用卡 比較', '最多 信用卡', '現金回饋 最多',
#         '立即', '最多', '現金回饋 最多 信用卡', '哪家 信用卡', '2019 現金回饋', '信用卡 比較 2019',
#         '較表', '信用卡 現金回饋', '信用卡 2019 現金回饋'], dtype='<U42'),
#  array(['pse', 'pse ee', 'http pse ee', 'http pse', 'pw', 'pse is',
#         'shinli', 'https pse is', 'https pse', 'piee', 'piee pw', 'shin',
#         'ee', 'shinli piee pw', 'http shinli', 'http shinli piee',
#         'shinli piee', 'http shinli piee pw', 'facebook http', 'is',
#         'facebook http pse', 'facebook http pse ee', '信用卡 評比', '大評',
#         'shin li', '評比', 'shinlii', '合作 信箱', 'instaram http pse',
#         'instaram http', 'instaram http pse ee', 'pse ee shinlii ig',
#         'instaram', 'pse ee shinli', 'ig facebook http pse',
#         'xshinxli gmail', 'ig facebook http', 'xshinxli gmail com',
#         '信箱 xshinxli gmail com', '合作 信箱 xshinxli gmail',
#         'ee shinlii ig facebook', 'ee shinlii ig', 'ee shinlii',
#         'ee shinli fb', 'ee shinli', 'shinlii ig facebook http',
#         'shinlii ig facebook', 'shinlii ig', 'shinli fb', 'pse ee shinlii'],
#        dtype='<U42'),
#  array(['最新 優惠 活動', '好康 最新 優惠', '好康 最新 優惠 活動', '辦卡 好康 最新', '辦卡 好康 最新 優惠',
#         '好康 最新', '辦卡 好康', '信用卡 舊戶', '舊戶 辦卡', '信用卡 舊戶 辦卡 好康', '舊戶 辦卡 好康 最新',
#         '舊戶 辦卡 好康', '信用卡 舊戶 辦卡', '活動 持續', '優惠 活動 持續', '優惠 活動 持續 更新',
#         '活動 持續 更新', '最新 優惠 活動 持續', '花旗 信用卡', '15 循環', '15 循環 利率', '花旗 卡優惠',
#         '申辦 花旗', '查詢 謹慎理財 信用', '查詢 謹慎理財', '查詢 謹慎理財 信用 至上', '活動 持續 更新 辦卡必',
#         '104 預借', '104 預借 現金 手續費', '100 其他 費用', '104 預借 現金', '循環 利率 88 15',
#         '利率 88 15', '循環 利率 88', '利率 88', 'www citibank',
#         'www citibank com tw', 'citibank com tw', 'citibank com',
#         'www citibank com', '100 其他', '88 15', '基準 104 預借', '基準 104 預借 現金',
#         '加上 100', '乘以 加上 100', '金金 乘以 加上 100', '花旗 網站', '信用卡 循環 利率 88',
#         '整理 本篇 介紹'], dtype='<U42'),
#  array(['回饋', '活動', '消費', '玉山', '優惠', '2019', '通路', '超商', '指定', '現金回饋',
#         '支付', '上限', '紅利', 'pay', '行動支付', '綁定', '台新', '折抵', '網購', '最高',
#         '刷卡', '單筆', '31', '分期', 'app', '使用', '一般 消費', '回饋 上限', '銀行', '全家',
#         '一般', '推出', '聯名卡', 'line', '國泰世華', '000', '12', '12 31', '加碼',
#         '30', '卡片', '繳費', 'pi', '自動', '卡友', '生活', '付款', '100', '兌換',
#         'icash'], dtype='<U42'),
#  array(['可以', '如果', '自己', '所以', '消費', 'https', '申請', '使用', '銀行', '就是',
#         '因為', '刷卡', '大家', '老狐狸', 'com', '10', '優惠', '還是', '一個', '需要', '其他',
#         '直接', '可能', '沒有', '推薦', '報導', '目前', '真的', '一下', '公司', '知道', '這個',
#         '不是', '日本', '回饋', '旅遊', '什麼', '台灣', '資料', '表示', '時間', '提供', '我們',
#         '分享', '帳戶', '信用', '這樣', '不過', '方式', 'www'], dtype='<U42'),
#  array(['換現', '刷卡 換現', '信用卡 換現', '換現 信用卡', '換現 信用卡 換現', '刷卡 換現 信用卡',
#         '刷卡 換現 信用卡 換現', '換現 刷卡', '換現 刷卡 換現', '信用卡 換現 刷卡', '信用卡 換現 刷卡 換現',
#         '換現 文章', '換現 全站 熱搜 作者', '換現 全站 熱搜', '換現 全站', '金融', '刷卡', '線上 刷卡',
#         '熱搜 作者', '熱搜', '全站 熱搜 作者', '全站 熱搜', '全站', '24h', '作者', '文章', '合法',
#         '德國', '宜蘭', '會不會', '全站 熱搜 作者 介紹', '熱搜 作者 介紹', '作者 介紹', '介紹', '補貼',
#         '最終', '人用', '停止', '排除', '信用卡 國外', '全球', '最大', '多久', '文章 信用卡',
#         '台灣銀行', '美國', '不會', '線上', '台北', '拿到'], dtype='<U42')]
