# %%
import pandas as pd
import json
import re
import pymongo
import jieba
import operator

# %%
IP:'123.241.175.34'
user:'root'
password:'1qaz@WSX3edc'

# %%
#連接 mongodb

client = pymongo.MongoClient(host='123.241.175.34', port=27017)

# %%
#mongodb帳號密碼

client.admin.authenticate('root', '1qaz@WSX3edc')



#設定名稱為test的資料庫 也可用 db = client['test']

db = client.raw_article
# Out:
# ['article_socialjson',
#  'article_webj',
#  'article_social',
#  'article_news',
#  'article_webjson']

# %%
#顯示db中所有collections
db.list_collection_names()
# Out:
# ['article_social', 'article_web', 'article_news']

# %%
#drop collection
db.article_socialjson.drop()

# %%
article_social=db.article_social.find()
article_web=db.article_web.find()
article_news=db.article_news.find()

# %%
df_article_social=pd.DataFrame(list(article_social))
df_article_web=pd.DataFrame(list(article_web))
df_article_news=pd.DataFrame(list(article_news))

# %%
df_article_social[:1]
# Out:
#                         _id                                            content
# 0  5dd39ed135cc75f4e568cc8f  #公告 信用卡板板主\n本板板主為：信用卡板小天使https://www.dcard.tw/...

# %%
df_article_news[:1]
# Out:
#                         _id                                            content
# 0  5dd3987235cc75f4e568b6b4  國內刷卡回饋重洗牌　無腦刷排行榜大車拼\n\n\n　　下半年信用卡市場「流血搶市」，多家銀行...

# %%
df_article_web[:1]
df_article_web['seg']=None
df_article_web['word_freq']=None

# %%
#df_article_web
n=len(df_article_web)
alltext=[]
stopset=set()
stop2=['/n','','\n']


with open(r'E:/專題/credit_card/DB104_hau/stop.txt','r',encoding='utf-8') as s:
    for line in s:
        stopset.add(line.strip('\n'))
jieba.load_userdict(r'E:/專題/credit_card/DB104_hau/userdict.txt')
for i in range(n):
    seg=''
    wf={}
    text= str(df_article_web.loc[i]['content'])
    cut=jieba.cut(text,cut_all=False)
    for j in cut:
        if j not in stopset:
            seg +=j+' '
    df_article_web['seg'][i]=seg
    for w in seg.split(' '):
        if w not in wf:
            wf[w]=1
        else:
            wf[w]+=1
    #word_list=[wf.items() for k in wf if k not in stop2 ]
    word_list=sorted(wf.items(),key=lambda a :a[1],reverse=True)
    df_article_web['word_freq'][i]=word_list

# %%
df_article_web[:10]
# Out:
#                                              content  \
# 0  玉山Pi拍錢包信用卡》國內4.5%.海外3%.繳稅1%持續坐穩神卡寶座！\n\nMay16T...
# 1  2019行事曆》連假出國旅遊請假攻略最高連休16天！日本韓國中國泰國各國假期懶人包\n\nD...
# 2  信用卡》2019海外刷卡消費現金回饋必備推薦TOP 7、手續費優惠、選卡小技巧\n\nJul...
# 3  信用卡》2019年出國刷卡租借wifi分享器上網優惠(0508更新)\n\nJan05Fri...
# 4  信用卡被盜刷怎麼處理？如何防止？遭盜刷快做這三件事補救！\n\nOct12Thu201717...
# 5  2018年請假攻略》最高連休23天！台灣、日本、韓國、中國連假行事曆整理，避開人潮輕鬆玩！\...
# 6  信用卡》想剪卡必知攻略！簡單4步驟剪卡不吃虧\n\nDec27Tue201613:30\n信...
# 7  信用卡》2019年刷卡加油優惠推薦(人工自助加油)｜中油、台塑、全國、西歐(10.02更新)...
# 8  信用卡》2019年各家刷卡「機場接送」優惠/免費機場接送總整理(推薦好讀表格版)\n\nJ...
# 9  信用卡》2019現金回饋卡推薦比較＋國內外網購選卡攻略(1106更新)\n\nJun07Tu...
#
#                                                  seg  \
# 0  玉山 Pi 拍錢包 信用卡 國內 4.5% 海外 3% 繳稅 1% 持續 坐 穩神 卡寶座 ...
# 1  2019 行事 曆 連假 出國 旅遊 請假 攻略 最高 連休 16 天 日本 韓國 中 國泰...
# 2  信用卡 2019 海外 刷卡 消費 現金回饋 必備 推薦 TOP   7 手續費 優惠 選卡...
# 3  信用卡 2019 年 出國 刷卡 租借 wifi 分享 器上 網優惠 0508 更新 \n ...
# 4  信用卡 被 盜刷 怎麼 處理 如何 防止 遭盜 刷 快 做 這 三件 事補救 \n \n O...
# 5  2018 年 請 假 攻略 最高 連休 23 天 台灣 日本 韓國 中國 連假 行事 曆 整...
# 6  信用卡 想 剪卡 必知 攻略 簡單 4 步驟 剪卡 不吃 虧 \n \n Dec27Tue2...
# 7  信用卡 2019 年 刷卡 加油 優惠 推薦 人工 自助 加油 ｜ 中油 台塑 全國 西歐 ...
# 8  信用卡 2019 年 各家 刷卡  機場 接送 優惠 免費 機場 接送 總 整理 推薦 好...
# 9  信用卡 2019 現金回饋 卡 推薦 比 較 ＋ 國內外 網購 選卡 攻略 1106 更新 ...
#
#                                            word_freq
# 0  [(\n, 97), (的, 43), (拍錢包, 21), (回饋, 20), (Pi, ...
# 1  [(\n, 37), (的, 25), (連假, 16), (旅遊, 13), (要, 8)...
# 2  [(\n, 143), (信用卡, 16), (★, 16), (＝, 16), (\t, ...
# 3  [(\n, 304), (★, 100), (\t, 90), (01, 54), (銀行,...
# 4  [(\n, 48), (的, 11), (卡片, 10), (刷, 8), (被, 7), ...
# 5  [(\n, 53), (2, 43), (天, 41), (放, 23), (連假, 22)...
# 6  [(\n, 41), (的, 22), (剪卡, 12), (信用卡, 10), (了, 7...
# 7  [(\n, 288), (●, 60), (元, 56), (信用卡, 53), (降, 5...
# 8  [(\n, 427), (★, 100), (2019, 97), (01, 88), (次...
# 9  [(\n, 320), (\t, 60), (★, 51), (卡, 37), (－, 34...

# %%
del df_article_web['wrod_freq']

# %%
del df_article_web['_id']

# %%
#article_social
df_article_social[:1]
df_article_social['seg']=None
df_article_social['word_freq']=None

# %%
df_article_social
# Out:
#                             _id  \
# 0      5dd39ed135cc75f4e568cc8f
# 1      5dd39ed135cc75f4e568cc90
# 2      5dd39ed135cc75f4e568cc91
# 3      5dd39ed135cc75f4e568cc92
# 4      5dd39ed135cc75f4e568cc93
# 5      5dd39ed135cc75f4e568cc94
# 6      5dd39ed135cc75f4e568cc95
# 7      5dd39ed135cc75f4e568cc96
# 8      5dd39ed135cc75f4e568cc97
# 9      5dd39ed135cc75f4e568cc98
# 10     5dd39ed135cc75f4e568cc99
# 11     5dd39ed135cc75f4e568cc9a
# 12     5dd39ed135cc75f4e568cc9b
# 13     5dd39ed135cc75f4e568cc9c
# 14     5dd39ed135cc75f4e568cc9d
# 15     5dd39ed135cc75f4e568cc9e
# 12122   贈送 寰宇商務通關\n贈送 寰宇商務通關時間Mon Oct  7 10:16:29 201...  None      None
#
# [12123 rows x 4 columns]

# %%
n=len(df_article_social)
alltext=[]
stopset=set()
stop2=['/n','','\n']


with open(r'E:/專題/credit_card/DB104_hau/stop.txt','r',encoding='utf-8') as s:
    for line in s:
        stopset.add(line.strip('\n'))
jieba.load_userdict(r'E:/專題/credit_card/DB104_hau/userdict.txt')
for i in range(n):
    seg=''
    wf={}
    text= str(df_article_social.loc[i]['content'])
    cut=jieba.cut(text,cut_all=False)
    for j in cut:
        if j not in stopset:
            seg +=j+' '
    df_article_social['seg'][i]=seg
    for w in seg.split(' '):
        if w not in wf:
            wf[w]=1
        else:
            wf[w]+=1
    #word_list=[wf.items() for k in wf if k not in stop2 ]
    word_list=sorted(wf.items(),key=lambda a :a[1],reverse=True)
    df_article_social['word_freq'][i]=word_list

# %%
del df_article_social['_id']
df_article_social[:10]
# Out:
#                                              content  \
# 0  #公告 信用卡板板主\n本板板主為：信用卡板小天使https://www.dcard.tw/...
# 1  信用卡板板規\n宗旨：信用卡資訊分享，包含核卡心得、使用心得、剪卡心得、里程累積心得。?? ...
# 2  #情報 街口聯名卡10/29上市\n不囉嗦 先上圖依目前資訊指定通路15%回饋綁定街口並使用...
# 3  #心得 永豐大戶核卡 小白\n職業類別：工程估算整合/資訊業年資：2個月年齡：23申請卡片：...
# 4  #詢問  照會後還未核卡\n10/5 線上申請信用卡10/9 顯示審核中10/26 大約早上...
# 5  #詢問 富邦額度都給很低嗎？\n上週六辦了富邦J卡我是富邦新戶核卡才給我五萬額度我台新玉山都...
# 6  #詢問 黑狗Gogo卡搭桃園公車\n想問 假如剩110可否直接跟店員或是有機器操作直接信用卡...
# 7  #詢問 永豐大戶\n我在10/24的時候申請數位帳戶 申請完後去申請了黑色那張卡後來資料填一...
# 8  #問題  Richart綠狗卡綁定line pay\n請問有人綠狗卡要綁定line pay ...
# 9  #詢問 簽帳卡有包含在學生三家銀行內嗎？\n小弟最近剛拿到美國運通的簽帳金（這是我的第三家銀...
#
#                                                  seg  \
# 0  公告   信用卡 板板主 \n 本板 板主為 信用卡 板 小天使 https www dca...
# 1  信用卡 板板規 \n 宗旨 信用卡 資訊 分享 包含 核卡 心得 使用 心得 剪卡 心得 里...
# 2  情報   街口 聯名卡 10 29 上市 \n 不 囉 嗦   先上 圖依 目前 資訊 指定...
# 3  心得   永豐 大戶 核卡   小白 \n 職業 類別 工程 估算 整合 資訊業 年資 2 ...
# 4  詢問     照會 後 還未 核卡 \n 10 5   線上 申請 信用卡 10 9   顯...
# 5  詢問   富邦 額度 都給 很 低 嗎 \n 上 週六辦 了 富邦 J 卡 我 是 富邦 新...
# 6  詢問   黑狗 Gogo卡 搭桃園 公車 \n 想問   假如 剩 110 可否 直接 跟 ...
# 7  詢問   永豐 大戶 \n 我 在 10 24 的 時候 申請 數位帳戶   申請 完後去 ...
# 8  問題     Richart 綠狗卡 綁定 line   pay \n 請問 有人 綠狗 卡...
# 9  詢問   簽帳 卡有 包含 在 學生 三家 銀行 內 嗎 \n 小弟 最近 剛 拿到 美國 ...
#
#                                            word_freq
# 0  [(, 3), (信用卡, 3), (板板主, 2), (本板, 2), (的, 2), (...
# 1  [(, 35), (的, 7), (心得, 6), (詢問, 6), (全站, 4), (禁...
# 2  [(, 9), (街口, 4), (回饋, 3), (詳細, 3), (等, 3), (上市...
# 3  [(, 45), (的, 8), (大戶, 6), (申請, 5), (永豐, 4), (1...
# 4  [(, 17), (核卡, 4), (10, 3), (照會, 2), (後, 2), (信...
# 5  [(額度, 4), (我, 4), (, 3), (富邦, 3), (嗎, 2), (是, ...
# 6  [(, 5), (直接, 2), (信用卡, 2), (詢問, 1), (黑狗, 1), (...
# 7  [(, 9), (申請, 5), (我, 4), (收到, 3), (後, 3), (嗎, ...
# 8  [(, 21), (pay, 6), (綁定, 5), (line, 4), (問題, 3)...
# 9  [(的, 8), (簽帳, 4), (, 3), (在, 3), (嗎, 3), (卡有, ...

# %%
#df_article_news
df_article_news[:1]
df_article_news['seg']=None
df_article_news['word_freq']=None

# %%
n=len(df_article_news)
alltext=[]
stopset=set()
stop2=['/n','','\n']


with open(r'E:/專題/credit_card/DB104_hau/stop.txt','r',encoding='utf-8') as s:
    for line in s:
        stopset.add(line.strip('\n'))
jieba.load_userdict(r'E:/專題/credit_card/DB104_hau/userdict.txt')
for i in range(n):
    seg=''
    wf={}
    text= str(df_article_news.loc[i]['content'])
    cut=jieba.cut(text,cut_all=False)
    for j in cut:
        if j not in stopset:
            seg +=j+' '
    df_article_news['seg'][i]=seg
    for w in seg.split(' '):
        if w not in wf:
            wf[w]=1
        else:
            wf[w]+=1
    #word_list=[wf.items() for k in wf if k not in stop2 ]
    word_list=sorted(wf.items(),key=lambda a :a[1],reverse=True)
    df_article_news['word_freq'][i]=word_list

# %%
del df_article_news['_id']
df_article_news[:10]
# Out:
#                                              content  \
# 0  國內刷卡回饋重洗牌　無腦刷排行榜大車拼\n\n\n　　下半年信用卡市場「流血搶市」，多家銀行...
# 1  直擊雙11電商AI倉儲　下單到出貨僅10分鐘\n\n\n　　雙11狂熱訂單爆量，電商平台拼「...
# 2  雙11網購主打賓士車　交易攻略回饋16.8萬元\n\n\n　　雙11購物節戰火激烈，網購平台...
# 3  刷信用卡繳納地價稅　24家銀行免收手續費\n\n\n　　今(2019)年最後一項稅款地價稅，...
# 4  4張行動支付聯名卡對決　街口卡力尬Pi拍錢包\n\n\n　　隨著街口聯名卡上市，炒熱行動支付...
# 5  零售4大錢包各顯神威　支付累點還能存零錢\n\n\n　　在行動支付的浪潮下，傳統的零售通路展...
# 6  前8月刷卡量衝2兆元　玉山包辦第3季發卡王\n\n\n　　歷經6月報稅入帳的高峰後，今(20...
# 7  刷信用卡如打怪衝等　累積紅利刺激養卡潮\n\n\n　　信用卡市場戰火連天，持卡人「逐回饋而刷...
# 8  電信聯名卡升級激戰　購機回饋分期0利率\n\n\n　　iPhone新機上市引爆電信續約與換約...
# 9  全聯多元支付大解放　實體信用卡封印解除\n\n\n　　全聯福利中心強力推出「PX Pay」行...
#
#                                                  seg  \
# 0  國內 刷卡 回饋 重 洗牌 　 無腦 刷 排行榜 大車 拼 \n \n \n 　 　 下半年...
# 1  直擊雙 11 電商 AI 倉儲 　 下 單到 出貨僅 10 分鐘 \n \n \n 　 　 ...
# 2  雙 11 網購 主打 賓士車 　 交易 攻略 回饋 16.8 萬元 \n \n \n 　 　...
# 3  刷 信用卡 繳納地 價稅 　 24 家銀行 免收 手續費 \n \n \n 　 　 今 20...
# 4  4 張 行動支付 聯名卡 對決 　 街口 卡力尬 Pi 拍錢包 \n \n \n 　 　 隨...
# 5  零售 4 大 錢包 各顯 神威 　 支付 累點 還能 存零錢 \n \n \n 　 　 在 ...
# 6  前 8 月 刷卡 量衝 2 兆元 　 玉山 包辦 第 3 季發 卡王 \n \n \n 　 ...
# 7  刷 信用卡 如打 怪衝 等 　 累積 紅利 刺激 養卡潮 \n \n \n 　 　 信用卡 ...
# 8  電信 聯名卡 升級 激戰 　 購機 回饋 分期 0 利率 \n \n \n 　 　 iPho...
# 9  全聯 多元 支付 大 解放 　 實體 信用卡 封印 解除 \n \n \n 　 　 全聯 福...
#
#                                            word_freq
# 0  [(回饋, 25), (, 25), (　, 15), (\n, 14), (消費, 9),...
# 1  [(　, 13), (\n, 12), (的, 8), (AI, 7), (出貨, 7), ...
# 2  [(, 23), (　, 11), (萬元, 8), (\n, 8), (11, 7), (...
# 3  [(\n, 12), (　, 11), (家銀行, 7), (銀, 7), (, 7), (...
# 4  [(, 21), (回饋, 17), (\n, 12), (　, 11), (聯名卡, 10...
# 5  [(, 17), (\n, 12), (　, 11), (儲值, 11), (與, 9), ...
# 6  [(月, 29), (億元, 26), (　, 25), (2, 17), (\n, 17)...
# 7  [(的, 21), (　, 15), (倍, 15), (紅利, 14), (回饋, 13)...
# 8  [(, 33), (回饋, 20), (元, 13), (\n, 12), (　, 11),...
# 9  [(元, 15), (　, 13), (\n, 13), (, 13), (福利, 12),...

# %%
db_ETL = client.ETL
#collsoc = db.article_social
collweb = db_ETL.article_web_seg
collnews =db_ETL.article_news_seg
collsocial = db_ETL.article_social_seg

# %%
#將dataframe轉成能存入mongodb的json格式

data_social = json.loads(df_article_social.T.to_json()).values()
data_news = json.loads(df_article_news.T.to_json()).values()
data_web = json.loads(df_article_web.T.to_json()).values()

# %%
#將資料存入mongodb
collsocial.insert_many(data_social)
collnews.insert_many(data_news)
collweb.insert_many(data_web)

# %%
db_ETL.list_collection_names()
# Out:
# ['article_news_seg', 'article_web_seg', 'article_social_seg']

# %%
#export to json
df_article_social.to_json('./article_social_seg.json',orient='index',force_ascii=False)
df_article_news.to_json('./article_news_seg.json',orient='index',force_ascii=False)
df_article_web.to_json('./article_web_seg.json',orient='index',force_ascii=False)

# %%
client.database_names()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: database_names is deprecated. Use list_database_names instead.
#   """Entry point for launching an IPython kernel.
# ['ETL', 'admin', 'config', 'local', 'raw_article', 'test']

# %%
test='abcd efgd 7789 fgfg'
x=jieba.lcut(test,cut_all=False)
x
# Out:
# ['abcd', ' ', 'efgd', ' ', '7789', ' ', 'fgfg']
