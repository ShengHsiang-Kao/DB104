# %%
import jieba
import json
import pandas as pd
import os

# %%
#各檔名
file_list=['cardU_news.xlsx',
           'dcard_cut.xlsx',
           'dfall_pixnet.xlsx',
           'FB_fanpage.xls',
           'final_99_cardu_opencard.csv',
           'ptt_cut.xlsx',
           'TVBS_card_news.xlsx',
           'udn_card_news.xlsx',
           'video_df2ex_utf16_seg.xlsx']

# %%
#df=pd.read_excel(r'D:/Google雲端硬碟/資料分析師班/專題/credit_card/credit_card/youtube_crawl/text_file/video_df2ex_utf16.xlsx',encoding='utf-16')
df_tmp=pd.read_excel(r'E:/專題/credit_card/DB104_hau/integrate/card_article/excel_file/cardU_news.xlsx',encoding='utf-16')

# %%
n=len(df_tmp)

# %%
#cardU_news.xlsx

# %%
df_tmp[:2]
# Out:
#    Unnamed: 0                      標題          時間  \
# 0           0     國內刷卡回饋重洗牌　無腦刷排行榜大車拼  2019-11-13
# 1           1  直擊雙11電商AI倉儲　下單到出貨僅10分鐘  2019-11-11
#
#                                                網址  \
# 0  https://www.cardu.com.tw/news/detail.php?39417
# 1  https://www.cardu.com.tw/news/detail.php?39391
#
#                                                   內文
# 0  \n\n\n　　下半年信用卡市場「流血搶市」，多家銀行不惜血本祭出超高回饋，使得排行榜大幅洗...
# 1  \n\n\n　　雙11狂熱訂單爆量，電商平台拼「出貨速度」，《卡優新聞網》直擊Yahoo奇摩...

# %%
#column
all_article=pd.DataFrame(columns=['content'])
all_article
# Out:
# Empty DataFrame
# Columns: [content]
# Index: []

# %%
for i in range(n):
    con=''
    con += df_tmp['標題'][i]+df_tmp['內文'][i]
    all_article = all_article.append({'content': con}, ignore_index=True)

# %%
all_article
# Out:
#                                                content
# 0    國內刷卡回饋重洗牌　無腦刷排行榜大車拼\n\n\n　　下半年信用卡市場「流血搶市」，多家銀行...
# 1    直擊雙11電商AI倉儲　下單到出貨僅10分鐘\n\n\n　　雙11狂熱訂單爆量，電商平台拼「...
# 2    雙11網購主打賓士車　交易攻略回饋16.8萬元\n\n\n　　雙11購物節戰火激烈，網購平台...
# 3    刷信用卡繳納地價稅　24家銀行免收手續費\n\n\n　　今(2019)年最後一項稅款地價稅，...
# 4    4張行動支付聯名卡對決　街口卡力尬Pi拍錢包\n\n\n　　隨著街口聯名卡上市，炒熱行動支付...
# 5    零售4大錢包各顯神威　支付累點還能存零錢\n\n\n　　在行動支付的浪潮下，傳統的零售通路展...
# 6    前8月刷卡量衝2兆元　玉山包辦第3季發卡王\n\n\n　　歷經6月報稅入帳的高峰後，今(20...
# 7    刷信用卡如打怪衝等　累積紅利刺激養卡潮\n\n\n　　信用卡市場戰火連天，持卡人「逐回饋而刷...
# 8    電信聯名卡升級激戰　購機回饋分期0利率\n\n\n　　iPhone新機上市引爆電信續約與換約...
# 9    全聯多元支付大解放　實體信用卡封印解除\n\n\n　　全聯福利中心強力推出「PX Pay」行...
# 10   第4季信用卡加油優惠　台塑卡折降4.2元超神\n\n\n　　9月中旬沙烏地阿拉伯原油設施遭到...
# 11   新光三越週年慶攻略　3大絕招衝高回饋率\n\n\n　　新光三越週年慶明(3)天開跑，姊妹們拿...
# 12   華航卡改嫁中國信託　台新銀低調迎娶街口\n\n\n　　信用卡戰局瞬息萬變，中華航空聯名卡傳出...
# 13   手機摔傷好險有保險　5大電信方案懶人包\n\n\n\r\n\t　　iPhone 11系列新機...
# 14   7月玉山卡「熊」利害　8月國泰世華超前200億\n\n\n\r\n\t　　信用卡賽事下半場一...
# 15   3大網購聯名卡大廝殺　比回饋比效期便利性\n\n\n\r\n\t　　國內3大電商平台皆已發行...
# ...

# %%
#df=pd.read_excel(r'D:/Google雲端硬碟/資料分析師班/專題/credit_card/credit_card/youtube_crawl/text_file/video_df2ex_utf16.xlsx',encoding='utf-16')
df_tmp2=pd.read_excel(r'E:/專題/credit_card/DB104_hau/integrate/card_article/excel_file/dcard_cut.xlsx',encoding='utf-16')
n=len(df_tmp2)

# %%
df_tmp2=df_tmp2.T

# %%
df_tmp2.columns=df_tmp2[1]
# Out:
#                                                0             1  \
# Unnamed: 0                                    標題            時間
# 0                                  #討論 十月信用卡板閒聊區    9月1日 13:24
# 1                                     #公告 信用卡板板主    8月1日 18:49
# 2                                         信用卡板板規   4月12日 15:38
# 3                               #情報 街口聯名卡10/29上市  10月28日 15:27
# 4                                  #心得 永豐大戶核卡 小白  10月28日 13:42
# 5                                   #詢問  照會後還未核卡  10月28日 01:46
# 6                                 #詢問 富邦額度都給很低嗎？  10月28日 23:43
# 7                               #詢問 黑狗Gogo卡搭桃園公車  10月28日 00:13
# 8                                       #詢問 永豐大戶  10月28日 22:48
# 9                      #問題  Richart綠狗卡綁定line pay  10月29日 10:38
# 10                          #詢問 簽帳卡有包含在學生三家銀行內嗎？  10月26日 23:44
# 11                               #詢問 中信卡費逾期4分鐘才繳  10月26日 15:33
# 12                                      #詢問 外送刷卡  10月26日 00:16
# ...

# %%
df_tmp2.cloumns=['標題','時間','網址','內文','斷詞','詞頻']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """Entry point for launching an IPython kernel.

# %%
df_tmp2.columns
# Out:
# RangeIndex(start=0, stop=6, step=1)
