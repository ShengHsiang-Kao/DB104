# %%
# %load youtube_selenium1025.py
from selenium.webdriver import Chrome
from selenium.webdriver.support.ui import Select
import requests
from bs4 import BeautifulSoup
import time
import os
import pandas as pd
from selenium.webdriver.common.keys import Keys    #鍵盤
from selenium.webdriver.support import expected_conditions as EC    #等到出現
import json
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import urllib

#data

card_col_name={'銀行':'','卡名':'','申請連結':'','卡片特性':'','首刷禮':''}

upath = r'./card_image'

if not os.path.exists(upath):
    os.mkdir(upath)

url = ('https://www.money101.com.tw/%E4%BF%A1%E7%94%A8%E5%8D%A1/%E5%85%A8%E9%83%A8')
# 開啟網頁
driver = Chrome('./chromedriver')

driver.get(url)
card_list=[]
#//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[260]/a/div/div/div/div/h3

#滾動到底
# last_height = driver.execute_script("return document.body.scrollHeight")
# while True:
#     # Scroll down to bottom
#     driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

#     # Wait to load page
#     time.sleep(0.5)

#     # Calculate new scroll height and compare with last scroll height
#     new_height = driver.execute_script("return document.body.scrollHeight")
#     if new_height == last_height:
#         break
#     last_height = new_height
    
for c in range(1,297):
    driver.find_element_by_tag_name('html').send_keys(Keys.END)
    
    
    time.sleep(1)
    name=driver.find_element_by_xpath('//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[{}]/a/div/div/div/div/h3'.format(c)).text
    card_list.append(name)
    driver.find_element_by_tag_name('html').send_keys(Keys.HOME)
    pic=driver.find_element_by_xpath('//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[{}]/a/div/div/img'.format(c))
    driver.find_element_by_tag_name('html').send_keys(Keys.PAGE_UP)
    time.sleep(1)
#     src = pic.get_attribute('src')
    
#     try:
#         urllib.request.urlretrieve(src, "card_image/{}.png".format(str(name)))
#     except:
#         pass
    


#driver.save_screenshot("screenshot.png")

driver.quit()
#pic=driver.get('https://moscowsg.megafon.ru/ps/scc/php/cryptographp.php?PHPSESSID=mfc540jkbeme81qjvh5t0v0bnjdr7oc6&ref=114&w=150')
#apply=driver.find_element_by_xpath('//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[5]/div/div[2]/button')
#applytest=driver.find_element_by_xpath('//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[5]/div/div[2]/button/div/div')

#apply=WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH,'//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[5]/div/div[2]/button')))
#apply.click
#2  //*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[2]/a/div/div/div/div/h3
#3 //*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[3]/a/div/div/div/div/h3
# //*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[59]/a/div/div/div/div/h3
#moreinfo=WebDriverWait(driver,10).until(EC.element_to_be_clickable((By.XPATH,'//*[@id="root"]/div[3]/div[2]/div/div/div[2]/div/div/div[5]/div/div[3]/div[1]/div[2]/button')))

# %%
card_list
# Out:
# ['渣打銀行 現金回饋御璽卡',
#  '彰化銀行 My樂現金回饋卡',
#  '花旗銀行 現金回饋PLUS卡',
#  '第一銀行 一卡通聯名卡',
#  '遠東商銀 快樂信用卡',
#  '聯邦銀行 賴點一卡通御璽卡',
#  '永豐銀行 DAWHO現金回饋信用卡',
#  '遠東商銀 Bankee信用卡',
#  '元大銀行 鑽金卡',
#  '元大銀行 鑽金 icash 聯名卡',
#  '上海商銀 簡單卡',
#  '台北富邦 J卡',
#  '兆豐銀行 利多御璽商旅卡',
#  '新光銀行 日本航空聯名卡',
#  '台新銀行 FlyGo卡',
#  '中國信託 雙幣商務卡',
#  '星展銀行 炫晶御璽卡',
#  '中國信託 中信商旅鈦金卡',
#  '華南銀行 享利樂活Combo卡',
#  '陽信銀行 曜晶卡',
#  '中國信託 現金回饋鈦金卡',
#  '中國信託 TAIPEI 101 夜光聯名卡',
#  '中國信託 Global Mall 聯名卡',
#  '台新銀行 商務卡',
#  '上海商銀 小小兵Bello回饋卡',
#  '滙豐銀行 現金回饋御璽卡',
#  '元大銀行 Wi-Ho!Online聯名卡',
#  '元大銀行 鑽金一卡通聯名卡',
#  '元大銀行 富貴無限卡',
#  '元大銀行 iCash樂享晶緻卡',
#  '元大銀行 iPASS現賺御璽卡',
#  '第一銀行 鈦金商旅卡',
#  '永豐銀行 現金回饋卡',
#  '日盛銀行 無限卡',
#  '永豐銀行 雙幣卡',
#  '國泰世華 現金回饋御璽卡',
#  '上海商銀 TeresaCard',
#  '合作金庫 雙幣信用卡',
#  '臺灣企銀 故宮之友認同卡',
#  '王道銀行 cama café聯名卡',
#  '王道銀行 簽帳金融卡',
#  '王道銀行 FunNow聯名卡',
#  '華南銀行 旅鑽商務御璽卡',
#  '日盛銀行 商務御璽卡',
#  '新光銀行 新光三越聯名卡',
#  '國泰世華 享購鈦金卡',
#  '永豐銀行 無限卡',
#  '王道銀行 公益認同卡',
#  '台灣樂天 樂天信用卡',
#  '新光銀行 寰宇現金回饋卡',
#  '聯邦銀行 幸福御守御璽卡',
# ...

# %%
all_card=[]
for i in card_list:
    cardname={'銀行':i[:4],'卡名':i[4:]}
    all_card.append(cardname)

# %%
all_card_df=pd.DataFrame(all_card,columns=['銀行','卡名'])

# %%
all_card_df.to_excel('./money101_all_card.xlsx',encoding='utf-16')
