# %%
import pandas as pd
import json
import re
import pymongo
import jieba
import operator

# %%
card_freature=pd.read_excel(r'./card_feature.xlsx',encoding='utf-16')

# %%
card_freature
# Out:
#        銀行                 卡名     國內回饋     國外回饋      國內哩程      國外哩程  自助加油  \
# 0    三信銀行            VISA白金卡  0.00000  0.00000  0.000000  0.000000   0.0
# 1    上海商銀                簡單卡  0.01000  0.02000  0.000000  0.000000   0.0
# 2    上海商銀        小小兵Bello回饋卡  0.01234  0.02234  0.000000  0.000000   0.0
# 3    上海商銀         TeresaCard  0.00000  0.00000  0.000000  0.000000   0.0
# 4    土地銀行        JCB一卡通聯名晶緻卡  0.01000  0.01000  0.000000  0.000000   0.0
# 5    土地銀行              白金商務卡  0.00000  0.00000  0.000000  0.000000   0.0
# 6    土地銀行              國際信用卡  0.00000  0.00000  0.000000  0.000000   0.0
# 7    中國信託              雙幣商務卡  0.00000  0.00000  0.000000  0.000000   0.0
# 8    中國信託            中信商旅鈦金卡  0.01000  0.02500  0.000000  0.000000   0.0
# 9    中國信託            現金回饋鈦金卡  0.00000  0.00000  0.000000  0.000000   0.0
# 10   中國信託   TAIPEI 101 夜光聯名卡  0.00000  0.00000  0.000000  0.000000   0.0
# 11   中國信託    Global Mall 聯名卡  0.00000  0.00000  0.000000  0.000000   0.0
# ...

# %%
card_freature['卡全名']=None

# %%
for i in range(len(card_freature)):
    card_freature['卡全名'][i]=card_freature['銀行'][i]+'-'+card_freature['卡名'][i].lstrip()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
card_freature['卡全名']
# Out:
# 0               三信銀行-VISA白金卡
# 1                   上海商銀-簡單卡
# 2           上海商銀-小小兵Bello回饋卡
# 3            上海商銀-TeresaCard
# 4           土地銀行-JCB一卡通聯名晶緻卡
# 5                 土地銀行-白金商務卡
# 6                 土地銀行-國際信用卡
# 7                 中國信託-雙幣商務卡
# 8               中國信託-中信商旅鈦金卡
# 9               中國信託-現金回饋鈦金卡
# 10     中國信託-TAIPEI 101 夜光聯名卡
# 11      中國信託-Global Mall 聯名卡
# 12              中國信託-寰遊美國運通卡
# 13            中國信託-LINE Pay卡
# 14               中國信託-iPlan卡
# 15              中國信託-中信兄弟聯名卡
# 16             中國信託-Yahoo聯名卡
# 17                中國信託-秀泰聯名卡
# 18            中國信託-中華電信聯名白金卡
# 19            中國信託-蘭城新月廣場聯名卡
# 20            中國信託-南紡購物中心聯名卡
# 21                中國信託-享想生活卡
# 22             中國信託-中油VIP聯名卡
# 23          中國信託-MUJI無印良品聯名卡
# 24                  中國信託-酷玩卡
# 25            中國信託-勤美天地聯名晶緻卡
# 26              中國信託-漢神百貨聯名卡
# 27                中國信託-紅利御璽卡
# 28           中國信託-大葉高島屋百貨聯名卡
# 29            中國信託-大中華攜手飛聯名卡
#                ...
# 286             臺灣企銀-故宮之友認同卡
# ...

# %%
card_freature.to_excel(r'./card_freature1127.xlsx',encoding='utf-16')
