# %%
y=dict()
with open(r'./video_seg1101.txt','r',encoding='utf-8') as j:
    x=j.read()
w=x.split(' ')
for i in w:
    if i not in y:
        y[i]=1
    else:
        y[i]+=1

# %%
word_list=[(k,y[k]) for k in y]
word_list.sort(key=lambda a :a[1],reverse=True)
word_list
# Out:
# [('', 33261),
#  ('\n', 18297),
#  ('信用卡', 2911),
#  ('https', 2224),
#  ('com', 997),
#  ('http', 930),
#  ('卡', 788),
#  ('回饋', 724),
#  ('www', 672),
#  ('️', 582),
#  ('be', 552),
#  ('youtu', 543),
#  ('消費', 499),
#  ('銀行', 463),
#  ('pse', 430),
#  ('現金回饋', 428),
#  ('bit', 395),
#  ('ly', 394),
#  ('🔺', 393),
#  ('元', 390),
#  ('is', 361),
#  ('玉山', 356),
#  ('使用', 341),
#  ('goo', 322),
#  ('gl', 322),
#  ('影片', 304),
#  ('pw', 300),
#  ('理財', 282),
#  ('piee', 282),
#  ('shinli', 274),
#  ('2019', 269),
#  ('刷卡', 269),
#  ('推薦', 266),
#  ('優惠', 261),
#  ('更多', 251),
#  ('好', 238),
#  ('分享', 237),
#  ('真的', 236),
#  ('nan', 236),
#  ('人', 219),
#  ('方法', 217),
#  ('youtube', 214),
#  ('刷', 213),
#  ('海外', 212),
#  ('申请', 209),
#  ('支付', 208),
#  ('月', 203),
#  ('頻道', 202),
#  ('評比', 201),
#  ('我的', 200),
#  ('信用', 200),
#  ('tw', 189),
#  ('訂閱', 185),
#  ('生活', 182),
#  ('手機', 179),
#  ('facebook', 178),
#  ('最', 176),
#  ('10', 172),
#  ('😂', 171),
#  ('◻', 167),
#  ('👍', 165),
#  ('點', 164),
#  ('一一', 158),
#  ('►', 157),
#  ('日本', 156),
#  ('年', 155),
#  ('點數', 155),
#  ('上限', 154),
#  ('台灣', 153),
#  ('▶', 153),
#  ('通路', 151),
#  ('你的', 149),
#  ('最高', 149),
#  ('5%', 147),
#  ('加油', 147),
#  ('视频', 145),
#  ('錢包', 144),
#  ('Richart', 144),
#  ('官方', 144),
#  ('美国', 143),
#  ('活動', 142),
#  ('比較', 139),
#  ('帳戶', 137),
#  ('吗', 137),
#  ('網路', 136),
#  ('綁定', 136),
#  ('一下', 136),
#  ('享', 135),
#  ('請問', 134),
#  ('需要', 131),
#  ('公司', 130),
#  ('法', 128),
#  ('👉', 127),
#  ('小', 127),
#  ('買', 127),
#  ('聯名卡', 125),
#  ('網購', 124),
#  ('指定', 124),
#  ('神卡', 124),
#  ('300', 124),
#  ('申請', 124),
#  ('再', 123),
#  ('没有', 123),
#  ('还', 123),
#  ('银行', 122),
#  ('張', 121),
#  ('存錢', 121),
#  ('暗网', 121),
#  ('辦', 120),
#  ('Pi錢包', 120),
#  ('直接', 119),
#  ('Pay', 118),
#  ('限', 118),
#  ('盜刷', 118),
#  ('会', 118),
#  ('付款', 117),
#  ('v', 117),
#  ('國內', 116),
#  ('支持', 116),
#  ('旅遊', 116),
#  ('Apple', 116),
#  ('方式', 116),
#  ('請', 114),
#  ('to', 114),
#  ('IG', 113),
#  ('喔', 113),
#  ('香港', 113),
#  ('後', 111),
#  ('这个', 111),
#  ('聯邦', 109),
#  ('想', 108),
#  ('ee', 108),
#  ('APP', 106),
#  ('这', 106),
#  ('FB', 105),
#  ('卡片', 104),
#  ('篇', 104),
#  ('現在', 103),
#  ('無上', 103),
#  ('500', 102),
#  ('每月', 102),
#  ('現金', 101),
#  ('000', 100),
#  ('中', 100),
#  ('機票', 99),
#  ('LINE', 98),
#  ('自動', 98),
#  ('合作', 97),
#  ('行動支付', 97),
#  ('一張', 97),
#  ('一个', 97),
#  ('日', 96),
#  ('資訊', 96),
#  ('做', 95),
#  ('1%', 95),
#  ('活存', 94),
#  ('➡', 94),
#  ('希望', 94),
#  ('gmail', 93),
#  ('購物', 92),
#  ('watch', 92),
#  ('CCTV', 92),
#  ('2%', 91),
#  ('台新', 91),
#  ('SHIN', 91),
#  ('也能', 91),
#  ('出國', 90),
#  ('教學', 90),
#  ('自己的', 90),
#  ('謝謝', 89),
#  ('3%', 88),
#  ('→', 88),
#  ('帳單', 87),
#  ('❤', 87),
#  ('高', 87),
#  ('攻略', 87),
#  ('SHINLI', 86),
#  ('100', 86),
#  ('年費', 86),
#  ('申辦', 86),
#  ('Facebook', 86),
#  ('10%', 85),
#  ('消费', 85),
#  ('街口', 84),
#  ('📌', 84),
#  ('知道', 84),
#  ('辦卡', 83),
#  ('成功', 83),
#  ('介紹', 83),
#  ('最新', 83),
#  ('说', 83),
#  ('pay', 82),
#  ('不用', 82),
#  ('中国', 82),
#  ('instagram', 81),
#  ('GOGO', 81),
#  ('都是', 81),
#  ('新', 80),
#  ('連結', 79),
#  ('這張', 79),
#  ('金融卡', 78),
#  ('小資族', 78),
#  ('省錢', 78),
#  ('感謝', 78),
#  ('達人', 78),
#  ('儲值', 78),
#  ('酒店', 78),
#  ('谷歌', 78),
#  ('一卡通', 77),
#  ('给', 77),
#  ('平台', 76),
#  ('前', 76),
#  ('悠遊卡', 76),
#  ('20', 76),
#  ('粉絲', 76),
#  ('返现', 76),
#  ('我是', 75),
#  ('網站', 75),
#  ('12', 75),
#  ('11', 75),
#  ('電子', 75),
#  ('00', 75),
#  ('什么', 75),
#  ('大戶', 74),
#  ('🏻', 74),
#  ('加碼', 74),
#  ('加入', 74),
#  ('channel', 74),
#  ('朋友', 74),
#  ('蘋果', 74),
#  ('小資', 73),
#  ('累積', 73),
#  ('歡迎', 73),
#  ('Bankee', 72),
#  ('廣告', 72),
#  ('点数', 72),
#  ('微信', 71),
#  ('超商', 71),
#  ('數位', 70),
#  ('無痛', 70),
#  ('太', 70),
#  ('資料', 70),
#  ('之前', 70),
#  ('📍', 70),
#  ('讚', 70),
#  ('了解', 69),
#  ('永豐', 69),
#  ('line', 69),
#  ('賴點卡', 69),
#  ('帳號', 69),
#  ('看到', 69),
#  ('方便', 69),
#  ('对', 69),
#  ('也可以', 68),
#  ('里程', 68),
#  ('萬', 68),
#  ('－', 68),
#  ('錢', 67),
#  ('云', 67),
#  ('喜歡', 66),
#  ('繳稅', 66),
#  ('超', 66),
#  ('問題', 66),
#  ('注册', 66),
#  ('整理', 65),
#  ('教', 65),
#  ('國外', 65),
#  ('哩程', 65),
#  ('簡單', 65),
#  ('系列', 65),
#  ('t', 65),
#  ('●', 65),
#  ('免费', 65),
#  ('匯豐', 64),
#  ('▌', 64),
#  ('也是', 64),
#  ('me', 64),
#  ('来', 64),
#  ('Card', 64),
#  ('为', 64),
#  ('信息', 64),
#  ('說', 63),
#  ('已', 63),
#  ('今天', 63),
#  ('后', 63),
#  ('UR', 63),
#  ('係', 63),
#  ('YouTube', 62),
#  ('划算', 62),
#  ('App', 62),
#  ('賺', 62),
#  ('‣', 61),
#  ('金', 61),
#  ('實用', 61),
#  ('投資', 61),
#  ('card', 61),
#  ('Chase', 61),
#  ('我们', 61),
#  ('服務', 60),
#  ('一次', 60),
#  ('時', 60),
#  ('将', 60),
#  ('唔', 60),
#  ('官網', 59),
#  ('I', 59),
#  ('app', 59),
#  ('線上', 59),
#  ('開箱', 59),
#  ('1.2%', 58),
#  ('以上', 58),
#  ('收到', 58),
#  ('地址', 58),
#  ('积分', 58),
#  ('━', 58),
#  ('送', 57),
#  ('KOKO', 57),
#  ('選擇', 57),
#  ('下載', 57),
#  ('个', 57),
#  ('實體', 56),
#  ('找', 56),
#  ('3.5%', 56),
#  ('200', 56),
#  ('幣', 56),
#  ('30', 56),
#  ('先', 56),
#  ('福利', 56),
#  ('■', 56),
#  ('高清', 56),
#  ('卡的', 55),
#  ('交易', 55),
#  ('51', 55),
#  ('王道', 54),
#  ('保費', 54),
#  ('幫', 54),
#  ('部落格', 54),
#  ('and', 54),
#  ('加值', 53),
#  ('好像', 53),
#  ('31', 53),
#  ('世界', 53),
#  ('遊戲', 53),
#  ('美金', 53),
#  ('you', 53),
#  ('推荐', 53),
#  ('所有', 52),
#  ('目前', 52),
#  ('信箱', 52),
#  ('20%', 52),
#  ('購買', 52),
#  ('收入', 52),
#  ('內容', 52),
#  ('美國', 52),
#  ('覺得', 52),
#  ('立即', 52),
#  ('谢谢', 52),
#  ('繳費', 51),
#  ('LI', 51),
#  ('金額', 51),
#  ('2.5%', 51),
#  ('50', 51),
#  ('✔', 51),
#  ('一直', 51),
#  ('a', 51),
#  ('the', 51),
#  ('还款', 51),
#  ('播放列表', 51),
#  ('記得', 50),
#  ('透過', 50),
#  ('手續費', 50),
#  ('完成', 50),
#  ('分', 50),
#  ('功能', 50),
#  ('开卡', 50),
#  ('怎么', 50),
#  ('提供', 49),
#  ('國泰', 49),
#  ('免', 49),
#  ('增加', 49),
#  ('即時', 49),
#  ('想要', 49),
#  ('直播', 49),
#  ('点击', 49),
#  ('获得', 49),
#  ('订阅', 49),
#  ('御璽', 48),
#  ('時間', 48),
#  ('玩', 48),
#  ('一起', 48),
#  ('感覺', 48),
#  ('下', 48),
#  ('请', 48),
#  ('美元', 48),
#  ('免費', 47),
#  ('XD', 47),
#  ('✉', 47),
#  ('刷禮', 47),
#  ('張卡', 47),
#  ('google', 47),
#  ('額度', 47),
#  ('cvv', 47),
#  ('料站', 47),
#  ('🤣', 46),
#  ('也有', 46),
#  ('FaceBook', 46),
#  ('中信', 46),
#  ('限制', 46),
#  ('必備', 46),
#  ('money101', 46),
#  ('花', 46),
#  ('不知道', 46),
#  ('旅行', 46),
#  ('發現', 46),
#  ('TVBS', 46),
#  ('主持人', 46),
#  ('频道', 46),
#  ('奖励', 46),
#  ('留言', 45),
#  ('聰明', 45),
#  ('利率', 45),
#  ('遠銀', 45),
#  ('月光族', 45),
#  ('....', 45),
#  ('金融', 45),
#  ('詳情', 45),
#  ('嘅', 45),
#  ('Instaram', 44),
#  ('SHINLII', 44),
#  ('愛奇藝', 44),
#  ('xshinxli', 44),
#  ('享首', 44),
#  ('航空', 44),
#  ('Linepay', 44),
#  ('核卡', 44),
#  ('Money101', 44),
#  ('credit', 44),
#  ('年费', 44),
#  ('cn', 44),
#  ('通过', 44),
#  ('出售', 44),
#  ('中天', 44),
#  ('詳細', 43),
#  ('紅利', 43),
#  ('折抵', 43),
#  ('新戶', 43),
#  ('我想', 43),
#  ('QIY', 43),
#  ('推出', 43),
#  ('商品', 43),
#  ('click', 43),
#  ('与', 43),
#  ('月付', 43),
#  ('術', 42),
#  ('NT', 42),
#  ('掃碼', 42),
#  ('選', 42),
#  ('有錢', 42),
#  ('會員', 42),
#  ('登入', 42),
#  ('15', 42),
#  ('三大', 42),
#  ('更新', 42),
#  ('要求', 42),
#  ('臉書', 42),
#  ('家', 42),
#  ('时候', 42),
#  ('机票', 42),
#  ('苹果', 42),
#  ('现在', 42),
#  ('⇩', 42),
#  ('1000', 41),
#  ('太多', 41),
#  ('需', 41),
#  ('哈哈哈', 41),
#  ('Google', 41),
#  ('旅平險', 41),
#  ('團', 41),
#  ('分析', 41),
#  ('安全', 41),
#  ('精華', 41),
#  ('iPhone', 41),
#  ('虚拟', 41),
#  ('機場', 40),
#  ('拍', 40),
#  ('正確', 40),
#  ('Line', 40),
#  ('事', 40),
#  ('2018', 40),
#  ('号', 40),
#  ('兑换', 40),
#  ('8%', 39),
#  ('綁', 39),
#  ('第一', 39),
#  ('PBLOG', 39),
#  ('利息', 39),
#  ('in', 39),
#  ('最近', 39),
#  ('⭐', 39),
#  ('即可', 39),
#  ('问题', 39),
#  ('睇', 39),
#  ('羊毛', 39),
#  ('还是', 39),
#  ('账户', 39),
#  ('没', 39),
#  ('链接', 39),
#  ('無腦', 38),
#  ('F4HP5', 38),
#  ('扣款', 38),
#  ('電影', 38),
#  ('幾個', 38),
#  ('富邦', 38),
#  ('p', 38),
#  ('Pi', 38),
#  ('網址', 38),
#  ('險', 38),
#  ('Youtube', 38),
#  ('工作', 38),
#  ('真', 38),
#  ('群', 38),
#  ('享有', 37),
#  ('FlyGo', 37),
#  ('之後', 37),
#  ('重要', 37),
#  ('⋯', 37),
#  ('支付寶', 37),
#  ('🚩', 37),
#  ('字幕', 37),
#  ('公告', 37),
#  ('一些', 37),
#  ('m101', 37),
#  ('解析', 37),
#  ('利用', 37),
#  ('自由', 37),
#  ('提醒', 37),
#  ('cc', 37),
#  ('享受', 37),
#  ('韓國', 37),
#  ('品宏', 37),
#  ('全家', 36),
#  ('華航', 36),
#  ('只能', 36),
#  ('渣打', 36),
#  ('輕鬆', 36),
#  ('折', 36),
#  ('里', 36),
#  ('客服', 36),
#  ('號', 36),
#  ('每日', 36),
#  ('记录', 36),
#  ('註冊', 36),
#  ('的话', 36),
#  ('学生', 36),
#  ('✰', 36),
#  ('必辦', 35),
#  ('應該', 35),
#  ('賺錢', 35),
#  ('2.8%', 35),
#  ('回饋金', 35),
#  ('期', 35),
#  ('400', 35),
#  ('解決', 35),
#  ('是不是', 35),
#  ('重點', 35),
#  ('注意', 35),
#  ('都有', 35),
#  ('唷', 35),
#  ('版', 35),
#  ('發票', 35),
#  ('让', 35),
#  ('➲', 35),
#  ('时', 35),
#  ('网址', 35),
#  ('□', 35),
#  ('😭', 34),
#  ('量販店', 34),
#  ('超過', 34),
#  ('無', 34),
#  ('＝', 34),
#  ('獲得', 34),
#  ('☛', 34),
#  ('一定', 34),
#  ('以下', 34),
#  ('ID', 34),
#  ('＿', 34),
#  ('JCB', 34),
#  ('钱', 34),
#  ('验证', 34),
#  ('警方', 34),
#  ('2017', 34),
#  ('账号', 34),
#  ('通道', 34),
#  ('1.5%', 33),
#  ('含', 33),
#  ('拿到', 33),
#  ('計算', 33),
#  ('兆豐', 33),
#  ('UBEAR', 33),
#  ('倍', 33),
#  ('影城', 33),
#  ('紀錄', 33),
#  ('秒', 33),
#  ('貸款', 33),
#  ('可愛', 33),
#  ('快速', 33),
#  ('聽', 33),
#  ('中文', 33),
#  ('已经', 33),
#  ('hk', 33),
#  ('撸', 33),
#  ('还有', 33),
#  ('那么', 33),
#  ('账单', 33),
#  ('Hyatt', 33),
#  ('教程', 33),
#  ('amzn', 33),
#  ('pi', 32),
#  ('電腦', 32),
#  ('P', 32),
#  ('一目了然', 32),
#  ('不需要', 32),
#  ('e', 32),
#  ('AE', 32),
#  ('不想', 32),
#  ('一定要', 32),
#  ('得到', 32),
#  ('就會', 32),
#  ('今年', 32),
#  ('地方', 32),
#  ('容易', 32),
#  ('Instagram', 32),
#  ('輸入', 32),
#  ('加', 32),
#  ('for', 32),
#  ('s', 32),
#  ('操作', 32),
#  ('买', 32),
#  ('TV', 32),
#  ('▫', 32),
#  ('◽', 32),
#  ('Visa', 31),
#  ('包含', 31),
#  ('航空公司', 31),
#  ('省', 31),
#  ('花旗', 31),
#  ('『', 31),
#  ('』', 31),
#  ('推', 31),
#  ('自助', 31),
#  ('習慣', 31),
#  ('好用', 31),
#  ('囉', 31),
#  ('这些', 31),
#  ('中國', 31),
#  ('．', 31),
#  ('因为', 31),
#  ('情况', 31),
#  ('点', 31),
#  ('为什么', 31),
#  ('間', 31),
#  ('繳', 30),
#  ('包', 30),
#  ('加高', 30),
#  ('太猛', 30),
#  ('不用錢', 30),
#  ('最後', 30),
#  ('13', 30),
#  ('24', 30),
#  ('電話', 30),
#  ('E', 30),
#  ('一名', 30),
#  ('黑', 30),
#  ('知識', 30),
#  ('部分', 30),
#  ('一年', 30),
#  ('欢迎', 30),
#  ('购买', 30),
#  ('从', 30),
#  ('次', 29),
#  ('中國信託', 29),
#  ('G7ZCN', 29),
#  ('DJQKA', 29),
#  ('EZ5ZY', 29),
#  ('EMYFR', 29),
#  ('E5YU7', 29),
#  ('DZHQB', 29),
#  ('FJ44A', 29),
#  ('告別', 29),
#  ('EA4D2', 29),
#  ('22K', 29),
#  ('存到', 29),
#  ('第一桶金', 29),
#  ('F47QW', 29),
#  ('user22896', 29),
#  ('C45C7', 29),
#  ('🙏', 29),
#  ('外', 29),
#  ('適用', 29),
#  ('R', 29),
#  ('買車', 29),
#  ('持有', 29),
#  ('追蹤', 29),
#  ('每年', 29),
#  ('根本', 29),
#  ('on', 29),
#  ('升級', 29),
#  ('我有', 29),
#  ('apple', 29),
#  ('清單', 29),
#  ('▣', 29),
#  ('無法', 29),
#  ('债务', 29),
#  ('并', 29),
#  ('感谢', 29),
#  ('有人', 29),
#  ('八達通', 29),
#  ('节目', 29),
#  ('选择', 29),
#  ('财富', 29),
#  ('哥', 29),
#  ('翻墙', 29),
#  ('嘉宾', 29),
#  ('每次', 28),
#  ('新的', 28),
#  ('告訴', 28),
#  ('組', 28),
#  ('辛苦', 28),
#  ('扣繳', 28),
#  ('DTNEM', 28),
#  ('第三方', 28),
#  ('耶', 28),
#  ('很棒', 28),
#  ('未', 28),
#  ('設定', 28),
#  ('中心', 28),
#  ('行動', 28),
#  ('完全', 28),
#  ('of', 28),
#  ('额度', 28),
#  ('这么', 28),
#  ('网站', 28),
#  ('paypal', 28),
#  ('被盗', 28),
#  ('Step', 28),
#  ('J49JE', 27),
#  ('icash', 27),
#  ('清楚', 27),
#  ('單筆', 27),
#  ('商店', 27),
#  ('算', 27),
#  ('期間', 27),
#  ('台北', 27),
#  ('萬元', 27),
#  ('✦', 27),
#  ('精彩', 27),
#  ('還要', 27),
#  ('提到', 27),
#  ('碼', 27),
#  ('三立', 27),
#  ('我覺得', 27),
#  ('晚上', 27),
#  ('播放', 27),
#  ('加油站', 27),
#  ('请问', 27),
#  ('21', 27),
#  ('最好', 27),
#  ('還能', 27),
#  ('側錄', 27),
#  ('时间', 27),
#  ('催收', 27),
#  ('契爾氏', 27),
#  ('每天', 26),
#  ('都可以', 26),
#  ('費用', 26),
#  ('學生', 26),
#  ('😍', 26),
#  ('建議', 26),
#  ('第一次', 26),
#  ('Mastercard', 26),
#  ('名', 26),
#  ('通知', 26),
#  ('機器人', 26),
#  ('定存', 26),
#  ('lOg7x1N3', 26),
#  ('VP1jWNUCyYA', 26),
#  ('idPC2NQCucc', 26),
#  ('每週', 26),
#  ('你好', 26),
#  ('全球', 26),
#  ('網', 26),
#  ('節目', 26),
#  ('消費者', 26),
#  ('未來', 26),
#  ('22', 26),
#  ('陳', 26),
#  ('看看', 26),
#  ('接受', 26),
#  ('手机', 26),
#  ('这样', 26),
#  ('密碼', 26),
#  ('Ubear', 25),
#  ('人生', 25),
#  ('考慮', 25),
#  ('KXJWW', 25),
#  ('登錄', 25),
#  ('結帳', 25),
#  ('東西', 25),
#  ('便利', 25),
#  ('這種', 25),
#  ('我要', 25),
#  ('電子支付', 25),
#  ('產品', 25),
#  ('就有', 25),
#  ('一點', 25),
#  ('店家', 25),
#  ('都會', 25),
#  ('管理', 25),
#  ('客戶', 25),
#  ('😄', 25),
#  ('video', 25),
#  ('兄弟', 25),
#  ('吃', 25),
#  ('♥', 25),
#  ('台', 25),
#  ('this', 25),
#  ('賣場', 25),
#  ('理财', 25),
#  ('手续费', 25),
#  ('貴賓室', 25),
#  ('取消', 25),
#  ('价值', 25),
#  ('回贈', 25),
#  ('咁', 25),
#  ('◄', 25),
#  ('韩国', 25),
#  ('600', 24),
#  ('費', 24),
#  ('只', 24),
#  ('i', 24),
#  ('不錯', 24),
#  ('FDDA4', 24),
#  ('謝謝你', 24),
#  ('25', 24),
#  ('有效', 24),
#  ('人在', 24),
#  ('適合', 24),
#  ('財富', 24),
#  ('相關', 24),
#  ('工具', 24),
#  ('我也', 24),
#  ('步驟', 24),
#  ('好了', 24),
#  ('繼續', 24),
#  ('抽', 24),
#  ('by', 24),
#  ('这种', 24),
#  ('开始', 24),
#  ('體驗', 24),
#  ('无需', 24),
#  ('CSP', 24),
#  ('HK', 24),
#  ('chase', 24),
#  ('提示', 24),
#  ('⬜', 24),
#  ('ctitv', 24),
#  ('2000', 23),
#  ('iCash', 23),
#  ('說明', 23),
#  ('兌換', 23),
#  ('STEAM', 23),
#  ('注意事項', 23),
#  ('哪張', 23),
#  ('💳', 23),
#  ('主題', 23),
#  ('機制', 23),
#  ('好好', 23),
#  ('越來越', 23),
#  ('找到', 23),
#  ('有點', 23),
#  ('X', 23),
#  ('能力', 23),
#  ('行', 23),
#  ('付費', 23),
#  ('感應', 23),
#  ('行銷', 23),
#  ('贊助', 23),
#  ('\u200d', 23),
#  ('不错', 23),
#  ('Credit', 23),
#  ('流程', 23),
#  ('動', 23),
#  ('无', 23),
#  ('二斤', 23),
#  ('chineseinla', 23),
#  ('国内', 23),
#  ('米哥', 23),
#  ('料', 23),
#  ('办理', 23),
#  ('dwz', 23),
#  ('匯率', 22),
#  ('真是', 22),
#  ('0.5%', 22),
#  ('商務', 22),
#  ('樂天', 22),
#  ('LinePay', 22),
#  ('PAY', 22),
#  ('搭配', 22),
#  ('主要', 22),
#  ('新手', 22),
#  ('影響', 22),
#  ('正', 22),
#  ('天', 22),
#  ('黑卡', 22),
#  ('越', 22),
#  ('看完', 22),
#  ('經濟', 22),
#  ('條件', 22),
#  ('柴鼠', 22),
#  ('看了', 22),
#  ('VISA', 22),
#  ('交流', 22),
#  ('辦理', 22),
#  ('reurl', 22),
#  ('喜欢', 22),
#  ('过', 22),
#  ('内', 22),
#  ('一张', 22),
#  ('增值', 22),
#  ('冇', 22),
#  ('支付宝', 22),
#  ('圈', 22),
#  ('明镜', 22),
#  ('單元', 21),
#  ('變', 21),
#  ('GoGo', 21),
#  ('真的是', 21),
#  ('RichartGOGO', 21),
#  ('遠東', 21),
#  ('歐付寶', 21),
#  ('限量', 21),
#  ('存款', 21),
#  ('02', 21),
#  ('首年', 21),
#  ('🎬', 21),
#  ('年底', 21),
#  ('多少錢', 21),
#  ('證明', 21),
#  ('Renee', 21),
#  ('驗證', 21),
#  ('擁有', 21),
#  ('關注', 21),
#  ('108', 21),
#  ('★', 21),
#  ('有了', 21),
#  ('他的', 21),
#  ('gogo', 21),
#  ('也要', 21),
#  ('重要的', 21),
#  ('快來', 21),
#  ('原來', 21),
#  ('我會', 21),
#  ('風險', 21),
#  ('會有', 21),
#  ('完整版', 21),
#  ('挖', 21),
#  ('的問題', 21),
#  ('银行卡', 21),
#  ('音樂', 21),
#  ('like', 21),
#  ('站', 21),
#  ('接收', 21),
#  ('论坛', 21),
#  ('应该', 21),
#  ('us', 21),
#  ('東森', 21),
#  ('介绍', 21),
#  ('无法', 21),
#  ('號碼', 21),
#  ('用户', 21),
#  ('刀', 21),
#  ('tutorial', 21),
#  ('kuan', 20),
#  ('現場', 20),
#  ('電費', 20),
#  ('國家', 20),
#  ('關關', 20),
#  ('付', 20),
#  ('萊爾富', 20),
#  ('01', 20),
#  ('悠遊', 20),
#  ('商銀', 20),
#  ('全聯', 20),
#  ('簡訊', 20),
#  ('裡面', 20),
#  ('下面', 20),
#  ('J', 20),
#  ('多元', 20),
#  ('不便', 20),
#  ('Selena', 20),
#  ('email', 20),
#  ...]

# %%
with open(r'./wordfreq.txt','w',encoding='utf-8') as f:
    f.write(str(word_list))
