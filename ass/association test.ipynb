# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)

frequent_itemsets
# Out:
#     support                     itemsets
# 0       0.8                       (Eggs)
# 1       1.0               (Kidney Beans)
# 2       0.6                       (Milk)
# 3       0.6                      (Onion)
# 4       0.6                     (Yogurt)
# 5       0.8         (Eggs, Kidney Beans)
# 6       0.6                (Eggs, Onion)
# 7       0.6         (Kidney Beans, Milk)
# 8       0.6        (Kidney Beans, Onion)
# 9       0.6       (Kidney Beans, Yogurt)
# 10      0.6  (Eggs, Kidney Beans, Onion)

# %%
te_ary
# Out:
# array([[False, False, False,  True, False,  True,  True,  True,  True,
#         False,  True],
#        [False, False,  True,  True, False,  True, False,  True,  True,
#         False,  True],
#        [ True, False, False,  True, False,  True,  True, False, False,
#         False, False],
#        [False,  True, False, False, False,  True,  True, False, False,
#          True,  True],
#        [False,  True, False,  True,  True,  True, False, False,  True,
#         False, False]])

# %%
df
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
#df=pd.read_excel(r'D:/Google雲端硬碟/資料分析師班/專題/credit_card/credit_card/youtube_crawl/jieba/video_df2ex_utf16_seg.xlsx',encoding='utf-16')
df=pd.read_excel(r'E:\專題\credit_card\DB104\tag/video_df2ex_utf16_tag.xlsx',encoding='utf-16')

# %%
df.loc(1)['bank'][1]
# Out:
# "{'Richart': 4, '永豐': 4, '玉山': 17, '國泰': 1, 'KOKO': 2, '兆豐': 2, '中信': 1, '台新': 1}"

# %%
#df=pd.read_excel(r'D:/Google雲端硬碟/資料分析師班/專題/credit_card/credit_card/youtube_crawl/jieba/video_df2ex_utf16_seg.xlsx',encoding='utf-16')
df1=pd.read_excel(r'E:\專題\credit_card\DB104\jieba/video_df2ex_utf16_seg.xlsx',encoding='utf-16')

# %%
bank={'中信':'中信','中國信託':'中信' ,'玉山':'玉山','Richart':'Richart', 'richart':'Richart','KOKO':'KOKO','koko':'KOKO',
       '國泰':'國泰','國泰世華':'國泰','台新':'台新','永豐':'永豐','兆豐':'兆豐'}
#bank =[{'中信':['中信','中國信託'] },{'玉山':'玉山'} ,{'Richart':['richart', 'Richart']},{'KOKO':['KOKO','koko']},
#       {'國泰':['國泰', '國泰世華']},{'台新':'台新'},{'永豐':'永豐'},{'兆豐':'兆豐銀'}]
card={'linepay':'Linepay','Linepay':'Linepay','LinePay':'Linepay','LINEPAY':'Linepay','GOGO':'GOGO','gogo':'GOGO',
       'flygo':'Flygo','Flygo':'Flygo','FLYGO':'Flygo','大戶':'dawho','dawho':'dawho','Dawho':'dawho',
       'PI':'Pi','Pi':'Pi','pi卡':'Pi','PI卡':'Pi','ubear':'Ubear','UBEAR':'Ubear','Ubear':'Ubear','ubear':'Ubear',
      'only':'Only','ONLY':'Only','Only':'Only'}

behavior={'跑步':'運動','健身房':'運動','運動':'運動','旅遊':'旅遊','旅行':'旅遊','機票':'旅遊','飯店':'旅遊','機場':'旅遊','旅平險':'旅遊','出國':'旅遊','保險':'保險','保費':'保險',
         '加油':'加油','中油':'加油','國外':'國外','海外':'國外','電影':'電影','國賓':'電影','威秀':'電影'}

# card=[{'linepay':['Linepay','linepay','LinePay','LINEPAY']},{'GOGO':['GOGO','gogo']},{'flygo':['Flygo','flygo']},
#       {'dawho':['大戶','dawho','Dawho']},{'PI':['pi','Pi','pi卡','PI卡']},{'ubear':['UBEAR','Ubear','ubear','UBear']}]

# behavior=[{'運動':['跑步','健身房','運動']},{'旅遊':['旅遊','旅行','機票','飯店','機場','旅平險','出國']},{'保險':['保險','保費']},
#          {'加油':['加油','中油']},{'國外':['海外','國外']}]

# %%
n=len(df1)
bank_tag=[]
for article in range(n):
    article_bank=set()
    for word in df['seg'][article].split(' '):
            if word in bank:
                article_bank.add(bank[word])
    bank_tag.append(list(article_bank))
print(bank_tag)
# Out:
# [['台新', '玉山', 'Richart', '永豐'], ['國泰', '永豐', '中信', '台新', '兆豐', 'KOKO', '玉山', 'Richart'], ['國泰', '永豐', '中信', '台新', '兆豐', 'KOKO', '玉山', 'Richart'], ['國泰', '永豐', '中信', '兆豐', 'KOKO', '玉山', 'Richart'], ['國泰', '永豐', '中信', '兆豐', 'KOKO', '玉山', 'Richart'], ['中信', '永豐', '兆豐', 'KOKO', '玉山', 'Richart'], ['玉山', 'Richart', '永豐'], ['永豐', '中信', '兆豐', 'KOKO', '玉山', 'Richart'], ['國泰', '永豐', '中信', '台新', '兆豐', 'KOKO', '玉山', 'Richart'], [], [], [], [], ['玉山', 'Richart'], [], ['國泰', '永豐', '中信', '兆豐', 'KOKO', '玉山', 'Richart'], [], ['玉山', 'Richart', 'KOKO', '兆豐'], ['玉山', '台新', '中信'], [], ['永豐', '中信', '台新', '兆豐', 'KOKO', '玉山', 'Richart'], ['玉山', 'Richart', '中信', 'KOKO'], ['玉山', '台新', 'Richart', '永豐'], [], ['國泰', '中信', '台新', '兆豐', 'KOKO'], ['玉山'], [], [], [], ['中信', '台新', '兆豐', '玉山', 'Richart'], ['台新', '玉山', '中信'], ['玉山', '台新'], [], ['玉山', '永豐'], [], ['KOKO'], ['中信'], [], [], ['永豐', '中信', '兆豐', 'KOKO', '玉山', 'Richart'], ['國泰', '玉山'], ['玉山', 'Richart', '永豐'], ['國泰', '玉山'], ['Richart'], ['國泰', '永豐', 'KOKO', '玉山', 'Richart'], [], ['國泰', '中信', '台新', 'KOKO', '玉山', 'Richart'], ['國泰', '中信', '台新', '玉山', 'Richart'], ['中信', '兆豐'], [], [], [], ['國泰', '中信', 'KOKO'], [], [], ['玉山'], [], [], ['台新', '玉山', 'Richart', '永豐'], ['玉山', 'Richart', '中信'], ['台新'], [], [], [], [], [], ['中信'], ['國泰', '玉山', '中信'], [], ['台新', '玉山', 'Richart', '永豐'], [], [], [], [], [], [], [], [], [], [], [], ['玉山'], ['台新', 'Richart', '永豐'], [], [], ['國泰', '永豐', '兆豐', 'KOKO', '玉山', 'Richart'], [], [], [], [], ['國泰', '中信', '台新', '兆豐', '玉山', 'Richart'], ['玉山', '中信'], ['國泰', '中信', '台新', 'KOKO', '玉山', 'Richart'], [], ['台新', '玉山', 'Richart', '永豐'], [], [], ['國泰', '中信', '永豐', '兆豐', 'KOKO', '玉山', 'Richart'], [], [], [], [], [], ['玉山', 'Richart', '中信', '永豐'], ['兆豐', 'Richart', '中信'], [], ['台新'], ['國泰', '玉山'], [], [], [], [], [], ['兆豐'], [], [], [], [], [], [], ['台新', '中信'], [], [], [], ['國泰', '台新', 'Richart'], ['台新', 'Richart'], [], [], [], [], [], [], [], [], [], ['國泰'], [], [], ['台新', 'Richart'], [], [], ['Richart'], [], [], [], [], [], ['國泰', '台新', '玉山', 'Richart'], ['中信', 'Richart', '永豐', '兆豐'], [], [], [], ['台新', 'Richart'], ['玉山'], ['玉山'], [], [], [], [], [], [], ['中信'], [], ['台新', '玉山', '兆豐', '中信'], [], [], [], [], [], [], [], [], [], [], [], ['國泰', '台新', 'Richart', 'KOKO'], [], [], [], [], ['玉山'], [], ['台新', 'Richart'], [], [], [], [], ['國泰'], [], [], [], [], [], [], [], ['國泰', 'Richart', '中信'], [], [], ['KOKO'], ['台新', 'Richart'], [], [], ['玉山', 'Richart'], [], ['國泰', 'KOKO'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['玉山'], ['玉山', '台新'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['玉山'], [], [], ['台新'], [], [], [], ['中信', '永豐'], [], [], [], ['台新'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['台新'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['台新'], [], [], [], [], [], [], [], [], [], [], [], [], [], ['國泰', 'KOKO'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['玉山'], [], [], [], [], [], [], [], [], [], ['台新'], [], [], [], [], [], ['玉山'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['玉山'], [], [], [], [], [], [], [], ['玉山'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['兆豐'], [], [], [], [], ['台新', '玉山', '兆豐'], [], [], ['國泰', '中信', '台新', 'KOKO', 'Richart'], [], [], [], ['台新', '玉山'], [], [], [], [], [], [], [], [], ['台新'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['台新'], [], [], ['中信'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['國泰'], [], [], [], ['玉山'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['玉山', '國泰', '中信'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['中信'], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], ['國 ...

# %%
n=len(df1)
card_tag=[]
for article in range(n):
    article_card=set()
    for word in df['seg'][article].split(' '):
            if word in card:
                article_card.add(card[word])
    card_tag.append(list(article_card))
card_tag[:10]
# Out:
# [['Ubear', 'dawho'],
#  ['Ubear', 'Linepay', 'Only', 'dawho', 'GOGO'],
#  ['Ubear', 'Linepay', 'Only', 'dawho', 'GOGO'],
#  ['Ubear', 'Linepay', 'Only', 'dawho', 'Pi', 'GOGO'],
#  ['Ubear', 'Linepay', 'Only', 'dawho', 'GOGO'],
#  ['Ubear', 'Linepay', 'Only', 'dawho', 'GOGO'],
#  ['Pi', 'GOGO', 'dawho', 'Linepay'],
#  ['GOGO', 'Ubear', 'Linepay', 'dawho'],
#  ['Pi', 'Ubear', 'GOGO', 'dawho'],
#  []]

# %%
n=len(df1)
behavior_tag=[]
for article in range(n):
    article_behavior=set()
    for word in df['seg'][article].split(' '):
            if word in behavior:
                article_behavior.add(behavior[word])
    behavior_tag.append(list(article_behavior))

# %%
len(bank_tag)
len(card_tag)
len(behavior_tag)
# Out:
# 570

# %%
alltag=[]
for i in range(100):
    each=card_tag[i]+behavior_tag[i]
    alltag.append(each)

# %%
len(behavior_tag)
# Out:
# 570

# %%
len(card_tag)
# Out:
# 570

# %%
behavior_tag[1]
# Out:
# ['加油', '國外', '旅遊', '電影']

# %%
 alltag
# Out:
# [['台新', '玉山', 'Richart', '永豐', 'Ubear', 'dawho', '加油', '保險', '國外', '旅遊'],
#  ['國泰',
#   '永豐',
#   '中信',
#   '台新',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['國泰',
#   '永豐',
#   '中信',
#   '台新',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['國泰',
#   '永豐',
#   '中信',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'Pi',
#   'GOGO',
#   '加油',
#   '保險',
#   '國外',
#   '旅遊',
#   '運動',
#   '電影'],
#  ['國泰',
#   '永豐',
#   '中信',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['中信',
#   '永豐',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['玉山', 'Richart', '永豐', 'Pi', 'GOGO', 'dawho', 'Linepay', '加油', '國外', '旅遊'],
#  ['永豐',
#   '中信',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'GOGO',
#   'Ubear',
#   'Linepay',
#   'dawho',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['國泰',
#   '永豐',
#   '中信',
#   '台新',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Pi',
#   'Ubear',
#   'GOGO',
#   'dawho',
#   '國外',
#   '旅遊'],
#  [],
#  ['國外', '旅遊'],
#  ['國外', '旅遊'],
#  [],
#  ['玉山', 'Richart', 'Pi', 'GOGO', '保險', '國外', '旅遊', '電影'],
#  [],
#  ['國泰',
#   '永豐',
#   '中信',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'GOGO',
#   'Ubear',
#   'Linepay',
#   'dawho',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  [],
#  ['玉山', 'Richart', 'KOKO', '兆豐', 'GOGO', '加油', '國外'],
#  ['玉山', '台新', '中信', 'Pi', 'Linepay'],
#  ['旅遊'],
#  ['永豐',
#   '中信',
#   '台新',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['玉山', 'Richart', '中信', 'KOKO', 'Ubear', 'GOGO', 'Linepay', '加油', '國外', '旅遊'],
#  ['玉山', '台新', 'Richart', '永豐', 'Flygo', 'GOGO', 'dawho', '加油', '國外', '旅遊'],
#  [],
#  ['國泰', '中信', '台新', '兆豐', 'KOKO', 'GOGO', '加油', '國外'],
#  ['玉山', 'Ubear', 'Linepay', '加油', '國外', '電影'],
#  ['加油'],
#  [],
#  [],
#  ['中信', '台新', '兆豐', '玉山', 'Richart', 'Pi', 'Flygo', 'GOGO', '加油', '國外', '旅遊'],
#  ['台新', '玉山', '中信', 'Pi', '保險'],
#  ['玉山', '台新', 'Ubear'],
#  [],
#  ['玉山', '永豐', 'dawho', '國外', '旅遊'],
#  [],
#  ['KOKO', '國外', '旅遊'],
#  ['中信', '電影'],
#  [],
#  [],
#  ['永豐',
#   '中信',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'GOGO',
#   'dawho',
#   'Linepay',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['國泰', '玉山', '旅遊'],
#  ['玉山', 'Richart', '永豐', 'Pi', 'Flygo', 'GOGO', '加油', '保險', '國外', '旅遊', '電影'],
#  ['國泰', '玉山', 'Pi', '旅遊'],
#  ['Richart', 'Linepay', '加油', '國外', '旅遊'],
#  ['國泰',
#   '永豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'dawho',
#   'Pi',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '運動'],
#  ['旅遊'],
#  ['國泰',
#   '中信',
#   '台新',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'GOGO',
#   'Only',
#   'Ubear',
#   'Linepay',
#   '加油',
#   '國外'],
#  ['國泰', '中信', '台新', '玉山', 'Richart', 'Pi', 'GOGO', 'Linepay', '加油'],
#  ['中信', '兆豐', '國外', '旅遊', '電影'],
#  [],
#  [],
#  [],
#  ['國泰', '中信', 'KOKO', '國外', '旅遊'],
#  [],
#  [],
#  ['玉山', 'Only', 'Ubear', '加油', '國外', '旅遊'],
#  [],
#  [],
#  ['台新',
#   '玉山',
#   'Richart',
#   '永豐',
#   'GOGO',
#   'Pi',
#   'Ubear',
#   'Linepay',
#   '加油',
#   '國外',
#   '旅遊'],
#  ['玉山', 'Richart', '中信', 'GOGO', 'Linepay', '加油', '保險', '國外'],
#  ['台新', '運動'],
#  [],
#  ['加油', '保險'],
#  [],
#  ['旅遊'],
#  [],
#  ['中信', 'Flygo', 'Linepay'],
#  ['國泰', '玉山', '中信', 'Pi'],
#  [],
#  ['台新',
#   '玉山',
#   'Richart',
#   '永豐',
#   'Pi',
#   'Flygo',
#   'GOGO',
#   'dawho',
#   '加油',
#   '國外',
#   '旅遊'],
#  ['旅遊'],
#  [],
#  ['國外', '旅遊'],
#  ['電影'],
#  ['國外'],
#  [],
#  ['旅遊'],
#  ['運動'],
#  [],
#  ['旅遊'],
#  ['旅遊'],
#  ['玉山'],
#  ['台新', 'Richart', '永豐', 'dawho', '加油', '國外', '旅遊'],
#  [],
#  [],
#  ['國泰', '永豐', '兆豐', 'KOKO', '玉山', 'Richart', 'Pi', 'dawho', '國外'],
#  ['旅遊'],
#  [],
#  ['國外'],
#  ['國外'],
#  ['國泰', '中信', '台新', '兆豐', '玉山', 'Richart', 'Pi', 'Flygo', '加油', '保險', '國外'],
#  ['玉山', '中信', 'Pi', '加油', '保險'],
#  ['國泰', '中信', '台新', 'KOKO', '玉山', 'Richart', 'GOGO', 'Linepay'],
#  [],
#  ['台新', '玉山', 'Richart', '永豐', 'Pi', 'GOGO'],
#  ['旅遊'],
#  ['國外', '旅遊'],
#  ['國泰',
#   '中信',
#   '永豐',
#   '兆豐',
#   'KOKO',
#   '玉山',
#   'Richart',
#   'Ubear',
#   'Linepay',
#   'Only',
#   'dawho',
#   'GOGO',
#   '加油',
#   '國外',
#   '旅遊',
#   '電影'],
#  ['旅遊'],
#  ['旅遊']]

# %%
te = TransactionEncoder()
te_ary = te.fit(alltag).transform(alltag)
df2 = pd.DataFrame(te_ary, columns=te.columns_)
frequent_itemsets = apriori(df2, min_support=0.15, use_colnames=True)

frequent_itemsets
# Out:
#     support                  itemsets
# 0      0.27                    (GOGO)
# 1      0.22                 (Linepay)
# 2      0.18                      (Pi)
# 3      0.19                   (Ubear)
# 4      0.19                   (dawho)
# 5      0.32                      (加油)
# 6      0.42                      (國外)
# 7      0.45                      (旅遊)
# 8      0.16                      (電影)
# 9      0.18           (GOGO, Linepay)
# 10     0.15             (Ubear, GOGO)
# 11     0.15             (GOGO, dawho)
# 12     0.23                (加油, GOGO)
# 13     0.24                (國外, GOGO)
# 14     0.20                (旅遊, GOGO)
# 15     0.15          (Ubear, Linepay)
# 16     0.19             (加油, Linepay)
# 17     0.18             (國外, Linepay)
# 18     0.15             (旅遊, Linepay)
# 19     0.17               (加油, Ubear)
# 20     0.18               (Ubear, 國外)
# 21     0.16               (Ubear, 旅遊)
# 22     0.16               (加油, dawho)
# 23     0.19               (國外, dawho)
# 24     0.18               (旅遊, dawho)
# 25     0.28                  (加油, 國外)
# 26     0.22                  (加油, 旅遊)
# 27     0.32                  (國外, 旅遊)
# 28     0.17       (加油, GOGO, Linepay)
# 29     0.16       (國外, GOGO, Linepay)
# 30     0.15         (Ubear, 國外, GOGO)
# 31     0.15         (國外, GOGO, dawho)
# 32     0.15         (旅遊, GOGO, dawho)
# 33     0.22            (加油, 國外, GOGO)
# 34     0.18            (旅遊, 加油, GOGO)
# 35     0.20            (旅遊, 國外, GOGO)
# 36     0.15      (加油, Ubear, Linepay)
# 37     0.15      (Ubear, 國外, Linepay)
# 38     0.18         (加油, 國外, Linepay)
# 39     0.15         (旅遊, 加油, Linepay)
# 40     0.15         (旅遊, 國外, Linepay)
# 41     0.17           (加油, Ubear, 國外)
# 42     0.15           (加油, Ubear, 旅遊)
# 43     0.16           (Ubear, 國外, 旅遊)
# 44     0.16           (加油, 國外, dawho)
# 45     0.16           (加油, 旅遊, dawho)
# 46     0.18           (國外, 旅遊, dawho)
# 47     0.22              (加油, 國外, 旅遊)
# 48     0.16   (加油, 國外, GOGO, Linepay)
# 49     0.15     (旅遊, 國外, GOGO, dawho)
# 50     0.18        (旅遊, 加油, 國外, GOGO)
# 51     0.15  (加油, Ubear, 國外, Linepay)
# 52     0.15     (旅遊, 加油, 國外, Linepay)
# 53     0.15       (加油, Ubear, 國外, 旅遊)
# 54     0.16       (加油, 國外, 旅遊, dawho)

# %%
df2
# Out:
#     Flygo   GOGO   KOKO  Linepay   Only     Pi  Richart  Ubear  dawho     中信  \
# 0   False  False  False    False  False  False     True   True   True  False
# 1   False   True   True     True   True  False     True   True   True   True
# 2   False   True   True     True   True  False     True   True   True   True
# 3   False   True   True     True   True   True     True   True   True   True
# 4   False   True   True     True   True  False     True   True   True   True
# 5   False   True   True     True   True  False     True   True   True   True
# 6   False   True  False     True  False   True     True  False   True  False
# 7   False   True   True     True  False  False     True   True   True   True
# 8   False   True   True    False  False   True     True   True   True   True
# 9   False  False  False    False  False  False    False  False  False  False
# 10  False  False  False    False  False  False    False  False  False  False
# 11  False  False  False    False  False  False    False  False  False  False
# 12  False  False  False    False  False  False    False  False  False  False
# 13  False   True  False    False  False   True     True  False  False  False
# 14  False  False  False    False  False  False    False  False  False  False
# 15  False   True   True     True  False  False     True   True   True   True
# 16  False  False  False    False  False  False    False  False  False  False
# 17  False   True   True    False  False  False     True  False  False  False
# 18  False  False  False     True  False   True    False  False  False   True
# 19  False  False  False    False  False  False    False  False  False  False
# 20  False   True   True     True   True  False     True   True   True   True
# 21  False   True   True     True  False  False     True   True  False   True
# 22   True   True  False    False  False  False     True  False   True  False
# 23  False  False  False    False  False  False    False  False  False  False
# 24  False   True   True    False  False  False    False  False  False   True
# 25  False  False  False     True  False  False    False   True  False  False
# 26  False  False  False    False  False  False    False  False  False  False
# 27  False  False  False    False  False  False    False  False  False  False
# 28  False  False  False    False  False  False    False  False  False  False
# 29   True   True  False    False  False   True     True  False  False   True
# ..    ...    ...    ...      ...    ...    ...      ...    ...    ...    ...
# 70  False  False  False    False  False  False    False  False  False  False
# 71  False  False  False    False  False  False    False  False  False  False
# 72  False  False  False    False  False  False    False  False  False  False
# 73  False  False  False    False  False  False    False  False  False  False
# 74  False  False  False    False  False  False    False  False  False  False
# 75  False  False  False    False  False  False    False  False  False  False
# 76  False  False  False    False  False  False    False  False  False  False
# 77  False  False  False    False  False  False    False  False  False  False
# 78  False  False  False    False  False  False    False  False  False  False
# 79  False  False  False    False  False  False    False  False  False  False
# 80  False  False  False    False  False  False    False  False  False  False
# 81  False  False  False    False  False  False    False  False  False  False
# 82  False  False  False    False  False  False     True  False   True  False
# 83  False  False  False    False  False  False    False  False  False  False
# 84  False  False  False    False  False  False    False  False  False  False
# 85  False  False   True    False  False   True     True  False   True  False
# 86  False  False  False    False  False  False    False  False  False  False
# 87  False  False  False    False  False  False    False  False  False  False
# 88  False  False  False    False  False  False    False  False  False  False
# 85  ...   True  False  False   True   True  False   True   True  False  False
# 86  ...  False  False  False  False  False   True  False  False  False  False
# 87  ...  False  False  False  False  False  False  False  False  False  False
# 88  ...  False  False  False   True  False  False  False  False  False  False
# 89  ...  False  False  False   True  False  False  False  False  False  False
# 90  ...   True   True   True   True   True  False  False   True  False  False
# 91  ...  False   True  False  False  False  False  False   True  False  False
# 92  ...  False  False   True  False   True  False  False   True  False  False
# 93  ...  False  False  False  False  False  False  False  False  False  False
# 94  ...  False  False   True  False  False  False   True   True  False  False
# 95  ...  False  False  False  False  False   True  False  False  False  False
# 96  ...  False  False  False   True  False   True  False  False  False  False
# 97  ...   True   True  False   True   True   True   True   True  False   True
# 98  ...  False  False  False  False  False   True  False  False  False  False
# 99  ...  False  False  False  False  False   True  False  False  False  False
#
# [100 rows x 21 columns]

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
# Out:
#               antecedents        consequents  antecedent support  \
# 0               (Linepay)             (GOGO)                0.22
# 1                 (Ubear)             (GOGO)                0.19
# 2                 (dawho)             (GOGO)                0.19
# 3                    (加油)             (GOGO)                0.32
# 4                  (GOGO)               (加油)                0.27
# 5                  (GOGO)               (國外)                0.27
# 6                  (GOGO)               (旅遊)                0.27
# 7                 (Ubear)          (Linepay)                0.19
# 8               (Linepay)               (加油)                0.22
# 9               (Linepay)               (國外)                0.22
# 10                (Ubear)               (加油)                0.19
# 11                (Ubear)               (國外)                0.19
# 12                (Ubear)               (旅遊)                0.19
# 13                (dawho)               (加油)                0.19
# 14                (dawho)               (國外)                0.19
# 15                (dawho)               (旅遊)                0.19
# 16                   (加油)               (國外)                0.32
# 17                   (國外)               (旅遊)                0.42
# 18                   (旅遊)               (國外)                0.45
# 19             (加油, GOGO)          (Linepay)                0.23
# 20          (加油, Linepay)             (GOGO)                0.19
# 21        (GOGO, Linepay)               (加油)                0.18
# 22              (Linepay)         (加油, GOGO)                0.22
# 23          (國外, Linepay)             (GOGO)                0.18
# 24        (GOGO, Linepay)               (國外)                0.18
# 25              (Linepay)         (國外, GOGO)                0.22
# 26            (Ubear, 國外)             (GOGO)                0.18
# 27          (Ubear, GOGO)               (國外)                0.15
# 28                (Ubear)         (國外, GOGO)                0.19
# 29            (國外, dawho)             (GOGO)                0.19
# ..                    ...                ...                 ...
# 109     (加油, 國外, Linepay)            (Ubear)                0.18
# 110  (Ubear, 國外, Linepay)               (加油)                0.15
# 111           (加油, Ubear)      (國外, Linepay)                0.17
# 112         (加油, Linepay)        (Ubear, 國外)                0.19
# 113           (Ubear, 國外)      (加油, Linepay)                0.18
# 114      (Ubear, Linepay)           (加油, 國外)                0.15
# 115         (國外, Linepay)        (加油, Ubear)                0.18
# 116               (Ubear)  (加油, 國外, Linepay)                0.19
# 117     (加油, 旅遊, Linepay)               (國外)                0.15
# 118     (國外, 旅遊, Linepay)               (加油)                0.15
# 119     (加油, 國外, Linepay)               (旅遊)                0.18
# 120         (旅遊, Linepay)           (加油, 國外)                0.15
# 121         (加油, Linepay)           (國外, 旅遊)                0.19
# 110                0.32     0.15    1.000000  3.125000    0.1020         inf
# 111                0.18     0.15    0.882353  4.901961    0.1194    6.970000
# 112                0.18     0.15    0.789474  4.385965    0.1158    3.895000
# 113                0.19     0.15    0.833333  4.385965    0.1158    4.860000
# 114                0.28     0.15    1.000000  3.571429    0.1080         inf
# 115                0.17     0.15    0.833333  4.901961    0.1194    4.980000
# 116                0.18     0.15    0.789474  4.385965    0.1158    3.895000
# 117                0.42     0.15    1.000000  2.380952    0.0870         inf
# 118                0.32     0.15    1.000000  3.125000    0.1020         inf
# 119                0.45     0.15    0.833333  1.851852    0.0690    3.300000
# 120                0.28     0.15    1.000000  3.571429    0.1080         inf
# 121                0.32     0.15    0.789474  2.467105    0.0892    3.230000
# 122                0.22     0.15    0.833333  3.787879    0.1104    4.680000
# 123                0.45     0.15    0.882353  1.960784    0.0735    4.675000
# 124                0.42     0.15    1.000000  2.380952    0.0870         inf
# 125                0.32     0.15    0.937500  2.929688    0.0988   10.880000
# 126                0.32     0.15    0.882353  2.757353    0.0956    5.780000
# 127                0.22     0.15    0.833333  3.787879    0.1104    4.680000
# 128                0.28     0.15    0.937500  3.348214    0.1052   11.520000
# 129                0.22     0.15    0.789474  3.588517    0.1082    3.705000
# 130                0.19     0.16    0.727273  3.827751    0.1182    2.970000
# 131                0.45     0.16    1.000000  2.222222    0.0880         inf
# 132                0.42     0.16    1.000000  2.380952    0.0928         inf
# 133                0.32     0.16    0.888889  2.777778    0.1024    6.120000
# 134                0.19     0.16    0.727273  3.827751    0.1182    2.970000
# 135                0.32     0.16    1.000000  3.125000    0.1088         inf
# 136                0.22     0.16    0.842105  3.827751    0.1182    4.940000
# 137                0.28     0.16    0.888889  3.174603    0.1096    6.480000
# 138                0.22     0.16    0.842105  3.827751    0.1182    4.940000
#
# [139 rows x 9 columns]

# %%
from mlxtend.frequent_patterns import association_rules

association_rules(frequent_itemsets, metric="lift", min_threshold=3)
# Out:
#            antecedents           consequents  antecedent support  \
# 0               (GOGO)             (Linepay)                0.27
# 1            (Linepay)                (GOGO)                0.22
# 2              (Ubear)             (Linepay)                0.19
# 3            (Linepay)               (Ubear)                0.22
# 4           (加油, GOGO)             (Linepay)                0.23
# 5        (加油, Linepay)                (GOGO)                0.19
# 6               (GOGO)         (加油, Linepay)                0.27
# 7            (Linepay)            (加油, GOGO)                0.22
# 8           (國外, GOGO)             (Linepay)                0.24
# 9        (國外, Linepay)                (GOGO)                0.18
# 10              (GOGO)         (國外, Linepay)                0.27
# 11           (Linepay)            (國外, GOGO)                0.22
# 12         (Ubear, 國外)                (GOGO)                0.18
# 13          (國外, GOGO)               (Ubear)                0.24
# 14             (Ubear)            (國外, GOGO)                0.19
# 15              (GOGO)           (Ubear, 國外)                0.27
# 16          (國外, GOGO)               (dawho)                0.24
# 17             (dawho)            (國外, GOGO)                0.19
# 18          (GOGO, 旅遊)               (dawho)                0.20
# 19         (旅遊, dawho)                (GOGO)                0.18
# 20              (GOGO)           (旅遊, dawho)                0.27
# 21             (dawho)            (GOGO, 旅遊)                0.19
# 22            (加油, 旅遊)                (GOGO)                0.22
# 23              (GOGO)              (加油, 旅遊)                0.27
# 24         (加油, Ubear)             (Linepay)                0.17
# 25       (加油, Linepay)               (Ubear)                0.19
# 26    (Ubear, Linepay)                  (加油)                0.15
# 27                (加油)      (Ubear, Linepay)                0.32
# 28             (Ubear)         (加油, Linepay)                0.19
# 29           (Linepay)           (加油, Ubear)                0.22
# ..                 ...                   ...                 ...
# 80            (加油, 國外)      (Ubear, Linepay)                0.28
# 81       (加油, Linepay)           (Ubear, 國外)                0.19
# 82         (Ubear, 國外)         (加油, Linepay)                0.18
# 83    (Ubear, Linepay)              (加油, 國外)                0.15
# 84       (國外, Linepay)           (加油, Ubear)                0.18
# 85                (加油)  (Ubear, 國外, Linepay)                0.32
# 86             (Ubear)     (加油, 國外, Linepay)                0.19
# 87           (Linepay)       (加油, Ubear, 國外)                0.22
# 88        (加油, 國外, 旅遊)             (Linepay)                0.22
# 89   (國外, 旅遊, Linepay)                  (加油)                0.15
# 90            (加油, 旅遊)         (國外, Linepay)                0.22
# 91       (旅遊, Linepay)              (加油, 國外)                0.15
# 92            (加油, 國外)         (旅遊, Linepay)                0.28
# 93       (國外, Linepay)              (加油, 旅遊)                0.18
# 94                (加油)     (國外, 旅遊, Linepay)                0.32
# 95           (Linepay)          (加油, 國外, 旅遊)                0.22
# 96        (加油, 國外, 旅遊)               (Ubear)                0.22
# 97            (加油, 國外)           (Ubear, 旅遊)                0.28
# 98            (加油, 旅遊)           (Ubear, 國外)                0.22
# 99         (Ubear, 國外)              (加油, 旅遊)                0.18
# 100        (Ubear, 旅遊)              (加油, 國外)                0.16
# 101            (Ubear)          (加油, 國外, 旅遊)                0.19
# 102       (加油, 國外, 旅遊)               (dawho)                0.22
# 103           (加油, 國外)           (旅遊, dawho)                0.28
# 104           (加油, 旅遊)           (國外, dawho)                0.22
# 105        (加油, dawho)              (國外, 旅遊)                0.16
# 106           (國外, 旅遊)           (加油, dawho)                0.32
# 107        (國外, dawho)              (加油, 旅遊)                0.19
# 108        (旅遊, dawho)              (加油, 國外)                0.18
# 109            (dawho)          (加油, 國外, 旅遊)                0.19
#
#      consequent support  support  confidence      lift  leverage  conviction
# 0                  0.22     0.18    0.666667  3.030303    0.1206    2.340000
# 1                  0.27     0.18    0.818182  3.030303    0.1206    4.015000
# 2                  0.22     0.15    0.789474  3.588517    0.1082    3.705000
# 3                  0.19     0.15    0.681818  3.588517    0.1082    2.545714
# 4                  0.22     0.17    0.739130  3.359684    0.1194    2.990000
# 5                  0.27     0.17    0.894737  3.313840    0.1187    6.935000
# 6                  0.19     0.17    0.629630  3.313840    0.1187    2.187000
# 7                  0.23     0.17    0.772727  3.359684    0.1194    3.388000
# 8                  0.22     0.16    0.666667  3.030303    0.1072    2.340000
# 9                  0.27     0.16    0.888889  3.292181    0.1114    6.570000
# 10                 0.18     0.16    0.592593  3.292181    0.1114    2.012727
# 11                 0.24     0.16    0.727273  3.030303    0.1072    2.786667
# 12                 0.27     0.15    0.833333  3.086420    0.1014    4.380000
# 13                 0.19     0.15    0.625000  3.289474    0.1044    2.160000
