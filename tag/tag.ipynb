# %%
import jieba
import json
import pandas as pd
import os

# %%
df=pd.read_excel(r'D:/Google雲端硬碟/資料分析師班/專題/credit_card/credit_card/youtube_crawl/jieba/video_df2ex_utf16_seg.xlsx',encoding='utf-16')

# %%
df1=df
df1['bank']=None
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-e98763658b2f> in <module>
#       1 df1=df
#       2 df1['bank']=None
# ----> 3 df1[1]
#
# ...

# %%
bank={'中信':['中信','中國信託'] ,'玉山':'玉山','Richart':['richart', 'Richart'],'KOKO':['KOKO','koko'],
       '國泰':['國泰', '國泰世華'],'台新':'台新','永豐':'永豐','兆豐':'兆豐銀'}
#bank =[{'中信':['中信','中國信託'] },{'玉山':'玉山'} ,{'Richart':['richart', 'Richart']},{'KOKO':['KOKO','koko']},
#       {'國泰':['國泰', '國泰世華']},{'台新':'台新'},{'永豐':'永豐'},{'兆豐':'兆豐銀'}]

card=[{'linepay':['Linepay','linepay','LinePay','LINEPAY']},{'GOGO':['GOGO','gogo']},{'flygo':['Flygo','flygo']},
      {'dawho':['大戶','dawho','Dawho']},{'PI':['pi','Pi','pi卡','PI卡']},{'ubear':['UBEAR','Ubear','ubear','UBear']}]

behavior=[{'運動':['跑步','健身房','運動']},{'旅遊':['旅遊','旅行','機票','飯店','機場','旅平險','出國']},{'保險':['保險','保費']},
         {'加油':['加油','中油']},{'國外':['海外','國外']}]

# %%
#n=len(df)
article_bank=[]
for article in range(1):
    for word in df['seg'][article].split('\n'):
        for b in bank1:
            if word in bank1[b]:
                print(b)
                #article_bank.append(b)
#print(article_bank)

# %%
bank =[{'中信':['中信','中國信託'] },{'玉山':'玉山'} ,{'Richart':['richart', 'Richart']},{'KOKO':['KOKO','koko']},
       {'國泰':['國泰', '國泰世華']},{'台新':'台新'},{'永豐':'永豐'},{'兆豐':'兆豐銀'}]




behavior=[{'運動':['跑步','健身房','運動']},{'旅遊':['旅遊','旅行','機票','飯店','機場','旅平險','出國']},{'保險':['保險','保費']},
         {'加油':['加油','中油']},{'國外':['海外','國外']}]

card=[{'linepay':['Linepay','linepay','LinePay','LINEPAY']},{'GOGO':['GOGO','gogo']},{'flygo':['Flygo','flygo']},
      {'dawho':['大戶','dawho','Dawho']},{'PI':['pi','Pi','pi卡','PI卡']},{'ubear':['UBEAR','Ubear','ubear','UBear']}]


#KOKO 花旗  匯豐 星展  彰銀 彰化 彰銀 第一 一銀  
#兆豐銀 渣打 凱基 元大 樂天 華南 富邦 上海  王道 新光 聯邦  樂天]
''''
信用卡: 
Linepay : linepay LinePay Linepay

lcardcard=l    
GOGO : GOOG gogo
flygo : Flygo flygo
大戶:  大戶 dahowho Dawho
Pi: pi 拍卡 Pi  PI
ubear: UBEAR Ubear ubear
only: ONLY  only 
賴點: 賴點卡 賴點
樂天
Omiyage


行為

運動:  跑步  健身房
旅遊:  旅遊 旅行 機票 飯店 
國外:  國外  海外
網購:  網購 網拍  蝦皮 電商
保險:  保險 保費
加油:  加油
現金回饋:  現金回饋
紅利: 紅利點數 紅利
百貨:  新光三越  SOGO sogo 遠百

'''
# Out:
# "'\n信用卡: \nLinepay : linepay LinePay Linepay\n\nlcardcard=l    \nGOGO : GOOG gogo\nflygo : Flygo flygo\n大戶:  大戶 dahowho Dawho\nPi: pi 拍卡 Pi  PI\nubear: UBEAR Ubear ubear\nonly: ONLY  only \n賴點: 賴點卡 賴點\n樂天\nOmiyage\n\n\n行為\n\n運動:  跑步  健身房\n旅遊:  旅遊 旅行 機票 飯店 \n國外:  國外  海外\n網購:  網購 網拍  蝦皮 電商\n保險:  保險 保費\n加油:  加油\n現金回饋:  現金回饋\n紅利: 紅利點數 紅利\n百貨:  新光三越  SOGO sogo 遠百\n\n"

# %%
for i in bank:
    for v in i.values():
        print(v)
        #print('中國信託' in v)
    #print('中國信託' in i.values())
# Out:
# ['中信', '中國信託']
# 玉山
# ['richart', 'Richart']
# ['KOKO', 'koko']
# ['國泰', '國泰世華']
# 台新
# 永豐
# 兆豐銀

# %%
for i in bank:
    for v in i.values():
        print(i.keys()[0])
    
        #print('中國信託' in v)
    #print('中國信託' in i.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-1460f5439e42> in <module>
#       1 for i in bank:
#       2     for v in i.values():
# ----> 3         print(i.keys()[0])
#       4
#       5         #print('中國信託' in v)
#
# TypeError: 'dict_keys' object is not subscriptable

# %%
for word in df['seg'][1].split(' '):
        for b in bank:
            if word in bank[b]:
                print(True)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %%
s=['中國信託','123','Richart','koko','銀行',' ']
for w in s:
    for i in bank1:
        if w in bank1[i]:
            print(i)
            #print(w)
# Out:
# 中信
# Richart
# KOKO

# %%
bank1 ={'中信':['中信','中國信託'] ,'玉山':'玉山','Richart':['richart', 'Richart'],'KOKO':['KOKO','koko'],
       '國泰':['國泰', '國泰世華'],'台新':'台新','永豐':'永豐','兆豐':'兆豐銀'}

# %%
[[v for v in i.values()] for i in bank]
# Out:
# [[['中信', '中國信託']],
#  ['玉山'],
#  [['richart', 'Richart']],
#  [['KOKO', 'koko']],
#  [['國泰', '國泰世華']],
#  ['台新'],
#  ['永豐'],
#  ['兆豐銀']]

# %%
df1[:1]
# Out:
#    Unnamed: 0  Unnamed: 0.1                                 title  \
# 0           0             0  【2019下半年必辦信用卡】超高8%現金回饋！海外、網路消費「無腦理財」
#
#                                            link        date    views  \
# 0  https://www.youtube.com//watch?v=5Kt5gqDyvQE  2019年8月27日  129,798
#
#                                          description  \
# 0  抱歉久等了！我為了這單元整理了好幾天！因為信用卡優惠一直在變，而且每次整理完，新的信用卡又出...
#
#                                              comment  \
# 0  【找關韶文來這裡】👉🏻\nFB ‣ https://www.facebook.com/eth...
#
#                                                  seg  \
# 0  2019 下半年 必辦 信用卡 超高 8% 現金回饋 海外 網路 消費 無腦 理財 \n 抱...
#
#                                            word_freq  bank
# 0  [('\n', 79), ('回饋', 17), ('消費', 14), ('卡', 12)...  None

# %%
x=df['seg'][article].split(' ')
#print(x)
for i in x:
    for b in bank1:
        if i in bank1[b]:
            print(i)
            #print(b)
# Out:
# 玉山
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 玉山
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 台新
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 永豐
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Richart
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 台新
#
#
#
#
#
#
#
#
# Richart
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Richart
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Richart
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Richart
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 永豐
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 玉山
# 玉山

# %%
x
# Out:
# ['2019',
#  '下半年',
#  '必辦',
#  '信用卡',
#  '超高',
#  '8%',
#  '現金回饋',
#  '海外',
#  '網路',
#  '消費',
#  '無腦',
#  '理財',
#  '\n',
#  '抱歉',
#  '久等',
#  '單元',
#  '整理',
#  '好幾天',
#  '信用卡',
#  '優惠',
#  '一直在',
#  '變',
#  '每次',
#  '整理',
#  '完',
#  '新的',
#  '信用卡',
#  '私訊',
#  '爆炸',
#  '每天',
#  '狂',
#  '被問',
#  '應該',
#  '辦',
#  '卡',
#  '現在',
#  '請',
#  '我樣',
#  '做',
#  '\n',
#  '\n',
#  '以前',
#  '教',
#  '要將',
#  '消費',
#  '分為',
#  '種',
#  '實體',
#  '消費',
#  '網路',
#  '消費',
#  '海外',
#  '消費',
#  '2019',
#  '下半年',
#  '信用卡',
#  '排行',
#  '洗牌',
#  '所有',
#  '回饋',
#  '強',
#  '在這裡',
#  '推永豐',
#  '大戶',
#  '卡',
#  '玉山',
#  'Ubear',
#  '卡',
#  '詳細',
#  '使用',
#  '規則',
#  '請看',
#  '影片',
#  '\n',
#  '\n',
#  '喜歡',
#  '這支',
#  '影片',
#  '記得',
#  '蒐',
#  '藏',
#  '轉發',
#  '如果有',
#  '講錯',
#  '想',
#  '了解',
#  '信用卡',
#  '忘記',
#  '留言',
#  '告訴',
#  '\n',
#  '\n',
#  '小資',
#  '男的',
#  '信用卡',
#  '理財',
#  '術',
#  '\n',
#  '一筆',
#  '消費',
#  '都可以',
#  '賺錢',
#  '\n',
#  '聰明',
#  '消費',
#  '才是',
#  '王道',
#  '\n',
#  '\n',
#  '我是',
# ...
