# %%
# !pip install jieba
# !pip install pandas

# %%
import jieba
import json
import pandas as pd
import os

# %%
df=pd.read_excel(r'C:/Users/Big data/Desktop/信用卡1.xlsx',encoding='utf-16')

# %%
df
# Out:
#       Unnamed: 0    ID                         卡片名稱    銀行  \
# 0              1     1             祝福卡商務卡MasterCard  臺灣銀行
# 1              2     2           金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 2              3     3             金采卡白金卡MasterCard  臺灣銀行
# 3              4     4       臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 4              5     5      鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 5              6     6                 國璽聯名卡白金卡VISA  臺灣銀行
# 6              7     7                  國璽聯名卡金卡VISA  臺灣銀行
# 7              8     8             富多卡白金卡MasterCard  臺灣銀行
# 8              9     9              富多卡金卡MasterCard  臺灣銀行
# 9             10    10  政府網路採購卡(虛擬卡)企業採購卡MasterCard  臺灣銀行
# 10            11    11             台灣菸酒採購卡企業採購卡VISA  臺灣銀行
# 11            12    12             商務卡商務卡MasterCard  臺灣銀行
# 12            13    13                    相片卡金卡VISA  臺灣銀行
# 13            14    14                    相片卡普卡VISA  臺灣銀行
# 14            15    15              相片卡金卡MasterCard  臺灣銀行
# ...

# %%
df['現金回饋'][0]
# Out:
# nan

# %%
for ii in df:
    for index,item in enumerate(df[ii]):
        if type(item)!=str:
            df[ii][index]=''
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
for index, item in enumerate(df['現金回饋']):
    #print(item)
    if item=='':
        if df['購物優惠'][index]=='':
            df=df.drop([index])

# for n,i in enumerate(df['現金回饋']):
#     print(i)
#     if i =='':
#         if ''==df['購物優惠'][n]:
#             df=df.drop([n])

# %%
df
# Out:
#      Unnamed: 0 ID                         卡片名稱    銀行  \
# 1                            金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 2                              金采卡白金卡MasterCard  臺灣銀行
# 3                        臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 4                       鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 5                                  國璽聯名卡白金卡VISA  臺灣銀行
# 6                                   國璽聯名卡金卡VISA  臺灣銀行
# 7                              富多卡白金卡MasterCard  臺灣銀行
# 8                               富多卡金卡MasterCard  臺灣銀行
# 11                             商務卡商務卡MasterCard  臺灣銀行
# 12                                    相片卡金卡VISA  臺灣銀行
# 13                                    相片卡普卡VISA  臺灣銀行
# 14                              相片卡金卡MasterCard  臺灣銀行
# 15                              相片卡普卡MasterCard  臺灣銀行
# 16                           紫絲帶認同卡金卡MasterCard  臺灣銀行
# 17                           紫絲帶認同卡普卡MasterCard  臺灣銀行
# 18                                大紀元認同卡白金卡VISA  臺灣銀行
# ...

# %%
df01=pd.DataFrame(columns=['卡片名稱','銀行','現金回饋','購物優惠','旅遊保險','機場接送','機場停車優惠','道路救援','聯名優惠','機場貴賓室','一般停車優惠','紅利集點','點數折抵現金','哩程數累積'])
for n,i in enumerate(df.index):
    df01.loc[n]=df['卡片名稱'][i],df['銀行'][i],df['現金回饋'][i],df['購物優惠'][i],df['旅遊保險'][i],df['機場接送'][i],df['機場停車優惠'][i],df['道路救援'][i],df['聯名優惠'][i],df['機場貴賓室'][i],df['一般停車優惠'][i],df['紅利集點'][i],df['點數折抵現金'][i],df['哩程數累積'][i]

# %%
a=[]
b=[]
for index,n in enumerate(df01['卡片名稱']):
    #print(n)
    if "金卡" in n:
        a.append(index)
    elif "普卡" in n:
        a.append(index)
    else:
        b.append(index)
for n in a:
    j=df01['卡片名稱'][n]
    if '白'in j:
        b.append(n)
    elif'鈦'in j:
        b.append(n)
    
for i in b:
    print(df01['卡片名稱'][i])
# Out:
# 商務卡商務卡MasterCard
# 白沙屯拱天宮媽祖認同卡晶緻卡JCB
# 亞洲微創手術中心認同卡晶緻卡JCB
# 極緻卡極緻卡JCB
# 圓山大飯店JCB一卡通聯名卡晶緻卡JCB
# 澎湖iPASS卡晶緻卡JCB
# JCB一卡通聯名晶緻卡晶緻卡JCB
# 白金商務卡商務卡MasterCard
# 鹿港天后宮晶緻一卡通認同卡晶緻卡JCB
# 利high卡(一卡通聯名卡)晶緻卡JCB
# 哆啦A夢悠遊聯名卡晶緻卡JCB
# 合作金庫世界卡世界卡MasterCard
# JCB悠遊晶緻卡晶緻卡JCB
# 御璽商旅卡御璽卡VISA
# 商務卡商務卡MasterCard
# 合作金庫無限卡無限卡VISA
# 綠活卡(一卡通)御璽卡VISA
# 綠活卡(悠遊卡)御璽卡VISA
# Wonderful星璨卡御璽卡VISA
# 一卡通聯名卡御璽卡VISA
# i-Fun愛玩樂卡晶緻卡JCB
# 一銀JCB卡御守系列晶緻卡JCB
# 商旅卡御璽卡VISA
# 菁英御璽卡御璽卡VISA
# ｉ網購生活卡(彩繪繽紛款)御璽卡VISA
# ｉ網購生活卡(布丁狗款酷企鵝款Hello Kitty)晶緻卡JCB
# 享利樂活combo卡商務御璽卡VISA
# ｉ網購生活卡(美樂蒂雙星仙子)御璽卡VISA
# ｉ網購生活卡(美樂蒂雙星仙子)晶緻卡JCB
# ｉ網購生活卡(正義聯盟)御璽卡VISA
# 夢時代一卡通聯名卡御璽卡VISA
# 夢時代icash 聯名卡無限卡VISA
# 夢時代icash 聯名卡御璽卡VISA
# 臺灣大學卡無限卡VISA
# 臺灣大學卡御璽卡VISA
# 臺灣大學卡商務卡VISA
# 大甲媽祖悠遊認同卡晶緻卡JCB
# ｉ網購生活卡晶緻卡JCB
# 旅鑽個人商務信用卡無限卡VISA
# 旅鑽個人商務信用卡世界卡MasterCard
# 旅鑽個人商務信用卡極緻卡JCB
# 超級現金回饋卡御璽卡VISA
# 超級現金回饋卡晶緻卡JCB
# 新竹市民認同卡晶緻卡JCB
# Combo Life卡御璽卡VISA
# 中國醫藥大學暨附設醫院晶緻認同卡晶緻卡JCB
# LOVE晶緻悠遊聯名卡－酷愛黑卡晶緻卡JCB
# LOVE晶緻悠遊聯名卡－寵愛紅卡晶緻卡JCB
# 旅鑽個人商務信用卡御璽卡VISA
# MasterCard世界卡世界卡MasterCard
# ...

# %%
for n,i in enumerate(df01.index):
    df01.loc[n]=df01['卡片名稱'][i],df01['銀行'][i],df01['現金回饋'][i],df01['購物優惠'][i],df01['旅遊保險'][i],df01['機場接送'][i],df01['機場停車優惠'][i],df01['道路救援'][i],df01['聯名優惠'][i],df01['機場貴賓室'][i],df01['一般停車優惠'][i],df01['紅利集點'][i],df01['點數折抵現金'][i],df01['哩程數累積'][i]

# %%
df01
# Out:
#                             卡片名稱    銀行  \
# 0             金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 1               金采卡白金卡MasterCard  臺灣銀行
# 2         臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 3        鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 4                   國璽聯名卡白金卡VISA  臺灣銀行
# 5                    國璽聯名卡金卡VISA  臺灣銀行
# 6               富多卡白金卡MasterCard  臺灣銀行
# 7                富多卡金卡MasterCard  臺灣銀行
# 8               商務卡商務卡MasterCard  臺灣銀行
# 9                      相片卡金卡VISA  臺灣銀行
# 10                     相片卡普卡VISA  臺灣銀行
# 11               相片卡金卡MasterCard  臺灣銀行
# 12               相片卡普卡MasterCard  臺灣銀行
# 13            紫絲帶認同卡金卡MasterCard  臺灣銀行
# 14            紫絲帶認同卡普卡MasterCard  臺灣銀行
# 15                 大紀元認同卡白金卡VISA  臺灣銀行
# 16                  大紀元認同卡金卡VISA  臺灣銀行
# 17                  大紀元認同卡普卡VISA  臺灣銀行
# 18                   台灣銀行白金卡VISA  臺灣銀行
# 19             台灣銀行白金卡MasterCard  臺灣銀行
# 20          金鑽商旅白金卡商務卡MasterCard  臺灣銀行
# 21            桐花認同卡白金卡MasterCard  臺灣銀行
# 22             桐花認同卡金卡MasterCard  臺灣銀行
# ...

# %%
for i in range(len(df01)):
    if i not in b:
        df01=df01.drop([i])

# %%
df01
# Out:
#                                    卡片名稱    銀行  \
# 0                    金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 1                      金采卡白金卡MasterCard  臺灣銀行
# 2                臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 3               鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 4                          國璽聯名卡白金卡VISA  臺灣銀行
# 6                      富多卡白金卡MasterCard  臺灣銀行
# 8                      商務卡商務卡MasterCard  臺灣銀行
# 15                        大紀元認同卡白金卡VISA  臺灣銀行
# 18                          台灣銀行白金卡VISA  臺灣銀行
# 19                    台灣銀行白金卡MasterCard  臺灣銀行
# 20                 金鑽商旅白金卡商務卡MasterCard  臺灣銀行
# 21                   桐花認同卡白金卡MasterCard  臺灣銀行
# 26             導盲犬認同卡(一卡通)白金卡MasterCard  臺灣銀行
# 44                    白沙屯拱天宮媽祖認同卡晶緻卡JCB  土地銀行
# 45                    亞洲微創手術中心認同卡晶緻卡JCB  土地銀行
# 46                            極緻卡極緻卡JCB  土地銀行
# 47                 圓山大飯店JCB一卡通聯名卡晶緻卡JCB  土地銀行
# 48                       澎湖iPASS卡晶緻卡JCB  土地銀行
# 49                    JCB一卡通聯名晶緻卡晶緻卡JCB  土地銀行
# ...

# %%
df02=pd.DataFrame(columns=['卡片名稱','銀行','現金回饋','購物優惠','旅遊保險','機場接送','機場停車優惠','道路救援','聯名優惠','機場貴賓室','一般停車優惠','紅利集點','點數折抵現金','哩程數累積'])
for n,i in enumerate(df01.index):
    df02.loc[n]=df01['卡片名稱'][i],df01['銀行'][i],df01['現金回饋'][i],df01['購物優惠'][i],df01['旅遊保險'][i],df01['機場接送'][i],df01['機場停車優惠'][i],df01['道路救援'][i],df01['聯名優惠'][i],df01['機場貴賓室'][i],df01['一般停車優惠'][i],df01['紅利集點'][i],df01['點數折抵現金'][i],df01['哩程數累積'][i]

# %%
df02
# Out:
#                                    卡片名稱    銀行  \
# 0                    金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 1                      金采卡白金卡MasterCard  臺灣銀行
# 2                臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 3               鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 4                          國璽聯名卡白金卡VISA  臺灣銀行
# 5                      富多卡白金卡MasterCard  臺灣銀行
# 6                      商務卡商務卡MasterCard  臺灣銀行
# 7                         大紀元認同卡白金卡VISA  臺灣銀行
# 8                           台灣銀行白金卡VISA  臺灣銀行
# 9                     台灣銀行白金卡MasterCard  臺灣銀行
# 10                 金鑽商旅白金卡商務卡MasterCard  臺灣銀行
# 11                   桐花認同卡白金卡MasterCard  臺灣銀行
# 12             導盲犬認同卡(一卡通)白金卡MasterCard  臺灣銀行
# 13                    白沙屯拱天宮媽祖認同卡晶緻卡JCB  土地銀行
# 14                    亞洲微創手術中心認同卡晶緻卡JCB  土地銀行
# 15                            極緻卡極緻卡JCB  土地銀行
# 16                 圓山大飯店JCB一卡通聯名卡晶緻卡JCB  土地銀行
# 17                       澎湖iPASS卡晶緻卡JCB  土地銀行
# 18                    JCB一卡通聯名晶緻卡晶緻卡JCB  土地銀行
# ...

# %%
a=[]
b=[]
for index,n in enumerate(df01['卡片名稱']):
    #print(n)
    if "金卡" in n:
        a.append(index)
    elif "普卡" in n:
        a.append(index)
    else:
        b.append(index)
for n in a:
    j=df01['卡片名稱'][n]
    if '白'in j:
        b.append(n)
    elif'鈦'in j:
        b.append(n)
    
for i in b:
    print(df01['卡片名稱'][i])
# Out:
#                             卡片名稱    銀行  \
# 0             金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 1               金采卡白金卡MasterCard  臺灣銀行
# 2         臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 3        鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 4                   國璽聯名卡白金卡VISA  臺灣銀行
# 5                    國璽聯名卡金卡VISA  臺灣銀行
# 6               富多卡白金卡MasterCard  臺灣銀行
# 7                富多卡金卡MasterCard  臺灣銀行
# 8               商務卡商務卡MasterCard  臺灣銀行
# 9                      相片卡金卡VISA  臺灣銀行
# 10                     相片卡普卡VISA  臺灣銀行
# 11               相片卡金卡MasterCard  臺灣銀行
# 12               相片卡普卡MasterCard  臺灣銀行
# 13            紫絲帶認同卡金卡MasterCard  臺灣銀行
# 14            紫絲帶認同卡普卡MasterCard  臺灣銀行
# 15                 大紀元認同卡白金卡VISA  臺灣銀行
# 16                  大紀元認同卡金卡VISA  臺灣銀行
# 17                  大紀元認同卡普卡VISA  臺灣銀行
# 18                   台灣銀行白金卡VISA  臺灣銀行
# 19             台灣銀行白金卡MasterCard  臺灣銀行
# 20          金鑽商旅白金卡商務卡MasterCard  臺灣銀行
# 21            桐花認同卡白金卡MasterCard  臺灣銀行
# 22             桐花認同卡金卡MasterCard  臺灣銀行
# ...

# %%
df02.to_excel('./card_info_etl.xlsx')

# %%
df03=pd.read_excel(r'C:/Users/Big data/PycharmProjects/PYETL1/card_info_etl.xlsx',encoding='utf-16')

# %%
for ii in df03:
    for index,item in enumerate(df03[ii]):
        if type(item)!=str:
            df03[ii][index]=''
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df03
# Out:
#     Unnamed: 0                                卡片名稱    銀行  \
# 0                               金采鈦商卡鈦金卡MasterCard  臺灣銀行
# 1                                 金采卡白金卡MasterCard  臺灣銀行
# 2                           臺北科大愛校認同卡鈦金卡MasterCard  臺灣銀行
# 3                          鈦金商旅卡(一卡通)鈦金卡MasterCard  臺灣銀行
# 4                                     國璽聯名卡白金卡VISA  臺灣銀行
# 5                                 富多卡白金卡MasterCard  臺灣銀行
# 6                                 商務卡商務卡MasterCard  臺灣銀行
# 7                                    大紀元認同卡白金卡VISA  臺灣銀行
# 8                                      台灣銀行白金卡VISA  臺灣銀行
# 9                                台灣銀行白金卡MasterCard  臺灣銀行
# 10                            金鑽商旅白金卡商務卡MasterCard  臺灣銀行
# 11                              桐花認同卡白金卡MasterCard  臺灣銀行
# 12                        導盲犬認同卡(一卡通)白金卡MasterCard  臺灣銀行
# 13                               白沙屯拱天宮媽祖認同卡晶緻卡JCB  土地銀行
# 14                               亞洲微創手術中心認同卡晶緻卡JCB  土地銀行
# ...

# %%
a=[]
import re
for i in df03['卡片名稱']:

    p=re.sub(r'JCB','',i)
    p=re.sub(r'VISA','',p)
    p=re.sub(r'MasterCard','',p)
    a.append(p)
    
df03['卡片名稱']=a

# %%
re.findall(r'國內:.?.?.?.?.?.?.?.?.?',df03['現金回饋'][0])
# Out:
# '黃金回饋國內：0.2%~1.2% (當月消費消費2,000元~30萬元以上) 國外：1.5%'

# %%
a
# Out:
# ['金采鈦商卡鈦金卡',
#  '金采卡白金卡',
#  '臺北科大愛校認同卡鈦金卡',
#  '鈦金商旅卡(一卡通)鈦金卡',
#  '國璽聯名卡白金卡',
#  '富多卡白金卡',
#  '商務卡商務卡',
#  '大紀元認同卡白金卡',
#  '台灣銀行白金卡',
#  '台灣銀行白金卡',
#  '金鑽商旅白金卡商務卡',
#  '桐花認同卡白金卡',
#  '導盲犬認同卡(一卡通)白金卡',
#  '白沙屯拱天宮媽祖認同卡晶緻卡',
#  '亞洲微創手術中心認同卡晶緻卡',
#  '極緻卡極緻卡',
#  '圓山大飯店一卡通聯名卡晶緻卡',
#  '澎湖iPASS卡晶緻卡',
#  '一卡通聯名晶緻卡晶緻卡',
#  '白金商務卡商務卡',
#  '台北市第五信用合作社聯名卡鈦金卡',
#  '卡娜赫拉的小動物icash聯名卡(夢想藍)鈦金卡',
#  '鈦金悠遊聯名卡鈦金卡',
#  'icash聯名卡鈦金卡',
#  '鹿港天后宮晶緻一卡通認同卡晶緻卡',
#  '鹿港天后宮鈦金悠遊認同卡鈦金卡',
#  '合庫雙幣信用卡(日圓)鈦金卡',
#  '合庫雙幣信用卡(美元)鈦金卡',
#  '利high卡(一卡通聯名卡)晶緻卡',
#  '哆啦A夢悠遊聯名卡晶緻卡',
#  '合作金庫世界卡世界卡',
#  '悠遊晶緻卡晶緻卡',
#  '晶片Combo card鈦金卡',
#  '御璽商旅卡御璽卡',
#  '商務卡商務卡',
#  '個人商旅卡白金卡',
#  'Sweet Home白金卡白金卡',
#  '合作金庫無限卡無限卡',
#  '綠活卡(一卡通)御璽卡',
#  '綠活卡(悠遊卡)御璽卡',
#  'Wonderful星璨卡御璽卡',
#  'NFC手機信用卡白金卡',
#  '雙幣鈦金商旅卡鈦金卡',
#  '一卡通聯名卡御璽卡',
#  'i-Fun愛玩樂卡白金卡',
#  'i-Fun愛玩樂卡晶緻卡',
#  '一銀卡御守系列晶緻卡',
#  '長庚紀念醫院悠遊認同卡白金卡',
#  '商旅卡鈦金卡',
#  '商旅卡御璽卡',
#  '菁英御璽卡御璽卡',
#  '里仁為美福智卡白金卡',
#  '媚儷鈦金卡鈦金卡',
#  '白金商旅卡白金卡',
#  '一銀卡御守系列白金卡',
#  '白金商旅卡白金卡',
# ...

# %%
a[65]
# Out:
# '聯名卡愛戀紅鈦金卡'
