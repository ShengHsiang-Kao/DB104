# %%
import gmaps
import pandas as pd
import gmplot
from mapsplotlib import mapsplot as mplt
from gmplot import gmplot

import gmaps.datasets
import folium

# %%
fmap = folium.Map(location=[24.052183, 121.044223], zoom_start=8)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for i in location_list2:
    fmap.add_child(folium.Marker(location=i,popup='Skytree'))

# %%
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mplt.register_api_key('AIzaSyBqCP4hrKh81pbTAPtute5vY1oo6bU-Rs8')

# %%
test=pd.DataFrame({'lat':store_location['lat'],'lng':store_location['lng']})

# %%
test
# Out:
#             lat         lng
# 0     25.097452  121.713030
# 1     25.128871  121.742670
# 2     25.130896  121.740541
# 3     25.129554  121.744538
# 4     25.131838  121.734483
# 5     25.120703  121.723488
# 6     25.140837  121.711277
# 7     25.134944  121.782909
# 8     25.099280  121.735908
# 9     25.112182  121.530389
# 10    25.086817  121.525297
# 11    25.095138  121.525798
# 12    25.094769  121.524124
# 13    25.119048  121.526070
# 14    25.117948  121.532230
# 15    25.088539  121.526547
# 16    25.085111  121.509909
# 17    25.086985  121.509336
# 18    25.084235  121.522974
# 19    25.104502  121.521938
# 20    25.107711  121.528683
# 21    25.109108  121.532599
# 22    25.049116  121.518535
# 23    25.064771  121.511230
# 24    25.052700  121.519437
# 25    25.071945  121.515291
# 26    25.054475  121.515192
# 27    25.033299  121.529752
# 28    25.029568  121.557149
# 29    25.020562  121.554630
# ...         ...         ...
# 1204  23.991588  120.974812
# ...

# %%
mplt.plot_markers(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-71097b6a9c01> in <module>
# ----> 1 mplt.plot_markers(test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mapsplotlib\mapsplot.py in plot_markers(markers, maptype)
#     110     # Checking input columns
#     111     fields = markers.columns.intersection(['latitude', 'longitude', 'color', 'label', 'size'])
# --> 112     if not fields or 'latitude' not in fields or 'longitude' not in fields:
#     113         msg = 'Input dataframe should contain at least colums \'latitude\' and \'longitude\' '
#     114         msg += '(and columns \'color\', \'label\', \'size\' optionally).'
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __nonzero__(self)
#    2229         raise ValueError("The truth value of a {0} is ambiguous. "
# ...

# %%
store_location=pd.read_excel(r'./store_location.xlsx',encoding='utf-16')

# %%
location_list=[]
for i in  range(len(store_location)):
    place=(store_location['lat'][i],store_location['lng'][i])
    location_list.append(place)

# %%
location_list2=[]
for i in  range(len(store_location)):
    place=[store_location['lat'][i],store_location['lng'][i]]
    location_list2.append(place)

# %%
 location_list
# Out:
# [(25.0974525, 121.7130302),
#  (25.1288711, 121.7426695),
#  (25.1308965, 121.740541),
#  (25.1295536, 121.7445376),
#  (25.1318384, 121.7344835),
#  (25.120703, 121.723488),
#  (25.140837, 121.711277),
#  (25.1349438, 121.7829088),
#  (25.09928, 121.7359079),
#  (25.112182, 121.5303888),
#  (25.0868169, 121.5252972),
#  (25.0951382, 121.5257982),
#  (25.0947693, 121.5241239),
#  (25.1190475, 121.5260698),
#  (25.117948, 121.5322296),
#  (25.0885386, 121.5265468),
#  (25.0851107, 121.5099094),
#  (25.0869854, 121.5093362),
#  (25.0842354, 121.5229738),
#  (25.1045016, 121.521938),
#  (25.107711, 121.5286826),
#  (25.1091076, 121.5325994),
#  (25.049116, 121.5185352),
#  (25.0647715, 121.5112303),
#  (25.0526999, 121.5194374),
#  (25.071945, 121.515291),
#  (25.054475, 121.515192),
#  (25.0332989, 121.529752),
#  (25.0295676, 121.5571492),
#  (25.0205622, 121.5546301),
#  (25.0272502, 121.5232883),
#  (25.0249436, 121.5465847),
#  (25.0257522, 121.5385237),
# ...

# %%
 location_list2
# Out:
# [[25.0974525, 121.7130302],
#  [25.1288711, 121.7426695],
#  [25.1308965, 121.740541],
#  [25.1295536, 121.7445376],
#  [25.1318384, 121.7344835],
#  [25.120703, 121.723488],
#  [25.140837, 121.711277],
#  [25.1349438, 121.7829088],
#  [25.09928, 121.7359079],
#  [25.112182, 121.5303888],
#  [25.0868169, 121.5252972],
#  [25.0951382, 121.5257982],
#  [25.0947693, 121.5241239],
#  [25.1190475, 121.5260698],
#  [25.117948, 121.5322296],
#  [25.0885386, 121.5265468],
#  [25.0851107, 121.5099094],
#  [25.0869854, 121.5093362],
#  [25.0842354, 121.5229738],
#  [25.1045016, 121.521938],
#  [25.107711, 121.5286826],
#  [25.1091076, 121.5325994],
#  [25.049116, 121.5185352],
#  [25.0647715, 121.5112303],
#  [25.0526999, 121.5194374],
#  [25.071945, 121.515291],
#  [25.054475, 121.515192],
#  [25.0332989, 121.529752],
#  [25.0295676, 121.5571492],
#  [25.0205622, 121.5546301],
#  [25.0272502, 121.5232883],
#  [25.0249436, 121.5465847],
#  [25.0257522, 121.5385237],
# ...

# %%
store_df = gmaps.datasets.load_dataset_as_df(test)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-26b30160a110> in <module>
# ----> 1 store_df = gmaps.datasets.load_dataset_as_df(test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gmaps\datasets\datasets.py in load_dataset_as_df(dataset_name)
#     133     """
#     134     import pandas as pd
# --> 135     data = load_dataset(dataset_name)
#     136     headers = dataset_metadata(dataset_name)["headers"]
#     137     return pd.DataFrame(data, columns=headers)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gmaps\datasets\datasets.py in load_dataset(dataset_name)
#     120     Fetch a dataset, returning an array of tuples.
#     121     """
# --> 122     url = METADATA[dataset_name]["url"]
#     123     column_types = METADATA[dataset_name]["types"]
#     124     f = urlopen(url)
#
# ...

# %%
fig = gmaps.figure()

# %%
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
gmap = gmplot.GoogleMapPlotter(37.766956, -122.438481, 13)
top_attraction_lats, top_attraction_lons = zip(*[
    (37.769901, -122.498331),
    (37.768645, -122.475328),
    (37.771478, -122.468677),
    (37.769867, -122.466102),
    (37.767187, -122.467496),
    (37.770104, -122.470436)
    ])
gmap.scatter(top_attraction_lats, top_attraction_lons, '#3B0B39', size=40, marker=False)
hidden_gem_lat, hidden_gem_lon = 37.770776, -122.461689
gmap.marker(hidden_gem_lat, hidden_gem_lon, 'cornflowerblue')
gmap.draw("my_map.html")
# Marker
hidden_gem_lat, hidden_gem_lon = 37.770776, -122.461689
gmap.marker(hidden_gem_lat, hidden_gem_lon, 'cornflowerblue')

# Draw
gmap.draw("my_map.html")

# %%
gmap = gmplot.GoogleMapPlotter(37.428, -122.145, 16)

gmap.plot(25.0951382, 121.5257982, 'cornflowerblue', edge_width=10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-43a684c3718a> in <module>
#       1 gmap = gmplot.GoogleMapPlotter(37.428, -122.145, 16)
#       2
# ----> 3 gmap.plot(25.0951382, 121.5257982, 'cornflowerblue', edge_width=10)
#
# C:\ProgramData\Anaconda3\lib\site-packages\gmplot\gmplot.py in plot(self, lats, lngs, color, c, **kwargs)
#     118         kwargs.setdefault("color", color)
#     119         settings = self._process_kwargs(kwargs)
# --> 120         path = zip(lats, lngs)
#     121         self.paths.append((path, settings))
#     122
#
# TypeError: zip argument #1 must support iteration

# %%
fig = gmaps.figure()
markers = gmaps.marker_layer( location_list)
fig.add_layer(markers)
fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-895dd508ca5e> in <module>
# ----> 1 fig = gmaps.figure()
#       2 markers = gmaps.marker_layer( location_list)
#       3 fig.add_layer(markers)
#       4 fig
#
# AttributeError: 'NoneType' object has no attribute 'figure'

# %%
gmaps.marker_layer( location_list)
# Out:
# Markers(data_bounds=[(22.807620656230863, 120.12627872277693), (26.165936161759422, 122.11556840159986)], mark…
