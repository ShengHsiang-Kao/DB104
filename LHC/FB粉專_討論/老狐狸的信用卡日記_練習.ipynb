# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 謝榮哥,帆哥 </font>

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 資策會網路有夠爛 </font>

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 信用卡FB粉專_老狐狸的信用卡日記 </font>

# %%
import pandas as pd
import re, time, requests, datetime, gc, os, sys
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
def 垃圾視窗NotNow():
    try:
        driver.find_element_by_xpath('//a[@id="expanding_cta_close_button"]').click()
    except:
#         print(sys.exc_info())
        time.sleep(0.1)

# %%
# 截取塗鴉墻上貼文的連結
def fuck_Wall_PostLink(i):
    Link = 'https://www.facebook.com' + i.find('a',{'class':'_5pcq'}).attrs['href'].split('?',2)[0]
    return Link
#截取塗鴉墻上貼文的發佈時間
def fuck_Wall_PostTime(i):
    try:
        Time = i.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = '沒發文時間阿肏你的'
    return Time
# 截取塗鴉墻上貼文的留言數
def fuck_Wall_PostComments(i):
    try:
        Comments = i.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in Comments:
            Comments = int(float(Comments.split('K')[0])*1000)
        else:
            Comments = int(Comments)
    except:
        Comments = 0
    return Comments
def CarwlList(urls, n, Posts):
    CheckList = pd.DataFrame(columns = ['Link','Time','Comments']) 

    driver.get(url)        
    for i in range(n):
        try:
            time.sleep(1)
            driver.find_element_by_css_selector('a.pam.uiBoxLightblue.uiMorePagerPrimary').click() # 加載下一頁喔糙
        except:
            time.sleep(1)
        #會跳出強迫登入的畫面喔肏
        垃圾視窗NotNow()
        soup = BeautifulSoup(driver.page_source)
        for i in soup.find_all('div', {'class':'_5pcr userContentWrapper'}):
            CheckList = pd.concat([CheckList, pd.DataFrame(data = [{'Link':fuck_Wall_PostLink(i),
                                                                    'Time':fuck_Wall_PostTime(i),
                                                                    'Comments':fuck_Wall_PostComments(i)}],
                                                           columns = ['Link','Time','Comments'])],
                                   ignore_index = True)
    #襙有重複問題為啥啊?
    CarwlList = pd.merge(left = CheckList,
                         right = Posts.loc[:,['Link','Comments']],
                         how='left',
                         on='Link',
                         suffixes=('_c', '_p'),
                         indicator=True)
    CarwlList = pd.concat([CarwlList.loc[CarwlList._merge == 'left_only', :], # 新貼文
                           CarwlList.loc[CarwlList.Comments_c > CarwlList.Comments_p, :]], # 舊貼文但有新留言
                          ignore_index=True)
    CarwlList = CarwlList.drop_duplicates(subset = 'Link',
                                          keep= 'first',
                                          inplace = False)
    return CarwlList

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 彈窗 </font>

# %%
# 關閉彈窗
def ClosePopup():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    垃圾視窗NotNow()
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
    time.sleep(1)
    垃圾視窗NotNow()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    垃圾視窗NotNow()
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    垃圾視窗NotNow()

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 展開留言 </font>

# %%
def open_comment():
    time.sleep(1)
    k = len(driver.find_elements_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]'))
    if k !=0:
        #這邊似乎FB不是很穩,往下拉兩次
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(1)
        垃圾視窗NotNow()
        try:
            driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
        except:
            print('fuckyou')
    time.sleep(1)


def ClickOldest():
    time.sleep(1)
    driver.find_element_by_xpath('//a[@data-testid="UFI2ViewOptionsSelector/link"]').click()
    time.sleep(1)
    try:
        driver.find_element_by_partial_link_text('Comments shown in chronological order with the newest comments at the top.').click()
    except:
        try:
            driver.find_element_by_partial_link_text('New comments and those with new replies appear at the top.').click()
        except:
            print('Plz, Check this post arragne type!')
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    垃圾視窗NotNow()
    time.sleep(1)
def MoreComments():
    k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 300):
        print('展開夠多留言： ' + str(l) + ' 次')
        try:
            driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
            # 若彈出註冊視窗點擊not now!
            垃圾視窗NotNow()
            driver.find_element_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]').click()
            time.sleep(1)
            k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_0"]'))
        except:
            time.sleep(0.1)
        finally:
            l += 1
    time.sleep(1)
# 偵測是否有「更多回覆」（第二層），若有則點擊
def MoreReplies():
    k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 300):
        l += 1
        print('加載： ' + str(l) + ' 次')
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        driver.find_element_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]').click()
        time.sleep(0.5)
        k = len(driver.find_elements_by_xpath('//a[@data-testid="UFI2CommentsPagerRenderer/pager_depth_1"]'))
    time.sleep(1)
# 偵測是否有「展開留言」（第二層留言內容），若有則點擊
def SeeMore():
    k = len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))
    # 卡住的次數超過100次就停止
    l = 0
    while (k != 0) & (l <= 1000):
        l += 1
        print('Click See More ： ' + str(l) + ' times.')
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        driver.find_element_by_xpath('//a[@class="_5v47 fss"]').click()
        time.sleep(0.5)
        k = len(driver.find_elements_by_xpath('//a[@class="_5v47 fss"]'))
    time.sleep(1)
def PostExpand():
#     ClosePopup()
#     ClickOldest() # 展開留言會有無法加載更多留言的問題，暫時先不使用
    open_comment()
    MoreComments()
    MoreReplies()
    SeeMore()

# 關閉彈窗
def ClosePopup():
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(1)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    垃圾視窗NotNow()
    driver.find_element_by_xpath('//div[@class="_5pcr userContentWrapper"]//a[@data-testid="UFI2CommentsCount/root"]').click()
    time.sleep(1)
    垃圾視窗NotNow()
    time.sleep(0.5)
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    垃圾視窗NotNow()
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    time.sleep(0.5)
    垃圾視窗NotNow()

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 貼文時間與內容 </font>

# %%
# 貼文留言數
def Post_Name(userContent):
    return userContent.find('img').attrs['aria-label']

# 貼文ID?
def Post_ID(userContent):
    return userContent.find('a', {'class':'_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe'}).attrs['href'].split('/?ref')[0].split('https://www.facebook.com/')[1]
# 貼文留言數
def Post_Comments(userContent):
    try:
        CommentCounts = userContent.find('a', {'data-testid':'UFI2CommentsCount/root'}).text.split(' ',2)[0]
        if 'K' in CommentCounts:
            CommentCounts = int(float(CommentCounts.split('K')[0])*1000)
        else:
            CommentCounts = int(CommentCounts)
    except:
        CommentCounts = 0 
    return CommentCounts
# 貼文時間
def Post_Time(userContent):
    try:
        Time = userContent.find('abbr').attrs['title']
        Time = datetime.datetime.strptime(Time, '%m/%d/%y, %I:%M %p')
        Time = Time.strftime("%Y-%m-%d %H:%M")
    except:
        Time = "Error, Please check this post's condiction!" 
    return Time

# 貼文內容
def Post_Content(userContent):
    try:
        Content = userContent.find('div', {'class':'_5pbx userContent _3576'}).text
    except:
        Content = "There's No Text Content!"
    return Content
# 文章內容與互動摘要
def PostInfo(soup):
    # 貼文區
    userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
    PostContent = pd.DataFrame(data = [{'Name':Post_Name(userContent),
                                        'ID':Post_ID(userContent),
                                        'Time':Post_Time(userContent),
                                        'Content':Post_Content(userContent),
                                        'Comments':Post_Comments(userContent),
                                        'Link':i}],
                            columns = ['Name', 'ID', 'Time', 'Content', 'Comments', 'Link'])
    return PostContent

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 留言內容 </font>

# %%
def Comment_Content(element):
    try:
        Content = element.find('span', {'dir':'ltr'}).text
    except:
        Content = 'img'
    return Content
# def CommentsInfo(soup):  
#     PostComments = pd.DataFrame()
#     userContent = soup.find('div', {'class':'_5pcr userContentWrapper'})
#     try:
#         for i in userContent.select('ul._7a9a > li'):
#             # 先抓留言並放在Comment
#             Comment = pd.DataFrame(data=[{'ID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
#                                           'Name':i.find('img').attrs['alt'],
#                                           'Time':datetime.datetime.strptime(i.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
#                                           'Content':Comment_Content(i),
#                                           'RepID':userContent.find('div', {'class':'_5pcp _5lel _2jyu _232_'}).attrs['id'].split(';')[0].split('feed_subtitle_')[-1],
#                                           'RepName':userContent.find('img').attrs['aria-label'],
#                                           'Link':driver.current_url}],
#                                    columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
#             PostComments = pd.concat([PostComments, Comment], ignore_index=True)
#             # 留言的留言
#             for j in i.findAll('div', {'data-testid':'UFI2Comment/root_depth_1'}):
#                 Comment = pd.DataFrame(data=[{'ID':j.find('a', {'class':' _3mf5 _3mg1'}).attrs['data-hovercard'].split('id=',2)[1],
#                                               'Name':j.find('img').attrs['alt'],
#                                               'Time':datetime.datetime.strptime(j.find('abbr',{'class':'livetimestamp'}).attrs['data-tooltip-content'], '%A, %B %d, %Y at %I:%M %p').strftime("%Y-%m-%d %H:%M"),
#                                               'Content':Comment_Content(j),
#                                               'RepID':i.find('a', {'class':' _3mf5 _3mg0'}).attrs['data-hovercard'].split('id=',2)[1],
#                                               'RepName':i.find('img').attrs['alt'],
#                                               'Link':driver.current_url}],
#                                        columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
#                 PostComments = pd.concat([PostComments, Comment], ignore_index=True)
#     except:
#         print('抓完囉!')
#     return PostComments
def 操你的留言(soup):  
    PostComments = pd.DataFrame()
    留言的留言 = soup.find('div', {'class':'_5pcr userContentWrapper'})
    try:
        for 靠 in 留言的留言:
            PostComments = pd.DataFrame(data=[{'Content': ','.join(幹.text for 幹 in 靠.select('ul[class="_7a9a"] span[class="_3l3x"]')),
                                         'Time':'隨便啦',
                                         'ID':'你猜',
                                         'RepID':'不重要',
                                         'RepName':'嘿嘿',
                                         'Name':'SKT',
                                         'Link':i
                                         }],                         
                                   columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])





#             PostComments = pd.concat([PostComments, Comment], ignore_index=True)

    except:
         print('我是遊覽器我是廢物')
    return PostComments

# %% [markdown]
# ## <table><tr><td bgcolor=orange> 以上是定義區</td></tr></table>

# %% [markdown]
# # <font color=#FF0000 size=100 face="標楷體"> 分隔線--------------------------------- </font>

# %% [markdown]
# ## <table><tr><td bgcolor=orange> 以下是執行區</td></tr></table>

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> excel_post_Comments </font>

# %%
try:
    Posts = pd.read_excel('C:\\Users\\Big data\\Desktop\\class\\web_crawler\\FB\\F1B.xls')
except:
    Posts = pd.DataFrame(columns=['Name', 'ID', 'Time', 'Content', 'Comments', 'Link'])
try:
    Comments = pd.read_pickle('C:\\Users\\Big data\\Desktop\\class\\web_crawler\\FB\\FB.xlsx')
except:
    Comments = pd.DataFrame(columns = ['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])

print(Posts.shape)
print(Comments.shape)
# #可放多個連結
# Out:
# (0, 6)
# (0, 7)

# %% [markdown]
# #  <font color=#8B4513 size=100 face="標楷體"> 開啟webdriver </font>

# %%
url = 'https://www.facebook.com/OldFoxCreditCardDiary/?__tn__=kC-R&eid=ARDLQtqgCt6qWY3Ezk4b0B3QRM6HB_PWG_3Hiq07Qh8hDK7disJv5wvn-47fI24tDjfeTmHtBhTwbUa_&hc_ref=ARS0lgzjQNPDL14cEETlM2f9o4Wwb9g6rosmuRMtyS4klPRu7V7EgknHmahX5PV-ww0&fref=nf&__xts__[0]=68.ARCFk7hahIvw8WUXeFCI7CZy0B-ez_RG9Xvr54Rpku02fG-ixMr7trpXMmK8hCSpiFA6k_mtlK34ASQPLv_FBLjgbaMJSHHgr5N3sg9_SY2RAgZb4LMhfoBR1kAHOi_ncW_ma_O4K9wcuGI84__JdfdJ4K2VeJO5CaHf4vyLBezMymaXf_7P5ODRcykYCb3zCR2Yj1Ru97gg_0ehoAuqNuvvzK1vyEMlV1_30qmjdy5UNaV25NEvcdDB9w527qre38GDRSHREErgqz_w5V55Nryc6BBXNdoIE1TxUwBnXq1paEopxk_6LcOG-8kVp5Z_1gsQia4GFp9wgGMi3SJiZ6yb_Q'
driver = webdriver.Chrome('C:\\Users\\Big data\\Desktop\\class\\web_crawler\\chromedriver\\chromedriver.exe')
driver.get('https://www.facebook.com/')
time.sleep(1)
driver.find_element_by_partial_link_text('English').click()

# %%
CarwlList你妹 = CarwlList(urls=urls, n=40, Posts = Posts)#n是下拉次數,次數愈多能加載的文章愈多
CarwlList你妹
# Out:
#                                                    Link              Time  \
# 0     https://www.facebook.com/OldFoxCreditCardDiary...  2016-02-26 17:00
# 1     https://www.facebook.com/OldFoxCreditCardDiary...  2019-11-02 06:00
# 6     https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-30 19:36
# 7     https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-30 11:07
# 8     https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-21 06:00
# 9     https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-20 15:30
# 10    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-18 06:00
# 25    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-15 17:56
# 26    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-15 05:00
# 27    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-13 07:13
# 28    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-10 22:10
# 29    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-09 12:27
# 30    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-28 06:00
# 31    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-27 06:00
# 32    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-21 19:22
# 33    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-19 14:51
# 34    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-16 20:24
# 35    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-08 17:35
# 36    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-03 03:54
# 37    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-02 04:13
# 38    https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-01 03:00
# 39    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-31 03:22
# 40    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-30 02:59
# 87    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-29 03:04
# 88    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-28 02:59
# 89    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-27 05:00
# 90    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-27 03:21
# 91    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-24 13:19
# 92    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-20 09:14
# 93    https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-20 05:26
# ...                                                 ...               ...
# 4891  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-19 14:30
# 4892  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-16 17:03
# 4893  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-15 15:12
# 4894  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-14 11:00
# 4895  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-13 13:10
# 4896  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-13 07:00
# 4897  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-08 07:29
# 4898  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-06 10:26
# 4899  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-05 06:00
# 4900  https://www.facebook.com/OldFoxCreditCardDiary...  2017-06-03 09:50
# 4901  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-30 22:26
# 4902  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-28 08:35
# 4903  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-16 13:45
# 4904  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-12 16:13
# 5184  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-11 10:44
# 5185  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-10 12:14
# 5186  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-04 13:54
# 5187  https://www.facebook.com/OldFoxCreditCardDiary...  2017-05-03 10:14
# 5188  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-27 17:30
# 5189  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-27 11:34
# 5190  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-25 17:36
# 5191  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-24 01:25
# 5479  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-22 12:45
# 5480  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-21 13:46
# 5481  https://www.facebook.com/notes/%E8%80%81%E7%8B...  2017-04-18 14:42
# 5482  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-12 09:52
# 5483  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-10 15:36
# 5484  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-10 08:00
# 5485  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-07 15:47
# 5486  https://www.facebook.com/OldFoxCreditCardDiary...  2017-04-06 15:15
#
#      Comments_c Comments_p     _merge
# 0           167        NaN  left_only
# 1            12        NaN  left_only
# 6           106        NaN  left_only
# 7            20        NaN  left_only
# 8            12        NaN  left_only
# 9            23        NaN  left_only
# 10            9        NaN  left_only
# 25           26        NaN  left_only
# 26           21        NaN  left_only
# 27           22        NaN  left_only
# 28          150        NaN  left_only
# 29           34        NaN  left_only
# 30            1        NaN  left_only
# 31           13        NaN  left_only
# 32           32        NaN  left_only
# 33            9        NaN  left_only
# 34            7        NaN  left_only
# 35           58        NaN  left_only
# 36           22        NaN  left_only
# 37            9        NaN  left_only
# 38           44        NaN  left_only
# 39           48        NaN  left_only
# 40           11        NaN  left_only
# 87           27        NaN  left_only
# 88           27        NaN  left_only
# 89           13        NaN  left_only
# 90           27        NaN  left_only
# 91           18        NaN  left_only
# 92           30        NaN  left_only
# 93           50        NaN  left_only
# ...         ...        ...        ...
# 4891         13        NaN  left_only
# 4892         16        NaN  left_only
# 4893          8        NaN  left_only
# 4894          0        NaN  left_only
# 4895         11        NaN  left_only
# 4896         17        NaN  left_only
# 4897          7        NaN  left_only
# 4898         12        NaN  left_only
# 4899         34        NaN  left_only
# 4900          4        NaN  left_only
# 4901         19        NaN  left_only
# 4902          0        NaN  left_only
# 4903         13        NaN  left_only
# 4904          1        NaN  left_only
# 5184          5        NaN  left_only
# 5185         21        NaN  left_only
# 5186         29        NaN  left_only
# 5187         65        NaN  left_only
# 5188         25        NaN  left_only
# 5189         22        NaN  left_only
# 5190         12        NaN  left_only
# 5191         14        NaN  left_only
# 5479         62        NaN  left_only
# 5480         26        NaN  left_only
# 5481          5        NaN  left_only
# 5482          4        NaN  left_only
# 5483         18        NaN  left_only
# 5484          3        NaN  left_only
# 5485         15        NaN  left_only
# 5486          2        NaN  left_only
#
# [295 rows x 5 columns]

# %%
aaa=CarwlList你妹[0:50]
aaa
# Out:
#                                                   Link              Time  \
# 0    https://www.facebook.com/OldFoxCreditCardDiary...  2016-02-26 17:00
# 1    https://www.facebook.com/OldFoxCreditCardDiary...  2019-11-02 06:00
# 6    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-30 19:36
# 7    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-30 11:07
# 8    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-21 06:00
# 9    https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-20 15:30
# 10   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-18 06:00
# 25   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-15 17:56
# 26   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-15 05:00
# 27   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-13 07:13
# 28   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-10 22:10
# 29   https://www.facebook.com/OldFoxCreditCardDiary...  2019-10-09 12:27
# 30   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-28 06:00
# 31   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-27 06:00
# 32   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-21 19:22
# 33   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-19 14:51
# 34   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-16 20:24
# 35   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-08 17:35
# 36   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-03 03:54
# 37   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-02 04:13
# 38   https://www.facebook.com/OldFoxCreditCardDiary...  2019-09-01 03:00
# 39   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-31 03:22
# 40   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-30 02:59
# 87   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-29 03:04
# 88   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-28 02:59
# 89   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-27 05:00
# 90   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-27 03:21
# 91   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-24 13:19
# 92   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-20 09:14
# 93   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-20 05:26
# 94   https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-17 18:43
# 126  https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-08 07:45
# 127  https://www.facebook.com/OldFoxCreditCardDiary...  2019-08-06 09:30
# 128  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-31 13:37
# 129  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-26 14:14
# 130  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-24 13:33
# 131  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-23 08:19
# 132  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-15 16:14
# 133  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-14 16:53
# 173  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-11 19:38
# 174  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-11 11:46
# 175  https://www.facebook.com/OldFoxCreditCardDiary...  2019-07-04 19:15
# 176  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-28 15:12
# 177  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-28 07:00
# 178  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-22 08:00
# 179  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-18 14:36
# 180  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-18 07:00
# 228  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-13 09:59
# 229  https://www.facebook.com/OldFoxCreditCardDiary...  2019-06-06 09:17
# 230  https://www.facebook.com/OldFoxCreditCardDiary...  2019-05-31 15:15
#
#     Comments_c Comments_p     _merge
# 0          167        NaN  left_only
# 1           12        NaN  left_only
# 6          106        NaN  left_only
# 7           20        NaN  left_only
# 8           12        NaN  left_only
# 9           23        NaN  left_only
# 10           9        NaN  left_only
# 25          26        NaN  left_only
# 26          21        NaN  left_only
# 27          22        NaN  left_only
# 28         150        NaN  left_only
# 29          34        NaN  left_only
# 30           1        NaN  left_only
# 31          13        NaN  left_only
# 32          32        NaN  left_only
# 33           9        NaN  left_only
# 34           7        NaN  left_only
# 35          58        NaN  left_only
# 36          22        NaN  left_only
# 37           9        NaN  left_only
# 38          44        NaN  left_only
# 39          48        NaN  left_only
# 40          11        NaN  left_only
# 87          27        NaN  left_only
# 88          27        NaN  left_only
# 89          13        NaN  left_only
# 90          27        NaN  left_only
# 91          18        NaN  left_only
# 92          30        NaN  left_only
# 93          50        NaN  left_only
# 94          32        NaN  left_only
# 126         76        NaN  left_only
# 127         25        NaN  left_only
# 128         18        NaN  left_only
# 129         46        NaN  left_only
# 130         78        NaN  left_only
# 131          0        NaN  left_only
# 132         77        NaN  left_only
# 133         33        NaN  left_only
# 173         33        NaN  left_only
# 174         71        NaN  left_only
# 175         34        NaN  left_only
# 176         33        NaN  left_only
# 177          4        NaN  left_only
# 178         14        NaN  left_only
# 179         21        NaN  left_only
# 180          5        NaN  left_only
# 228         32        NaN  left_only
# 229         47        NaN  left_only
# 230         12        NaN  left_only

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 爬資料(雙表,可擴展,目前暫定把留言與連言回復合併為一表) </font>

# %%
nComments = pd.DataFrame(columns=['ID', 'Name', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
nPost = pd.DataFrame(columns=[ 'Name','ID', 'Time', 'Content', 'RepID', 'RepName', 'Link'])
for i in CarwlList你妹.Link:
    print('正在抓: ' + i)
    driver.get(i)
    try:
        PostExpand()
        print('完成!')
        try:
            soup = BeautifulSoup(driver.page_source)
            time.sleep(1)
            PostContent = PostInfo(soup)
            nPost = pd.concat([nPost, PostContent],sort=True, ignore_index=True)
            PostComments = 操你的留言(soup)
            nComments = pd.concat([nComments, PostComments], ignore_index=True)
            
  
           
        except:
            print('抓取留言出現錯誤喔傻屌A_A')
    except:
        print('這篇留言過少所以不用展開喔傻屌A_A')
    gc.collect()
    print('完成時間: ' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '\n\n------------------')
# Out:
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/239089886430361
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 18:43:59
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/1007337132938962
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 18:44:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/1005660113106664/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 18:45:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/1005387003133975
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 18:45:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/993623234310352
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 18:46:07
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/996272127378796/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 18:46:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/993918204280855/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 18:46:49
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/991620931177249
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:47:38
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/990049628001046
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:48:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/989555004717175/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 18:48:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/987507758255233/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 加載： 15 次
# 加載： 16 次
# 加載： 17 次
# 加載： 18 次
# 加載： 19 次
# 加載： 20 次
# 加載： 21 次
# 加載： 22 次
# 加載： 23 次
# 加載： 24 次
# 加載： 25 次
# 加載： 26 次
# 加載： 27 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# Click See More ： 3 times.
# Click See More ： 4 times.
# Click See More ： 5 times.
# Click See More ： 6 times.
# Click See More ： 7 times.
# Click See More ： 8 times.
# Click See More ： 9 times.
# Click See More ： 10 times.
# Click See More ： 11 times.
# Click See More ： 12 times.
# Click See More ： 13 times.
# Click See More ： 14 times.
# Click See More ： 15 times.
# Click See More ： 16 times.
# Click See More ： 17 times.
# Click See More ： 18 times.
# Click See More ： 19 times.
# Click See More ： 20 times.
# Click See More ： 21 times.
# Click See More ： 22 times.
# Click See More ： 23 times.
# Click See More ： 24 times.
# Click See More ： 25 times.
# Click See More ： 26 times.
# Click See More ： 27 times.
# Click See More ： 28 times.
# Click See More ： 29 times.
# Click See More ： 30 times.
# Click See More ： 31 times.
# Click See More ： 32 times.
# Click See More ： 33 times.
# 完成!
# 完成時間: 2019-11-03 18:50:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/986368011702541
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 18:50:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/976445832694759
# 完成!
# 完成時間: 2019-11-03 18:50:33
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/976444239361585
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 18:50:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/972492343090108/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 18:51:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/970785189927490
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 18:51:14
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/968722283467114/
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 18:51:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/962557674083575/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 完成!
# 完成時間: 2019-11-03 18:51:43
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/958423967830279/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 18:51:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/956967024642640/
# 完成!
# 完成時間: 2019-11-03 18:52:04
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/956989577973718/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 18:52:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/956299638042712/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 18:52:41
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/955360061470003
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 18:52:53
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/954900744849268/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:53:07
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/954176614921681/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 18:53:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/953375475001795
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 18:53:36
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/953624394976903/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:53:51
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/949279015411441/
# 展開夠多留言： 0 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:54:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/949038045435538/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 18:54:18
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/948599705479372
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 完成!
# 完成時間: 2019-11-03 18:54:36
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/947233765615966/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 18:54:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/940534916285851/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 完成!
# 完成時間: 2019-11-03 18:55:10
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/939579556381387
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:55:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/935786956760647
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 18:55:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/932508717088471/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 18:55:51
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/931101957229147/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:56:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/929990334006976
# 完成!
# 完成時間: 2019-11-03 18:56:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/924994197839923/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:56:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/924363587902984/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:56:54
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/922350041437672/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:57:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/922156078123735/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 加載： 15 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:57:30
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/917827855223224/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 18:57:47
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/913672192305457/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 18:58:00
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/906929439646399
# 完成!
# 完成時間: 2019-11-03 18:58:11
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/905813809757962/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 18:58:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/906379309701412
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 18:58:39
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/905816779757665
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 18:58:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/902770883395588
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 完成!
# 完成時間: 2019-11-03 18:59:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/896401487365861/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 完成!
# 完成時間: 2019-11-03 18:59:25
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/891912974481379
# 展開夠多留言： 0 次
# 加載： 1 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 18:59:38
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/884752888530721/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 18:59:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/882283082111035
# 完成!
# 完成時間: 2019-11-03 18:59:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/881251738880836
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:00:10
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/873463742992969
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:00:20
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/873462759659734
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:00:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/868332693506074/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:00:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/867089906963686
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:00:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/856987354640608
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:01:10
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/854637498208927
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:01:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/853966358276041/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:01:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/852663525072991
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:01:47
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/851603175179026/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:02:01
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/851013915237952/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 完成!
# 完成時間: 2019-11-03 19:02:18
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/846624499010227
# 完成!
# 完成時間: 2019-11-03 19:02:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/845603755778968
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 完成!
# 完成時間: 2019-11-03 19:02:43
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/842032579469419/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:02:59
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/841714379501239
# 完成!
# 完成時間: 2019-11-03 19:03:09
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/838123386527005/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:03:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/834329533573057/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:03:33
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/833196183686392/
# 展開夠多留言： 0 次
# 展開夠多留言： 1 次
# 展開夠多留言： 2 次
# 展開夠多留言： 3 次
# 展開夠多留言： 4 次
# 展開夠多留言： 5 次
# 展開夠多留言： 6 次
# 展開夠多留言： 7 次
# 展開夠多留言： 8 次
# 展開夠多留言： 9 次
# 展開夠多留言： 10 次
# 展開夠多留言： 11 次
# 展開夠多留言： 12 次
# 展開夠多留言： 13 次
# 展開夠多留言： 14 次
# 展開夠多留言： 15 次
# 展開夠多留言： 16 次
# 展開夠多留言： 17 次
# 展開夠多留言： 18 次
# 展開夠多留言： 19 次
# 展開夠多留言： 20 次
# 展開夠多留言： 21 次
# 展開夠多留言： 22 次
# 展開夠多留言： 23 次
# 展開夠多留言： 24 次
# 展開夠多留言： 25 次
# 展開夠多留言： 26 次
# 展開夠多留言： 27 次
# 展開夠多留言： 28 次
# 展開夠多留言： 29 次
# 展開夠多留言： 30 次
# 展開夠多留言： 31 次
# 展開夠多留言： 32 次
# 展開夠多留言： 33 次
# 展開夠多留言： 34 次
# 展開夠多留言： 35 次
# 展開夠多留言： 36 次
# 展開夠多留言： 37 次
# 展開夠多留言： 38 次
# 展開夠多留言： 39 次
# 展開夠多留言： 40 次
# 展開夠多留言： 41 次
# 展開夠多留言： 42 次
# 展開夠多留言： 43 次
# 展開夠多留言： 44 次
# 展開夠多留言： 45 次
# 展開夠多留言： 46 次
# 展開夠多留言： 47 次
# 展開夠多留言： 48 次
# 展開夠多留言： 49 次
# 展開夠多留言： 50 次
# 展開夠多留言： 51 次
# 展開夠多留言： 52 次
# 展開夠多留言： 53 次
# 展開夠多留言： 54 次
# 展開夠多留言： 55 次
# 展開夠多留言： 56 次
# 展開夠多留言： 57 次
# 展開夠多留言： 58 次
# 展開夠多留言： 59 次
# 展開夠多留言： 60 次
# 展開夠多留言： 61 次
# 展開夠多留言： 62 次
# 展開夠多留言： 63 次
# 展開夠多留言： 64 次
# 展開夠多留言： 65 次
# 展開夠多留言： 66 次
# 展開夠多留言： 67 次
# 展開夠多留言： 68 次
# 展開夠多留言： 69 次
# 展開夠多留言： 70 次
# 展開夠多留言： 71 次
# 展開夠多留言： 72 次
# 展開夠多留言： 73 次
# 展開夠多留言： 74 次
# 展開夠多留言： 75 次
# 展開夠多留言： 76 次
# 展開夠多留言： 77 次
# 展開夠多留言： 78 次
# 展開夠多留言： 79 次
# 展開夠多留言： 80 次
# 展開夠多留言： 81 次
# 展開夠多留言： 82 次
# 展開夠多留言： 83 次
# 展開夠多留言： 84 次
# 展開夠多留言： 85 次
# 展開夠多留言： 86 次
# 展開夠多留言： 87 次
# 展開夠多留言： 88 次
# 展開夠多留言： 89 次
# 展開夠多留言： 90 次
# 展開夠多留言： 91 次
# 展開夠多留言： 92 次
# 展開夠多留言： 93 次
# 展開夠多留言： 94 次
# 展開夠多留言： 95 次
# 展開夠多留言： 96 次
# 展開夠多留言： 97 次
# 展開夠多留言： 98 次
# 展開夠多留言： 99 次
# 展開夠多留言： 100 次
# 展開夠多留言： 101 次
# 展開夠多留言： 102 次
# 展開夠多留言： 103 次
# 展開夠多留言： 104 次
# 展開夠多留言： 105 次
# 展開夠多留言： 106 次
# 展開夠多留言： 107 次
# 展開夠多留言： 108 次
# 展開夠多留言： 109 次
# 展開夠多留言： 110 次
# 展開夠多留言： 111 次
# 展開夠多留言： 112 次
# 展開夠多留言： 113 次
# 展開夠多留言： 114 次
# 展開夠多留言： 115 次
# 展開夠多留言： 116 次
# 展開夠多留言： 117 次
# 展開夠多留言： 118 次
# 展開夠多留言： 119 次
# 展開夠多留言： 120 次
# 展開夠多留言： 121 次
# 展開夠多留言： 122 次
# 展開夠多留言： 123 次
# 展開夠多留言： 124 次
# 展開夠多留言： 125 次
# 展開夠多留言： 126 次
# 展開夠多留言： 127 次
# 展開夠多留言： 128 次
# 展開夠多留言： 129 次
# 展開夠多留言： 130 次
# 展開夠多留言： 131 次
# 展開夠多留言： 132 次
# 展開夠多留言： 133 次
# 展開夠多留言： 134 次
# 展開夠多留言： 135 次
# 展開夠多留言： 136 次
# 展開夠多留言： 137 次
# 展開夠多留言： 138 次
# 展開夠多留言： 139 次
# 展開夠多留言： 140 次
# 展開夠多留言： 141 次
# 展開夠多留言： 142 次
# 展開夠多留言： 143 次
# 展開夠多留言： 144 次
# 展開夠多留言： 145 次
# 展開夠多留言： 146 次
# 展開夠多留言： 147 次
# 展開夠多留言： 148 次
# 展開夠多留言： 149 次
# 展開夠多留言： 150 次
# 展開夠多留言： 151 次
# 展開夠多留言： 152 次
# 展開夠多留言： 153 次
# 展開夠多留言： 154 次
# 展開夠多留言： 155 次
# 展開夠多留言： 156 次
# 展開夠多留言： 157 次
# 展開夠多留言： 158 次
# 展開夠多留言： 159 次
# 展開夠多留言： 160 次
# 展開夠多留言： 161 次
# 展開夠多留言： 162 次
# 展開夠多留言： 163 次
# 展開夠多留言： 164 次
# 展開夠多留言： 165 次
# 展開夠多留言： 166 次
# 展開夠多留言： 167 次
# 展開夠多留言： 168 次
# 展開夠多留言： 169 次
# 展開夠多留言： 170 次
# 展開夠多留言： 171 次
# 展開夠多留言： 172 次
# 展開夠多留言： 173 次
# 展開夠多留言： 174 次
# 展開夠多留言： 175 次
# 展開夠多留言： 176 次
# 展開夠多留言： 177 次
# 展開夠多留言： 178 次
# 展開夠多留言： 179 次
# 展開夠多留言： 180 次
# 展開夠多留言： 181 次
# 展開夠多留言： 182 次
# 展開夠多留言： 183 次
# 展開夠多留言： 184 次
# 展開夠多留言： 185 次
# 展開夠多留言： 186 次
# 展開夠多留言： 187 次
# 展開夠多留言： 188 次
# 展開夠多留言： 189 次
# 展開夠多留言： 190 次
# 展開夠多留言： 191 次
# 展開夠多留言： 192 次
# 展開夠多留言： 193 次
# 展開夠多留言： 194 次
# 展開夠多留言： 195 次
# 展開夠多留言： 196 次
# 展開夠多留言： 197 次
# 展開夠多留言： 198 次
# 展開夠多留言： 199 次
# 展開夠多留言： 200 次
# 展開夠多留言： 201 次
# 展開夠多留言： 202 次
# 展開夠多留言： 203 次
# 展開夠多留言： 204 次
# 展開夠多留言： 205 次
# 展開夠多留言： 206 次
# 展開夠多留言： 207 次
# 展開夠多留言： 208 次
# 展開夠多留言： 209 次
# 展開夠多留言： 210 次
# 展開夠多留言： 211 次
# 展開夠多留言： 212 次
# 展開夠多留言： 213 次
# 展開夠多留言： 214 次
# 展開夠多留言： 215 次
# 展開夠多留言： 216 次
# 展開夠多留言： 217 次
# 展開夠多留言： 218 次
# 展開夠多留言： 219 次
# 展開夠多留言： 220 次
# 展開夠多留言： 221 次
# 展開夠多留言： 222 次
# 展開夠多留言： 223 次
# 展開夠多留言： 224 次
# 展開夠多留言： 225 次
# 展開夠多留言： 226 次
# 展開夠多留言： 227 次
# 展開夠多留言： 228 次
# 展開夠多留言： 229 次
# 展開夠多留言： 230 次
# 展開夠多留言： 231 次
# 展開夠多留言： 232 次
# 展開夠多留言： 233 次
# 展開夠多留言： 234 次
# 展開夠多留言： 235 次
# 展開夠多留言： 236 次
# 展開夠多留言： 237 次
# 展開夠多留言： 238 次
# 展開夠多留言： 239 次
# 展開夠多留言： 240 次
# 展開夠多留言： 241 次
# 展開夠多留言： 242 次
# 展開夠多留言： 243 次
# 展開夠多留言： 244 次
# 展開夠多留言： 245 次
# 展開夠多留言： 246 次
# 展開夠多留言： 247 次
# 展開夠多留言： 248 次
# 展開夠多留言： 249 次
# 展開夠多留言： 250 次
# 展開夠多留言： 251 次
# 展開夠多留言： 252 次
# 展開夠多留言： 253 次
# 展開夠多留言： 254 次
# 展開夠多留言： 255 次
# 展開夠多留言： 256 次
# 展開夠多留言： 257 次
# 展開夠多留言： 258 次
# 展開夠多留言： 259 次
# 展開夠多留言： 260 次
# 展開夠多留言： 261 次
# 展開夠多留言： 262 次
# 展開夠多留言： 263 次
# 展開夠多留言： 264 次
# 展開夠多留言： 265 次
# 展開夠多留言： 266 次
# 展開夠多留言： 267 次
# 展開夠多留言： 268 次
# 展開夠多留言： 269 次
# 展開夠多留言： 270 次
# 展開夠多留言： 271 次
# 展開夠多留言： 272 次
# 展開夠多留言： 273 次
# 展開夠多留言： 274 次
# 展開夠多留言： 275 次
# 展開夠多留言： 276 次
# 展開夠多留言： 277 次
# 展開夠多留言： 278 次
# 展開夠多留言： 279 次
# 展開夠多留言： 280 次
# 展開夠多留言： 281 次
# 展開夠多留言： 282 次
# 展開夠多留言： 283 次
# 展開夠多留言： 284 次
# 展開夠多留言： 285 次
# 展開夠多留言： 286 次
# 展開夠多留言： 287 次
# 展開夠多留言： 288 次
# 展開夠多留言： 289 次
# 展開夠多留言： 290 次
# 展開夠多留言： 291 次
# 展開夠多留言： 292 次
# 展開夠多留言： 293 次
# 展開夠多留言： 294 次
# 展開夠多留言： 295 次
# 展開夠多留言： 296 次
# 展開夠多留言： 297 次
# 展開夠多留言： 298 次
# 展開夠多留言： 299 次
# 展開夠多留言： 300 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:05:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/830990060573671
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:05:20
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/824191757920168/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:05:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/822975401375137/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:05:47
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/821615531511124/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:05:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/821277581544919
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:06:12
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/819405288398815/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:06:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/816380855367925
# 完成!
# 完成時間: 2019-11-03 19:06:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/812690312403646/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:06:45
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/810652719274072
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:06:56
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/videos/1993869540906847/
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:07:07
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/807960739543270
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:07:29
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/807360076270003
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:07:41
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/805931879746156
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:07:52
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/805043743168303/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:08:07
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/804495243223153
# 完成!
# 完成時間: 2019-11-03 19:08:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/801203543552323/
# 展開夠多留言： 0 次
# 加載： 1 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:08:29
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/795488210790523
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:08:41
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/797773003895377/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:08:54
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/795579664114711/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:09:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/795487507457260
# 完成!
# 完成時間: 2019-11-03 19:09:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/794362737569737
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:09:28
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/792004874472190
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:09:43
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/791614527844558
# 完成!
# 完成時間: 2019-11-03 19:09:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/790256361313708/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:10:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/783896828616328/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:10:19
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/782620545410623/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:10:33
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/782180445454633/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:10:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/781977348808276/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 加載： 15 次
# 加載： 16 次
# 加載： 17 次
# 加載： 18 次
# 加載： 19 次
# 加載： 20 次
# 加載： 21 次
# 加載： 22 次
# 加載： 23 次
# 加載： 24 次
# 加載： 25 次
# 加載： 26 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# Click See More ： 3 times.
# 完成!
# 完成時間: 2019-11-03 19:11:17
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/781463545526323/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:11:28
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/777969375875740/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:11:44
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/773384703000874/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:11:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/773353416337336/
# 展開夠多留言： 0 次
# 展開夠多留言： 1 次
# 展開夠多留言： 2 次
# 展開夠多留言： 3 次
# 展開夠多留言： 4 次
# 展開夠多留言： 5 次
# 展開夠多留言： 6 次
# 展開夠多留言： 7 次
# 展開夠多留言： 8 次
# 展開夠多留言： 9 次
# 展開夠多留言： 10 次
# 展開夠多留言： 11 次
# 展開夠多留言： 12 次
# 展開夠多留言： 13 次
# 展開夠多留言： 14 次
# 展開夠多留言： 15 次
# 展開夠多留言： 16 次
# 展開夠多留言： 17 次
# 展開夠多留言： 18 次
# 展開夠多留言： 19 次
# 展開夠多留言： 20 次
# 展開夠多留言： 21 次
# 展開夠多留言： 22 次
# 展開夠多留言： 23 次
# 展開夠多留言： 24 次
# 展開夠多留言： 25 次
# 展開夠多留言： 26 次
# 展開夠多留言： 27 次
# 展開夠多留言： 28 次
# 展開夠多留言： 29 次
# 展開夠多留言： 30 次
# 展開夠多留言： 31 次
# 展開夠多留言： 32 次
# 展開夠多留言： 33 次
# 展開夠多留言： 34 次
# 展開夠多留言： 35 次
# 展開夠多留言： 36 次
# 展開夠多留言： 37 次
# 展開夠多留言： 38 次
# 展開夠多留言： 39 次
# 展開夠多留言： 40 次
# 展開夠多留言： 41 次
# 展開夠多留言： 42 次
# 展開夠多留言： 43 次
# 展開夠多留言： 44 次
# 展開夠多留言： 45 次
# 展開夠多留言： 46 次
# 展開夠多留言： 47 次
# 展開夠多留言： 48 次
# 展開夠多留言： 49 次
# 展開夠多留言： 50 次
# 展開夠多留言： 51 次
# 展開夠多留言： 52 次
# 展開夠多留言： 53 次
# 展開夠多留言： 54 次
# 展開夠多留言： 55 次
# 展開夠多留言： 56 次
# 展開夠多留言： 57 次
# 展開夠多留言： 58 次
# 展開夠多留言： 59 次
# 展開夠多留言： 60 次
# 展開夠多留言： 61 次
# 展開夠多留言： 62 次
# 展開夠多留言： 63 次
# 展開夠多留言： 64 次
# 展開夠多留言： 65 次
# 展開夠多留言： 66 次
# 展開夠多留言： 67 次
# 展開夠多留言： 68 次
# 展開夠多留言： 69 次
# 展開夠多留言： 70 次
# 展開夠多留言： 71 次
# 展開夠多留言： 72 次
# 展開夠多留言： 73 次
# 展開夠多留言： 74 次
# 展開夠多留言： 75 次
# 展開夠多留言： 76 次
# 展開夠多留言： 77 次
# 展開夠多留言： 78 次
# 展開夠多留言： 79 次
# 展開夠多留言： 80 次
# 展開夠多留言： 81 次
# 展開夠多留言： 82 次
# 展開夠多留言： 83 次
# 展開夠多留言： 84 次
# 展開夠多留言： 85 次
# 展開夠多留言： 86 次
# 展開夠多留言： 87 次
# 展開夠多留言： 88 次
# 展開夠多留言： 89 次
# 展開夠多留言： 90 次
# 展開夠多留言： 91 次
# 展開夠多留言： 92 次
# 展開夠多留言： 93 次
# 展開夠多留言： 94 次
# 展開夠多留言： 95 次
# 展開夠多留言： 96 次
# 展開夠多留言： 97 次
# 展開夠多留言： 98 次
# 展開夠多留言： 99 次
# 展開夠多留言： 100 次
# 展開夠多留言： 101 次
# 展開夠多留言： 102 次
# 展開夠多留言： 103 次
# 展開夠多留言： 104 次
# 展開夠多留言： 105 次
# 展開夠多留言： 106 次
# 展開夠多留言： 107 次
# 展開夠多留言： 108 次
# 展開夠多留言： 109 次
# 展開夠多留言： 110 次
# 展開夠多留言： 111 次
# 展開夠多留言： 112 次
# 展開夠多留言： 113 次
# 展開夠多留言： 114 次
# 展開夠多留言： 115 次
# 展開夠多留言： 116 次
# 展開夠多留言： 117 次
# 展開夠多留言： 118 次
# 展開夠多留言： 119 次
# 展開夠多留言： 120 次
# 展開夠多留言： 121 次
# 展開夠多留言： 122 次
# 展開夠多留言： 123 次
# 展開夠多留言： 124 次
# 展開夠多留言： 125 次
# 展開夠多留言： 126 次
# 展開夠多留言： 127 次
# 展開夠多留言： 128 次
# 展開夠多留言： 129 次
# 展開夠多留言： 130 次
# 展開夠多留言： 131 次
# 展開夠多留言： 132 次
# 展開夠多留言： 133 次
# 展開夠多留言： 134 次
# 展開夠多留言： 135 次
# 展開夠多留言： 136 次
# 展開夠多留言： 137 次
# 展開夠多留言： 138 次
# 展開夠多留言： 139 次
# 展開夠多留言： 140 次
# 展開夠多留言： 141 次
# 展開夠多留言： 142 次
# 展開夠多留言： 143 次
# 展開夠多留言： 144 次
# 展開夠多留言： 145 次
# 展開夠多留言： 146 次
# 展開夠多留言： 147 次
# 展開夠多留言： 148 次
# 展開夠多留言： 149 次
# 展開夠多留言： 150 次
# 展開夠多留言： 151 次
# 展開夠多留言： 152 次
# 展開夠多留言： 153 次
# 展開夠多留言： 154 次
# 展開夠多留言： 155 次
# 展開夠多留言： 156 次
# 展開夠多留言： 157 次
# 展開夠多留言： 158 次
# 展開夠多留言： 159 次
# 展開夠多留言： 160 次
# 展開夠多留言： 161 次
# 展開夠多留言： 162 次
# 展開夠多留言： 163 次
# 展開夠多留言： 164 次
# 展開夠多留言： 165 次
# 展開夠多留言： 166 次
# 展開夠多留言： 167 次
# 展開夠多留言： 168 次
# 展開夠多留言： 169 次
# 展開夠多留言： 170 次
# 展開夠多留言： 171 次
# 展開夠多留言： 172 次
# 展開夠多留言： 173 次
# 展開夠多留言： 174 次
# 展開夠多留言： 175 次
# 展開夠多留言： 176 次
# 展開夠多留言： 177 次
# 展開夠多留言： 178 次
# 展開夠多留言： 179 次
# 展開夠多留言： 180 次
# 展開夠多留言： 181 次
# 展開夠多留言： 182 次
# 展開夠多留言： 183 次
# 展開夠多留言： 184 次
# 展開夠多留言： 185 次
# 展開夠多留言： 186 次
# 展開夠多留言： 187 次
# 展開夠多留言： 188 次
# 展開夠多留言： 189 次
# 展開夠多留言： 190 次
# 展開夠多留言： 191 次
# 展開夠多留言： 192 次
# 展開夠多留言： 193 次
# 展開夠多留言： 194 次
# 展開夠多留言： 195 次
# 展開夠多留言： 196 次
# 展開夠多留言： 197 次
# 展開夠多留言： 198 次
# 展開夠多留言： 199 次
# 展開夠多留言： 200 次
# 展開夠多留言： 201 次
# 展開夠多留言： 202 次
# 展開夠多留言： 203 次
# 展開夠多留言： 204 次
# 展開夠多留言： 205 次
# 展開夠多留言： 206 次
# 展開夠多留言： 207 次
# 展開夠多留言： 208 次
# 展開夠多留言： 209 次
# 展開夠多留言： 210 次
# 展開夠多留言： 211 次
# 展開夠多留言： 212 次
# 展開夠多留言： 213 次
# 展開夠多留言： 214 次
# 展開夠多留言： 215 次
# 展開夠多留言： 216 次
# 展開夠多留言： 217 次
# 展開夠多留言： 218 次
# 展開夠多留言： 219 次
# 展開夠多留言： 220 次
# 展開夠多留言： 221 次
# 展開夠多留言： 222 次
# 展開夠多留言： 223 次
# 展開夠多留言： 224 次
# 展開夠多留言： 225 次
# 展開夠多留言： 226 次
# 展開夠多留言： 227 次
# 展開夠多留言： 228 次
# 展開夠多留言： 229 次
# 展開夠多留言： 230 次
# 展開夠多留言： 231 次
# 展開夠多留言： 232 次
# 展開夠多留言： 233 次
# 展開夠多留言： 234 次
# 展開夠多留言： 235 次
# 展開夠多留言： 236 次
# 展開夠多留言： 237 次
# 展開夠多留言： 238 次
# 展開夠多留言： 239 次
# 展開夠多留言： 240 次
# 展開夠多留言： 241 次
# 展開夠多留言： 242 次
# 展開夠多留言： 243 次
# 展開夠多留言： 244 次
# 展開夠多留言： 245 次
# 展開夠多留言： 246 次
# 展開夠多留言： 247 次
# 展開夠多留言： 248 次
# 展開夠多留言： 249 次
# 展開夠多留言： 250 次
# 展開夠多留言： 251 次
# 展開夠多留言： 252 次
# 展開夠多留言： 253 次
# 展開夠多留言： 254 次
# 展開夠多留言： 255 次
# 展開夠多留言： 256 次
# 展開夠多留言： 257 次
# 展開夠多留言： 258 次
# 展開夠多留言： 259 次
# 展開夠多留言： 260 次
# 展開夠多留言： 261 次
# 展開夠多留言： 262 次
# 展開夠多留言： 263 次
# 展開夠多留言： 264 次
# 展開夠多留言： 265 次
# 展開夠多留言： 266 次
# 展開夠多留言： 267 次
# 展開夠多留言： 268 次
# 展開夠多留言： 269 次
# 展開夠多留言： 270 次
# 展開夠多留言： 271 次
# 展開夠多留言： 272 次
# 展開夠多留言： 273 次
# 展開夠多留言： 274 次
# 展開夠多留言： 275 次
# 展開夠多留言： 276 次
# 展開夠多留言： 277 次
# 展開夠多留言： 278 次
# 展開夠多留言： 279 次
# 展開夠多留言： 280 次
# 展開夠多留言： 281 次
# 展開夠多留言： 282 次
# 展開夠多留言： 283 次
# 展開夠多留言： 284 次
# 展開夠多留言： 285 次
# 展開夠多留言： 286 次
# 展開夠多留言： 287 次
# 展開夠多留言： 288 次
# 展開夠多留言： 289 次
# 展開夠多留言： 290 次
# 展開夠多留言： 291 次
# 展開夠多留言： 292 次
# 展開夠多留言： 293 次
# 展開夠多留言： 294 次
# 展開夠多留言： 295 次
# 展開夠多留言： 296 次
# 展開夠多留言： 297 次
# 展開夠多留言： 298 次
# 展開夠多留言： 299 次
# 展開夠多留言： 300 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:13:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/769169026755775
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:13:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/769167790089232
# 完成!
# 完成時間: 2019-11-03 19:13:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/769838766688801/
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:14:09
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/769447626727915
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:14:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/769166450089366
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:14:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/764867527185925
# 完成!
# 完成時間: 2019-11-03 19:14:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/762092797463398
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:15:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/761216674217677/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:15:19
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/758258051180206/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:15:36
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/757836464555698/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:15:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/755452601460751
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# Click See More ： 3 times.
# 完成!
# 完成時間: 2019-11-03 19:16:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/753413741664637/
# fuckyou
# 完成!
# 完成時間: 2019-11-03 19:16:18
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/751885641817447/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 加載： 15 次
# 加載： 16 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:16:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/751473098525368/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:16:56
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/745350612470950
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:17:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/748875275451817/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:17:21
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/748321265507218/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:17:33
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/747444965594848
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:17:48
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/746372809035397/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:18:01
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/745351599137518
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:18:11
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/740392369633441
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:18:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/741472699525408
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:18:38
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/740390452966966
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:18:52
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/738785643127447/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:19:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/738144926524852/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:19:18
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/728174057521939
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:19:30
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/733957210276957/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:19:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/731876787151666/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:19:51
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/728172077522137
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:20:01
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/730040877335257/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:20:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/729214454084566
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:20:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/721107744895237/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 完成!
# 完成時間: 2019-11-03 19:20:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/711988539140491
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:20:59
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/713401285665883/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# Click See More ： 3 times.
# 完成!
# 完成時間: 2019-11-03 19:21:17
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/710160275989984
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:21:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/708032932869385/
# 完成!
# 完成時間: 2019-11-03 19:21:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/708026132870065/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:21:51
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/706797722992906/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:22:05
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/704671249872220/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:22:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/699552107050801/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:22:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/697459513926727/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:22:44
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/695321534140525/
# fuckyou
# 完成!
# 完成時間: 2019-11-03 19:22:54
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/693493400990005
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:23:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/692115627794449
# 完成!
# 完成時間: 2019-11-03 19:23:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/690889831250362/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:23:28
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/689793758026636/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:23:40
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/688955874777091/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:23:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/683256895346989
# 完成!
# 完成時間: 2019-11-03 19:24:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/682852242054121/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:24:14
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/674832866189392
# 展開夠多留言： 0 次
# 加載： 1 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:24:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/664374417235237
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:24:38
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/669299723409373
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:24:48
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/670775779928434/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:25:01
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/658559061150106
# 完成!
# 完成時間: 2019-11-03 19:25:09
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/658531941152818
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:25:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/656734324665913
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:25:32
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/653552484984097
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:25:45
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/653599294979416
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:25:53
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/652846148388064/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:26:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/649729265366419/
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:26:19
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/646969205642425
# 完成!
# 完成時間: 2019-11-03 19:26:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/642985379374141
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:26:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/636586286680717/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:26:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/635178003488212/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:27:11
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/634704430202236/
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:27:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/633588546980491/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:27:37
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/630100873995925/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:27:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/629840290688650
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:28:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/629475337391812/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:28:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/628792727460073
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:28:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/627108397628506
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:28:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/624812514524761/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:28:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/622059641466715
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:29:09
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/621931584812854/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 完成!
# 完成時間: 2019-11-03 19:29:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/620267444979268/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:29:41
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/619147348424611/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:29:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/618501755155837
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 完成!
# 完成時間: 2019-11-03 19:30:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/614996245506388
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:30:29
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/616413025364710
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:30:39
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/617053411967338
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# 加載： 15 次
# 加載： 16 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:31:03
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/615984212074258
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:31:13
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/611782689161077
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:31:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/612998029039543/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 完成!
# 完成時間: 2019-11-03 19:31:44
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/609814209357925/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:31:58
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/609021239437222
# 完成!
# 完成時間: 2019-11-03 19:32:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/606769066329106/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 加載： 13 次
# 加載： 14 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:32:29
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/603088116697201
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:32:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/599745503698129
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:32:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/600670803605599/
# fuckyou
# 完成!
# 完成時間: 2019-11-03 19:33:05
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/599742863698393
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:33:17
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/596293634043316
# 完成!
# 完成時間: 2019-11-03 19:33:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/596292864043393
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:33:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/594945987511414/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:33:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/594939264178753
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:34:10
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/594523470886999/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:34:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/593871144285565/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:34:40
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/592367751102571/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:34:52
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/592021287803884/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:35:05
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/588730614799618
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 完成!
# 完成時間: 2019-11-03 19:35:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/587836691555677/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:35:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/586102515062428
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:35:45
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/585781908427822
# 完成!
# 完成時間: 2019-11-03 19:35:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/585469095125770/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:36:09
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/584757265196953
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 完成!
# 完成時間: 2019-11-03 19:36:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/582423298763683
# 完成!
# 完成時間: 2019-11-03 19:36:36
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/577544729251540/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:36:48
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/569212436751436
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:37:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/569210160084997
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:38:13
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/568136840192329/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 加載： 8 次
# 加載： 9 次
# 加載： 10 次
# 加載： 11 次
# 加載： 12 次
# 完成!
# 完成時間: 2019-11-03 19:39:49
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/565798583759488
# 完成!
# 完成時間: 2019-11-03 19:39:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/567011866971493
# 完成!
# 完成時間: 2019-11-03 19:40:04
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/565281693811177/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:40:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/561002080905805
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:41:17
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/556166808055999
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:41:53
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/556349044704442/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:42:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/554133711592642
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:42:48
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/553677844971562
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:43:31
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/550543135285033/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:44:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/549889502017063/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:45:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/548278542178159/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:45:49
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/547141178958562
# 完成!
# 完成時間: 2019-11-03 19:45:56
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/544475839225096
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:46:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/541257486213598/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# 完成!
# 完成時間: 2019-11-03 19:46:25
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/539241586415188
# 完成!
# 完成時間: 2019-11-03 19:46:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/539124516426895/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:46:50
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/536995889973091/
# 加載： 1 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:47:01
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/535435273462486
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:47:12
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/533801913625822
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:47:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/531488183857195
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:47:40
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/530691673936846/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 完成!
# 完成時間: 2019-11-03 19:47:54
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/530430257296321
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:48:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/529694247369922/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:48:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/528103867528960
# 完成!
# 完成時間: 2019-11-03 19:48:30
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/527897457549601/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:48:43
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/527150557624291
# 完成!
# 完成時間: 2019-11-03 19:48:53
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/525866624419351/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:49:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/524905894515424/
# 完成!
# 完成時間: 2019-11-03 19:49:13
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.166324657040218/519119458427401/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# Click See More ： 1 times.
# 完成!
# 完成時間: 2019-11-03 19:49:30
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/518230135183000/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:49:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/517990888540258/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 完成!
# 完成時間: 2019-11-03 19:49:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/516329765373037
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:50:07
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/515825345423479
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# Click See More ： 1 times.
# Click See More ： 2 times.
# Click See More ： 3 times.
# 完成!
# 完成時間: 2019-11-03 19:50:24
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/515143775491636
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:50:36
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/512350939104253
# 完成!
# 完成時間: 2019-11-03 19:50:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/511972129142134/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:50:59
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/510497789289568/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 加載： 6 次
# 加載： 7 次
# 完成!
# 完成時間: 2019-11-03 19:51:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/510218595984154/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 加載： 4 次
# 加載： 5 次
# 完成!
# 完成時間: 2019-11-03 19:51:29
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/505494709789876
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:51:40
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/504830423189638
# 完成!
# 完成時間: 2019-11-03 19:51:48
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/504138363258844/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:51:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/502419590097388/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:52:08
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.128480554157962/501388713533809/
# 完成!
# 完成時間: 2019-11-03 19:52:16
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/501384100200937/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:52:27
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/501241206881893/
# 完成!
# 完成時間: 2019-11-03 19:52:38
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/500967710242576/
# 展開夠多留言： 0 次
# 加載： 1 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:52:46
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/498906967115317/
# 展開夠多留言： 0 次
# 加載： 1 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:52:54
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/497248700614477
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:53:06
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/495508277455186/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:53:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/494409880898359/
# 展開夠多留言： 0 次
# 加載： 1 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:53:23
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/491584224514258
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:53:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/490806637925350
# 完成!
# 完成時間: 2019-11-03 19:53:43
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/490392287966785
# 完成!
# 完成時間: 2019-11-03 19:53:51
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/490166927989321/
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:54:02
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/489654028040611
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:54:14
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/488275044845176/
# 展開夠多留言： 0 次
# 完成!
# 完成時間: 2019-11-03 19:54:25
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/487675058238508/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:54:34
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/486963154976365
# 完成!
# 完成時間: 2019-11-03 19:54:42
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/486474158358598/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 加載： 3 次
# 完成!
# 完成時間: 2019-11-03 19:54:55
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/486115771727770/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:55:04
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/483956438610370
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:55:15
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/482928735379807
# 展開夠多留言： 0 次
# 加載： 1 次
# 完成!
# 完成時間: 2019-11-03 19:55:26
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/482037778802236/
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:55:35
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/481269912212356
# 完成!
# 完成時間: 2019-11-03 19:55:45
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/479574069048607
# 展開夠多留言： 0 次
# 加載： 1 次
# 加載： 2 次
# 完成!
# 完成時間: 2019-11-03 19:55:57
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/478444432494904
# 完成!
# 完成時間: 2019-11-03 19:56:05
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/photos/a.129779610694723/472797179726296/
# 展開夠多留言： 0 次
# 加載： 1 次
# 這篇留言過少所以不用展開喔傻屌A_A
# 完成時間: 2019-11-03 19:56:13
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/470886106584070
# 完成!
# 完成時間: 2019-11-03 19:56:22
#
# ------------------
# 正在抓: https://www.facebook.com/OldFoxCreditCardDiary/posts/470161976656483
# 加載： 1 次

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 合併 </font>

# %%
fkk = pd.merge(nPost,nComments, on='Link', how='outer', indicator='indicator_column',suffixes=['_文章','_留言'])
終於=fkk.loc[:, ['Content_文章','Time_文章', 'Comments','Content_留言','Link']]
終於
# Out:
#                                           Content_文章           Time_文章  \
# 0  美國運通新綠卡 - 全面分析 如果懶得點閱讀這篇，這裡直接重點整理一下: 1. 消費回饋變好...  2019-10-30 11:07
# 1  不算秘密的秘密 - 兩年內拿超過一張 Chase Ink Preferred 今天這篇來聊聊...  2019-10-21 06:00
#
#    Comments                                         Content_留言  \
# 0      20.0  沒有SSN，看到45K首刷先衝再說當初PRG也才50K而已😅,然後現在 Gold 也悄悄改成...
# 1      12.0  請問有推薦哪家信用可來付今年剛收到的地價稅嗎？可開新卡。謝謝,Angela Chu 可以讀看...
#
#                                                 Link
# 0  https://www.facebook.com/OldFoxCreditCardDiary...
# 1  https://www.facebook.com/OldFoxCreditCardDiary...

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 保存資料</font>

# %%
終於.to_excel('C:\\Users\\Big data\\Desktop\\class\\web_crawler\\FB\\FB粉專_老狐狸的信用卡日記.xls')

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 資源參考</font>

# %%
#合併
https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-7-pd-merge/
http://justimchung.blogspot.com/2018/06/pandas-dataframe.html
# Out:
#   File "<ipython-input-666-1eb1a4973449>", line 2
#     https://morvanzhou.github.io/tutorials/data-manipulation/np-pd/3-7-pd-merge/
#            ^
# SyntaxError: invalid syntax

# %%
留言的留言
# Out:
# <div class="_5pcr userContentWrapper" data-ft='{"tn":"-R"}' style=""><div class="_1dwg _1w_m _q7o"><div class="_4r_y"><div class="_1wbl"></div></div><div><span class="_47we _42b7"></span><div class="l_c3pyo2v0u i_c3pynyi2f clearfix"><div class="clearfix y_c3pyo2ta3"><a aria-hidden="true" class="_5pb8 o_c3pynyi2g _8o _8s lfloat _ohe" data-ft='{"tn":"\u003C"}' href="https://www.facebook.com/OldFoxCreditCardDiary/?ref=nf&amp;hc_ref=ARTbuAU7B-eVAVBYoeX2j9OZAcOGbCBpVNZc58F4gtJufhbMg7rby_i_PuvgiOZ9gTM&amp;__xts__%5B0%5D=68.ARBq2P75I9mveCVW29_t78yFVhnzOSIY1PzAXQTmZOwXa-6AKJ2-bNpZk1V7BfwQI970cia4DrqWaI43GNQ2JdWso3S0ZQR2XW3B4Pe1o-5OiW_wY2U5SBZ4g55IeT1sHApaXJmzPUCFM1EuaOOZrmtS2lDclCUp8xbDXhhBrAQzyNnAkOrUeCJw2_4Teq-l_ThShJBEmyo5QigEJe2nwFpQzqORGs2lLkJwj2TdD35nyd8cc4qXpIvpUNV2D-J04k1IvN9GD4ZUzsq10wJWwWKBWIWMfPE_WW3fExNNxaru9lViq11VqmOxvT_85VSxdox7TtvuQ4TYBtHl7cS-K0w&amp;__tn__=%3C-R" tabindex="-1" target=""><div class="_38vo"><!-- react-mount-point-unstable --><div><img alt="" aria-label="老狐狸的信用卡日記" class="_s0 _4ooo _5xib _5sq7 _44ma _rw img" role="img" src="https://scontent-hkg3-1.xx.fbcdn.net/v/t1.0-1/p50x50/11754234_129800797359271_4089333941381587716_n.jpg?_nc_cat=108&amp;_nc_oc=AQlG_NSOi2hMekJdGU4qLI1D2yi1ytUC7ZrfIJBpnO8Di03zUk0tBcyzLDTzAPk-cu0&amp;_nc_ht=scontent-hkg3-1.xx&amp;oh=9d287c9be715f0c6a9e10983c713ab11&amp;oe=5E5C07A1"/></div></div></a><div class="clearfix _42ef"><div class="rfloat _ohf"></div><div class="u_c3pyo2ta4"><div><div class="_6a _5u5j"><div class="_6a _6b" style="height:40px"></div><div class="_6a _5u5j _6b"><h5 class="_7tae _14f3 _14f5 _5pbw _5vra" data-ft='{"tn":"C"}' id="js_0"><span class="fwn fcg"><span class="fwb fcg" data-ft='{"tn":"k"}'><a href="https://www.facebook.com/OldFoxCreditCardDiary/?hc_ref=ARQDD-kWrKq9BdXngw6Mp-YQzzx_vfcxBoRrcRMCbYEBT-NsUahqXzK0if1aKCdMSBk&amp;fref=nf&amp;__xts__%5B0%5D=68.ARBq2P75I9mveCVW29_t78yFVhnzOSIY1PzAXQTmZOwXa-6AKJ2-bNpZk1V7BfwQI970cia4DrqWaI43GNQ2JdWso3S0ZQR2XW3B4Pe1o-5OiW_wY2U5SBZ4g55IeT1sHApaXJmzPUCFM1EuaOOZrmtS2lDclCUp8xbDXhhBrAQzyNnAkOrUeCJw2_4Teq-l_ThShJBEmyo5QigEJe2nwFpQzqORGs2lLkJwj2TdD35nyd8cc4qXpIvpUNV2D-J04k1IvN9GD4ZUzsq10wJWwWKBWIWMfPE_WW3fExNNxaru9lViq11VqmOxvT_85VSxdox7TtvuQ4TYBtHl7cS-K0w&amp;__tn__=kC-R">老狐狸的信用卡日記</a><a href="https://www.facebook.com/OldFoxCreditCardDiary/?hc_ref=ARQDD-kWrKq9BdXngw6Mp-YQzzx_vfcxBoRrcRMCbYEBT-NsUahqXzK0if1aKCdMSBk&amp;fref=nf&amp;__xts__%5B0%5D=68.ARBq2P75I9mveCVW29_t78yFVhnzOSIY1PzAXQTmZOwXa-6AKJ2-bNpZk1V7BfwQI970cia4DrqWaI43GNQ2JdWso3S0ZQR2XW3B4Pe1o-5OiW_wY2U5SBZ4g55IeT1sHApaXJmzPUCFM1EuaOOZrmtS2lDclCUp8xbDXhhBrAQzyNnAkOrUeCJw2_4Teq-l_ThShJBEmyo5QigEJe2nwFpQzqORGs2lLkJwj2TdD35nyd8cc4qXpIvpUNV2D-J04k1IvN9GD4ZUzsq10wJWwWKBWIWMfPE_WW3fExNNxaru9lViq11VqmOxvT_85VSxdox7TtvuQ4TYBtHl7cS-K0w&amp;__tn__=kC-R"></a></span></span></h5><div class="_5pcp _5lel _2jyu _232_" data-testid="story-subtitle" id="feed_subtitle_128440004162017;922358034770206;;9"><span class="z_c3pyo1brp"><span class="fsm fwn fcg"><a ajaxify="/OldFoxCreditCardDiary/photos/a.129779610694723/922350041437672/?type=3&amp;size=300%2C300&amp;fbid=922350041437672&amp;source=12&amp;player_origin=story_view&amp;__xts__%5B0%5D=68.ARBq2P75I9mveCVW29_t78yFVhnzOSIY1PzAXQTmZOwXa-6AKJ2-bNpZk1V7BfwQI970cia4DrqWaI43GNQ2JdWso3S0ZQR2XW3B4Pe1o-5OiW_wY2U5SBZ4g55IeT1sHApaXJmzPUCFM1EuaOOZrmtS2lDclCUp8xbDXhhBrAQzyNnAkOrUeCJw2_4Teq-l_ThShJBEmyo5QigEJe2nwFpQzqORGs2lLkJwj2TdD35nyd8cc4qXpIvpUNV2D-J04k1IvN9GD4ZUzsq10wJWwWKBWIWMfPE_WW3fExNNxaru9lViq11VqmOxvT_85VSxdox7TtvuQ4TYBtHl7cS-K0w&amp;__tn__=-R" class="_5pcq" href="/OldFoxCreditCardDiary/photos/a.129779610694723/922350041437672/?type=3&amp;__xts__%5B0%5D=68.ARBq2P75I9mveCVW29_t78yFVhnzOSIY1PzAXQTmZOwXa-6AKJ2-bNpZk1V7BfwQI970cia4DrqWaI43GNQ2JdWso3S0ZQR2XW3B4Pe1o-5OiW_wY2U5SBZ4g55IeT1sHApaXJmzPUCFM1EuaOOZrmtS2lDclCUp8xbDXhhBrAQzyNnAkOrUeCJw2_4Teq-l_ThShJBEmyo5QigEJe2nwFpQzqORGs2lLkJwj2TdD35nyd8cc4qXpIvpUNV2D-J04k1IvN9GD4ZUzsq10wJWwWKBWIWMfPE_WW3fExNNxaru9lViq11VqmOxvT_85VSxdox7TtvuQ4TYBtHl7cS-K0w&amp;__tn__=-R" rel="theater" target=""><ab ...

# %% [markdown]
# # <font color=#8B4513 size=100 face="標楷體"> 保存資料</font>
